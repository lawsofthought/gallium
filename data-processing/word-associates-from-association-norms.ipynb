# %% [markdown]
# # Predicted Word Associates of Texts, based on Word Association Norms
#
# $$
# \newcommand{\data}{\mathcal{D}}
# \newcommand{\Prob}[1]{\mathrm{P}( #1 )}
# \newcommand{\given}{\vert}
# $$
#
# Here, we will calculate the predicted word associates of the texts that are used in the text memory experiment. These predictions can be used to test a word association account of text memory.
#
# Word association norms can, at least in most cases, be defined by a matrix $A$, such that
# $$
# A_{ij} \triangleq \text{frequency that word $w_i$ is stated as associated with word $w_j$}.
# $$
#
# Therefore, the conditional (empirical) probability of word $w_i$ given $w_j$ is
# $$
# \mathrm{P}(w_i \vert w_j) = \frac{A_{ij}}{\sum_{i=1}^V A_{ij}},
# $$
# where $V$ is the total number of words in our vocabulary of response words.
#
# Given a text, $\textrm{text}_{t}$, defined as
# $
# \textrm{text}_{t} \triangleq w_{t 1}, w_{t 2} \ldots w_{t n_{t}},
# $
# the predicted probability that word $w_k$ is associated with $\textrm{text}_{t}$ is
# $$
# \mathrm{P}(w_k \vert \textrm{text}_{t}) = \frac{1}{n_{t}} \sum_{i = 1}^{n_t} \mathrm{P}(w_k \vert w_{t i}).
# $$

# %% [markdown]
# ## Preface
#
# This notebook requires existing datasets, and will write a new dataset, see below. It will execute all cells completely in about 10-20 seconds.

# %% [markdown]
# ## Set up
#
# In the following steps, we basically set up the data that we need.

# %%
from __future__ import division

# Standard library imports
import os
from collections import defaultdict
import cPickle as pickle
import string

# Third party imports
import configobj
import numpy
import pandas
from numpy.random import randint, dirichlet, rand
from numpy import ones, zeros, unique, empty
from scipy.sparse import coo_matrix
from gustav.samplers import fortransamplers

# Local imports
from utils import utils, topicmodels

# %% [markdown]
# Create some helper classes and functions.

# %%
class MakeVocab(object):
    
    '''
    A class to make a vocabulary.
    '''
    
    @classmethod
    def new(cls, word_list):
        
        return cls(word_list)
    
    def __init__(self, word_list):
        
        self.word_list = word_list
        
        self.V = len(word_list)
    
        self.word2index = {w:i for i,w in enumerate(word_list)}
        self.index2word = {i:w for i,w in enumerate(word_list)}

        
def text_to_words(text, vocabulary):
    '''Extract words from a text'''
    return [word 
            for word in utils.tokenize(text) 
            if word in vocabulary.word2index]


class WordAssociations(object):
    
    '''
    An class to store the word association data in a dict of dict format, e.g
    
    associations['stimulus']['associate'] = count
    
    where `count` gives the number of times that `associate` was listed
    as an associate of `stimulus`.
    
    '''
    

    def __init__(self, word_associations_data):
        
        self.word_associations_data = word_associations_data
            
        self.build_associations()

    def build_associations(self):
        
        '''
        Return dictionary whose keys are the stimulus words, and
        whose values are the dictionaries whose keys are the associate
        words and whose values are the frequencies of their association 
        with the stimulus word.
        
        Thus,
        
        self.associations['foo']['bar'] 
        
        gives the number of times the word 'bar' was said to be 
        associated with the word 'foo'.

        Note: We will convert all stimulus words to lowercase. This 
        will in effect fold stimulus words that are upper or lower case 
        variants of one another. 
        
        This is not really an issue, however, because this  
        will only affect one word, Sunday/sunday, as can be verified below with
        self.check_stimulus_words_case()
        
        We will also fold all associate words to lower case. Thus, an 
        associate 'foo' is treated as identical to 'Foo'.
        
        '''
        
        self.associations = defaultdict(lambda : defaultdict(int))
        
        for row in self.word_associations_data:
            
            subject, stimulus, assoc1, assoc2, assoc3 = row.split(';')
            
            for associate in (assoc1, assoc2, assoc3):
                
                # We will make all stimulus words lowercase
                # Effectively folding stimulus words
                self.associations[stimulus.lower()][associate.lower()] += 1
                
                
    def check_stimulus_words_case(self):
        
        '''
        Return the list of stimulus words that are upper/lower case
        variants of one another. For example, if one stimulus word is
        'Foo' and the other is 'foo', this will be returned.

        '''
        
        stimuli = defaultdict(dict)
        
        for row in self.word_associations_data:
            
            _, stimulus, _, _, _ = row.split(';')
            
            stimuli[stimulus.lower()][stimulus] = None    
                
        
        return filter(lambda items: len(items[1]) > 1, stimuli.items())

# %% [markdown]
# Download and prepare all the data files etc needed for this analysis

# %%
cache_directory = '../cache'
cache_fullpath = lambda path: os.path.join(cache_directory, path)

filenames = {
    'experiment_cfg' : [('Brismo.cfg',
                         '909d9f8de483c4547f26fb4c34b91e12908ab5c144e065dc0fe6c1504b1f22c9')],
    'corpus' : [('bnc_78723408_250_500_49328.npz.bz2', 
                 'b9d828f7697871e01a263b8f3978911c70ff45cab9af4c86fbb43c3baef969d9')]
}

utils.verify_cache_files(filenames['experiment_cfg'] + filenames['corpus'],
                         cache=cache_directory,
                         verbose=False)

stimuli = configobj.ConfigObj(cache_fullpath('Brismo.cfg'))['text_memoranda']

corpus_data = utils.loadnpz('bnc_78723408_250_500_49328.npz.bz2', 
                            cache=cache_directory,
                            verbose=False)

bnc_vocabulary = MakeVocab.new(word_list=corpus_data['vocabulary'])

texts = {}
for key,value in stimuli.items():
    texts[key] = text_to_words(value['text'], vocabulary=bnc_vocabulary)

# %% [markdown]
# The following assumes that the file `associations_en_05_01_2015.csv.bz2`, whose sha256 checksum is `06a527e5c9647f37a4a2ee0744a309f57f259e203238b87e0f466b74f7a6e63e` is available in the `_cache` directory.
#
# This is a compressed csv file of word association norms collected at https://www.smallworldofwords.org/en and generously shared by Simon De Deyne (https://simondedeyne.me/).
#
# Unfortunately, I am not at liberty to share this data presently, and so please contact either Simon De Deyne or Gert Storms in order to obtain it.

# %%
assert os.path.exists(cache_fullpath('associations_en_05_01_2015.csv.bz2'))
assert utils.checksum(cache_fullpath('associations_en_05_01_2015.csv.bz2'))\
    == '06a527e5c9647f37a4a2ee0744a309f57f259e203238b87e0f466b74f7a6e63e'
    
word_associations_data = utils.loadcsv('associations_en_05_01_2015.csv.bz2', 
                                       cache=cache_directory)

# %% [markdown]
# ## Create association matrix $A$, etc
#
# We'll use all stimulus words but we'll restrict ourselves to associate words that are in the BNC corpus. Thus avoids dealing with the mass of highly infrequent responses. We will form the union of this set abd the set of recalled words that are in the BNC corpus. This will give us all the association norms data that we'll need for the recognition and recall analyses.

# %%
word_associations = WordAssociations(word_associations_data)

# Get the stimulus vocabulary 
stimulus_vocabulary = MakeVocab.new(
    sorted(
        set(
            word_associations.associations.keys()
        )
    )
)

# Get the association vocabulary
association_vocabulary = []
for stimulus_word in stimulus_vocabulary.word_list:
    association_vocabulary.extend(
        filter(lambda word: word in bnc_vocabulary.word2index, 
               word_associations.associations[stimulus_word])
    )

Df = {}
Df['recall'] = pandas.read_pickle(cache_fullpath('brisbane_06b643a_recall_results.pkl'))

recalled_words = sorted(
     set(
         filter(lambda word: word in bnc_vocabulary.word2index,
                map(string.lower, Df['recall']['word'].values)
               )
     )
)
  
association_vocabulary_word_list = sorted(set(association_vocabulary + recalled_words))

associate_vocabulary = MakeVocab.new(association_vocabulary_word_list)

# %% [markdown]
# Here, we'll make some functions that will help the creation of the $A$ matrix.

# %% [markdown]
# The following creates a sparse representation of the $A$ count matrix.

# %%
def get_association_matrix(word_associations, stimulus_vocabulary, associate_vocabulary):

    rows = []
    cols = []
    values = []
    for stimulus_word in word_associations.associations:
        for associate_word in word_associations.associations[stimulus_word]:

            try:

                j = stimulus_vocabulary.word2index[stimulus_word]
                k = associate_vocabulary.word2index[associate_word]

                value = word_associations.associations[stimulus_word][associate_word]

                rows.append(j)
                cols.append(k)
                values.append(value)

            except KeyError:

                pass

    # Make a sparse array, but return the dense array (note the .A at the end)
    return coo_matrix((values, (rows, cols)), 
                   shape=(stimulus_vocabulary.V, associate_vocabulary.V)).A

A = get_association_matrix(word_associations, stimulus_vocabulary, associate_vocabulary)

# %% [markdown]
# The following will create a probability vector of length equal to the number of word associates. The probability of associate $j$ is
# $$
# f_j  \propto \epsilon + \sum_{i=1}^V A_{ij},
# $$
# which is the sum of frequency of association of word $j$ over all stimulus words plus $\epsilon$. The value of $\epsilon$ will be set by default to be $1.0$, and is essentially a smoothing variable, particularly to avoid underflow problems that might arise when $\sum_{i=1}^V A_{ij} = 0$.

# %%
def get_unigram_probability(A, eps=1.0):
    _f = A.sum(0) + eps
    return (_f/_f.sum()).flatten()

f = get_unigram_probability(A)

# %% [markdown]
# Now, we will calculate
# $$
# \mathrm{P}(w_i \vert w_j) \propto
# \begin{cases}
# \frac{A_{ij}}{\sum_{i=1}^V A_{ij}},&\quad\text{if $A_{ij}>0$},\\
# f_i, &\quad\text{if $A_{ij}=0$},
# \end{cases}
# $$
#
# The effect of this is as follows: In situations where $A_{ji}$ is 0, we replace the predicted probability $\frac{A_{ij}}{\sum_{i=1}^V A_{ij}}$, which will necessarily be 0.0, by $\Prob{w_i}$. In other words, this gives a *back-off* model for the zero counts. The main purpose and benefit of this is to ensure that all observed zero count stimulus-associate word pairs are given a reasonable nonzero estimate. Also, as above, the values of zero would cause trouble in analyses where we need to calculate logarithms.

# %%
smoothed_association_matrix = numpy.zeros_like(A, dtype=float)
for j, Aj in enumerate(A):
    
    I = Aj == 0
    
    _p = Aj/Aj.sum()
    
    _p[I] = f[I]
    
    smoothed_association_matrix[j] = _p/_p.sum()

# %% [markdown]
# Some sanity checking. Sample some words, and make sure their predicted associates according to the model match the original data, except for the low probability predictions, which will have back off to the marginal probabilities in the smoothed model.

# %%
def check_some_words(K, N, seed):
    random = numpy.random.RandomState(seed)
    
    for k in random.permutation(smoothed_association_matrix.shape[0])[:K]:
        
        smoothed_associates = ','.join([associate_vocabulary.index2word[i] 
                                        for i in numpy.flipud(numpy.argsort(smoothed_association_matrix[k]))[:N]])
        
        original_associates = ','.join([associate_vocabulary.index2word[i] 
                                        for i in numpy.flipud(numpy.argsort(A[k]))[:N]])
    
    
        print(stimulus_vocabulary.index2word[k].capitalize())
        print('Smoothed: ' + smoothed_associates)
        print('-'*10)
        print('Original: ' + original_associates)
        print('='*100)

check_some_words(25, 100, 1001)
# Out:
# Hinge
# Smoothed: door,metal,swing,squeak,bend,close,bracket,unhinged,depend,joint,screw,creaky,creak,gate,unhinge,knob,rusty,cupboard,crux,squeaky,iron,pin,connection,brass,flap,oil,swinging,pivot,money,food,water,dangerous,lid,brain,wood,angle,balance,laptop,decision,dangle,sharp,rock,drawer,table,screws,elbow,rotate,frame,rust,peep,latch,flexible,machine,flex,book,sanity,choice,mechanics,change,nail,leverage,fold,brink,suspense,attachment,window,squeaking,bronze,jacket,failure,handle,lock,cabinet,join,hardware,screen,wait,bilge,key,holds,connected,dependent,stuck,bolt,dependency,car,music,green,love,red,sex,happy,white,dog,cold,school,time,bad,sad,fun
# ----------
# Original: door,metal,swing,squeak,close,bend,bracket,unhinged,depend,joint,screw,knob,gate,creaky,creak,rusty,unhinge,connection,swinging,brass,cupboard,squeaky,crux,pivot,oil,iron,flap,pin,suspense,dependent,laptop,dependency,sharp,key,lock,failure,stuck,connected,decision,peep,balance,rust,bilge,dangle,wait,brain,table,flex,book,flexible,screen,bronze,holds,drawer,leverage,window,join,cabinet,screws,brink,change,fold,sanity,wood,hardware,latch,squeaking,bolt,rotate,mechanics,attachment,nail,lid,elbow,frame,angle,machine,choice,dangerous,handle,rock,jacket,feminism,ferrets,ferocious,ferret,ferries,fiche,ferrous,ferrule,ferry,fibula,ferns,fermentation,fern,feminists,fen,fence,femur,femoral
# ====================================================================================================
# Facade
# Smoothed: fake,front,building,mask,false,house,wall,lie,pretend,surface,cover,architecture,window,decade,hiding,appearance,view,stone,ruse,play,brick,plaster,act,money,food,water,shift,houses,theater,war,disguise,showcase,deceive,color,grand,set,screen,veneer,angels,fruit,wrong,orange,copy,unreal,liar,stucco,white,changeling,embellishment,physiognomy,fence,decorator,acting,presence,fraudulent,decorative,grey,reason,covering,games,honest,tall,outer,style,dishonesty,role,exterior,circle,metamorphosis,glass,dissolve,display,decoration,ornate,outward,frontage,fade,tropical,superficial,pattern,walls,scenery,appearances,town,shadow,insincere,charade,facile,fronting,car,music,green,love,red,sex,happy,dog,cold,school,time
# ----------
# Original: fake,front,building,mask,false,house,wall,pretend,lie,cover,surface,architecture,window,play,stone,ruse,appearance,view,act,decade,hiding,plaster,brick,color,grey,pattern,veneer,dissolve,fraudulent,screen,insincere,deceive,copy,exterior,facile,town,shadow,fronting,glass,houses,charade,frontage,presence,walls,fade,orange,fruit,honest,covering,grand,liar,stucco,theater,showcase,ornate,role,shift,appearances,changeling,embellishment,white,unreal,decorator,decorative,decoration,outward,physiognomy,tall,tropical,scenery,superficial,metamorphosis,acting,dishonesty,wrong,disguise,style,games,outer,reason,angels,war,fence,display,set,circle,feminine,fennel,fermentation,fencing,ferment,fermented,fend,females,fences,feminists,fencer,fenced,fen,feral
# ====================================================================================================
# Stretch
# Smoothed: exercise,pull,yoga,yawn,muscle,elastic,muscles,cat,reach,flex,rubber,relax,tear,truth,flexible,gum,tight,fit,fat,legs,length,marks,dog,story,pants,arms,elongate,burn,painful,body,gooey,pain,fetch,wake,extend,food,water,jeans,denim,thin,bendy,bend,throw,awake,limousine,time,workout,loose,touch,run,reaching,cheese,strength,strengthen,stress,tone,cash,toffee,feel,loosen,arm,arduous,membrane,laze,tighten,rubbery,accommodate,sigh,ache,limber,limo,blanket,morning,tall,lift,expand,taffy,happily,horizontal,fabricate,fabric,money,blue,harried,dude,shirt,comfortable,rip,foreskin,bond,bones,sleep,frugal,widen,distort,limits,hands,excessive,field,gym
# ----------
# Original: exercise,pull,yoga,yawn,muscle,elastic,muscles,cat,reach,rubber,relax,flex,gum,truth,flexible,tear,fit,fetch,story,length,dog,wake,painful,tight,pants,marks,pain,body,extend,elongate,legs,arms,fat,gooey,burn,loose,strengthen,strength,vibration,flow,limousine,limo,touch,loosen,runner,limits,membrane,rip,vertical,workout,span,thin,joyfully,time,inning,stockings,cash,run,expand,comfortable,tall,sleep,piece,bendy,gym,bend,gymnastics,grab,arm,foreskin,injury,taffy,ache,leg,tighten,girl,feel,dude,stress,injured,mountain,accommodate,rubbery,blue,mind,awake,fade,reaching,lengthen,dough,relieved,money,hands,rope,gloves,ability,rack,frugal,field,spectroscopy
# ====================================================================================================
# Haystack
# Smoothed: needle,farm,barn,field,hay,horse,straw,yellow,farmer,cow,fire,grass,cows,corn,horses,bale,golden,summer,play,farming,fodder,allergy,farms,giant,sleep,dry,pin,country,childhood,sex,food,animals,painting,money,water,poetry,fork,cart,monument,difficult,round,prickly,shiny,pile,chicken,wheat,mow,yard,pitchfork,fast,jump,colloquialism,barrel,elk,sunshine,ranch,search,scarecrow,sun,tossing,feed,burn,countryside,stack,wire,harvest,sneeze,color,snake,cattle,scent,asleep,winter,messy,prairie,uncomfortable,metaphor,scratchy,bailing,donkey,tumble,desert,fun,sleeping,rick,chocolate,village,lovers,car,music,green,love,red,happy,white,dog,cold,school,time,bad
# ----------
# Original: needle,farm,barn,field,hay,horse,straw,yellow,farmer,cow,fire,grass,cows,corn,horses,bale,golden,food,allergy,sleep,fodder,painting,country,dry,giant,play,sex,summer,pin,childhood,farming,animals,farms,village,prairie,chicken,mow,sleeping,rick,cattle,stack,pitchfork,lovers,elk,difficult,asleep,barrel,yard,scent,scarecrow,metaphor,fast,donkey,uncomfortable,search,scratchy,color,desert,countryside,chocolate,burn,ranch,wire,sun,prickly,poetry,winter,jump,pile,sunshine,colloquialism,shiny,feed,wheat,fork,fun,tumble,cart,messy,bailing,round,monument,sneeze,snake,harvest,tossing,felled,feller,flab,fellow,fellows,fellowship,felon,felony,female,females,felling,fishermen,feminine,fellatio
# ====================================================================================================
# Discard
# Smoothed: trash,throw,toss,rubbish,waste,garbage,useless,leave,cards,card,lose,bin,unwanted,reject,poker,chuck,avoid,refuse,disregard,ignore,clothing,eliminate,erase,unused,pile,litter,recycle,unimportant,money,draw,cull,drop,uncaring,sadness,opportunities,bad,time,letter,abandon,descant,discourage,uninterested,worthless,destroy,discredit,obsolete,deselect,discus,throwaway,container,rummy,junk,retard,despair,careless,dispose,rid,upset,die,shuffle,abdicate,paper,dustbin,lost,basket,scrap,flick,hand,kill,disrespect,change,remove,landfill,disqualify,neglect,forgotten,food,water,car,music,green,love,red,sex,happy,white,dog,cold,school,sad,fun,house,black,hair,bird,pain,baby,hot,tree,death
# ----------
# Original: trash,throw,toss,rubbish,garbage,waste,useless,cards,leave,card,lose,unwanted,bin,refuse,avoid,poker,chuck,reject,pile,eliminate,ignore,unimportant,clothing,litter,recycle,erase,disregard,unused,dispose,bad,die,sadness,retard,shuffle,scrap,discourage,flick,lost,remove,worthless,abandon,opportunities,upset,descant,despair,forgotten,disrespect,discus,rummy,hand,kill,paper,cull,basket,uncaring,abdicate,uninterested,junk,container,discredit,letter,time,obsolete,drop,rid,landfill,careless,disqualify,throwaway,change,deselect,destroy,draw,neglect,dustbin,ferrous,ferries,ferrule,females,fertile,female,ferry,fern,ferrets,feminine,feminists,femur,fen,fence,fenced,fencer,fences,fencing,fend,fender,fennel,fens,feminist,ferment,fermentation
# ====================================================================================================
# Angel
# Smoothed: wings,heaven,halo,god,white,devil,demon,religion,guardian,wing,cherub,angle,fairy,pure,messenger,snow,food,holy,cake,fly,hell,sky,spirit,angelic,protection,saviour,harp,fantasy,girl,heavenly,protector,hair,money,water,saint,false,lord,sacrifice,symbol,love,child,ocean,host,mythical,tinsel,wave,sing,sings,fortune,cloud,soft,holiness,health,fallen,flight,christian,friends,shine,shining,church,motorcycle,light,seraphim,evil,unreal,powerful,fake,ethereal,bright,theism,sweet,sweetheart,girlfriend,gentle,benefactor,baby,paradise,feathers,bird,celestial,divine,baseball,celebrity,band,beauty,dove,heroes,spiritual,spirituality,peace,pear,death,actor,arch,avenging,beautiful,goodness,real,soul,boy
# ----------
# Original: wings,heaven,halo,god,white,devil,demon,religion,guardian,wing,cherub,angle,food,holy,hell,pure,fly,fairy,cake,sky,messenger,snow,spirit,protection,protector,harp,hair,fantasy,angelic,saviour,girl,heavenly,host,flight,ethereal,paradise,celestial,saint,unreal,pin,dust,avenging,baseball,celebrity,tinsel,motorcycle,baby,sacrifice,health,real,shine,girlfriend,pear,soft,death,peace,boy,arch,wave,bird,false,sings,sing,lord,holiness,powerful,benefactor,feathers,dove,spirituality,spiritual,theism,child,stupidity,fortune,fallen,heroes,beautiful,divine,actor,shining,beauty,light,ocean,church,soul,godsend,christian,goodness,bright,friends,love,fake,mythical,evil,seraphim,star,sweet,fish,symbol
# ====================================================================================================
# Rummy
# Smoothed: cards,gin,game,drunk,fun,rum,alcohol,alcoholic,tummy,card,gamble,drink,play,parents,party,friends,win,king,strange,money,matches,smell,runs,maths,snot,challenge,sailor,slur,dodgy,sailors,sinus,silly,children,pirate,cold,shoe,sheila,rummage,neighbors,mummy,grandma,gas,tiles,frustration,bitter,late,asshole,sweet,sweat,bottle,drunkard,happy,pals,stupid,noise,liquor,gross,butter,hobo,finish,casino,family,bar,eyes,yuck,yummy,yum,food,water,car,music,green,love,red,sex,white,dog,school,time,bad,sad,house,black,hair,bird,paper,pain,baby,hot,tree,death,fire,book,light,child,computer,animal,fish,people,woman
# ----------
# Original: cards,gin,game,drunk,rum,fun,alcohol,alcoholic,tummy,drink,gamble,card,king,friends,parents,party,strange,play,win,sweet,grandma,stupid,liquor,bar,family,sinus,bottle,slur,smell,snot,children,neighbors,sweat,gas,casino,runs,finish,tiles,mummy,noise,sailor,butter,eyes,cold,sheila,shoe,frustration,rummage,maths,drunkard,pirate,bitter,pals,matches,challenge,gross,dodgy,sailors,silly,yuck,yummy,late,yum,happy,hobo,asshole,fervently,fertiliser,ferries,ferrous,ferrule,ferry,fated,fester,fertile,fertilisation,fertilise,fervour,fertility,fateful,fatherless,fatherland,ferret,fatherhood,fervid,father,fates,fertilization,fertilize,fertilizer,fervent,ferrets,fauns,ferocious,fathomless,feminist,feminists,fathoms,femoral,femur
# ====================================================================================================
# Hurdle
# Smoothed: jump,obstacle,track,race,run,leap,difficulty,overcome,barrier,challenge,horse,curdle,throw,running,girdle,hindrance,stumble,struggle,cross,sports,gym,difficult,mountain,surmount,fail,heavy,sport,athletics,money,food,water,destroy,rugby,disadvantage,light,power,hop,load,football,flight,break,agility,dog,climb,roadblock,hardship,hard,swoop,road,turtle,plastic,connection,breaker,bound,hamstring,block,conquer,dome,marathon,horses,lift,skip,charge,field,competition,easy,topple,lard,obstruct,opportunity,barring,meters,obstruction,kilogram,split,sprinter,sprint,mind,falling,soft,sand,object,objective,step,rumble,movement,tough,athletic,bump,trip,height,bard,fall,achievement,steeplechase,weight,car,music,green,love
# ----------
# Original: jump,obstacle,track,race,run,leap,difficulty,overcome,barrier,challenge,throw,horse,curdle,stumble,difficult,running,sports,girdle,fail,sport,struggle,gym,surmount,mountain,athletics,hindrance,cross,heavy,rugby,sprint,turtle,dog,load,trip,sprinter,bard,falling,kilogram,lard,hamstring,competition,roadblock,road,split,barring,flight,bump,power,tough,sand,mind,block,plastic,achievement,movement,agility,charge,weight,football,athletic,objective,lift,step,skip,connection,object,break,horses,hop,light,conquer,topple,marathon,dome,hard,meters,hardship,opportunity,obstruct,fall,breaker,height,destroy,easy,swoop,soft,bound,steeplechase,disadvantage,climb,rumble,field,obstruction,femininity,feminine,feminism,ferocious,ferns,fern,feminist
# ====================================================================================================
# Tooth
# Smoothed: ache,dentist,fairy,decay,white,mouth,brush,enamel,bite,paste,cavity,nail,gums,eat,tongue,dental,pain,loose,molar,canine,teeth,chew,toothpaste,shiny,sore,grin,plaque,jaw,sweet,bone,incisor,gum,toothbrush,hard,pull,pick,floss,sharp,fang,money,food,water,hole,grooves,stain,grill,extract,claw,smile,booth,wisdom,eating,molars,cat,root,grinding,tiger,health,sabre,incisors,ouch,yellow,saber,front,red,truth,ridge,clean,braces,pearly,canines,false,cream,fight,caries,filling,toothy,lip,calcium,gear,soothe,car,music,green,love,sex,happy,dog,cold,school,time,bad,sad,fun,house,black,hair,bird,paper,baby
# ----------
# Original: ache,dentist,fairy,decay,white,mouth,brush,enamel,bite,paste,cavity,nail,gums,eat,molar,pain,tongue,loose,dental,chew,toothpaste,teeth,canine,incisor,pick,jaw,sweet,fang,grin,pull,plaque,sharp,shiny,gum,bone,toothbrush,floss,hard,sore,calcium,front,truth,incisors,tiger,extract,hole,false,toothy,claw,soothe,pearly,molars,root,braces,saber,grinding,sabre,ouch,grooves,smile,grill,canines,health,eating,stain,wisdom,cream,clean,lip,filling,booth,fight,cat,caries,gear,red,ridge,yellow,ferrule,femininity,feminism,fertile,ferrous,feminist,ferries,ferry,ferrets,fenced,ferret,fertilise,fences,fencing,fence,fend,fen,fender,femur,femoral,fennel,fens
# ====================================================================================================
# Nuke
# Smoothed: bomb,nuclear,microwave,war,destroy,explosion,weapon,atomic,death,missile,kill,boom,destruction,energy,explode,fire,duke,fear,atom,burn,puke,power,cola,blast,eradicate,money,water,disaster,irradiate,demolish,chemicals,tragedy,ballistic,warhead,threat,radiation,whale,terrorism,sixties,stop,hunt,hydrogen,idiots,cold,slaughter,bombs,cooking,blow,reheat,bush,reactor,radioactive,paganism,danger,dead,killing,thermonuclear,naked,food,missiles,attack,hell,nuke,fry,nucleus,niche,hit,explosive,vessels,negative,arms,murder,main,avengers,mushroom,trouble,mistletoe,car,music,green,love,red,sex,happy,white,dog,school,time,bad,sad,fun,house,black,hair,bird,paper,pain,baby,hot,tree
# ----------
# Original: bomb,microwave,nuclear,war,destroy,explosion,weapon,death,missile,atomic,kill,boom,explode,fire,duke,energy,destruction,atom,cola,puke,fear,power,eradicate,burn,blast,chemicals,terrorism,reactor,arms,hydrogen,hell,stop,idiots,cold,blow,slaughter,main,tragedy,mushroom,nucleus,niche,avengers,fry,whale,naked,killing,dead,bush,threat,danger,mistletoe,radiation,hit,food,murder,bombs,demolish,thermonuclear,disaster,irradiate,ballistic,paganism,warhead,vessels,hunt,reheat,sixties,radioactive,explosive,attack,trouble,cooking,nuke,negative,missiles,ferret,ferns,feminism,ferocious,ferrets,fermenting,fern,ferries,fend,fermented,fermentation,feminist,femoral,femur,fen,fence,fenced,fencer,fences,fencing,feminists,fender,fennel,fens,feral
# ====================================================================================================
# Lights
# Smoothed: bright,camera,dark,bulb,action,sun,lamps,electricity,city,yellow,night,northern,street,pretty,stars,brightness,car,stage,lamp,unknown,bulbs,fairy,switch,shine,day,illumination,candle,candles,illuminate,shiny,streetlights,headlights,white,globe,neon,money,food,water,traffic,glow,winter,bicycle,starry,star,photos,cozy,photons,headlamps,illuminations,illuminating,smile,illuminates,tea,migraine,disco,blackout,roof,twinkle,exciting,cigarettes,cheery,sunshine,flickers,clarity,fun,blinding,singer,color,pure,low,laboratory,laser,flood,crucial,fires,strong,tree,brilliant,crosswords,shining,necessity,fire,fixtures,read,stop,flame,rays,exercise,model,sounds,drama,carnival,ignite,beautiful,theater,relax,luminosity,footlights,nice,safe
# ----------
# Original: bright,camera,dark,bulb,lamps,action,sun,electricity,night,city,yellow,northern,stars,brightness,stage,car,pretty,street,shine,lamp,unknown,bulbs,fairy,switch,streetlights,illumination,shiny,illuminate,candle,headlights,day,neon,globe,candles,white,blackout,illuminating,bicycle,sea,illuminations,photons,photos,star,rays,divinity,cozy,footlights,sounds,blinding,exciting,glow,luminescence,roof,illuminates,ignite,drama,fire,flame,singer,sunshine,cigarettes,stop,necessity,read,fires,model,flickers,migraine,house,shining,orbs,beautiful,luminosity,crucial,starry,carnival,laboratory,smile,sparkle,nice,flood,tea,fun,tree,low,strong,brilliant,flash,traffic,exercise,winter,fixtures,clarity,laser,relax,theater,headlamps,ecological,twinkle,crosswords
# ====================================================================================================
# Clique
# Smoothed: girls,friends,exclusive,school,teenagers,gang,popular,circle,unfriendly,people,click,exclusion,crew,snobby,bitch,snob,popularity,set,nasty,club,closed,social,mouse,negative,snotty,posse,snap,crowd,money,select,frustrating,structure,kids,mothering,lamb,hostile,friendship,elite,politics,smart,snobbish,compete,parties,unwelcoming,peer,females,rap,insecure,blanket,gossip,discriminatory,air,retarded,friend,horrible,space,hurtful,woman,stick,fake,cadre,fence,women,bullying,clack,pressure,shun,catty,left,lonely,expensive,selective,bitchy,black,bully,science,coat,outsiders,isolate,girly,bad,groupie,subset,clock,effete,bond,conflict,ensemble,fans,object,team,bark,aloof,associates,white,buddies,tree,statue,teens,trends
# ----------
# Original: girls,friends,exclusive,school,teenagers,gang,circle,popular,unfriendly,click,people,crew,club,bitch,negative,posse,snobby,social,set,snotty,snap,mouse,popularity,closed,nasty,snob,crowd,exclusion,unwelcoming,fans,trends,politics,stick,hair,insecure,feet,ensemble,selective,discriminatory,air,lamb,coat,commies,expensive,inclusive,bullying,bully,mothering,girly,science,bad,select,left,comrade,structure,fake,team,retarded,rap,hostile,faction,knife,kids,peer,private,pressure,conflict,aloof,woman,women,blanket,frustrating,horrible,elite,cadre,black,clack,gossip,friend,catty,inbred,clap,friendship,choosy,teens,females,tree,bitchy,space,groupie,fence,isolate,effete,scum,hurtful,clock,subset,associates,smart,buddies
# ====================================================================================================
# Dust
# Smoothed: dirt,dirty,clean,sneeze,wind,bunny,desert,ashes,sand,particles,bunnies,skin,mop,mite,sweep,cough,chore,cleaning,dry,bowl,grey,air,grime,powder,rag,mites,particle,speck,mess,unused,allergy,feather,allergies,couch,star,soot,vacuum,storm,fairy,grit,pledge,floor,sun,tiny,buster,money,food,water,bite,house,red,irritating,corpse,replace,fireplace,spider,household,filthy,coughing,field,filth,mote,bag,settles,basement,murky,mud,guns,breathe,cloth,cloud,book,gross,musty,muck,throat,feathers,fluff,car,soil,motes,boxes,residue,gold,table,pan,slovenly,broom,curtain,swirl,ash,heat,thirst,weird,blue,falling,blown,float,brown,frank
# ----------
# Original: dirt,dirty,clean,sneeze,bunny,wind,desert,ashes,sand,bunnies,skin,particles,chore,bowl,cough,sweep,cleaning,mite,mop,dry,grey,rag,powder,grime,particle,speck,mites,air,couch,storm,buster,feather,star,grit,floor,tiny,fairy,vacuum,unused,pledge,sun,soot,mess,allergy,allergies,field,duster,rain,household,mud,white,spider,slovenly,house,fireplace,irritating,motes,mote,cloth,table,curtain,musty,bag,residue,muck,basement,float,swirl,bite,pan,weird,pollen,death,thirst,blown,beige,gross,bin,space,murky,blue,boxes,filthy,filth,soil,fluff,feathers,falling,book,frank,guns,brown,settles,throat,replace,kitty,gold,teach,chalk,corpse
# ====================================================================================================
# Mousse
# Smoothed: chocolate,hair,dessert,foam,gel,cream,soft,mouse,fluffy,whipped,sweet,pudding,creamy,food,lemon,salmon,strawberry,moose,air,cake,eggs,desert,spoon,raspberry,froth,eat,style,money,water,gross,meringue,muse,hairspray,shampoo,tail,smooth,cheese,yogurt,custard,yum,appearance,dear,cold,shower,rich,white,chiffon,filling,cushions,curls,wild,pleasure,cloudy,airy,hole,product,eating,fat,savory,trust,delicious,tasty,brother,foamy,cow,liver,id,souffle,bubbles,wow,deer,fluff,sticky,caramel,legs,fish,lost,fix,beige,car,music,green,love,red,sex,happy,dog,school,time,bad,sad,fun,house,black,bird,paper,pain,baby,hot,tree
# ----------
# Original: chocolate,hair,dessert,foam,gel,cream,fluffy,soft,mouse,creamy,lemon,pudding,sweet,whipped,food,salmon,moose,strawberry,air,cake,spoon,eggs,desert,eat,style,froth,raspberry,chiffon,curls,liver,savory,tail,sticky,fish,cow,custard,hole,delicious,shower,cushions,lost,fat,dear,legs,tasty,souffle,muse,deer,cold,foamy,filling,wow,rich,product,airy,fluff,appearance,brother,gross,beige,shampoo,yogurt,hairspray,smooth,id,eating,bubbles,white,caramel,pleasure,trust,fix,cloudy,cheese,wild,yum,meringue,ferns,ferocious,favorite,fatherhood,fern,fatherland,fatherless,fermenting,father,ferries,ferret,ferrets,fermented,ferrous,ferrule,ferry,fertile,fertilisation,fertilise,fertiliser,fertility,fertilization,fertilize
# ====================================================================================================
# Sight
# Smoothed: vision,eyes,eye,glasses,view,sound,light,blind,spectacle,unseen,aim,line,hearing,color,mind,beauty,smell,retina,blindness,future,eyeglasses,landmark,vista,words,fore,love,scope,sight,blue,money,food,water,art,candy,beautiful,unknown,vitreous,archeological,landscape,orange,lines,oversight,image,distance,field,bright,dogs,doctor,brother,perspective,lens,standard,brain,plain,horizon,weapon,advance,appearance,knowing,visual,viewpoint,flash,sparse,telescope,target,taste,mountains,ghosts,hindsight,wisdom,sense,short,bird,senses,glass,binoculars,eyeballs,scene,thankful,gaze,green,ocular,bat,usual,flight,normal,research,sore,amazing,touch,evolution,true,car,music,red,sex,happy,white,dog,cold
# ----------
# Original: vision,eyes,eye,glasses,view,sound,light,spectacle,unseen,blind,hearing,aim,color,line,future,smell,mind,fore,love,scope,retina,sight,blue,vista,blindness,landmark,beauty,eyeglasses,words,beautiful,bird,telescope,plain,image,doctor,advance,ocular,touch,landscape,standard,ghosts,art,binoculars,flight,candy,sparse,lens,bright,knowing,taste,sore,field,horizon,weapon,target,archeological,distance,brain,orange,normal,wisdom,amazing,glass,lines,short,unknown,bat,appearance,oversight,viewpoint,mountains,evolution,eyeballs,usual,brother,thankful,scene,senses,visual,research,gaze,flash,hindsight,sense,dogs,true,perspective,green,vitreous,fathoms,fatiguing,fervid,ferrule,ferry,fertile,fertilisation,fertilise,fervently,fertiliser,fervent
# ====================================================================================================
# Whore
# Smoothed: prostitute,slut,woman,sex,dirty,bitch,hooker,pimp,girl,harlot,cheap,ugly,money,house,red,insult,female,brothel,lady,cunt,bad,filthy,women,makeup,slag,easy,pig,food,water,struggle,vampire,church,negative,naughty,river,tramp,demeaning,trapped,lace,trashy,swear,madam,raunchy,needy,impoverished,boobs,bag,beneath,gigolo,morality,bible,pose,cake,surf,reclamation,rake,city,selling,attractive,hussy,brick,porn,whoring,ankle,hoe,swears,night,strumpet,misogyny,meretricious,angry,skin,darkness,sellout,concubine,greedy,skirt,hot,vagina,rude,cold,promiscuous,scarlet,bubbles,sin,bimbo,loose,republicans,street,ocean,streets,mad,stinks,car,music,green,love,happy,white,dog
# ----------
# Original: prostitute,slut,sex,woman,dirty,hooker,bitch,pimp,girl,harlot,money,cheap,house,ugly,pig,bad,insult,slag,filthy,female,easy,cunt,brothel,lady,red,women,makeup,cold,bimbo,hoe,river,trashy,streets,madam,mad,reclamation,hot,swear,darkness,bag,swears,vampire,city,sellout,lace,stinks,rake,strumpet,surf,gigolo,brick,rude,night,concubine,loose,cake,beneath,sin,misogyny,tramp,trapped,attractive,promiscuous,selling,ocean,street,struggle,skin,republicans,negative,pose,bubbles,church,boobs,angry,scarlet,greedy,vagina,skirt,naughty,raunchy,ankle,bible,demeaning,hussy,impoverished,needy,porn,meretricious,morality,whoring,fender,fend,fennel,festivities,ferment,fens,feral,fences,fermentation
# ====================================================================================================
# Future
# Smoothed: past,tomorrow,hope,tense,ahead,time,unknown,life,uncertain,plan,space,forward,coming,dreams,travel,technology,bleak,anticipation,distant,car,prospect,days,advanced,proof,plans,career,spaceships,bright,prediction,death,unsure,history,goal,fate,outlook,shock,food,water,money,begin,desire,retire,fast,actor,possibilities,stock,infinity,spaceship,hopeful,empty,onward,rest,forecast,midnight,sunshine,visionary,net,exciting,astronauts,short,prosperity,future,buildings,prospects,futuristic,enjoy,forever,futurists,foresight,tribe,quantify,metal,rockets,dread,gloom,goals,science,upcoming,save,golden,anticipate,perfect,inventive,generation,unpredictable,period,change,rosy,innovation,distance,confidence,uncertainty,happening,fear,study,love,benefits,happiness,music,green
# ----------
# Original: past,tomorrow,hope,tense,ahead,time,unknown,life,uncertain,plan,coming,forward,dreams,space,travel,proof,bleak,shock,distant,plans,anticipation,unsure,history,advanced,technology,days,spaceships,bright,prediction,death,career,outlook,fate,goal,car,prospect,goals,inventive,benefits,golden,possibilities,forever,innovation,visionary,retire,fear,science,fast,anticipate,perfect,prosperity,tribe,futurists,future,sunshine,actor,astronauts,net,exciting,short,midnight,infinity,foresight,save,happening,futuristic,study,dread,upcoming,desire,buildings,begin,forecast,change,generation,quantify,enjoy,stock,period,empty,hopeful,gloom,uncertainty,unpredictable,love,prospects,spaceship,rosy,money,metal,rockets,onward,happiness,rest,distance,confidence,fellow,fellows,feverish,fellowship
# ====================================================================================================
# Discourage
# Smoothed: sad,stop,encourage,dissuade,fear,negative,unhappy,failure,bad,sadness,warn,deter,disappoint,depressed,deny,undermine,coward,prevent,support,dishearten,learning,courage,deflate,fail,disappointed,advice,avoid,frown,school,manipulate,depression,money,pessimist,dismay,goals,persuade,detract,surrender,perseverance,family,yell,shame,dislike,unnatural,cry,difficult,gloomy,gloom,timid,intention,discouraged,faith,reason,plan,boo,disarm,discomfort,abandon,shake,influence,angry,anger,negate,worry,negativity,inactive,succeed,suggest,scare,boys,embarrass,grey,emotion,blah,encouragement,muscle,mountain,ignore,drugs,doubt,despondent,academic,setback,downplay,upset,dread,dreams,halt,parenting,reality,violence,impediment,motivation,selfish,control,disapprove,weak,limit,block,life
# ----------
# Original: sad,stop,encourage,dissuade,fear,negative,unhappy,failure,warn,bad,sadness,disappoint,deter,manipulate,advice,dishearten,avoid,prevent,frown,school,coward,undermine,support,learning,deny,courage,depressed,deflate,disappointed,depression,fail,muscle,dismay,lose,surrender,violence,unnatural,reality,repeal,reason,advise,blah,downplay,suggest,emotion,yell,impediment,deceive,flee,frightened,dislike,timid,anger,faith,leave,halt,perseverance,ignore,losing,dread,depressing,shame,warning,plan,difficult,forbidden,worry,convince,shake,mountain,discouraged,selfish,academic,behavior,dreams,family,boys,succeed,motivation,inactive,block,defeat,children,encouragement,doubt,influence,discomfort,parenting,disarm,detract,dampen,goals,despondent,pride,redirect,frustrate,setback,boo,scare,bar
# ====================================================================================================
# Socialize
# Smoothed: friends,party,talk,people,fun,drink,network,friendly,chat,interact,drinks,talking,mingle,social,gather,dinner,food,join,gathering,parties,company,communicate,meet,bar,extrovert,chatting,society,laugh,alcohol,learn,friend,discuss,night,conversation,networking,pub,converse,media,crowds,money,water,bonbons,children,marriage,comfort,hope,physics,murder,human,bars,train,booze,communism,sociable,wine,fellowship,meeting,medicine,nigger,busy,poo,warm,play,women,extroverted,awkward,exchange,community,mix,adjust,person,popular,assimilate,butterfly,skill,club,color,cocktails,crowd,flight,cry,girls,engage,study,loud,penguin,biology,lunch,culture,flirt,enjoyment,dance,floor,greeting,loneliness,experiment,enjoy,peers,girl,trivial
# ----------
# Original: friends,party,talk,people,fun,drink,mingle,social,talking,friendly,interact,network,gather,chat,drinks,meet,bar,company,communicate,dinner,food,gathering,join,parties,conversation,friend,society,pub,learn,discuss,alcohol,extrovert,chatting,networking,media,laugh,converse,crowds,night,bend,person,study,girls,speak,flight,floor,marriage,convivial,girl,wine,loud,cocktails,flirt,familiarity,bars,sociable,biology,family,experiment,physics,mix,popular,penguin,butterfly,color,women,extroverted,cry,busy,decision,peers,hope,skill,lunch,crowd,medicine,human,nigger,poo,adjust,meeting,culture,comfort,picnic,train,awkward,warm,play,clarify,fellowship,definition,murder,booze,loneliness,children,visit,laughing,enjoy,greeting,engage
# ====================================================================================================
# Razor
# Smoothed: sharp,blade,shave,cut,edge,beard,shaving,thin,hair,legs,straight,metal,silver,cutting,electric,suicide,whiskers,cuts,burn,slice,blood,skin,scooter,pain,shower,smooth,leg,wire,money,food,water,blaze,dad,speed,leaf,perfection,margin,phone,danger,bathroom,condom,nick,gouge,ground,thicket,deadly,accurate,morning,foam,cutthroat,gaze,steel,bumps,mind,wit,bleed,shaver,knife,hairy,raze,car,music,green,love,red,sex,happy,white,dog,cold,school,time,bad,sad,fun,house,black,bird,paper,baby,hot,tree,death,fire,book,light,child,computer,animal,fish,people,woman,war,hard,wood,church,cat,fruit,game,sweet
# ----------
# Original: sharp,blade,shave,cut,edge,beard,shaving,thin,hair,legs,silver,straight,cutting,suicide,electric,metal,shower,wire,smooth,leg,cuts,slice,pain,burn,whiskers,scooter,blood,skin,cutthroat,thicket,danger,nick,hairy,mind,foam,bumps,morning,bathroom,accurate,shaver,phone,leaf,margin,condom,gouge,wit,raze,ground,dad,knife,gaze,bleed,speed,deadly,perfection,steel,blaze,fermented,ferment,felony,fellow,fermentation,ferret,fellows,fermenting,fern,felon,ferns,feral,ferrets,fellowship,ferocious,fennel,fens,female,ferrous,fenced,fencer,fen,fences,fencing,fend,femur,femoral,feminists,feminist,feminism,femininity,feminine,females,fender,fence,ferries,fervour,ferrule,fiance,fetter,fetters,fetus,feud
# ====================================================================================================
# Color
# Smoothed: red,blue,green,hue,rainbow,crayon,black,orange,colour,yellow,shade,white,paint,purple,blind,bright,vibrant,light,spectrum,brown,crayons,tint,palette,life,wheel,art,race,sea,tone,pink,sky,money,water,nuance,possibility,scale,description,scheme,word,expression,color,saturation,lens,animal,halt,summer,depth,flowers,pretty,artist,bar,food,whiz,copy,balls,sound,beach,tinge,suffrage,rib,fashion,fast,writing,favourite,autumn,true,wheat,deaf,map,spelling,erase,tempt,primary,clothes,colourful,skin,leaf,draw,highlight,shirt,distinguishing,pictures,personality,magenta,hex,dye,male,statement,sighted,sheen,dumb,pigment,sight,hues,visions,vivid,happy,car,music,love
# ----------
# Original: red,blue,green,hue,rainbow,black,crayon,orange,yellow,shade,colour,paint,bright,purple,blind,white,spectrum,light,vibrant,tint,palette,crayons,brown,art,wheel,race,tone,pink,sky,sea,life,nuance,tinge,halt,suffrage,beach,colourful,description,sighted,sheen,dye,summer,color,visions,artist,favourite,hues,personality,dumb,pictures,magenta,tempt,rib,pretty,possibility,depth,expression,male,deaf,draw,flowers,distinguishing,copy,saturation,lens,hex,writing,wheat,happy,clothes,vivid,leaf,true,bar,erase,scale,pigment,skin,sight,scheme,map,balls,food,fast,primary,animal,fashion,statement,spelling,autumn,sound,whiz,shirt,highlight,word,feminist,fender,fellowship,fencing,fellows
# ====================================================================================================
# Roasted
# Smoothed: chicken,oven,potatoes,meat,cooked,peanuts,nuts,toasted,baked,hot,beef,food,vegetables,pig,turkey,fire,pork,almonds,duck,brown,peanut,cook,burnt,pepper,chestnuts,tasty,sun,golden,skin,delicious,comedy,dinner,potato,roast,spit,broiled,peppers,marshmallows,heat,coffee,burned,bake,money,water,jeered,fried,smoke,coasted,lamb,celebrity,salty,bread,ox,garlic,grilled,browned,fox,paprika,seeds,warm,goose,eat,honey,comedian,cashews,drunk,mockery,smoky,sunburned,satirized,pot,boss,distasteful,aubergine,rape,marshmallow,chestnut,succulent,posted,ash,humour,criticized,teased,celebrated,joke,cooking,sunburn,yummy,car,music,green,love,red,sex,happy,white,dog,cold,school,time
# ----------
# Original: chicken,oven,cooked,meat,potatoes,peanuts,nuts,toasted,hot,baked,beef,vegetables,food,pork,turkey,fire,pig,duck,brown,almonds,peanut,cook,tasty,chestnuts,pepper,burnt,sun,peppers,coffee,skin,bake,roast,burned,golden,potato,marshmallows,spit,delicious,broiled,heat,comedy,dinner,lamb,humour,warm,paprika,boss,cooking,celebrated,cashews,seeds,marshmallow,drunk,mockery,sunburn,celebrity,bread,joke,chestnut,browned,ash,jeered,grilled,succulent,satirized,fried,honey,pot,criticized,goose,comedian,posted,rape,teased,aubergine,ox,garlic,distasteful,sunburned,salty,coasted,fox,yummy,smoke,smoky,eat,fishmonger,fences,flagstone,flagship,feminists,femoral,femur,fen,fence,fenced,fencer,fencing,fern,flags
# ====================================================================================================
# Indoors
# Smoothed: outdoors,inside,house,warm,home,couch,computer,window,windows,patio,games,shelter,cat,safe,dry,rain,pool,television,carpet,quiet,chair,plants,sport,winter,reading,sleep,ceiling,interior,glass,fire,furniture,table,fun,protected,protection,boring,dust,walls,bed,comfort,money,water,narrow,yard,cuddling,car,play,pillow,rainy,warmth,dog,night,air,venue,schmaltz,naked,cats,floor,hallway,comfortable,dirty,plant,wood,food,books,fluorescent,activities,cozy,covered,closed,controlled,tennis,white,kitchen,laziness,cooking,badminton,relaxing,sewing,stay,cooped,libraries,isolation,arena,doorway,playground,cold,playing,golf,door,doors,stuffy,stuck,internal,sitting,cheese,track,weather,plumbing,dark
# ----------
# Original: outdoors,inside,house,warm,home,couch,computer,windows,window,patio,games,television,rain,shelter,safe,dry,carpet,cat,pool,winter,comfort,sport,walls,sleep,fire,interior,dust,quiet,boring,plants,table,glass,protected,reading,chair,protection,fun,ceiling,furniture,bed,isolation,hallway,apartment,venue,relaxing,stuck,clean,yard,plant,wood,fireplace,food,daughter,activities,cozy,narrow,pillow,sewing,badminton,stuffy,kitchen,weather,heat,track,sitting,warmth,fluorescent,cats,comfortable,internal,floor,cooped,arena,air,libraries,cuddling,rainy,golf,covered,naked,night,camping,cold,sports,dog,cooking,playing,stay,schmaltz,cheese,books,doors,dirty,white,doorway,playground,fit,play,plumbing,closed
# ====================================================================================================
# Industrialise
# Smoothed: factory,business,city,build,industry,develop,machines,pollution,machinery,mechanical,modernize,nation,machine,urban,manufacture,revolution,progress,factories,pollute,metal,change,country,modern,smoke,smog,automate,nations,china,corporate,wealth,economy,workers,manufacturing,opportunity,century,jobs,destroy,food,water,noise,stagnant,efficiency,compromise,expand,bobbins,labor,chimney,busy,nationalize,warehouse,mechanisation,copper,growth,workforce,grow,neighborhood,company,waste,pastry,grey,create,hire,enterprise,advances,railroad,rural,advance,world,potent,buildings,industrialize,western,finally,culture,money,clothes,dune,region,laws,noisy,improve,comprehend,economise,productive,economics,scale,energy,cities,industrial,cotton,development,ruin,steam,modernise,steel,spelling,systemic,global,rise,technology
# ----------
# Original: factory,business,industry,build,city,develop,machines,pollution,machinery,mechanical,factories,nation,progress,manufacture,revolution,urban,machine,pollute,modernize,automate,modern,smog,smoke,country,metal,change,nations,workers,china,opportunity,jobs,destroy,economy,corporate,century,manufacturing,wealth,waste,global,efficiency,comprehend,unsightly,chimney,industrialize,modernise,industrial,bobbins,cities,world,systemic,rise,sell,nationalize,compromise,improve,finally,technology,homeless,quality,organize,potent,products,productive,network,warehouse,copper,rural,culture,labor,region,stagnant,dune,grow,ruin,coda,growth,technical,commerce,commercial,commercialise,empathize,railroad,advance,western,advances,management,enterprise,globalisation,paltry,expand,noise,impersonal,mechanisation,clothes,harm,cotton,create,yuk,music,action
# ====================================================================================================
# Waffle
# Smoothed: syrup,iron,breakfast,pancake,food,cone,house,butter,talk,sweet,waver,potato,square,eat,dough,squares,strawberries,maker,chicken,pancakes,cream,yum,nonsense,undecided,griddle,blather,bullshit,plate,blueberry,grid,brown,batter,crisp,pecan,fries,bread,pattern,delicious,sandwich,money,water,politician,fold,yellow,waves,shop,rubbish,salesmen,fudge,donkey,box,ball,deviate,maple,converse,sin,fry,avoidance,fluffy,baked,flaky,expose,strudel,niche,chips,soda,dither,sweets,hatched,puff,boring,cooker,chocolate,flop,wrong,sugar,bat,sex,disingenuous,teeter,hesitate,gabble,chatter,crossed,hedge,changeable,tasty,drone,tree,change,indecisive,fork,jam,uneven,meal,waffle,material,brunch,cube,toast
# ----------
# Original: syrup,iron,breakfast,pancake,food,cone,house,sweet,butter,talk,waver,potato,chicken,strawberries,maker,squares,dough,eat,square,pancakes,pattern,plate,grid,yum,fries,blueberry,crisp,nonsense,bread,sandwich,bullshit,undecided,cream,batter,delicious,blather,griddle,pecan,brown,material,deviate,wrong,gabble,chatter,cooker,cube,yellow,niche,flaky,rubbish,avoidance,toast,toaster,converse,boring,fork,chips,jam,fluffy,sin,weave,hatched,strudel,crossed,hesitate,sex,box,waffle,ball,salesmen,fold,uneven,soda,bat,meal,tree,change,sugar,tasty,blanket,brunch,hedge,drone,changeable,indecisive,teeter,waves,disingenuous,donkey,shop,maple,fudge,puff,baked,sweets,expose,fry,dither,chocolate,flop
# ====================================================================================================

# %% [markdown]
# ## Make predictions of associates for each text
#
# The following does the
# $$
# \mathrm{P}(w_k \vert \textrm{text}) = \frac{1}{n} \sum_{j = 1}^{n} \mathrm{P}(w_k \vert w_{j}).
# $$
# for each text.

# %%
predicted_associates = {}
for text_name in stimuli:
    
    w = numpy.zeros_like(smoothed_association_matrix[0])
    
    for word in texts[text_name]:

        try:
            j = stimulus_vocabulary.word2index[word]
            w += smoothed_association_matrix[j]
        except:
            pass
    
    predicted_associates[text_name] = w/w.sum()

# %% [markdown]
# Let's have a look at these predictions.

# %%
for text_name in stimuli:
    print(stimuli[text_name]['text'])
    print('-'*26)
    print(','.join([associate_vocabulary.index2word[i] 
                    for i in numpy.flipud(numpy.argsort(predicted_associates[text_name]))[:100]]))
    print('='*50)
# Out:
# ‘I don't know what I did without it’ is the sentiment. There is a difference
# between fully automatic washing machines — which change the nature of the task
# altogether — and ‘twin tub’ machines where the hot wet washing has to be
# lifted manually into a separate drying compartment. The women who had this type
# of machine complained about the considerable amount of work still required of
# the housewife, and the mess on the kitchen floor to be cleared up afterwards. In
# a similar way the launderette does not remove the physical drudgery of washing.
# The housewife has to get the washing there in the first place, she has to unload
# it, sort it, sit and watch it wash and dry (or dash out to shop in the interim)
# and then pack it all up again. This, when there is a baby in the pram and a two-
# or three-year-old to attend to, is no mean feat.
# --------------------------
# clothes,water,clean,machine,car,money,laundry,dishes,baby,soap,food,bath,job,cold,time,alike,chair,mother,woman,cleaning,run,dog,store,wet,type,green,computer,sex,dirty,hair,home,box,buy,dry,girl,carriage,wood,hands,school,love,hot,red,change,children,divide,fast,cook,line,truck,warm,rain,child,house,music,identical,arid,quantity,cooking,suitcase,brother,tree,stand,white,trees,drying,clock,desert,wait,sister,mandatory,body,chore,move,listen,train,people,paper,pain,keyboard,happy,delete,observe,infant,coins,divorce,fun,robot,empty,girls,alter,bubbles,sexy,hard,sink,dirt,metal,board,study,church,travel
# ==================================================
# Don Juan today has lost whatever sympathetic press the years of male domination
# gave him. Feminism and a greater acknowledged (though not necessarily practised)
# awareness of the equality and independence of sexual rights have becalmed the
# Don as a fool of time. Psychology has dissected him to death. AIDS has ousted
# him out of history. But there is little point, for instance, in turning on an
# artistic, enlightened medieval king because he also enjoyed slaughtering
# hundreds of deer in a day's hunt and daubing the fresh blood on his own face and
# those of his friends. Examples can be multiplied. To yank someone entirely out
# of their time and smack them around for not being of our time is perhaps a
# salutary but only a limited exercise. Yet the times have indeed changed: and
# Burton's early sexual insatiability, his later infidelities, his many women and
# his concurrent devotion to monogamy all need some explaining.
# --------------------------
# clock,love,time,female,sex,red,freedom,night,queen,food,newspaper,women,disease,hit,day,money,power,life,found,watch,light,water,mind,past,fun,nice,world,creative,hour,sad,animal,black,woman,hot,penis,human,music,rights,sun,car,paper,happy,clean,dog,castle,brain,idiot,knight,war,stupid,strong,boy,space,slap,moment,people,school,girls,green,fruit,girl,knowledge,book,study,pain,math,iron,flies,forest,family,caring,deer,fast,god,gender,science,child,equality,paint,bad,knights,white,cold,game,hard,religion,company,kill,prince,flag,gun,sick,fish,dark,history,story,jester,sweat,free,hair
# ==================================================
# When John Major talks of a ‘nation being at ease with itself’, which
# particular nation is he speaking about? Is he addressing his comments to all
# those who have become marginalised and dispossessed as a result of right-wing
# Conservative policies over the years? Or is he speaking about that nation of
# complacent and indifferent shopkeepers who long for nothing other than a return
# to the days of imperial hegemony? The shopkeeper as the centre around which the
# social world revolves is a commercial image hammered into English consciousness
# by Mrs Thatcher. Self reliance, individual enterprise, ‘what's in it for
# me’, as opposed to‘how can we help our neighbour’, was the message. This
# theology slipped over the iron hand of the capitalist market like a silk glove.
# England became one nation again, a land of hope and glory, Elgar, teacakes and
# cricket. This England is not one recognised by many of my friends.
# --------------------------
# country,money,talking,person,business,people,hand,religion,love,god,picture,earth,middle,flag,food,building,minor,weeks,water,wide,home,time,soft,happy,politics,war,republican,awake,car,words,smooth,army,united,music,mind,cold,globe,fun,game,green,text,months,letter,fingers,easy,metal,ball,government,party,talk,king,white,sea,unique,bat,red,family,voice,study,test,school,single,clothes,insect,pride,peace,opposite,royal,company,power,mouth,sun,listening,language,answer,pain,sell,awareness,photo,outcome,store,boring,finger,worm,loud,uncaring,apathetic,church,world,land,warm,hot,sex,life,city,strong,light,week,foot,bad
# ==================================================
# The form of animal husbandry adopted depends on the type of facilities available
# and the nature of the experiments. If an experiment produces animals that are to
# be kept for a long period, or that are to form the basis of a breeding colony,
# some form of barrier system is essential. If no precautions are taken to prevent
# infections it is inevitable that the health of the animals will deteriorate with
# a resulting decrease in breeding performance or death. A minimal barrier system
# requires people entering the animal area to remove their laboratory coats worn
# in other areas, and to put on protective  clothing. It is essential that they
# wash their hands thoroughly before handling the animals and the wearing of
# surgical gloves and a change of footwear or overshoes should be considered. A
# more stringent barrier includes the requirement for staff to shower on entering
# the unit and a complete change of clothes.
# --------------------------
# dog,stop,wall,water,shape,science,clean,clothes,cat,money,shoes,paper,food,computer,time,reef,finish,fingers,life,hands,car,shirt,green,doctor,cold,love,music,finished,coins,warm,block,dogs,foundation,function,pants,alter,fence,wild,pets,white,test,feet,cats,school,people,zoo,black,blood,red,sex,happy,human,required,ants,lessen,bad,death,tree,dress,body,tired,horse,birds,study,sad,mold,mother,person,style,family,furry,basic,soap,hair,pain,fill,bird,trees,measure,plan,increase,house,play,shoe,mandatory,keyboard,jeans,rain,socks,mammals,fun,wet,hot,soft,job,hospital,obstacle,letter,unavoidable,math
# ==================================================
# I then took her forward slightly to the evening after the operation, a time when
# she was fully awake and over the more drastic effects of the anaesthetic. I
# asked her how she felt now. To my surprise Kirsty burst into tears. No, she told
# me, she was not in any great pain — simply the discomfort she would have
# expected to follow surgery. She was not aware of feeling particularly ill. It
# was just that she knew that there was something seriously wrong with her —
# something far more dramatic than a grumbling appendix or the normal after-
# effects of an operation. Oh, the doctors and nurses had assured her again and
# again that she was fine and would soon be fit and well again. And yet, as she
# kept repeating, she was convinced that there was something that no one was
# telling her.
# --------------------------
# sick,surgery,pain,doctor,hurt,story,sad,hospital,happy,party,bad,night,clock,morning,emotion,water,lead,alert,money,easy,healthy,book,explode,backward,confident,incorrect,sleep,game,time,awake,food,cry,birthday,play,love,day,uncomfortable,easily,red,average,crying,unexpected,surgeon,ouch,usual,dark,light,eyes,medical,cold,operation,touch,car,baby,thin,asleep,balloon,bubble,cut,sadness,blood,tired,conscious,heart,boring,bed,pop,white,green,music,error,fast,hair,ahead,line,procedure,bit,dog,school,death,body,theatre,fun,watch,speak,organ,leader,shock,sense,barely,talk,military,dusk,hot,knowing,abnormal,sex,calm,clothes,words
# ==================================================
# It was mentioned above that overflow records arise singly. In addition, an
# embedded overflow area will usually contain varying numbers of records from
# several tracks. This leads to overflow records usually being stored in unblocked
# format, even if the records in the prime data area are blocked. There is some
# advantage in treating the whole embedded overflow area as a single large blocked
# record, and manufacturers' software often does transfer the whole track into
# main storage when an addition is to be made; this allows for the addition
# itself, creation of link fields, changes of index, etc. However, handling the
# whole track as a single block would prevent rapid transfer of individual records
# from the embedded overflow area during direct access reference, which is the
# reason this method is often not adopted (but see the section on software
# packages, p. 264).
# --------------------------
# water,computer,subtraction,math,person,stop,money,book,fast,river,move,train,hardware,toilet,flood,music,chain,extra,run,unmarried,multiplication,green,street,information,time,god,follow,quick,paper,food,excess,field,spill,race,unique,logic,library,science,car,finger,house,box,married,pipe,space,path,love,straight,wood,change,road,division,word,program,running,cup,card,single,maths,school,woman,red,baby,excuse,dam,rib,door,animal,mathematics,line,life,mess,art,grass,sex,add,disc,computers,fire,player,list,record,file,sea,dog,connection,double,bad,happy,study,document,game,orange,join,exchange,white,madness,primary,corn,closet
# ==================================================
# Though innovation is a very positive term, it is important to remember that any
# particular innovation is only positive in retrospect, after it has worked. Before
# that, because change by definition is something no one has seen yet (despite
# models that may exist elsewhere), it has to be taken at least partially on
# faith. For example, why a continuing education program now? Why use funds to
# develop a new product when there are so many already on the market? Why take the
# risk of decentralizing the accounting office? In short, unless there is somebody
# behind the idea willing to take the risk of speaking up for it, the idea will
# evaporate and disappear. One reason there is so little change in most
# traditional bureaucratic organizations, I argue, is that they have conditioned
# out of people the willingness to stand up for a new idea. Instead, people learn
# to back off at the first sign that somebody might disapprove.
# --------------------------
# money,school,negative,water,creative,tall,happy,computer,word,smart,invention,live,fight,vanish,study,concept,danger,meaning,food,bright,game,plan,god,person,religion,coins,paper,alter,brain,grow,memory,talking,stop,forget,teach,bad,mind,time,dictionary,clothes,fun,words,inspiration,language,light,family,logic,life,music,knowledge,boring,love,friends,humans,red,teacher,green,change,car,create,sit,desk,crowd,disagree,science,technology,excuse,sell,church,book,math,store,recall,semester,optimistic,creation,steam,alive,hot,reward,thinking,belief,business,idea,people,bank,hope,learn,magic,debate,persons,wrong,gamble,job,space,sad,notion,progress,university,white
# ==================================================
# Some social scientists have conceptualised these workers in terms of a reserve
# army of labour. In this case, they would constitute a pool of labour which can
# be utilised in boom periods and disregarded in recessions. This view sees the
# experience of the Third world as being little different from that of the
# industrialised countries. The large numbers who are unable to find regular
# work are not seen as a phenomenon characteristic of underdevelopment, but part
# of the capitalist division of labour and, therefore, a similar feature to the
# industrialisation process of European countries, differing in terms of quantity
# rather than quality. For Marx, however, the function of the reserve army of
# labour was keeping wages low and, to this end, the absolute size of the reserve
# army need not be very great. The high numbers and continuing growth of this
# sector in Latin America would suggest that concepts of European analysis are not
# sufficient.
# --------------------------
# money,party,water,war,soldier,birth,navy,hard,amount,conditions,love,math,toil,green,save,time,normal,union,food,alike,school,military,quality,baby,nations,map,job,words,travel,army,life,globe,politics,earth,day,restaurant,table,hold,movie,book,pay,world,loud,event,people,study,pain,explosion,trait,car,salary,rules,science,death,music,red,quiet,bad,film,vodka,effort,blood,sad,fun,game,total,happy,blue,power,quantity,childbirth,guns,idea,bank,happening,special,measure,sex,section,complete,person,fight,swim,swimming,contract,tree,knowledge,gun,labor,medium,short,computer,boring,plenty,business,nature,paper,multiplication,private,office
# ==================================================
# In the case of time constant, a production worker tends to be focused on the
# production schedule for today or this week. An R&D worker is aware that what he
# does today will not affect company output in this order of time span. It may be
# months or years before his work today makes an impact: in the case of a project
# failure it may never do so. Words such as ‘hurriedly’ and ‘quickly’ are
# likely to be associated with different orders of time spans in the minds of the
# two people. Salesmen are probably in between these two. They have in some cases
# a weekly or monthly schedule of orders to win but the long-term relationship
# with their customer is also of great importance and the weight to be put on the
# two factors at any one time calls for the exercise of judgement.
# --------------------------
# clock,time,day,calendar,fast,money,love,school,watch,factory,bee,friends,hard,lose,daily,hour,period,job,month,effect,business,food,play,movie,input,water,game,sex,life,flies,employee,fat,change,heavy,car,run,bad,computer,awake,busy,bridge,family,monthly,court,space,person,hit,language,music,line,plan,influence,film,friend,fun,paper,sad,days,result,task,alert,service,red,judge,happy,store,green,loss,success,timetable,weekly,hours,product,book,gym,length,magazine,yearly,attention,mass,late,study,letters,theatre,significance,wait,crash,priority,pain,people,measure,labor,white,newspaper,boring,train,hurry,schedule,steady,construction
# ==================================================
# In the afternoon, we have a rehearsal, but without the guests. I just walk
# through the basic moves so the cameras can plot where everybody's going to be,
# and we try to work out how long people will take to walk down the stairs so we
# can play the right amount of music. If they can make it, we like the guests to
# arrive before the audience starts to go in, so they can walk through it, too.
# Those steps  down to the set can be daunting — I think it's everybody's
# nightmare, stepping out and falling flat on your face. Dusty Springfield was
# wearing new shoes, with very high heels, and was terrified that she'd slip, so
# just before she was due to go on, one of the team was dispatched to look for
# some scissors to scratch the soles with. Oh, the glamour of it all.
# --------------------------
# run,money,scared,play,cut,fall,dog,paper,stairs,scary,exercise,talk,simple,itch,feet,story,practice,climb,dirty,fun,time,water,dream,music,theatre,hard,stroll,game,late,red,food,easy,tea,sharp,date,steps,crowd,dance,love,book,fear,sport,sleep,dress,amble,people,cat,hair,quantity,hike,walk,baby,sidewalk,ball,car,house,sports,player,table,movie,pain,plan,home,dark,games,morning,tennis,land,nap,garden,wood,theater,ice,person,friends,apartment,frightened,shoes,fast,slide,night,green,stage,hurt,tool,horror,child,total,move,task,socks,leave,school,difficult,sun,happy,song,sex,travel,tree
# ==================================================
# My understanding of the law is that an adult patient who is capable of doing so
# must give consent to any medical treatment if that treatment is to be lawful. At
# the time of the decision the patient needs a capacity commensurate with the
# gravity of that decision. If the patient lacks the requisite capacity, then the
# doctors must act in what they perceive to be his or her best interests, with
# information garnered from previous knowledge of the patient, discussion with
# family and friends, and taking into account any relevant directive previously
# made by the patient. What the legal force and effect of any such directive might
# be is uncertain; it is unclear whether health care staff are required to carry
# out the terms of the directive or whether those who act in good faith with the
# terms of the directive are immune from civil or criminal prosecution. There is,
# apparently, no case law on this point.
# --------------------------
# doctor,hospital,calm,play,love,sick,money,school,lawyer,police,legal,knowledge,earlier,law,medicine,prior,waiting,conditions,wait,past,time,power,food,words,water,child,bank,court,rule,talk,ability,rules,study,sex,people,god,war,nurse,choice,music,unsure,religion,clock,happy,agree,understand,smart,volume,agreement,bad,book,strong,illness,space,change,books,judge,car,size,fun,green,medical,red,affect,result,mind,hold,life,health,weight,care,mature,system,bed,action,crime,earth,contract,giving,heavy,baby,justice,disease,white,cancer,jail,nice,family,home,cold,data,mother,movie,tree,quiet,polite,dog,computer,field,belief
# ==================================================
# The bones are bound to each other by tough, flexible ligaments and are
# articulated at the joints by muscles. There are just over 600 voluntary muscles
# in the human body. For our purposes, it is only necessary to mention the larger,
# superficial muscle groups which affect the shape of the body and are responsible
# for the movement of the limbs. These are referred to as skeletal muscles, most
# of which are attached at both ends to bones. The muscles that give expression to
# the face are also referred to as skeletal muscles, and they link bone to skin. A
# whole complex system of muscles is brought into play for each movement of the
# body: bending an arm involves the shortening of the biceps, while the tricep
# muscles at the back of the arm must relax and lengthen in unison. Meanwhile,
# others immobilise joints not needed in the action, while others still adjust to
# stabilize the body's equilibrium.
# --------------------------
# strong,strength,skeleton,body,leg,arms,hard,person,bigger,exercise,gym,balance,change,hand,water,white,arm,dog,chain,skin,food,mind,movement,soul,anatomy,stretch,difficult,money,red,muscle,fun,human,move,dance,music,muscles,happy,car,square,soft,tone,free,fake,computer,run,workout,time,love,sleep,circle,tendons,bring,effect,bones,fit,sex,fat,tied,people,movie,legs,torso,emotion,game,corpus,beautiful,form,language,head,pain,woman,flesh,life,weak,green,hair,ache,death,calm,flex,power,motion,sad,weights,rest,broken,rope,limb,corpse,talk,shallow,skull,blood,beach,yoga,round,reaction,ball,smile,science
# ==================================================
# The extent to which subject coverage on the shelves can be achieved is a matter
# of library policy, funding, the amount of shelf space available, and the
# efficiency of interlending systems to which the authority has recourse. These
# influences are considered in more detail in Chapter 12. The case for immediate
# shelf representation in a public library is made at some length by Ranganathan,
# in his fourth library law —‘save the time of the reader’. ‘Mental hunger
# for books is not compelling in the case of most people. Mental thirst for
# information is not inexorable in the case of most people. Both of them are
# fleeting in their nature. They both die out, unless satisfied immediately on
# their taking shape. No time lag should come between demand and supply. The tempo
# for reading is often momentary. It should be harnessed at the very moment.’
# --------------------------
# book,books,time,money,food,water,knowledge,clock,fast,happy,music,crazy,quiet,brain,school,library,wood,life,slow,reading,police,drink,person,librarian,study,news,health,demand,green,read,death,width,mind,quick,rule,speed,government,space,words,paper,square,car,minute,storage,people,beat,sex,love,friends,wall,circle,rules,object,smart,watch,content,humans,insurance,lawyer,giving,red,crowd,tree,quantity,law,fun,power,data,science,computer,family,pain,trees,measure,writing,world,form,jet,ruler,live,head,sad,height,provide,topic,size,house,bad,politics,quarter,store,round,boss,illness,dark,white,private,clean,mass,short
# ==================================================
# In Ordinary Justice the National Consumer Council were scathingly critical of
# such court proceedings which in practice, they said, became a rubber stamp. The
# documents the court sent out were difficult to understand and no guidance was
# given on completing it. The ‘defendant’ was not asked about his personal
# circumstances. The Civil Justice Review found that a third of banks and building
# societies, and a fifth of local authorities, did not enquire about the debtor's
# circumstances before the hearing. Three quarters of local authorities did not
# follow up the Department of Environment's advice and carry out checks to see if
# the tenant was receiving the right benefits. Sixty-seven per cent of creditors
# had no knowledge of the debtor's financial state at the time of the original
# transaction, and 77 per cent did not obtain any further information before or
# during the proceedings.
# --------------------------
# money,law,penny,judge,hard,store,lost,court,food,house,knowledge,green,dollar,comprehend,lead,music,water,private,power,paper,government,war,clock,tennis,office,school,bank,papers,book,perfect,study,lawyer,plain,river,giving,people,gift,close,letter,home,buy,red,normal,boring,business,city,rent,love,dog,country,unique,landlord,nearby,sound,fair,data,coin,car,learn,aid,ear,time,happy,bad,information,advice,smart,receive,space,tree,mail,words,legal,ball,apartment,baby,books,meeting,computer,easy,news,mine,sex,wisdom,condom,pride,word,polite,band,police,percent,lift,hold,buyer,friend,person,shop,white,woo,tote
# ==================================================
# The Dickens study tells us that not every dismissed employee eligible to claim
# unfair dismissal does so. Only about one in ten of those eligible to claim
# actually does so. Among those who apply there is a greater tendency to bring
# unfair dismissal proceedings where the employer is a small single establishment
# employer with below average unionization. Nearly half of all applications are
# against employers with fewer than 20 employees. The larger the employer, the
# less likely it is that there will be an unfair dismissal claim. There are a
# number of possible explanations for this pattern of application. Larger
# employers are likely to have internal appeals procedures and failure there,
# where union representation may have been provided, is the point at which the
# employee draws the line. Employees may feel a sense of powerlessness in taking
# on a large organization or it may be that advisers are more reluctant to take on
# large organizations.
# --------------------------
# job,boss,bigger,money,worker,touch,employee,unjust,life,carry,company,wrong,inside,food,form,school,straight,smell,mine,insurance,bad,marriage,huge,people,sad,business,water,habit,fair,hard,hesitant,love,learn,giving,size,fingers,time,gold,normal,common,middle,person,child,ownership,law,car,unmarried,music,feel,paper,emotion,fat,happy,green,justice,house,assert,red,book,office,stealing,stake,sex,salary,shy,game,computer,white,false,external,woman,loss,organs,black,manager,sense,books,cold,poor,math,married,staff,toes,unwilling,soft,success,fun,dog,twenty,test,college,boring,check,feeling,lie,study,milk,brought,lawyer,ticket
# ==================================================
# Our terms of reference suggested that we should consider drama in the context of
# the great dramatic works of literature. We believe that plays should be
# approached through the dramatic medium; children should often see or participate
# in the play being acted, and not just read the text. This approach will not only
# result in an appreciation of the literary merits, but also foster an
# understanding of stagecraft. There is still an important place within drama
# activity for the exploration and study of scripted plays, and we addressed this
# aspect in our statements of attainment and programmes of study. At primary
# level, the range of material for exploration needs to be more diverse: myth,
# legend, fairy stories, poems. At secondary level, such work can expand naturally
# into the exploration of dramatic texts. Children's own writing can also be
# explored — at both levels — through the medium of drama.
# --------------------------
# book,play,school,books,kids,story,theatre,fun,theater,words,middle,learn,queen,adventure,child,tale,paper,reading,money,library,love,hard,water,game,travel,stage,average,food,actor,movie,knowledge,read,size,flat,primary,drama,green,happy,class,legend,music,acting,girl,research,straight,conditions,grow,care,test,car,hero,map,join,psychic,home,science,world,fabric,tertiary,red,time,message,space,life,gratitude,meaning,write,study,discovery,tales,children,view,family,act,people,dog,ball,contract,parent,games,education,religion,word,sex,art,wings,baby,floor,pen,bad,color,myth,sad,magic,girls,sea,writing,white,nature,cloth
# ==================================================
# Activity 1 (15–20 mins): Identify a small group of clients, such as the first six
# people you saw in your last day's community care, the first six people attending
# your outpatients' clinic, or six individuals in a bay in your ward. For each
# client, list the nursing interventions either by yourself or someone else, such
# as ‘insulin injection’, ‘mouth care’, ‘socialisation’, ‘health
# promotion’, that each required in the fist hour of care, say between eight and
# nine, or nine and 10 in the morning. You should end up with at least six
# separate lists, some with perhaps only one item on it, others with several
# items, listed in the order that each client received, or was assisted with, that
# care. Are there any items common to several, or all, of the clients? Did they
# receive similar care at the same time or in the same order?
# --------------------------
# love,time,hospital,money,doctor,stuff,customer,water,clock,night,person,concern,alike,list,job,health,light,sun,people,food,hand,home,gift,day,minute,friends,punch,child,medicine,nurse,baby,teeth,nurture,family,shopping,needle,package,fun,service,business,bear,grocery,mother,humans,objects,patient,caring,watch,lips,exercise,careful,words,happy,crowd,car,medical,white,tend,ocean,children,play,red,object,paper,feel,school,groceries,mandatory,green,music,divide,lawyer,pain,raise,sex,fight,divorce,caution,cold,persons,loving,sick,glass,shot,sea,wealth,church,sunrise,boat,dog,care,human,women,tongue,store,beach,life,sad,bad,study
# ==================================================
# Once again that requirement to get on with people, clients, account executives
# and the creative teams is basic to your daily work. Just how does cooperation
# between a planner and the creative team work? After all, creative people are
# supposed to be sensitive and aware of the consumer and society and in real touch
# with change and mood. Let's take an example of the planner and creative team
# together. Trying to devise the strategy for a lager campaign, the planner found
# out through the research that the key benefit consumers looked for in lager was
# refreshment — incidentally something no other beer advertiser mentioned. The
# creative team took this new insight and used it as a spring-board to create a
# very successful campaign based on sprouting leaves and the headline: "Refreshes
# the parts other beers cannot reach" , thus demonstrating the imaginative leap
# creative people make from research findings to effect communication messages.
# --------------------------
# art,money,artistic,study,happy,sport,person,player,jump,newspaper,plan,lost,calendar,feel,sports,politics,lock,paper,music,news,people,friends,bank,simple,smart,war,green,food,water,diary,science,knowledge,writing,humans,mind,tree,game,book,love,sad,thinking,car,change,family,talk,frog,fall,crowd,paint,imagination,affect,door,football,spirit,painting,fun,time,day,true,school,easy,drink,soft,feeling,trees,persons,bad,world,red,stretch,skin,party,grab,awake,hand,result,dog,artist,wedding,life,job,woman,emotion,story,play,president,cold,political,human,sex,create,leader,business,clothes,population,light,house,win,idea,fake
# ==================================================
# While many of these may be social occasions, work groups especially in large
# companies may often stay on late to participate in quality control circles or
# zero defect clubs. There are up to four million quality control circle
# participants in Japanese industry and in large companies two in five workers are
# members. Quality consciousness is said to be very high among Japanese workers
# who endeavour to eliminate components that are rejected as substandard. Each
# smaller work group attempts to perform better than their rival groups in both
# quality control and in the number of suggestions they offer to improve
# productivity. Workplace harmony is enhanced by communal sports clubs, company
# vacation resorts, one-class cafeterias and the absence of status barriers within
# the plant. There is an hierarchical structure, but managerial authority is
# respected as a benign guardian of company interests. Corporate identification
# with workers knowing their place is in short "a managers Nirvana".
# --------------------------
# business,quantity,money,power,music,friends,building,green,control,school,peace,bad,office,knowledge,enemy,round,time,people,food,tall,job,angel,mind,water,life,heaven,dog,police,freak,corporation,car,holiday,act,dollars,home,factory,awake,card,tardy,parent,play,friend,love,football,person,fun,beach,pieces,join,boss,tree,computer,happy,remain,destroy,missing,party,broken,kill,dance,band,dead,square,team,remove,class,stop,billion,red,house,government,night,smart,worth,expensive,busy,learn,update,hard,sex,study,boring,assurance,gift,family,manage,company,flower,child,clothes,awareness,cold,death,guests,wrong,sun,white,stage,leave,remote
# ==================================================
# While it would be unlikely for a firm contractual commitment to be made which
# binds a record company to produce a promotional video, it is a matter of fact
# that a promotional video will be produced to support an artist's first single.
# With limited production costs, this video would fall into the £15,000 to
# £30,000 range, as opposed to the six-figure costs incurred by the established
# major artists. The cost of the promotional video for a developing artist would
# be recoupable against both audio and video income received by the record
# company. The income to pay these video costs is usually minimal with new
# artists, so these expenses are often set against future video exploitation. This
# is income which increases as the artist gains greater success and begins to
# release such items as compilation videos comprising selected promotional videos,
# or full length videos of live concert performances.
# --------------------------
# money,movie,tape,music,film,game,audio,salary,camera,business,player,painter,friends,paint,tax,visual,free,sound,television,food,watch,recorder,stuff,love,store,price,time,hard,minor,water,width,marriage,job,play,life,painting,autumn,company,pay,car,art,vegetables,past,corporation,fruit,cassette,creative,happy,record,army,space,home,green,picture,create,fun,people,red,friend,bad,house,law,factory,list,family,black,relationship,height,unmarried,solid,strong,sex,win,disc,white,school,computer,opposite,distance,write,ruler,person,poor,book,happiness,dog,die,child,science,cold,musician,guests,stove,paper,hurt,stage,tennis,woman,pain,color
# ==================================================
# Despite the challenges associated with building up large-scale production, the
# Japanese are forging ahead in display technology — and for very good reasons.
# Obviously the straightforward replacement of bulky cathode ray tubes with flat
# panel display leads to significant power and weight reductions as exemplified in
# the commercialisation of laptop computers. The most strategically important
# reason for investing in flat panel display technology, however, is that with
# continued miniaturisation of the integrated circuits the display itself will
# become the platform on which the system is built. This raises the prospect of
# fully integrated systems for which the sourcing of individual components such as
# drivers, memory chips and processors on the world market would no longer be an
# issue. Countries with such a display manufacturing capability would dominate the
# market and effectively eliminate competition based on older technology made up
# from discrete components.
# --------------------------
# computer,screen,monitor,window,wood,person,food,pieces,money,exhibit,science,heavy,light,future,board,fat,earth,factory,store,sun,shop,computers,people,water,electricity,art,gold,car,fish,forward,house,apartment,sell,wall,globe,game,stage,ability,quiet,win,magazine,music,logic,level,sex,easy,destroy,potato,map,control,love,unique,strong,kill,power,machine,glass,school,green,time,strength,travel,electronics,brain,train,substitute,paper,smooth,job,red,movie,ingredients,world,view,remove,race,war,honest,line,tire,single,excuse,bad,politics,fun,happy,secret,judge,picture,television,meaningful,nations,dog,play,white,space,direct,buy,industry,gun
# ==================================================
# Though less visible, it was export competition in goods and services which had a
# more fundamental effect on UK towns and cities. The internal economic geography
# of the UK has been reworked over a century by fundamental change in the nature
# and orientation of exports, which has reflected the success of individual
# industries and their factories. This demonstrates the principal changes so far this
# century in the composition of export goods. In 1900, the country was still
# largely dependent on exports of textiles, metals and coal, whereas by 1987
# nearly half the country's exports were accounted for by ‘machinery and
# transport equipment’ and chemicals. The impact of North Sea oil on the
# structure of the balance of payments may actually have reduced the absolute
# volume of manufacturing exports. This is because it raised the real sterling
# exchange rate, rendering ‘marginal’ manufacturing exports uncompetitive. We
# shall return to this issue at several points later in this volume.
# --------------------------
# money,music,building,time,import,hundred,silver,school,water,factory,car,loud,person,trade,black,child,sound,ocean,south,change,home,green,tools,ship,food,inside,cold,land,map,affect,nation,metal,invisible,win,world,true,direction,move,science,industry,light,trees,magazine,happy,book,noise,city,result,business,love,sexual,power,send,rural,fire,writing,history,speed,vodka,amount,sex,clothes,hit,red,paper,pole,country,game,tree,unique,single,space,life,essay,hair,war,dirty,train,blue,house,coins,white,bad,carry,weight,plant,cars,east,travel,job,horse,sight,independent,west,cricket,size,earth,machine,complete,fake
# ==================================================
# As far as the Royal Navy were concerned the nuisance of excessive leakage was
# largely put a stop to when Sir Robert Seppings (1764–1840) introduced diagonal
# iron bracing into wooden hulls about 1830. Seppings, who used to say ‘partial
# strength produces general weakness’, seems to have been one of the first Naval
# Architects to have a clear mental picture of the stress systems in a ship's
# hull. In the merchant service wooden hulls were to a considerable extent
# replaced by composite and iron and steel construction after the middle of the
# century. A number of wooden ships continued to be built without adequate shear
# bracing, however, and such ships got more leaky as they got older, until, in an
# age when most of the pumping was done by hand, it became uneconomic to run them
# any longer. Up till 1914 Norwegian shipowners were still making money by buying
# up British sailing ships and running them with windmill pumps.
# --------------------------
# boat,sea,ship,water,metal,boats,money,time,ocean,hard,blue,strong,fast,sail,worried,cash,power,tree,sails,red,table,navy,sign,food,line,child,hundred,frame,king,car,building,spoon,crazy,annoying,stiff,queen,halt,green,center,madam,wood,brain,military,photo,house,strength,pain,half,love,army,average,school,steel,shop,clothes,health,music,wind,build,furniture,orange,horse,sailing,hot,sailor,exercise,sufficient,iron,muscle,bad,painting,cold,chair,shoes,leg,war,sad,sex,mind,death,job,fat,fingers,fun,sends,life,family,knight,board,walk,white,store,seller,happy,church,finger,anxiety,dog,worker,paper
# ==================================================
# Clear out all your possessions and be ruthless. Now is the time to take rubbish
# to the dump, to give things away to charity shops and jumble sales. There is no
# point in taking all your useless rubbish with you. Also clear up the garden. You
# are not supposed to leave rubbish behind for the next occupants to cope with,
# although you can leave it bagged up outside the door for the dustmen to take
# later. If you are leaving the area do not forget to pick up any clothes that are
# at the cleaners, or shoes, clocks, or other items that are away being mended.
# You will also need to withdraw sufficient cash from the bank to pay for the
# removal. It is common practice to tip the people who have done the removal work
# so you may want to withdraw enough for this too.
# --------------------------
# money,trash,garbage,depart,exit,waste,giving,green,leave,choose,remember,sad,clock,remove,goodbye,water,food,perfect,flowers,retreat,stuff,feet,deal,junk,door,car,van,person,music,worthless,window,red,bin,love,nonsense,lose,hair,house,people,memory,sex,home,rubbish,flower,holiday,tree,vacation,time,truck,bad,plenty,socks,day,nose,pants,shirt,river,assumed,top,poor,handle,absence,train,happy,family,salary,list,check,job,manage,school,friends,stealing,bank,store,hard,shopping,white,pain,poop,smell,dirt,alleged,stupid,drugs,horse,select,left,close,knob,cold,stay,fruit,dog,dump,boring,watch,mind,war,fun
# ==================================================
# Individual goals may well be in conflict with organisational goals even where
# there is a strong commitment to one goal by the organisation. It is worth
# repeating that there may also be competing goals within the organisation itself.
# Thus, for example, the prison service may wish to pursue the twin goals of the
# punishment of offenders  and at the same time their rehabilitation. These two
# goals may prove to be incompatible and yet each will have its supporters. Within
# the National Health Service there may well be a commitment to provide the best
# possible medical care that the state of medical knowledge will allow and yet
# this may be tempered by the requirement to act within tight financial
# constraints. The two goals may be in conflict. Many organisations will face the
# problem of which goals to prioritise in the light of competing goals.
# --------------------------
# soccer,money,doctor,football,aims,war,love,marriage,fight,person,life,chase,achievement,aim,play,food,jail,hospital,achievements,achieve,success,plans,crime,objectives,school,car,company,clock,score,power,water,net,future,relationship,target,business,dark,dreams,aspirations,country,health,hopes,reach,time,military,hockey,support,nurse,bad,game,church,follow,job,ambition,pain,bright,white,dream,medicine,win,music,weak,unique,career,red,green,wealth,targets,happy,single,argument,brother,sister,book,happiness,pride,bulb,resolution,family,field,people,smart,cost,necessity,bank,sun,cold,anger,promise,sex,death,goal,house,station,dog,supply,care,study,run,child
# ==================================================
# On 25 July 1985 the dock company put in a planning application for the
# construction of a Roll on — Roll off (‘Ro-Ro’) terminal in the River
# Medway. Permission was refused, there was an appeal and an inquiry by an
# inspector whose recommendations the Secretary of State for the Environment
# accepted. The appeal was dismissed. The main consideration was undoubtedly the
# increase in heavy goods vehicles that would be generated by the new development
# and the consequent increase in noise levels, in particular night-time levels in
# Medway Road and Bridge Road. These environmental objections were considered to
# be serious enough to outweigh the economic benefits of allowing the proposal. It
# was this development and in particular the evidence given at the Ro-Ro inquiry
# which in due course prompted the council to bring the present proceedings. In
# March 1988 the council passed the necessary resolution and the writ was issued
# on 20 July 1988.
# --------------------------
# water,question,money,street,car,sex,rock,court,police,building,job,boat,carry,business,bread,loud,grow,green,cars,food,weight,decrease,proof,marriage,meeting,music,airport,city,school,train,detective,government,gadget,build,house,friends,highway,add,path,law,light,ball,assistant,paper,road,time,travel,wedding,computer,month,ring,cancer,growth,board,date,crime,nice,child,walk,tumble,white,ship,love,committee,trip,arrested,death,sound,form,wood,study,river,red,fat,stream,happy,people,baby,sea,office,bus,request,tree,army,worker,nature,judge,cold,housing,enlarge,bun,decision,plan,traffic,fun,dog,friend,woman,bad,desk
# ==================================================
# At the start of the exercise, the actual procedure was checked against a
# conceptual model that included the activities deemed necessary to achieve the
# agreed transformation. If the changes revealed by this comparison have not been
# made prior to the audit commencing, this could be the reason for the failure to
# meet the target levels of attainment. If, however, the procedure does comply
# with the procedure description derived earlier, then it will be necessary to
# subject each element or activity of the model to further scrutiny, for example
# by breaking them down to lower-order activities, or by auditing each element in
# the same manner as the parent procedure. This process is similar to work study
# exercises where measurable elements of a task are identified before the actual
# measurement takes place, and consideration is given to the resources required at
# each level, including the skills and experience of the operator.
# --------------------------
# real,operation,water,job,fire,chemistry,begin,true,process,science,money,time,alike,steps,school,doctor,method,food,goal,fun,greet,rules,medical,mother,car,child,task,surgery,learn,polite,study,knowledge,telephone,follow,hard,red,phone,logic,father,morning,bad,table,love,life,earth,test,success,past,ruler,people,hot,obey,finish,agree,computer,object,previous,weather,music,paper,skinny,words,green,aim,contrast,plan,truth,book,play,woman,game,list,excuse,fashion,sad,thin,books,win,happy,mandatory,instructions,succeed,topic,tall,house,run,nice,plane,cold,protocol,practice,store,metal,sex,wind,smooth,thinking,flat,oxygen,bird
# ==================================================
# The Knights of the Blazing Sun were created after the Battle of Magritta in 1457
# during the crusades which eventually freed the land of Estalia from the Arabian
# invaders. The battle was a great victory for the Knights of the Old World, made
# all the remarkable by a strange and prophetic occurrence. During fierce street
# fighting around the temple of Myrmidia, the warrior goddess of Estalia, a group
# of knights found themselves surrounded by the dreaded Black Guard led by Emir
# Wasr the Cruel. Just as the Arabians closed in a sudden earth tremor shook the
# temple, dislodging a huge bronze statue of the goddess which plummeted to the
# street below crushing the Emir and many of his troops. The event was to prove
# the turning point of the battle. Afterwards, the surviving knights established
# the Order of the Blazing Sun with Myrmidia as its patron and protector.
# --------------------------
# war,fight,road,god,white,lost,light,army,church,weird,earth,moon,car,worship,avenue,money,door,religion,water,strong,death,planet,win,gold,odd,green,time,dog,hot,soldier,ship,shut,dark,party,love,stone,food,bright,head,beauty,people,globe,metal,evil,sword,quick,protect,battle,night,happy,red,finally,leader,blue,round,soldiers,sex,warm,shine,synagogue,home,shield,sea,art,fire,music,house,angry,fast,unusual,bad,day,military,woman,blood,life,saint,beautiful,person,star,fighter,liberty,fun,medal,enormous,unexpected,yellow,field,follow,silver,ground,hair,mother,holy,cold,sad,lane,address,power,statue
# ==================================================
# The answer to the first, or ‘why’, question begins with a recognition that
# banks are private sector, profit-making organisations with obligations to
# shareholders to increase profits over time. Thus they will always be looking for
# ways of expanding their balance sheets provided this leads to extra profit. Look
# again at Table 3.3 which shows the aggregate balance sheet of a large number of
# banks. Notice that assets are composed of various forms of lending: to the
# personal sector, the commercial sector, the government or the Bank of England.
# The liabilities side is dominated by deposits. Notice also that we can express
# any class of asset as a proportion of total assets or liabilities and remember
# too that in section 1.1.5 we said that these ratios are arrived at as a matter
# of deliberate choice and are assumed to represent portfolio equilibrium.
# --------------------------
# money,bed,paper,private,river,balance,question,answer,school,sum,section,business,public,space,equal,secret,fast,food,house,memory,white,clock,water,size,forget,observe,beam,division,music,scale,piece,chair,property,region,art,wealth,recall,time,train,weight,car,complete,add,sign,politics,people,life,bank,mine,green,information,decision,portion,mark,red,cash,zone,finance,stuff,love,grow,army,study,reply,option,bad,steady,science,gain,response,math,clean,board,sex,decrease,additional,act,happy,personal,computer,job,orange,advertisement,test,savings,mind,brain,financial,family,dog,watch,dark,circle,letter,building,cold,mass,note,attention,sleep
# ==================================================
# Using the golfing tips he gleaned from such fine players, Andy soon had his
# handicap down to two. He was by then an assistant pro in its fullest sense, so
# he decided to try his hand at playing tournaments. Although he qualified for a
# few regional events, in fact he was aiming much higher: he wanted a crack at the
# Open Championship. So in 1973 Andy decided to try and qualify for the Open at
# Royal Troon — and it was here that an incident occurred that changed his
# career. He had played the first round, but before he had a chance even to hit a
# ball in the second he was out of the pre-qualifier, suffering from injuries he
# had received in a car accident with his caddie. Swallowing hard on the
# disappointment, Andy spent the next few years taking even more blows on the
# chin.
# --------------------------
# money,pain,job,accident,ball,car,sad,fun,game,circle,tired,difficult,sport,sports,helper,professional,smell,king,queen,sadness,green,soft,golf,time,local,wheelchair,music,football,water,food,giving,secretary,cocaine,luck,hair,opportunity,party,children,baseball,feel,round,fingers,common,red,life,happening,hurt,event,happy,club,bad,advice,games,play,finger,bat,mistake,love,mouth,winner,competition,crash,foot,break,blue,death,dance,beard,stealing,drive,disability,failure,sex,exhausted,occurrence,punch,boring,con,sphere,tennis,table,risk,trophy,kids,hard,cards,happenings,purple,win,auto,disabled,family,grass,house,easy,fat,woman,run,dog,rock
# ==================================================
# Improve your mood and counteract stress: Ask anyone who exercises regularly and
# they will tell you that they always feel exhilarated at the end of a session —
# even if they had begun by feeling that they were not in the mood for exercise
# ...
# ==================================================
# She'd been convinced all along that eventually she must lose him, that Marianne
# was right — some other attraction must inevitably draw him away. She hadn't
# changed her mind about that — a man such as Dane would always attract
# beautiful women, and Shannon could never hope to compete. But would the pain of
# losing him be any the less simply because she'd managed to hold him at bay?
# Eventually, probably sooner rather than later, he'd grow tired of waiting for
# Shannon, and then she'd be left with nothing, in any case. Though she could
# never let him know it, he already possessed her heart; if she were to give
# herself to him body and soul, at least the memories would be rich and ultimately
# fulfilling. Right now all she'd have to look back on would be frustration and
# longing suppressed by fear.
# --------------------------
# love,water,time,money,brain,win,garden,tools,finally,tool,game,hair,sad,hurt,wood,red,dog,girl,pretty,food,sleepy,music,desire,sex,fur,future,easy,mind,anger,waiting,poor,light,wealthy,hand,weight,someday,pencil,death,happy,green,winning,house,heart,magnet,backyard,picture,skin,sleep,spirit,blood,ocean,patience,car,door,body,faith,easily,lose,bed,soul,hot,life,race,line,lost,barn,child,paper,shack,woman,female,angry,exhausted,art,quick,white,fun,farm,bad,storage,beautiful,loss,fast,past,girls,sports,cat,boat,scared,ship,handed,plant,tight,head,tree,baby,sea,leave,sweet,hard
# ==================================================
# There can be no doubt that for many women fear of loss is built into us by the
# way we've been reared. As children we may have been made to feel inadequate,
# silly or useless because we were never praised. In adult life, some may be
# submissive and ingratiating, expecting to be in the wrong, expecting to be
# discarded and unwanted. And surprise, surprise, they get just that sort of
# treatment. The only way to stop it happening, and therefore to stop the fear of
# it, is to develop self-esteem. Learn to be assertive, stand up for yourself and
# your own value. That way people will see you as even more lovable. That is what
# I mean by making fear your friend. If you are subject to these irrational fears,
# then use that fear as a trigger to change your attitude. It could revolutionise
# your life.
# --------------------------
# death,party,sign,scared,love,happy,halt,bad,gun,red,money,school,child,birthday,event,touch,kids,afraid,sad,crazy,type,fun,grow,water,study,person,teach,food,mature,car,sex,incorrect,shock,stupid,loathing,funny,dark,unexpected,dog,time,emotion,object,fear,girl,tall,music,green,family,terror,pain,weak,joy,movie,light,sit,question,girls,anxiety,anger,gift,clothes,scare,film,topic,cease,live,children,baby,sense,worthless,hospital,coins,hair,danger,medicine,friends,hurt,worry,create,alter,female,desist,error,life,living,spiders,pal,uncertainty,smile,book,dominant,horse,current,people,buddy,medical,soft,unknown,cold,religion
# ==================================================
# The prime document for EC statistics is now the VAT return. All who are engaged
# in intra-EC trade must now show thereon the total value of all goods dispatched
# to other EC customers and received from other EC suppliers in the special boxes
# provided on the return form. Where either category has exceeded £135,000 during
# 1992 further, more detailed information has to be submitted within the very
# strict time limit of ten working days after each month end. Known as the
# Intrastat system, the data can be submitted by a computerised medium but only if
# it meets Customs specification requirements and has prior approval. Specific
# details relating to each consignment are required but values and quantities may
# be aggregated where all other details are identical. Up to ten items of coded
# information are required comprising such details as the commodity reference of
# the goods, delivery terms, weight, method of transport and, for arrivals, the
# country of origin.
# --------------------------
# time,paper,knowledge,information,money,data,home,car,computer,book,day,twins,math,sum,words,fingers,precise,food,mandatory,water,library,weeks,exact,complete,music,clock,school,beginning,middle,study,start,unique,stuff,specific,twin,week,shape,happy,science,speed,teacher,rules,fat,love,move,toes,baby,twenty,conditions,green,family,list,decimal,heavy,ring,past,plan,exchange,eleven,months,morals,married,word,life,enter,boring,red,age,type,calendar,job,fine,marriage,size,travel,average,truck,news,field,hard,class,mail,rib,white,package,books,dog,annoying,sun,sex,species,stop,barter,previous,carry,pizza,game,bad,land,busy
# ==================================================
# Back home, the observation would have been no less apt. In the years leading up
# to the First World War the Hooligan embarked on a remarkable career, appearing
# in name if not in person before numerous governmental and semi-official bodies
# of enquiry. He loomed large in the apocalyptic discourse surrounding the fears
# of racial decline and physical inefficiency. He figured centrally in the
# Edwardian era's deliberations on the ‘boy labour’ question. He would crop up
# repeatedly in the anxious preoccupation with the demoralising influence of
# popular amusements, the collapse of ‘fair play’ sportsmanship, and the
# allegations of excessive ‘freedom’and ‘affluence’ that were levelled
# against the young. The name of the Hooligan, in fact, provided a crystallising
# focus for any number of overlapping anxieties associated with imperial decline,
# military incapacity, the erosion of social discipline and moral authority, the
# eclipse of family life, and what was feared to be the death rattle of ‘Old
# England’.
# --------------------------
# girl,time,fall,people,baby,job,death,love,house,answer,money,moon,food,sun,nervous,lots,fun,child,party,snake,human,study,war,black,army,life,power,age,refuse,water,friends,peace,music,family,talk,earth,game,school,hard,science,green,woman,globe,circle,happy,friend,bad,apartment,car,leader,play,pain,red,birth,police,shake,friendly,sex,children,sad,reject,body,mark,king,ball,white,hair,cut,field,corn,light,building,dog,environment,individual,slope,boss,royal,heart,fight,games,person,dark,equal,conversation,farm,noise,discussion,control,cold,tree,home,period,warm,amazing,law,story,fat,toy,animal
# ==================================================
# In fact, as I soon discovered, these ruins are inhabited. I met the old lady as
# I was walking down a steep path out of the village. She was struggling up, bent
# under a heavy sack. We greeted each other. The skin of her face hung in purple
# folds and the old eyes were blurred with cataract. When I offered to carry her
# sack she waved me aside. Who was this impertinent stranger eyeing her baggage?
# We moved on up to her tumbledown tower on the last crag of the village. At the
# base was a terrace with one stool on it. Before us stretched an enormous view of
# mountain, promontory and shimmering sea. From my pack I offered her an apple,
# the only food I had. She dismissed it with a regal gesture. Then I saw her
# toothless gums. I left her in peace with her bundle, her stool and her majestic
# view.
# --------------------------
# bag,town,royal,chair,teeth,ocean,huge,water,woman,blue,green,hill,red,bar,luggage,tall,hand,love,mountain,ball,people,poop,money,weight,eye,king,fire,sit,road,baby,fruit,home,suitcase,eat,travel,danger,eyes,food,war,opinion,window,light,vista,potato,tree,color,gigantic,queen,sight,mouth,soft,car,pink,orange,unknown,white,climb,scene,wave,metal,horse,watch,brown,fat,music,heavy,seat,running,lift,castle,sex,dark,dog,snow,load,death,person,beautiful,idiot,vision,tote,hair,sad,cold,happy,elephant,joy,handed,race,wood,sticks,broken,hold,bottom,bed,legs,dead,lunch,clothes,walk
# ==================================================
# Such integration can be largely formal; in Lesotho, for instance, the evidence
# of real integration in between Mathematics and Science is very slight. On the
# other hand it may represent a genuine attempt by specialists in related subjects
# to sit down together and plan a programme which allows for separate activities
# but suggests common themes and provides examples of integrated lessons as in the
# Nigerian Cultural and Creative Art syllabus. Yet again it may be the product of
# basic rethinking and true integration founded on new objectives and a fresh
# approach as in the Social Studies syllabus now under development in Sierra Leone
# where an integrated programme with significant regional variations is being
# planned in a series of central and local workshops and where a special series of
# booklets on skills development (e.g. map making, note taking skills, creative
# skills) is being produced for teachers.
# --------------------------
# school,music,art,computer,television,time,world,food,family,real,study,people,abilities,money,chair,true,false,book,water,simple,fail,talent,knowledge,paper,close,math,honest,middle,talents,books,proof,love,painting,science,job,dog,fun,easy,event,hard,smart,car,country,unique,green,black,local,learning,calculus,artistic,child,education,clean,fruit,red,party,life,fake,dress,person,happy,giving,friends,dance,moment,city,truth,meaningful,blue,house,research,paint,mad,thin,race,sex,movie,stand,test,schedule,crime,home,set,maths,change,language,arrested,white,writing,divide,similar,game,cold,building,fingers,list,society,growth,police,children
# ==================================================
# Regarding access to health care, we meet the fact that women usually live longer
# than men. This is one area of life in which women have a definite advantage! It
# would appear that access to the health service is reasonably equitable between
# men and women, and that women's longer lives should not be attributed to
# prejudice against men in the health sector! However, some writers have suggested
# that the diseases commonly found among men are treated with greater concern and
# more expensive medical treatment than those more commonly found among women. For
# instance, attention has recently been drawn to the inadequate provision of
# screening for cervical cancer despite the fact that this service could provide
# the means of identifying early forms of the disease before it reaches its
# incurable and lethal stage. (More discussion of women and health can be found in
# chapter 9, section 9.5.)
# --------------------------
# lost,doctor,food,money,girls,love,death,book,girl,time,wealth,female,care,hospital,life,worry,happy,sex,medicine,yesterday,car,sick,talk,people,strong,happiness,greet,water,ladies,play,door,sickness,illness,children,exercise,bad,music,beautiful,dog,red,body,lady,green,military,mother,friends,school,pain,church,pretty,females,hair,supply,health,black,hot,house,key,section,moment,wellness,paper,nurse,ill,denied,disease,fun,home,discovered,fitness,friend,power,past,computer,job,child,pride,sad,keys,enter,wife,pencil,breast,piece,cancer,alive,white,conversation,strength,station,boobs,rich,die,business,cure,war,breathe,entry,study,family
# ==================================================
# The Dinner or Luncheon Party: Whatever time of day it is, this is most likely to
# mean inviting a group of people over for a ‘sit-down’ meal. The grandness of
# the meal, and how much of it you pay for, depends upon the expectations of
# yourself and your guests and perhaps their relationship to you. If, say, you are
# a young person — student or worker — who has invited over friends of the
# same age, they will probably expect to bring a bottle of wine with them. In
# fact, most friends, of any age, would bring a bottle of something — unless the
# dinner party was very grand. Relatives often seem to feel that they do not need
# to bring a contribution, unless, of course, you are young, living alone for the
# first time and being visited by your mother, in which case she will probably
# bring a month's supply of food and wash up for you as well!
# --------------------------
# food,carry,time,family,love,eat,fun,money,clock,day,beer,dinner,wine,people,red,water,glass,brought,night,lunch,supper,human,birthday,touch,school,happy,friends,baby,party,clean,warm,demand,light,drink,father,car,gift,life,fetch,piano,white,hope,teacher,music,sex,green,animal,sun,woman,hungry,close,hard,person,provide,anticipate,watch,friend,calendar,child,bee,deliver,politics,alcohol,donation,week,hour,dead,period,meal,pals,alive,era,individual,clothes,salary,job,meat,emotion,study,share,evening,mother,tote,hands,home,house,bad,cheese,death,nice,table,youth,mom,container,dog,hopes,sad,fast,friendly,space
# ==================================================
# The implementation of care management in April could rapidly illustrate how the
# admirable intentions of the government's community care policy might founder on
# the unintended consequences of more powerful forces and contradictions. Firstly,
# although the transfer of social security funds will allow more needs driven
# services, it will also cash limit expenditure. Secondly, this transfer punishes
# local authorities with few residential care homes and cuts off money for future
# expansion. Thirdly, the directive that care managers should not themselves give
# direct care runs counter to the core of good social work practice and creates a
# new corps of care administrators, thereby reducing the number of staff available
# to give direct care. Fourthly, no central guidance has emerged on how to
# coordinate at the local level, care management, the care programme approach, and
# hospital discharge procedures, thus inviting triplication of planning effort.
# --------------------------
# love,money,concern,home,people,boss,straight,move,food,strong,nurture,car,party,middle,package,child,bear,draw,time,health,school,computer,green,water,bad,careful,music,friendly,friends,nurse,close,cash,doctor,hard,tend,apple,family,warm,bank,perfect,caution,feel,lead,top,baby,change,mother,past,book,earth,police,politics,study,sick,plan,center,speed,paper,network,children,control,neighborhood,town,nearby,loving,law,safe,hospital,business,tender,honest,affection,red,life,happy,power,fire,rule,white,fun,direction,rules,map,government,dog,house,service,city,rich,caring,butterfly,worry,picture,death,sex,bed,organize,worker,forward,line
# ==================================================
# It was a great discovery. But it was utterly disastrous for classical physics.
# An electron encircling a nucleus is continuously subject to acceleration as its
# velocity keeps on changing direction. (Acceleration is just the rate of change
# of velocity.) It is an inexorable consequence of classical physics that such an
# accelerating electron radiates off some of its energy at a frequency
# corresponding to the frequency of the electron's circulation. This causes the
# electron to move closer to the nucleus and changes the frequency. The radiation
# loss continues. In other words, a classical "solar system" atom under
# electromagnetic forces is nothing like the actual solar system held together by
# gravitational forces. The atom would be unstable, as its electrons spiralled
# ever closer to the nucleus, and it would emit its dying radiation in a band of
# frequencies with no trace of discreteness. The nuclear atom dealt
# the coup de grâce to classical physics.
# --------------------------
# music,science,speed,atom,bomb,sun,physics,neutron,proton,fast,car,cell,power,chemistry,nuclear,money,center,real,blood,time,energy,nucleus,radio,molecule,light,math,particle,nearer,water,electricity,school,death,art,computer,food,microscope,electron,love,heat,war,green,space,core,negative,heart,house,sound,cancer,bad,true,centre,movement,panel,result,sad,language,hertz,guitar,biology,pitch,red,book,danger,books,waves,farther,study,wave,paper,life,hot,amount,hard,ray,dance,object,matter,plan,quantum,family,sex,dog,piano,north,charge,happy,literature,astronomy,velocity,gas,tiny,truth,clothes,flare,cold,white,smell,architecture,channel,positron
# ==================================================

# %% [markdown]
# ## Write predictions of recall & recognition words to file
#
# Get all the predictions for each recalled words and all words in the recognition tests.

# %%
stimuli_words = []

for text_name in stimuli:
    
    _, n = text_name.split('_')
    n = int(n)+1
    inwords = stimuli[text_name]['inwords'].split(',')
    outwords = stimuli[text_name]['outwords'].split(',')
    for word in inwords+outwords+recalled_words:
        try:
            p = predicted_associates[text_name][associate_vocabulary.word2index[word]]
            stimuli_words.append((str(n) + '-' + word, p))
        except KeyError:
            print('Unknown word in text %s: "%s"' % (text_name,word))

associations_predictions = dict(stimuli_words)

with open(cache_fullpath('word_associates_from_association_norms.pkl'), 'wb') as f:
    pickle.dump(associations_predictions, f, protocol=2)
# Out:
# Unknown word in text text_22: "dhow"

# %% [markdown]
# ## Create csv file with predictions for recalled words
#
# Here, we'll create a special file for use with the multionomial logistic regression modelling of the recall memory results. This file is a $J \times V^\prime + 1$ matrix, written as a csv file, where $J$ is the number of texts and $V^\prime$ is the set of recalled words, across all participants, that are also in the training corpus vocabulary.
#
# See `posterior-predictive-distributions` notebook for more details. There, an identical procedure is followed.

# %%
predictive_probabilities = []
text_names = sorted(predicted_associates.keys(), key=lambda arg: int(arg.split('_')[1]))
for text_name in text_names:
    f = []
    for word in recalled_words:
        f.append(predicted_associates[text_name][associate_vocabulary.word2index[word]])
    predictive_probabilities.append(f)

predictive_probabilities = numpy.array(predictive_probabilities)

predictive_probabilities = numpy.c_[predictive_probabilities, 1-predictive_probabilities.sum(1)]

header = ','.join(recalled_words + ['ALTERNATIVE_WORD'])

M = [header]
for i,f in enumerate(predictive_probabilities):
    M.append(text_names[i] + ',' + ','.join(map(str, f)))
M = '\n'.join(M)
    
association_predictions_of_recalled_words = 'association_predictions_of_recalled_words.csv'

with open(cache_fullpath(association_predictions_of_recalled_words), 'w') as f:
    f.write(M)

# Verify the integrity of the exported csv file.
assert utils.checksum(cache_fullpath(association_predictions_of_recalled_words))\
    == '34b7f4dd9bea8bac9248699ae3313e096b12572f2eae8fb763dcef3448b25c6f'
