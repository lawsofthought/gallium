# %% [markdown]
# # Predicted Word Associates of Texts, based on Word Cooccurrence Statistics
#
# Here, we will calculate the predicted word associates of the texts that are used in our text memory experiment. These predictions can be used to test a word association account of text memory, where word associations are defined in terms of cooccurrence statistics in the language.
#
# $$
# \newcommand{\data}{\mathcal{D}}
# \newcommand{\Prob}[1]{\mathrm{P}( #1 )}
# \newcommand{\given}{\vert}
# $$
#
# For this, we need to calculate
# $$
# \Prob{w_k \given w_l} \triangleq \frac{ \Prob{w_k,w_l} }{\Prob{w_l}},
# $$
# which is the empirical probability of observing word $w_k$ in some linguistic context, e.g., a short text, given that we've observed $w_l$ there. This is calculated as follows. First, we calculate $\Prob{w_k, w_l \given \textrm{text}=j}$, or the joint (empirical) probability of finding word $w_k$ and word $w_l$ in a given text $j$. If text $j$ has $n_j$ words, then
# there are $n_j (n_j - 1)$ ordered word pairs in total in text $j$. If there are $n_{jk}$ and $n_{jl}$ occurrences of words $w_k$ and $w_l$, respectively, when $w_k \neq w_l$,  there are $n_{jk} n_{jl}$ pairs containing the words $w_k$ and $w_l$. When $w_k = w_l$, there are $n_{jk} (n_{jl}-1)$ word pairs that are of words $w_k$ and $w_l$.
# From this,
# $$
# \mathrm{P}(w_k,w_l \given \textrm{text}=j) = \frac{n_{jk} (n_{jl} - \mathbb{I}(k = l))}{n_j (n_j-1)},
# $$
# where $\mathbb{I}(k = l)$ takes the value of 1 whenever $w_k = w_l$, and 0 otherwise. Consequently,
# averaging over all $J$ texts, we have
# $$
# \mathrm{P}(w_k,w_l) =\frac{1}{J} \sum_{j=1}^J \mathrm{P}(w_k,w_l \given \textrm{text}=j),
# $$
# and so from this, we may easily calculate $\Prob{w_k \given w_l} = \tfrac{ \Prob{w_k,w_l} }{\Prob{w_l}}$.
#
# Having calculated $\Prob{w_k \given w_l}$, given a text
# $$
# \textrm{text}_{j^\prime} \triangleq w_{j^\prime 1}, w_{j^\prime 2} \ldots w_{j^\prime n_{j^\prime}},
# $$
# the predicted probability that word $w_k$ is associated with $\textrm{text}_{j^\prime}$ is
# $$
# \mathrm{P}(w_k \vert \textrm{text}_{j^\prime}) = \frac{1}{n_{j^\prime}} \sum_{i = 1}^{n_{j^\prime}} \mathrm{P}(w_k \vert w_{j^\prime i}).
# $$

# %% [markdown]
# ## Preface
#
# This notebook requires some existing datasets, and will create a new dataset, see below. Some of the sparse matrix calculates are relatively intensive, but it will execute all cells completely in about 2-3 minutes.

# %%
from __future__ import division

# Standard library imports
import os
import pickle

# Third party imports
import pandas
import configobj
import numpy
from scipy.sparse import coo_matrix, csc_matrix, lil_matrix

# Home spun third party imports
from gustav import models
from gustav.utils import SparseCountMatrix

# Local imports
from utils import utils, datautils

# %% [markdown]
# ## Check required files
#
# Check the integrity of required data files.

# %%
cache_directory = '../cache'
cache_fullpath = lambda path: os.path.join(cache_directory, path)

filenames = {
    'experiment_cfg' : [('Brismo.cfg',
                         '909d9f8de483c4547f26fb4c34b91e12908ab5c144e065dc0fe6c1504b1f22c9')],
    'text-corpus' : [('bnc_texts_78639361_183975_251_499.txt.bz2',
                      '0db086c97c7d3a26c131c8c51c03e45368dc95d8c8202fb6fdbed23d159afe02')],
    'vocabulary' : [('bnc_vocab_49324.txt',
                     'ecf66c77121cf67e416580cf5cc0853bd1813dcfd946298723134e547324cb6b')],
    'recall_results' : [('brisbane_06b643a_recall_results.pkl',
                         'a94d812373123b9a8b1eac848276e8ffc6a563ebca71ff2bf5adc97c825cbc14')],
}

utils.verify_cache_files(filenames['experiment_cfg'] +\
                         filenames['text-corpus'] +\
                         filenames['vocabulary'] +\
                         filenames['recall_results'], 
           cache=cache_directory,
           verbose=False)

# bunzip the text-corpus
utils.bunzip(filenames['text-corpus'][0][0], cache=cache_directory)

# %% [markdown]
# ## Process the data:
#
# * Get the text stimuli that were used in the experiment
# * Get the corpus vocabulary as a Vocab object instance
# * Convert each text stimuli into a bag of words
# * Read in the experiment recall results
# * Find the recalled words that are also in the corpus vocabulary

# %%
memoranda = configobj.ConfigObj(cache_fullpath(filenames['experiment_cfg'][0][0]))['text_memoranda']

text_filename = cache_fullpath(os.path.splitext(filenames['text-corpus'][0][0])[0])

vocabulary_filename = cache_fullpath(filenames['vocabulary'][0][0])

vocabulary = open(vocabulary_filename).read().split()
vocab = datautils.Vocab(vocabulary)

text_to_words = lambda text: [word for word in datautils.tokenize(text) if word in vocab.word2index]

texts_as_words = {}
for text_name in memoranda:
    texts_as_words[text_name] = text_to_words(memoranda[text_name]['text'])

Df = {}
Df['recall'] = pandas.read_pickle(cache_fullpath('brisbane_06b643a_recall_results.pkl'))

recalled_words = sorted(set(Df['recall']['word'].values).intersection(vocabulary))

# %% [markdown]
# ## Make sparse matrix of document-word counts
#
# The following calculates a $J \times V$ sparse matrix $R$, where
# $$
# R_{jk} \triangleq \text{frequency of term $k$ in text $j$}.
# $$

# %%
#sparse_count_matrix_filename = 'bnc_78723408_250_500_vocab49328_sparse_matrix_count'

sparse_count_matrix = SparseCountMatrix.new(text_filename = text_filename,
                                            vocabulary_filename = vocabulary_filename)

# Create a coo sparse matrix
#sparse_count_matrix = numpy.load(cache_fullpath(sparse_count_matrix_filename) + '.npz')

R = coo_matrix((sparse_count_matrix['values'], 
                (sparse_count_matrix['rows'], sparse_count_matrix['cols'])), 
               shape=(sparse_count_matrix['J'], sparse_count_matrix['V'])).tolil()

# %% [markdown]
# We will compute a $J \times V$ matrix $S$ such that
# $$
# S_{jk} = \frac{n_{jk}}{n_j (n_j-1)}.
# $$
#
#
# For $w_k \neq w_l$, we can calculate $\Prob{w_k, w_l}$ as follows:
# $$
# \begin{aligned}
# \mathrm{P}(w_k,w_l) &= \frac{1}{J} \sum_{j=1}^J \frac{n_{jk} n_{jl}}{n_j (n_j-1)},\\
#                     &= \frac{1}{J} \sum_{j=1}^J S_{jk} R_{jl}.
# \end{aligned}
# $$
#
# However, whenever $w_k = w_l$,
# $$
# \begin{aligned}
# \mathrm{P}(w_k,w_l) &= \frac{1}{J} \sum_{j=1}^J \frac{n_{jk} (n_{jl} - 1)}{n_j (n_j-1)},\\
#                     &= \frac{1}{J} \left( \sum_{j=1}^J S_{jk} R_{jl} - \sum_{j=1}^J S_{jk} \right)
# \end{aligned}
# $$

# %%
def get_joint_prob(R):
    
    J, V = R.shape 

    Rj = R.sum(1).A.flatten()

    z = Rj * (Rj - 1)

    Z = lil_matrix((J,J))

    Z.setdiag(1/z)

    S = (R.T * Z ).T 

    C = S.T * R 

    C.setdiag(C.diagonal() - S.sum(0).A.flatten())
    
    return C/J 

def get_conditional_prob(P):

    Pz = P.sum(1).A.flatten()
    
    Z = lil_matrix(P.shape)
    
    Z.setdiag(1/Pz)
    
    return (P.T * Z).T

# %%
P = get_joint_prob(R)

# %%
C = get_conditional_prob(P)

# %%
f = P.sum(0).A.flatten()

# %% [markdown]
# Here, we add an optional "smoothing" feature such that if the observed counts $R_{kl}$ are 0, we replaced the predicted probability $\Prob{w_k\given w_l}$, which will necessarily be 0.0, by $\Prob{w_k}$. In other words, this gives *back-off* model for the zero counts. The main purpose and benefit of this is to ensure that all zero count bigrams are given a reasonable nonzero estimate, and the values of zero would cause trouble in analysis when we need to calculate logarithms.

# %%
def get_conditional_probability(C, f, word, smooth=True):
    
    '''
    Return probability of cooccurrence given word `word`.
    `f` is unigram frequency of word
    '''
    
    j = vocab.word2index[word]
    
    Rj = C[j].A.flatten()
    
    p = Rj/Rj.sum()
        
    if smooth:
        I = Rj == 0
        p[I] = f[I] # Where observed cooccurrence is 0, use unigram frequency instewad
    
    return p/p.sum()

# %% [markdown]
# Do some sanity checks, by checking the cooccurrences of randomly chosen words.

# %%
def check_some_words(K, N, seed):
    random = numpy.random.RandomState(seed)
    
    for k in random.permutation(P.shape[0])[:K]:
        
        word_k = vocab.index2word[k]
        
        smoothed_associates = ','.join([vocab.index2word[i] 
                                        for i in numpy.flipud(numpy.argsort(get_conditional_probability(C, f, word_k)))[:N]])
        
        original_associates = ','.join([vocab.index2word[i] 
                                        for i in numpy.flipud(numpy.argsort(get_conditional_probability(C, f, word_k, smooth=False)))[:N]])
    
    
        print(vocab.index2word[k].capitalize())
        print('Smoothed: ' + smoothed_associates)
        print('-'*10)
        print('Original: ' + original_associates)
        print('='*100)

check_some_words(25, 100, 1001)
# Out:
# Futurity
# Smoothed: nature,empty,possessed,tomorrow,set,baffled,futurity,book,novelist,reading,mind,letter,reader,town,decision,replies,suicide,peter,life,ad,bound,real,world,trust,imagine,tale,outcomes,newspaper,road,children,human,future,reality,hands,management,verb,chapter,fiction,doubt,revelation,free,contemplating,intellectual,standpoint,words,lying,means,aiming,double,apocalyptic,heart,clause,including,aim,nurse,bishop,inside,attach,exchange,persuade,impossibility,spare,bent,brilliant,eternity,imagined,quintets,attacks,sets,agonized,laws,poisoned,boundless,jest,crazed,negative,lighted,urges,intention,rudderless,lamp,saviour,response,wood,metaphysical,lots,wondering,circles,single,guaranteed,cross,neutrally,retains,wrote,torpor,collective,lonely,chip,obscure,bafflement
# ----------
# Original: nature,empty,possessed,tomorrow,set,baffled,futurity,book,novelist,reading,mind,letter,reader,town,decision,replies,suicide,peter,life,ad,bound,real,world,imagine,outcomes,tale,newspaper,road,trust,children,human,future,reality,hands,management,verb,chapter,fiction,revelation,doubt,free,contemplating,intellectual,words,standpoint,lying,means,aiming,apocalyptic,double,heart,clause,including,sets,inside,negative,cross,boundless,persuade,aim,kills,bent,saviour,neutrally,universal,secret,chip,river,bafflement,conjured,urges,frustration,crazed,quintets,wrote,single,received,arguing,blends,guaranteed,impossibility,obscure,wood,torpor,emptiness,wondering,exchange,attach,fulfilled,intention,poisoned,imagined,corpse,laws,freedom,safe,becalmed,answer,collective,provincial
# ====================================================================================================
# Registries
# Smoothed: registry,land,data,cancer,information,public,district,registration,registries,search,health,disease,time,costs,aged,government,legal,records,national,form,notice,age,rules,bill,regional,office,electronic,study,analyses,local,scheme,rights,report,title,property,forms,cancers,incidence,registered,practice,authorities,bills,county,details,trade,patients,table,court,sources,period,leukaemia,law,black,executive,international,individual,issued,approach,children,set,service,population,register,included,company,official,including,people,northern,childhood,dementia,mineral,transaction,rates,based,conveyancing,commercial,department,parties,giving,uniformity,message,recordings,life,day,plan,hospital,applications,require,covered,responsibility,agency,probable,political,charge,act,research,crown,obtained,epidemiological
# ----------
# Original: registry,land,data,cancer,information,public,district,registration,registries,search,health,disease,time,costs,aged,government,legal,records,national,form,notice,age,rules,bill,regional,office,electronic,study,analyses,local,scheme,rights,report,title,property,forms,cancers,incidence,registered,practice,authorities,bills,county,details,trade,patients,table,court,sources,period,leukaemia,law,black,executive,international,individual,issued,approach,children,set,service,population,register,included,company,official,including,people,northern,childhood,dementia,mineral,transaction,rates,based,conveyancing,commercial,department,parties,giving,recordings,uniformity,message,plan,hospital,applications,require,covered,agency,responsibility,probable,political,charge,act,research,crown,obtained,epidemiological,complete,access
# ====================================================================================================
# Puckers
# Smoothed: sugar,junctions,junction,conformations,transition,values,figure,data,shown,modelling,phosphate,results,phase,low,energy,conformation,correlation,amplitude,central,transitions,note,involving,puckers,structure,termed,observed,distances,site,steps,type,constraints,found,backbone,angles,studies,study,optimized,led,rotation,belong,effects,structural,people,imposed,creation,compared,diet,earlier,field,exception,effect,minor,groove,recently,twist,symmetry,helical,solution,table,sequence,structures,leading,agreement,losses,cosy,test,time,cellulite,constant,passage,modified,direction,sites,curve,involved,indicating,coupling,perturbation,suggest,intermediate,region,orientation,closely,complex,result,occurred,minima,perturbations,transformed,noted,facing,centre,single,base,skin,helix,head,mouth,police,left
# ----------
# Original: sugar,junctions,junction,conformations,transition,values,figure,data,shown,modelling,phosphate,results,phase,low,energy,conformation,amplitude,correlation,central,transitions,involving,note,puckers,structure,termed,observed,distances,site,steps,type,constraints,found,backbone,angles,studies,study,optimized,led,belong,rotation,effects,structural,imposed,compared,creation,diet,earlier,field,exception,groove,minor,effect,recently,twist,symmetry,helical,solution,table,sequence,cosy,leading,test,agreement,losses,structures,time,cellulite,constant,direction,involved,passage,perturbation,sites,curve,indicating,coupling,modified,suggest,closely,orientation,region,intermediate,complex,result,centre,noted,facing,occurred,transformed,perturbations,minima,single,base,skin,helix,police,head,mouth,left,lead
# ====================================================================================================
# Fewer
# Smoothed: people,time,cent,women,government,children,world,labour,fewer,local,found,social,life,home,party,population,system,national,day,family,education,age,market,public,country,change,set,industry,half,support,million,patients,major,service,control,level,school,workers,increase,money,council,house,rate,times,business,means,war,week,companies,company,training,development,result,services,period,left,effect,century,average,schools,total,form,jobs,staff,research,increased,table,terms,south,care,main,economic,compared,days,study,west,report,past,power,policy,political,employment,community,range,information,health,north,provide,child,management,countries,minister,proportion,similar,firms,future,figures,difficult,parents,including
# ----------
# Original: people,time,cent,women,government,children,world,labour,fewer,local,found,social,life,home,party,population,system,national,day,family,education,age,market,public,country,change,set,industry,half,support,million,patients,major,service,control,level,school,workers,increase,money,council,house,rate,times,business,means,war,week,companies,company,training,development,result,services,period,left,effect,century,average,schools,total,form,jobs,staff,research,increased,table,terms,south,care,main,economic,compared,days,study,west,report,past,power,policy,political,employment,community,range,information,health,north,provide,child,management,countries,minister,proportion,similar,firms,future,figures,difficult,parents,including
# ====================================================================================================
# Opulent
# Smoothed: time,world,white,house,people,left,car,life,found,set,building,night,wine,street,hall,day,style,fine,road,days,hotel,built,public,buildings,stood,rich,music,sir,john,love,top,hand,houses,bed,fruit,beach,stone,company,past,mother,door,told,century,cream,design,red,business,centre,quality,square,city,ground,elegant,glass,beautiful,country,market,flowers,hair,round,looked,light,floor,songs,eyes,bar,garden,opera,dark,vintage,family,real,performance,called,war,stop,service,taking,body,sound,feel,success,late,wines,major,tea,film,range,fresh,bright,station,table,father,children,makes,court,art,finally,main,wide
# ----------
# Original: time,world,white,house,people,left,car,life,found,set,building,night,wine,street,hall,day,style,fine,road,days,hotel,built,public,buildings,stood,rich,music,sir,john,love,top,hand,houses,bed,fruit,beach,stone,company,past,mother,door,told,century,cream,design,red,business,centre,quality,square,city,ground,elegant,glass,beautiful,country,market,flowers,hair,round,looked,light,floor,songs,eyes,bar,garden,opera,dark,vintage,family,real,performance,called,war,stop,service,taking,body,sound,feel,success,late,wines,major,tea,film,range,fresh,bright,station,table,father,children,makes,court,art,finally,main,wide
# ====================================================================================================
# Harassment
# Smoothed: police,women,people,harassment,sexual,black,time,person,government,council,conduct,public,section,act,violence,racial,behaviour,support,policy,local,house,children,law,employment,home,court,offence,rights,victim,action,political,cent,staff,family,report,housing,school,told,officers,evidence,life,day,company,community,security,job,months,reported,month,male,social,charges,president,employees,found,commission,travellers,office,national,abuse,week,alarm,question,trade,training,pay,white,left,deal,committee,power,criminal,move,information,victims,words,issue,force,distress,campaign,department,country,legal,service,party,contact,war,world,called,workers,authorities,stop,physical,movement,complaints,leave,held,rape,attacks,age
# ----------
# Original: police,women,people,harassment,sexual,black,time,person,government,council,conduct,public,section,act,violence,racial,behaviour,support,policy,local,house,children,law,employment,home,court,offence,rights,victim,action,political,cent,staff,family,report,housing,school,told,officers,evidence,life,day,company,community,security,job,months,reported,month,male,social,charges,president,employees,found,commission,travellers,office,national,abuse,week,alarm,question,trade,training,pay,white,left,deal,committee,power,criminal,move,information,victims,words,issue,force,distress,campaign,department,country,legal,service,party,contact,war,world,called,workers,authorities,stop,physical,movement,complaints,leave,held,rape,attacks,age
# ====================================================================================================
# Eventualities
# Smoothed: time,people,home,terms,holiday,cover,car,days,partners,war,client,partnership,process,day,sexual,house,child,system,world,left,firm,government,bank,job,business,awareness,life,require,father,relations,staff,foal,constitution,moment,act,prepare,insurance,political,partner,customer,court,money,hand,book,period,dishonest,means,information,east,disclosure,parliament,power,plan,real,duties,ahead,task,set,local,agreement,provide,major,line,head,worry,law,public,mind,mare,babies,teeth,force,legal,conflict,told,feeling,centre,date,account,pay,family,video,emergency,top,cut,peace,circumstances,company,passed,notes,food,community,giving,future,eyes,brought,required,mother,called,believed
# ----------
# Original: time,people,home,terms,holiday,cover,car,days,partners,war,client,partnership,process,day,sexual,house,child,system,world,left,firm,government,bank,job,business,awareness,life,require,father,relations,staff,foal,constitution,moment,act,prepare,insurance,political,partner,customer,court,money,hand,book,period,dishonest,means,information,east,disclosure,parliament,power,plan,real,duties,ahead,task,set,local,agreement,provide,major,line,head,worry,law,public,mind,mare,babies,teeth,force,legal,conflict,told,feeling,centre,date,account,pay,family,video,emergency,top,cut,peace,circumstances,company,passed,notes,food,community,giving,future,brought,required,mother,called,believed,contract
# ====================================================================================================
# Jailer
# Smoothed: rabbit,children,time,mother,life,dad,feel,woman,front,wife,father,carry,looked,john,king,peter,death,day,told,ferret,rabbits,home,sort,family,days,dreams,film,simply,found,brother,money,people,dead,bored,green,sir,tea,walk,married,real,child,love,set,prepared,company,theatre,worth,actors,army,tom,car,half,unable,incapable,position,vote,degree,stale,tired,guide,august,system,thousand,daughter,parliament,world,comedy,scandal,ago,government,scared,mum,surprisingly,blame,sympathy,house,choice,stage,town,round,legs,beginning,lot,fucking,actress,generation,true,burrow,occur,blockage,hole,suddenly,fight,taking,beggar,regarded,burden,mad,ghost,quarries
# ----------
# Original: rabbit,children,time,mother,life,dad,feel,woman,front,wife,father,carry,looked,john,king,peter,death,day,told,rabbits,ferret,home,sort,family,days,dreams,film,simply,found,brother,money,people,dead,bored,green,sir,walk,tea,married,real,child,love,set,prepared,company,theatre,worth,actors,army,tom,car,half,unable,position,incapable,tired,stale,vote,degree,guide,august,system,thousand,daughter,parliament,world,comedy,scandal,ago,scared,mum,surprisingly,choice,house,sympathy,blame,stage,town,round,legs,beginning,lot,actress,fucking,true,generation,blockage,burrow,hole,suddenly,occur,fight,taking,beggar,regarded,quarries,burden,ghost,easier,mad
# ====================================================================================================
# Cadging
# Smoothed: time,dodger,told,widow,people,yer,home,professor,table,gulls,miss,street,shields,restaurant,drink,mother,birds,stewardess,round,food,school,hotel,child,eyes,looked,lost,husband,head,corner,hall,pay,black,summer,women,hat,honour,city,dinner,grand,drinks,lower,smoke,conversation,children,absolutely,tips,heard,tension,spotted,daughter,body,white,living,death,woman,hair,house,left,eye,arrived,plumage,rebel,stars,kids,times,mum,matter,relief,dad,fine,found,officer,hung,playing,nineties,called,music,freedom,provost,fee,sat,sir,book,south,smiling,dead,bad,smile,returned,ordinary,government,talk,included,striking,suggest,world,informed,waiting,past,sockets
# ----------
# Original: time,dodger,told,widow,people,yer,home,professor,table,gulls,miss,street,shields,restaurant,drink,mother,birds,stewardess,round,food,school,hotel,child,eyes,looked,lost,husband,head,corner,hall,pay,black,summer,women,city,hat,honour,grand,drinks,dinner,lower,smoke,conversation,children,absolutely,tips,heard,tension,spotted,daughter,body,white,living,death,woman,hair,house,left,eye,arrived,rebel,stars,plumage,times,kids,dad,relief,mum,matter,fine,found,hung,officer,music,called,nineties,playing,provost,sir,sat,freedom,fee,book,south,dead,smiling,smile,bad,returned,ordinary,talk,striking,included,suggest,informed,waiting,past,sighed,half,fly
# ====================================================================================================
# Delegate
# Smoothed: party,time,people,government,council,conference,authority,power,minister,national,delegate,committee,control,meeting,president,secretary,held,management,political,responsibility,act,executive,local,union,delegation,elected,women,person,association,parliament,congress,public,labour,policy,law,court,delegates,world,decisions,judges,trade,job,house,services,system,called,country,organisation,representative,south,business,task,staff,subordinates,social,managers,form,schools,day,cent,development,service,support,decision,ministers,life,international,company,change,structure,special,election,parties,delegated,role,information,responsible,office,set,home,communist,school,head,powers,manager,practice,question,training,representatives,rights,affairs,foreign,level,countries,united,education,involved,pope,ensure,position
# ----------
# Original: party,time,people,government,council,conference,authority,power,minister,national,delegate,committee,control,meeting,president,secretary,held,management,political,responsibility,act,executive,local,union,delegation,elected,women,person,association,parliament,congress,public,labour,policy,law,court,delegates,world,decisions,judges,trade,job,house,services,system,called,country,organisation,representative,south,business,task,staff,subordinates,social,managers,form,schools,day,cent,development,service,support,decision,ministers,life,international,company,change,structure,special,election,parties,delegated,role,information,responsible,office,set,home,communist,school,head,powers,manager,practice,question,training,representatives,rights,affairs,foreign,level,countries,united,education,involved,pope,ensure,position
# ====================================================================================================
# Greenest
# Smoothed: fresh,company,body,transport,half,public,rail,sales,countries,world,teaspoon,dried,trees,waste,publishers,energy,leaves,city,bands,day,council,country,telephone,seeds,parasites,record,election,found,local,tax,market,environment,car,hotel,line,forest,taxes,black,river,environmental,reduced,garden,people,hazardous,convention,beach,time,skin,titles,fennel,pumpkin,companies,plans,trade,officer,moment,road,verandah,silver,money,looked,government,includes,film,green,charlie,million,set,watch,top,included,quality,effect,standards,past,safety,home,management,decided,town,national,spring,building,cost,park,effective,mind,land,summer,hero,happened,left,faced,federal,power,gas,children,protest,policy,earth
# ----------
# Original: fresh,company,body,transport,half,public,rail,sales,countries,world,dried,teaspoon,trees,waste,publishers,energy,leaves,city,bands,day,council,country,telephone,parasites,seeds,record,election,found,local,tax,market,environment,car,hotel,line,forest,taxes,black,river,environmental,reduced,garden,people,convention,hazardous,beach,time,fennel,pumpkin,titles,skin,companies,plans,trade,officer,moment,road,verandah,silver,money,looked,government,includes,film,green,charlie,million,set,watch,top,included,quality,effect,standards,past,safety,home,management,decided,town,national,spring,building,cost,park,effective,mind,land,summer,hero,happened,left,faced,federal,gas,power,earth,protest,policy,investment
# ====================================================================================================
# Ropey
# Smoothed: time,music,bank,game,smith,week,single,horse,movement,debt,barber,speak,real,bush,cover,fall,bit,round,billion,night,day,auction,charity,mind,squad,conductor,pop,intimate,money,feel,half,called,light,world,hard,page,times,nasty,hit,government,provisions,assets,smiths,strings,girl,sat,pieces,performance,rescue,bimbos,declared,growth,summit,set,hand,star,morning,rock,top,raised,word,sound,stars,admit,fine,caring,orchestra,symphony,slightly,race,term,pretty,issue,stride,left,season,poor,rivals,ratio,low,feeling,executive,rose,tent,harry,team,camp,scene,named,concert,pair,tune,candidate,republicans,democrats,yesterday,minute,tone,shop,lovable
# ----------
# Original: time,music,bank,game,smith,week,single,horse,movement,debt,barber,speak,real,bush,cover,fall,bit,round,billion,night,day,auction,charity,mind,squad,conductor,pop,intimate,money,feel,half,called,light,world,hard,page,times,nasty,hit,provisions,assets,smiths,sat,pieces,girl,strings,performance,bimbos,rescue,declared,growth,summit,set,hand,star,morning,rock,top,raised,word,sound,stars,admit,fine,caring,symphony,orchestra,slightly,race,term,pretty,issue,stride,season,poor,rivals,ratio,low,feeling,executive,rose,tent,team,harry,camp,named,pair,concert,scene,tune,candidate,democrats,republicans,yesterday,tone,minute,paper,lovable,shop,strangers
# ====================================================================================================
# Contentiously
# Smoothed: world,based,rules,animals,claim,compromise,approach,simply,surplus,local,majority,women,monopoly,entrants,mature,support,hill,mergers,processes,dominant,evidence,major,retarded,defective,human,sense,society,size,assumed,economic,benefits,communities,result,lesbian,unemployment,prefer,public,life,modern,uncertainty,offset,free,firms,created,ability,argue,climate,policy,ideology,bureaucrats,film,producers,substantial,nature,friendships,consensus,democratic,demand,forecasts,competition,treatment,meaning,time,comparison,imbeciles,baby,babies,retardation,capable,primitive,effects,social,existing,perspective,people,perfect,wider,reality,broad,results,total,television,efficiency,platoon,operation,consumers,words,word,frequently,involved,inclined,association,inevitably,operate,political,losses,basis,female,rivalry,marriage
# ----------
# Original: world,based,rules,animals,claim,compromise,approach,simply,surplus,local,majority,women,monopoly,entrants,mature,support,hill,mergers,processes,dominant,evidence,major,human,defective,retarded,sense,society,size,assumed,economic,benefits,communities,result,lesbian,unemployment,prefer,public,life,modern,climate,firms,argue,free,ability,uncertainty,created,offset,policy,ideology,bureaucrats,film,producers,substantial,nature,friendships,democratic,consensus,demand,forecasts,competition,treatment,meaning,time,imbeciles,baby,babies,comparison,primitive,retardation,capable,effects,social,existing,perspective,people,perfect,wider,reality,broad,total,results,television,efficiency,platoon,consumers,operation,words,word,frequently,inclined,involved,inevitably,operate,association,political,losses,basis,female,rivalry,marriage
# ====================================================================================================
# Drawn
# Smoothed: time,people,government,world,life,found,day,house,party,left,local,set,home,children,system,social,looked,line,drawn,national,public,head,women,hand,eyes,form,power,school,information,political,law,told,called,water,cent,country,family,question,court,attention,terms,level,light,development,round,act,war,support,view,held,labour,change,council,evidence,company,night,control,mind,service,child,means,john,money,door,business,major,period,effect,position,real,policy,figure,century,art,body,woman,days,main,church,sense,process,matter,father,times,words,book,education,research,society,death,subject,god,result,black,half,committee,class,white,bank,close
# ----------
# Original: time,people,government,world,life,found,day,house,party,left,local,set,home,children,system,social,looked,line,drawn,national,public,head,women,hand,eyes,form,power,school,information,political,law,told,called,water,cent,country,family,question,court,attention,terms,level,light,development,round,act,war,support,view,held,labour,change,council,evidence,company,night,control,mind,service,child,means,john,money,door,business,major,period,effect,position,real,policy,figure,century,art,body,woman,days,main,church,sense,process,matter,father,times,words,book,education,research,society,death,subject,god,result,black,half,committee,class,white,bank,close
# ====================================================================================================
# Prescience
# Smoothed: time,war,labour,world,north,poem,book,wrote,people,government,won,office,told,age,earth,foreign,times,hand,artillery,blank,sheikh,army,assumption,half,youth,battle,feel,day,independence,family,moment,soul,line,picture,price,mind,view,secretary,true,beginning,house,unions,united,hero,books,boy,party,political,revolution,painted,experience,earlier,brought,physics,classification,purposes,future,possibility,public,policy,court,painting,defeated,knowledge,conservatives,success,operation,option,union,century,moral,city,events,spiritual,defined,situation,school,spoke,social,forced,position,days,enemy,women,writing,precisely,home,association,division,produced,human,traditional,company,striking,dead,report,powers,granted,prophet,king
# ----------
# Original: time,war,labour,world,north,poem,book,wrote,people,government,won,office,told,age,earth,foreign,times,hand,artillery,blank,sheikh,army,assumption,half,youth,battle,feel,day,independence,family,moment,soul,line,picture,price,mind,view,secretary,true,beginning,unions,united,books,hero,boy,party,political,revolution,painted,experience,earlier,brought,physics,classification,purposes,future,possibility,public,policy,court,painting,defeated,knowledge,conservatives,success,operation,option,union,century,moral,city,events,spiritual,defined,situation,school,spoke,forced,position,days,enemy,writing,precisely,home,association,division,produced,human,traditional,striking,dead,report,powers,granted,prophet,king,visit,evidence,organization,request
# ====================================================================================================
# Prospected
# Smoothed: mining,companies,prospecting,local,convention,roach,information,land,community,international,resources,company,time,meeting,gold,enterprise,world,environmental,brought,major,share,conservation,looked,reaction,wave,mars,imminence,films,film,proposed,campaign,awareness,permission,uranium,people,mine,days,planning,public,landowners,mines,operations,opposition,objections,economic,industry,south,north,day,profits,current,communities,eventually,born,appeared,hardy,gang,laurel,comedy,children,council,impact,left,facilities,deliverance,stopped,started,rod,knowing,guess,technology,situation,welcomed,pollution,bonanza,promised,miners,united,conference,terms,private,nodules,sea,seabed,countries,hundred,blue,bed,operating,resistance,committee,controversies,projects,highly,moved,purpose,rest,chairperson,tourism,care
# ----------
# Original: mining,companies,prospecting,local,convention,roach,information,land,community,international,resources,company,meeting,gold,enterprise,world,environmental,brought,major,share,conservation,looked,reaction,wave,imminence,mars,films,film,proposed,campaign,awareness,permission,uranium,people,mine,days,planning,public,landowners,mines,opposition,operations,economic,objections,industry,south,north,day,profits,current,eventually,communities,born,appeared,laurel,comedy,gang,hardy,children,council,impact,left,deliverance,knowing,facilities,started,rod,guess,stopped,technology,situation,welcomed,pollution,promised,bonanza,miners,private,nodules,sea,countries,terms,united,conference,seabed,blue,hundred,bed,operating,resistance,committee,projects,controversies,highly,moved,purpose,rest,talc,care,mountain,tourism
# ====================================================================================================
# Matriculation
# Smoothed: students,education,university,school,certificate,degree,time,completion,mature,college,qualifications,schools,entry,examination,study,advanced,life,satisfactory,level,oxford,rates,children,universities,entrants,board,father,subjects,matriculation,degrees,courses,women,basis,secondary,polytechnic,student,speech,age,political,final,examinations,system,class,recognised,found,told,people,black,cent,son,special,formal,home,white,standard,joint,scheme,entering,parents,diploma,information,remember,access,entrance,family,results,death,form,mother,research,success,society,boys,war,performance,candidates,difficult,meet,master,report,educational,love,examined,required,technical,connection,strong,term,significant,noble,teaching,ability,approved,south,institutions,studies,miss,church,teachers,diplomas,money
# ----------
# Original: students,education,university,school,certificate,degree,time,completion,mature,college,qualifications,schools,entry,examination,study,advanced,life,satisfactory,level,oxford,rates,children,universities,entrants,board,father,subjects,matriculation,degrees,courses,women,basis,secondary,polytechnic,student,speech,age,political,final,examinations,system,class,recognised,found,told,people,black,cent,son,special,formal,home,white,standard,joint,scheme,entering,parents,diploma,information,remember,access,entrance,family,results,death,form,mother,research,success,society,boys,war,performance,candidates,difficult,meet,master,report,educational,love,examined,required,technical,connection,strong,term,significant,noble,teaching,ability,approved,south,institutions,studies,miss,church,teachers,diplomas,money
# ====================================================================================================
# Denigrate
# Smoothed: people,life,women,time,world,black,customers,god,political,community,girls,society,real,national,written,company,economic,orange,round,woman,encourage,complaints,development,experience,anger,issue,companies,sort,war,silly,innocent,deal,race,power,voice,standard,city,social,talk,assets,day,involved,love,difficult,sense,suddenly,lower,days,john,words,found,authority,job,question,practical,recently,book,position,skills,advice,legal,easy,police,behaviour,body,ideas,role,dead,nature,parades,images,attempt,feminist,business,differences,history,industrial,recent,view,live,lead,attitude,couple,hope,person,education,human,rest,children,friends,times,line,information,simply,western,head,service,age,offer,angry
# ----------
# Original: people,life,women,time,world,black,customers,god,political,community,girls,society,real,national,written,company,economic,orange,round,woman,encourage,complaints,development,experience,anger,issue,companies,sort,war,silly,innocent,deal,race,power,voice,standard,city,social,talk,assets,day,involved,love,difficult,sense,suddenly,lower,days,john,words,found,authority,job,question,practical,recently,book,position,skills,advice,legal,easy,police,behaviour,body,ideas,role,dead,nature,parades,images,attempt,feminist,business,differences,history,industrial,recent,view,live,lead,attitude,couple,hope,person,education,human,rest,children,friends,times,line,information,simply,western,head,service,age,offer,angry
# ====================================================================================================
# Walkers
# Smoothed: walk,road,walkers,route,people,day,miles,time,mountain,walking,path,local,countryside,national,north,loch,hills,park,left,hill,south,mountains,valley,car,village,water,public,top,days,access,country,traffic,land,track,climb,west,ridge,house,home,river,mile,set,views,walks,guide,glen,climbing,popular,town,cyclists,walker,centre,paths,line,commission,east,council,feet,snow,book,found,routes,summit,railway,main,coast,view,natural,head,visit,called,bridge,beautiful,easy,climbers,enjoy,built,summer,district,forest,past,sea,footpath,world,ramblers,nature,range,taking,wild,peak,half,pass,island,start,round,hotel,family,life,lake,farmers
# ----------
# Original: walk,road,walkers,route,people,day,miles,time,mountain,walking,path,local,countryside,national,north,loch,hills,park,left,hill,south,mountains,valley,car,village,water,public,top,days,access,country,traffic,land,track,climb,west,ridge,house,home,river,mile,set,views,walks,guide,glen,climbing,popular,town,cyclists,walker,centre,paths,line,commission,east,council,feet,snow,book,found,routes,summit,railway,main,coast,view,natural,head,visit,called,bridge,beautiful,easy,climbers,enjoy,built,summer,district,forest,past,sea,footpath,world,ramblers,nature,range,taking,wild,peak,half,pass,island,start,round,hotel,family,life,lake,farmers
# ====================================================================================================
# Infinity
# Smoothed: infinity,time,line,charge,field,god,potential,history,world,infinite,light,surface,set,star,form,equation,space,life,result,rate,difference,terms,charges,love,velocity,universe,woman,black,constant,electric,radius,left,energy,idea,distance,return,body,positive,ideas,experience,simple,hole,totality,model,people,process,infinitely,lines,shown,impossible,called,theory,escape,figure,guitar,period,means,due,finite,real,current,effect,makes,mind,system,day,art,distribution,origin,sense,human,found,concept,approaches,sequence,argument,knowledge,control,trajectories,round,meanings,meaningless,circle,vertical,moment,matter,past,music,produce,belief,close,rock,night,common,neck,individual,earth,directly,existence,read
# ----------
# Original: infinity,time,line,charge,field,god,potential,history,world,infinite,light,surface,set,star,form,equation,space,life,result,rate,difference,terms,charges,love,velocity,universe,woman,black,constant,electric,radius,left,energy,idea,distance,return,body,positive,ideas,experience,simple,hole,totality,model,people,process,infinitely,lines,shown,impossible,called,theory,escape,figure,guitar,period,means,due,finite,real,current,effect,makes,mind,system,day,art,distribution,origin,sense,human,found,concept,approaches,sequence,argument,knowledge,control,trajectories,round,meanings,meaningless,circle,vertical,moment,matter,past,music,produce,belief,close,rock,night,common,neck,individual,earth,directly,existence,read
# ====================================================================================================
# Idealistic
# Smoothed: people,world,war,time,political,children,life,love,social,set,nature,government,local,john,party,day,view,real,called,found,child,movement,public,book,community,power,means,change,action,home,form,question,national,country,reason,school,personal,experience,politics,left,century,family,society,father,matter,idea,age,relations,difficult,money,approach,sense,economic,students,business,leader,house,simply,history,feel,meeting,past,effect,service,parents,character,reality,education,true,ideas,street,person,future,hope,words,science,church,letters,trouble,strong,south,support,attitudes,ideal,system,policy,free,death,liberal,mind,read,care,romantic,established,centre,teachers,company,process,individual,material
# ----------
# Original: people,world,war,time,political,children,life,love,social,set,nature,government,local,john,party,day,view,real,called,found,child,movement,public,book,community,power,means,change,action,home,form,question,national,country,reason,school,personal,experience,politics,left,century,family,society,father,matter,idea,age,relations,difficult,money,approach,sense,economic,students,business,leader,house,simply,history,feel,meeting,past,effect,service,parents,character,reality,education,true,ideas,street,person,future,hope,words,science,church,letters,trouble,strong,south,support,attitudes,ideal,system,policy,free,death,liberal,mind,read,care,romantic,established,centre,teachers,company,process,individual,material
# ====================================================================================================
# Prevailing
# Smoothed: time,people,social,political,rate,conditions,market,life,government,women,system,world,children,economic,society,form,workers,labour,rates,power,education,public,cent,development,local,view,money,period,national,day,change,wind,war,policy,company,level,terms,school,price,family,effect,means,country,law,found,set,sense,individual,real,community,north,major,prevailing,countries,support,result,low,care,common,strong,days,practice,service,production,influence,evidence,capital,home,pay,south,house,culture,called,account,control,business,research,theory,values,question,water,health,future,unemployment,situation,party,cost,experience,basis,century,process,return,times,subject,information,management,approach,age,demand,movement
# ----------
# Original: time,people,social,political,rate,conditions,market,life,government,women,system,world,children,economic,society,form,workers,labour,rates,power,education,public,cent,development,local,view,money,period,national,day,change,wind,war,policy,company,level,terms,school,price,family,effect,means,country,law,found,set,sense,individual,real,community,north,major,prevailing,countries,support,result,low,care,common,strong,days,practice,service,production,influence,evidence,capital,home,pay,south,house,culture,called,account,control,business,research,theory,values,question,water,health,future,unemployment,situation,party,cost,experience,basis,century,process,return,times,subject,information,management,approach,age,demand,movement
# ====================================================================================================
# Resists
# Smoothed: time,resists,resist,water,world,child,social,nature,women,language,paradigm,materials,theory,form,light,people,developed,hair,woman,god,means,left,pride,buyer,history,glass,salesperson,process,chips,heart,life,children,position,person,white,set,chip,hand,john,book,desire,research,micrometres,methods,industry,material,power,soviet,execution,duty,act,sexual,sense,makes,market,negative,special,resistance,remove,human,anomalies,found,simply,natural,real,control,science,development,policy,difficult,pattern,mind,food,constable,public,term,war,ion,meeting,etching,level,law,objection,heat,crisis,night,exceeding,ideology,forms,free,read,texts,street,fine,claims,propositions,faith,living,results,positive
# ----------
# Original: time,resists,resist,water,world,child,social,nature,women,language,paradigm,materials,theory,form,light,people,developed,hair,woman,god,means,left,pride,buyer,history,glass,salesperson,process,chips,heart,life,children,position,person,white,set,chip,hand,john,book,desire,research,micrometres,methods,industry,material,power,soviet,duty,execution,act,sexual,sense,makes,market,negative,special,resistance,remove,human,anomalies,found,simply,natural,real,control,science,development,policy,difficult,pattern,mind,food,constable,public,term,war,ion,etching,meeting,level,law,objection,heat,crisis,exceeding,ideology,forms,free,read,texts,street,fine,claims,propositions,faith,living,results,positive,scale
# ====================================================================================================
# Foams
# Smoothed: foam,fire,water,cent,system,time,business,body,quality,filter,biological,products,play,cystitis,media,market,chemicals,control,values,main,effective,hath,sales,systems,calls,phone,bacteria,filtration,capable,degree,growth,performance,mouth,agents,lost,joint,pond,storage,action,gels,shower,requirements,war,sprays,flame,application,smoke,type,urethra,manager,circle,form,customers,strong,day,gases,foams,offers,life,scanning,government,house,carter,letters,expected,avoid,attack,lot,operations,linked,liquids,block,easy,black,instruments,apply,continue,limits,soap,home,low,fragrances,growing,conscious,moisturisers,cleansers,range,valued,sense,sourness,execution,camp,ideals,characters,spirits,existence,sour,wanton,aught,cynicism
# ----------
# Original: foam,fire,water,cent,system,time,business,body,quality,filter,biological,products,play,cystitis,media,market,chemicals,control,values,main,effective,hath,sales,systems,phone,calls,bacteria,filtration,capable,degree,growth,performance,mouth,agents,lost,joint,pond,storage,action,gels,shower,requirements,war,sprays,flame,application,smoke,type,urethra,manager,circle,form,customers,strong,day,gases,foams,offers,life,scanning,letters,carter,house,expected,avoid,attack,lot,operations,linked,liquids,block,easy,black,instruments,apply,continue,limits,soap,low,conscious,fragrances,cleansers,moisturisers,growing,range,fantastic,existence,aught,roaring,valued,motive,cynical,sense,friend,characters,armed,camp,sour,cynicism,sourness
# ====================================================================================================
# Tangent
# Smoothed: line,function,tangent,curve,angle,draw,components,circle,time,vector,length,straight,equation,file,lines,surface,fixed,form,distance,figure,equal,space,values,plane,called,degrees,coordinates,direction,sine,cosine,transformation,centre,waves,curves,axis,range,vertical,defined,metric,theorem,arc,strain,terms,drawn,result,obtained,radius,symmetry,slope,field,hand,mosaic,program,argument,similar,statement,set,solution,vertex,government,rate,spaces,power,free,system,single,stress,locally,curvature,byte,shown,count,circular,read,condition,continuous,angles,positive,printer,size,moment,top,forms,circles,means,helix,section,mark,local,found,coordinate,parabola,temperature,energy,computer,force,image,gravitational,change,phase
# ----------
# Original: line,function,tangent,curve,angle,draw,components,circle,time,vector,length,straight,equation,file,lines,surface,fixed,form,distance,figure,equal,space,values,plane,called,degrees,coordinates,direction,sine,cosine,transformation,centre,waves,curves,axis,range,vertical,defined,metric,theorem,arc,strain,terms,drawn,result,obtained,radius,symmetry,slope,field,hand,mosaic,program,argument,similar,statement,set,solution,vertex,rate,spaces,power,free,system,single,stress,locally,curvature,byte,shown,count,circular,read,condition,continuous,angles,positive,printer,size,moment,top,forms,circles,means,helix,section,mark,local,found,coordinate,parabola,temperature,energy,computer,force,image,gravitational,change,phase,suppose
# ====================================================================================================

# %% [markdown]
# Calculate the predicted probability that word $w_k$ is associated with $\textrm{text}_{j^\prime}$:
# $$
# \mathrm{P}(w_k \vert \textrm{text}_{j^\prime}) = \frac{1}{n_{j^\prime}} \sum_{i = 1}^{n_{j^\prime}} \mathrm{P}(w_k \vert w_{j^\prime i}).
# $$

# %%
predictions = {}
for text_name in memoranda:
    
    prime_words = texts_as_words[text_name]
    
    _predictions = numpy.zeros(len(vocabulary))
    for prime_word in prime_words:
        _predictions += get_conditional_probability(P, f, prime_word)
    
    _predictions /= len(prime_words)
    
    predictions[text_name] = dict(zip(vocabulary, _predictions))

# %% [markdown]
# View the predictions.

# %%
def print_topic(text_name, K=25):   
    return ','.join([w for w,_ in sorted(predictions[text_name].items(), 
                                         key=lambda value: value[1], 
                                         reverse=True)][:K])

# %%
for text_name in memoranda:
    print(memoranda[text_name]['text'])
    print('*'*10)
    print(print_topic(text_name, K=100))
    print('='*25)
# Out:
# ‘I don't know what I did without it’ is the sentiment. There is a difference
# between fully automatic washing machines — which change the nature of the task
# altogether — and ‘twin tub’ machines where the hot wet washing has to be
# lifted manually into a separate drying compartment. The women who had this type
# of machine complained about the considerable amount of work still required of
# the housewife, and the mess on the kitchen floor to be cleared up afterwards. In
# a similar way the launderette does not remove the physical drudgery of washing.
# The housewife has to get the washing there in the first place, she has to unload
# it, sort it, sit and watch it wash and dry (or dash out to shop in the interim)
# and then pack it all up again. This, when there is a baby in the pram and a two-
# or three-year-old to attend to, is no mean feat.
# **********
# time,people,day,women,home,life,house,water,children,found,left,world,looked,mother,hand,set,told,head,system,eyes,night,family,door,days,feel,woman,government,mind,money,round,machine,social,called,child,local,change,company,job,form,school,week,information,cent,hard,father,half,times,car,love,lot,top,body,white,baby,control,business,table,light,wife,housewife,washing,front,bed,power,care,hands,bit,party,black,line,service,hair,john,public,months,morning,held,start,moment,main,sort,person,leave,words,country,means,food,run,court,past,question,real,difficult,hours,support,road,war,national,idea,girl
# =========================
# Don Juan today has lost whatever sympathetic press the years of male domination
# gave him. Feminism and a greater acknowledged (though not necessarily practised)
# awareness of the equality and independence of sexual rights have becalmed the
# Don as a fool of time. Psychology has dissected him to death. AIDS has ousted
# him out of history. But there is little point, for instance, in turning on an
# artistic, enlightened medieval king because he also enjoyed slaughtering
# hundreds of deer in a day's hunt and daubing the fresh blood on his own face and
# those of his friends. Examples can be multiplied. To yank someone entirely out
# of their time and smack them around for not being of our time is perhaps a
# salutary but only a limited exercise. Yet the times have indeed changed: and
# Burton's early sexual insatiability, his later infidelities, his many women and
# his concurrent devotion to monogamy all need some explaining.
# **********
# time,people,women,life,world,day,found,social,government,home,children,left,family,house,set,political,told,system,local,party,power,hand,public,sexual,head,form,called,woman,days,school,country,looked,king,national,times,change,mother,history,father,war,society,death,mind,john,law,child,god,cent,book,night,love,money,feel,company,human,terms,sense,century,person,question,support,means,age,control,act,body,eyes,information,view,held,church,court,male,past,period,business,development,experience,real,major,words,week,black,position,half,evidence,subject,education,water,matter,idea,round,nature,common,effect,months,result,brought,process,difficult
# =========================
# When John Major talks of a ‘nation being at ease with itself’, which
# particular nation is he speaking about? Is he addressing his comments to all
# those who have become marginalised and dispossessed as a result of right-wing
# Conservative policies over the years? Or is he speaking about that nation of
# complacent and indifferent shopkeepers who long for nothing other than a return
# to the days of imperial hegemony? The shopkeeper as the centre around which the
# social world revolves is a commercial image hammered into English consciousness
# by Mrs Thatcher. Self reliance, individual enterprise, ‘what's in it for
# me’, as opposed to‘how can we help our neighbour’, was the message. This
# theology slipped over the iron hand of the capitalist market like a silk glove.
# England became one nation again, a land of hope and glory, Elgar, teacakes and
# cricket. This England is not one recognised by many of my friends.
# **********
# time,people,government,world,social,life,day,party,political,home,house,national,local,labour,left,found,system,public,power,women,set,war,country,economic,john,hand,cent,market,god,major,development,children,business,told,family,policy,form,support,company,head,society,looked,change,days,called,minister,money,school,land,view,class,night,terms,held,law,community,control,mind,means,times,question,sense,century,council,information,church,eyes,service,mother,position,education,past,south,history,future,international,week,period,real,process,united,father,round,act,words,feel,main,centre,west,body,trade,level,person,result,brought,industry,office,common,water,city
# =========================
# The form of animal husbandry adopted depends on the type of facilities available
# and the nature of the experiments. If an experiment produces animals that are to
# be kept for a long period, or that are to form the basis of a breeding colony,
# some form of barrier system is essential. If no precautions are taken to prevent
# infections it is inevitable that the health of the animals will deteriorate with
# a resulting decrease in breeding performance or death. A minimal barrier system
# requires people entering the animal area to remove their laboratory coats worn
# in other areas, and to put on protective  clothing. It is essential that they
# wash their hands thoroughly before handling the animals and the wearing of
# surgical gloves and a change of footwear or overshoes should be considered. A
# more stringent barrier includes the requirement for staff to shower on entering
# the unit and a complete change of clothes.
# **********
# time,people,system,life,found,world,day,government,water,form,children,set,home,information,local,animals,social,change,cent,left,house,women,health,control,public,company,family,head,patients,development,body,hand,care,school,national,effect,called,power,days,period,business,means,level,service,money,human,act,party,support,looked,told,research,staff,process,person,terms,country,major,result,times,animal,market,main,study,food,night,species,provide,eyes,law,difficult,range,view,common,light,evidence,services,child,including,age,months,question,feel,white,held,individual,mind,similar,words,political,mother,court,type,education,half,land,past,experience,black,nature
# =========================
# I then took her forward slightly to the evening after the operation, a time when
# she was fully awake and over the more drastic effects of the anaesthetic. I
# asked her how she felt now. To my surprise Kirsty burst into tears. No, she told
# me, she was not in any great pain — simply the discomfort she would have
# expected to follow surgery. She was not aware of feeling particularly ill. It
# was just that she knew that there was something seriously wrong with her —
# something far more dramatic than a grumbling appendix or the normal after-
# effects of an operation. Oh, the doctors and nurses had assured her again and
# again that she was fine and would soon be fit and well again. And yet, as she
# kept repeating, she was convinced that there was something that no one was
# telling her.
# **********
# time,people,day,life,home,told,found,left,looked,eyes,house,world,head,children,night,patients,hand,mother,feel,set,women,government,mind,days,family,hospital,health,door,care,father,system,local,woman,called,love,body,round,money,change,school,child,moment,information,voice,week,months,form,social,times,water,words,john,public,heard,pain,patient,hard,person,effect,cent,half,company,morning,party,god,bed,business,car,control,light,doctor,operation,past,country,hands,hours,lot,leave,treatment,service,held,difficult,idea,question,start,means,matter,sense,real,feeling,taking,experience,national,war,support,power,police,table,death,girl
# =========================
# It was mentioned above that overflow records arise singly. In addition, an
# embedded overflow area will usually contain varying numbers of records from
# several tracks. This leads to overflow records usually being stored in unblocked
# format, even if the records in the prime data area are blocked. There is some
# advantage in treating the whole embedded overflow area as a single large blocked
# record, and manufacturers' software often does transfer the whole track into
# main storage when an addition is to be made; this allows for the addition
# itself, creation of link fields, changes of index, etc. However, handling the
# whole track as a single block would prevent rapid transfer of individual records
# from the embedded overflow area during direct access reference, which is the
# reason this method is often not adopted (but see the section on software
# packages, p. 264).
# **********
# time,records,people,system,record,data,information,overflow,track,file,set,software,government,company,found,world,form,cent,systems,local,home,day,life,control,water,left,index,development,social,main,house,required,computer,business,section,market,times,public,process,support,provide,level,means,children,single,national,change,act,access,additions,terms,shown,party,held,added,power,effect,result,range,period,major,position,called,head,including,line,service,court,figure,key,research,school,individual,women,files,management,space,hand,view,services,half,run,based,money,country,prime,law,days,start,person,common,similar,question,road,family,provided,minister,field,words,evidence
# =========================
# Though innovation is a very positive term, it is important to remember that any
# particular innovation is only positive in retrospect, after it has worked. Before
# that, because change by definition is something no one has seen yet (despite
# models that may exist elsewhere), it has to be taken at least partially on
# faith. For example, why a continuing education program now? Why use funds to
# develop a new product when there are so many already on the market? Why take the
# risk of decentralizing the accounting office? In short, unless there is somebody
# behind the idea willing to take the risk of speaking up for it, the idea will
# evaporate and disappear. One reason there is so little change in most
# traditional bureaucratic organizations, I argue, is that they have conditioned
# out of people the willingness to stand up for a new idea. Instead, people learn
# to back off at the first sign that somebody might disapprove.
# **********
# time,people,government,life,world,social,system,change,local,market,day,public,children,found,education,information,set,company,school,development,form,women,business,political,home,power,cent,national,party,house,control,left,money,process,terms,support,means,view,management,idea,level,hand,told,research,question,family,policy,god,economic,person,called,effect,law,labour,act,country,society,major,service,risk,head,sense,experience,services,period,result,mind,community,real,difficult,individual,office,study,feel,care,days,provide,language,words,position,times,looked,future,child,main,health,training,product,water,financial,companies,held,common,industry,war,staff,human,past,subject,role
# =========================
# Some social scientists have conceptualised these workers in terms of a reserve
# army of labour. In this case, they would constitute a pool of labour which can
# be utilised in boom periods and disregarded in recessions. This view sees the
# experience of the Third world as being little different from that of the
# industrialised countries. The large numbers who are unable to find regular
# work are not seen as a phenomenon characteristic of underdevelopment, but part
# of the capitalist division of labour and, therefore, a similar feature to the
# industrialisation process of European countries, differing in terms of quantity
# rather than quality. For Marx, however, the function of the reserve army of
# labour was keeping wages low and, to this end, the absolute size of the reserve
# army need not be very great. The high numbers and continuing growth of this
# sector in Latin America would suggest that concepts of European analysis are not
# sufficient.
# **********
# time,people,labour,government,social,world,cent,party,system,economic,life,political,women,local,national,public,terms,development,market,found,form,countries,set,day,power,workers,children,country,change,war,level,information,policy,major,home,control,support,left,period,production,money,process,society,company,business,means,house,service,class,view,rate,growth,trade,education,family,industry,real,result,army,effect,school,law,research,act,question,services,economy,main,international,community,nature,experience,position,water,minister,industrial,times,individual,called,million,evidence,union,century,united,increase,sense,capital,study,provide,common,role,age,future,including,force,management,health,held,hand,south
# =========================
# In the case of time constant, a production worker tends to be focused on the
# production schedule for today or this week. An R&D worker is aware that what he
# does today will not affect company output in this order of time span. It may be
# months or years before his work today makes an impact: in the case of a project
# failure it may never do so. Words such as ‘hurriedly’ and ‘quickly’ are
# likely to be associated with different orders of time spans in the minds of the
# two people. Salesmen are probably in between these two. They have in some cases
# a weekly or monthly schedule of orders to win but the long-term relationship
# with their customer is also of great importance and the weight to be put on the
# two factors at any one time calls for the exercise of judgement.
# **********
# time,people,company,day,life,world,social,home,government,system,children,found,set,information,cent,business,local,left,house,form,women,production,money,change,family,week,market,public,control,told,development,days,person,school,support,act,power,service,national,hand,terms,level,period,means,head,party,labour,months,times,called,words,looked,management,workers,care,major,feel,country,question,mind,court,services,process,effect,political,job,night,policy,research,child,rate,staff,result,view,project,real,law,experience,office,john,body,cost,society,half,difficult,eyes,pay,past,future,main,health,including,individual,mother,community,age,position,price,sense,provide
# =========================
# In the afternoon, we have a rehearsal, but without the guests. I just walk
# through the basic moves so the cameras can plot where everybody's going to be,
# and we try to work out how long people will take to walk down the stairs so we
# can play the right amount of music. If they can make it, we like the guests to
# arrive before the audience starts to go in, so they can walk through it, too.
# Those steps  down to the set can be daunting — I think it's everybody's
# nightmare, stepping out and falling flat on your face. Dusty Springfield was
# wearing new shoes, with very high heels, and was terrified that she'd slip, so
# just before she was due to go on, one of the team was dispatched to look for
# some scissors to scratch the soles with. Oh, the glamour of it all.
# **********
# time,people,day,life,home,left,house,looked,world,head,night,found,set,told,door,hand,eyes,children,round,days,feel,called,mother,play,music,mind,money,week,john,top,school,family,front,father,water,woman,women,love,black,car,road,local,white,times,moment,government,half,company,light,hard,lot,voice,heard,morning,party,past,hands,team,bit,body,start,system,business,bed,feet,country,hair,change,public,walk,street,form,held,real,run,idea,line,words,leave,close,evening,person,position,child,short,taking,minutes,job,office,police,remember,main,table,girl,book,months,started,information,air,hours
# =========================
# My understanding of the law is that an adult patient who is capable of doing so
# must give consent to any medical treatment if that treatment is to be lawful. At
# the time of the decision the patient needs a capacity commensurate with the
# gravity of that decision. If the patient lacks the requisite capacity, then the
# doctors must act in what they perceive to be his or her best interests, with
# information garnered from previous knowledge of the patient, discussion with
# family and friends, and taking into account any relevant directive previously
# made by the patient. What the legal force and effect of any such directive might
# be is uncertain; it is unclear whether health care staff are required to carry
# out the terms of the directive or whether those who act in good faith with the
# terms of the directive are immune from civil or criminal prosecution. There is,
# apparently, no case law on this point.
# **********
# time,people,law,patient,court,act,patients,government,life,information,health,social,care,treatment,children,public,system,person,found,day,company,local,world,home,terms,national,set,family,house,form,women,decision,authority,question,power,service,community,effect,evidence,section,party,child,business,control,support,directive,services,cent,hospital,legal,view,left,staff,change,action,means,development,council,political,school,medical,held,matter,told,result,period,practice,process,policy,education,level,study,individual,country,subject,common,required,provide,police,days,position,experience,body,hand,major,society,money,months,called,research,knowledge,age,nature,words,report,sense,reason,mind,including,market
# =========================
# The bones are bound to each other by tough, flexible ligaments and are
# articulated at the joints by muscles. There are just over 600 voluntary muscles
# in the human body. For our purposes, it is only necessary to mention the larger,
# superficial muscle groups which affect the shape of the body and are responsible
# for the movement of the limbs. These are referred to as skeletal muscles, most
# of which are attached at both ends to bones. The muscles that give expression to
# the face are also referred to as skeletal muscles, and they link bone to skin. A
# whole complex system of muscles is brought into play for each movement of the
# body: bending an arm involves the shortening of the biceps, while the tricep
# muscles at the back of the arm must relax and lengthen in unison. Meanwhile,
# others immobilise joints not needed in the action, while others still adjust to
# stabilize the body's equilibrium.
# **********
# time,people,body,muscles,head,life,found,day,system,hand,eyes,left,world,form,government,set,looked,water,home,feel,social,women,children,house,arm,local,human,muscle,exercise,times,development,information,position,told,mind,control,called,change,night,power,hands,level,effect,public,round,party,means,hard,cent,days,light,action,person,act,family,arms,movement,national,main,leg,money,top,front,line,political,process,held,words,company,half,result,support,bones,moment,woman,real,difficult,question,training,close,period,skin,major,sense,school,law,move,cells,child,bone,similar,black,door,terms,white,business,view,start,figure,common
# =========================
# The extent to which subject coverage on the shelves can be achieved is a matter
# of library policy, funding, the amount of shelf space available, and the
# efficiency of interlending systems to which the authority has recourse. These
# influences are considered in more detail in Chapter 12. The case for immediate
# shelf representation in a public library is made at some length by Ranganathan,
# in his fourth library law —‘save the time of the reader’. ‘Mental hunger
# for books is not compelling in the case of most people. Mental thirst for
# information is not inexorable in the case of most people. Both of them are
# fleeting in their nature. They both die out, unless satisfied immediately on
# their taking shape. No time lag should come between demand and supply. The tempo
# for reading is often momentary. It should be harnessed at the very moment.’
# **********
# time,people,life,government,information,world,system,public,local,library,day,found,social,children,set,house,home,law,form,book,left,school,money,books,national,women,party,hand,act,company,cent,change,development,head,power,terms,political,policy,business,control,subject,looked,level,services,words,question,service,mind,court,told,means,education,research,care,person,support,called,family,major,view,health,market,water,eyes,process,country,child,times,days,effect,authority,sense,real,staff,community,labour,period,matter,evidence,body,main,study,feel,experience,held,provide,section,individual,difficult,war,society,position,night,result,action,past,council,language,systems,god
# =========================
# In Ordinary Justice the National Consumer Council were scathingly critical of
# such court proceedings which in practice, they said, became a rubber stamp. The
# documents the court sent out were difficult to understand and no guidance was
# given on completing it. The ‘defendant’ was not asked about his personal
# circumstances. The Civil Justice Review found that a third of banks and building
# societies, and a fifth of local authorities, did not enquire about the debtor's
# circumstances before the hearing. Three quarters of local authorities did not
# follow up the Department of Environment's advice and carry out checks to see if
# the tenant was receiving the right benefits. Sixty-seven per cent of creditors
# had no knowledge of the debtor's financial state at the time of the original
# transaction, and 77 per cent did not obtain any further information before or
# during the proceedings.
# **********
# time,court,people,government,local,act,cent,law,information,company,public,party,system,social,business,house,children,service,life,day,council,national,set,money,found,home,world,form,person,section,authority,evidence,services,action,terms,power,bank,development,support,family,held,left,question,market,care,appeal,period,legal,education,political,authorities,women,pay,decision,country,school,control,child,office,policy,effect,health,report,debtor,property,proceedings,society,view,means,costs,told,change,provide,subject,days,practice,community,matter,police,financial,minister,major,including,process,level,called,tax,result,position,months,application,million,committee,land,labour,building,staff,required,management,economic
# =========================
# The Dickens study tells us that not every dismissed employee eligible to claim
# unfair dismissal does so. Only about one in ten of those eligible to claim
# actually does so. Among those who apply there is a greater tendency to bring
# unfair dismissal proceedings where the employer is a small single establishment
# employer with below average unionization. Nearly half of all applications are
# against employers with fewer than 20 employees. The larger the employer, the
# less likely it is that there will be an unfair dismissal claim. There are a
# number of possible explanations for this pattern of application. Larger
# employers are likely to have internal appeals procedures and failure there,
# where union representation may have been provided, is the point at which the
# employee draws the line. Employees may feel a sense of powerlessness in taking
# on a large organization or it may be that advisers are more reluctant to take on
# large organizations.
# **********
# time,people,government,court,company,social,cent,system,act,local,employer,party,employee,business,employment,women,life,information,law,public,national,world,labour,found,union,set,terms,children,day,form,house,employees,contract,pay,political,job,home,power,period,service,workers,support,trade,claim,development,person,change,action,left,question,policy,council,control,market,school,dismissal,staff,management,money,education,held,position,level,section,effect,means,family,result,view,employers,country,major,evidence,services,provide,decision,economic,days,minister,process,tax,appeal,industrial,week,authority,society,health,community,individual,subject,office,told,rights,hand,reason,care,called,age,training,study
# =========================
# Our terms of reference suggested that we should consider drama in the context of
# the great dramatic works of literature. We believe that plays should be
# approached through the dramatic medium; children should often see or participate
# in the play being acted, and not just read the text. This approach will not only
# result in an appreciation of the literary merits, but also foster an
# understanding of stagecraft. There is still an important place within drama
# activity for the exploration and study of scripted plays, and we addressed this
# aspect in our statements of attainment and programmes of study. At primary
# level, the range of material for exploration needs to be more diverse: myth,
# legend, fairy stories, poems. At secondary level, such work can expand naturally
# into the exploration of dramatic texts. Children's own writing can also be
# explored — at both levels — through the medium of drama.
# **********
# time,people,children,world,life,school,social,language,found,information,government,set,education,form,system,day,study,local,level,drama,play,women,development,terms,public,book,home,child,national,family,cent,experience,house,left,change,company,schools,political,john,words,view,research,sense,history,process,role,means,major,subject,business,act,called,teachers,writing,question,range,power,support,period,control,effect,text,age,hand,real,society,country,read,pupils,evidence,approach,told,individual,music,party,students,times,training,care,provide,stage,difficult,main,class,nature,human,production,community,story,war,programme,person,knowledge,including,head,days,written,result,mind,material
# =========================
# Activity 1 (15–20 mins): Identify a small group of clients, such as the first six
# people you saw in your last day's community care, the first six people attending
# your outpatients' clinic, or six individuals in a bay in your ward. For each
# client, list the nursing interventions either by yourself or someone else, such
# as ‘insulin injection’, ‘mouth care’, ‘socialisation’, ‘health
# promotion’, that each required in the fist hour of care, say between eight and
# nine, or nine and 10 in the morning. You should end up with at least six
# separate lists, some with perhaps only one item on it, others with several
# items, listed in the order that each client received, or was assisted with, that
# care. Are there any items common to several, or all, of the clients? Did they
# receive similar care at the same time or in the same order?
# **********
# time,people,care,social,health,patients,home,day,children,local,services,life,information,community,found,government,service,system,client,family,set,hospital,house,women,world,left,public,support,staff,company,cent,child,form,person,money,school,business,development,told,control,patient,change,study,hand,act,national,days,clients,head,provide,individual,practice,party,research,treatment,terms,looked,education,court,age,level,week,management,society,process,means,times,feel,night,law,training,authority,called,list,major,market,report,months,mother,difficult,including,period,policy,effect,experience,country,question,office,main,items,involved,action,evidence,power,body,words,held,result,view,common
# =========================
# Once again that requirement to get on with people, clients, account executives
# and the creative teams is basic to your daily work. Just how does cooperation
# between a planner and the creative team work? After all, creative people are
# supposed to be sensitive and aware of the consumer and society and in real touch
# with change and mood. Let's take an example of the planner and creative team
# together. Trying to devise the strategy for a lager campaign, the planner found
# out through the research that the key benefit consumers looked for in lager was
# refreshment — incidentally something no other beer advertiser mentioned. The
# creative team took this new insight and used it as a spring-board to create a
# very successful campaign based on sprouting leaves and the headline: "Refreshes
# the parts other beers cannot reach" , thus demonstrating the imaginative leap
# creative people make from research findings to effect communication messages.
# **********
# time,people,world,life,day,government,information,research,social,found,home,set,local,company,public,system,children,business,team,house,cent,national,market,left,women,development,school,change,form,money,party,service,support,major,head,told,terms,country,process,experience,real,called,society,means,family,hand,days,power,mind,person,times,level,services,john,book,political,education,week,looked,view,care,control,community,feel,job,act,individual,night,labour,management,sense,question,idea,council,effect,study,provide,staff,health,account,main,period,action,water,words,play,industry,result,past,future,policy,difficult,war,including,language,office,law,training,half,position
# =========================
# While many of these may be social occasions, work groups especially in large
# companies may often stay on late to participate in quality control circles or
# zero defect clubs. There are up to four million quality control circle
# participants in Japanese industry and in large companies two in five workers are
# members. Quality consciousness is said to be very high among Japanese workers
# who endeavour to eliminate components that are rejected as substandard. Each
# smaller work group attempts to perform better than their rival groups in both
# quality control and in the number of suggestions they offer to improve
# productivity. Workplace harmony is enhanced by communal sports clubs, company
# vacation resorts, one-class cafeterias and the absence of status barriers within
# the plant. There is an hierarchical structure, but managerial authority is
# respected as a benign guardian of company interests. Corporate identification
# with workers knowing their place is in short "a managers Nirvana".
# **********
# time,people,company,government,social,world,system,local,life,cent,control,business,day,public,information,management,set,workers,market,women,found,national,development,power,children,home,companies,labour,quality,form,party,service,house,political,industry,support,services,level,change,major,left,school,terms,million,money,family,act,education,country,staff,process,means,economic,policy,health,care,community,research,authority,provide,society,view,training,called,law,individual,council,trade,days,times,hand,period,experience,result,position,person,week,including,job,main,class,effect,future,production,court,held,water,head,question,told,action,union,involved,sense,cost,john,role,international,real,based
# =========================
# While it would be unlikely for a firm contractual commitment to be made which
# binds a record company to produce a promotional video, it is a matter of fact
# that a promotional video will be produced to support an artist's first single.
# With limited production costs, this video would fall into the £15,000 to
# £30,000 range, as opposed to the six-figure costs incurred by the established
# major artists. The cost of the promotional video for a developing artist would
# be recoupable against both audio and video income received by the record
# company. The income to pay these video costs is usually minimal with new
# artists, so these expenses are often set against future video exploitation. This
# is income which increases as the artist gains greater success and begins to
# release such items as compilation videos comprising selected promotional videos,
# or full length videos of live concert performances.
# **********
# time,people,video,company,world,government,cent,set,system,costs,life,information,business,market,local,income,day,home,public,art,national,money,tax,cost,social,found,children,form,house,support,women,major,party,development,service,record,court,school,companies,terms,million,family,including,act,pay,left,music,production,period,level,control,power,country,services,means,book,price,week,john,change,range,rate,called,effect,provide,future,days,language,management,labour,main,times,real,policy,staff,industry,view,society,person,artist,sales,result,programme,training,artists,law,total,political,question,process,individual,economic,trade,months,based,subject,material,held,position,hand
# =========================
# Despite the challenges associated with building up large-scale production, the
# Japanese are forging ahead in display technology — and for very good reasons.
# Obviously the straightforward replacement of bulky cathode ray tubes with flat
# panel display leads to significant power and weight reductions as exemplified in
# the commercialisation of laptop computers. The most strategically important
# reason for investing in flat panel display technology, however, is that with
# continued miniaturisation of the integrated circuits the display itself will
# become the platform on which the system is built. This raises the prospect of
# fully integrated systems for which the sourcing of individual components such as
# drivers, memory chips and processors on the world market would no longer be an
# issue. Countries with such a display manufacturing capability would dominate the
# market and effectively eliminate competition based on older technology made up
# from discrete components.
# **********
# time,people,system,world,market,company,government,information,systems,set,development,local,cent,business,life,day,power,social,technology,found,form,control,computer,public,left,children,home,national,industry,data,change,house,support,major,level,process,research,management,production,service,country,party,political,called,money,software,companies,terms,means,economic,main,range,labour,school,including,provide,water,women,future,services,hand,view,based,cost,policy,times,result,million,line,effect,head,countries,education,position,question,price,design,family,international,war,products,week,period,days,individual,single,john,product,car,real,top,run,office,told,society,half,quality,difficult,staff,community
# =========================
# Though less visible, it was export competition in goods and services which had a
# more fundamental effect on UK towns and cities. The internal economic geography
# of the UK has been reworked over a century by fundamental change in the nature
# and orientation of exports, which has reflected the success of individual
# industries and their factories. This demonstrates the principal changes so far this
# century in the composition of export goods. In 1900, the country was still
# largely dependent on exports of textiles, metals and coal, whereas by 1987
# nearly half the country's exports were accounted for by ‘machinery and
# transport equipment’ and chemicals. The impact of North Sea oil on the
# structure of the balance of payments may actually have reduced the absolute
# volume of manufacturing exports. This is because it raised the real sterling
# exchange rate, rendering ‘marginal’ manufacturing exports uncompetitive. We
# shall return to this issue at several points later in this volume.
# **********
# time,people,cent,government,world,market,trade,economic,industry,social,system,million,country,local,company,national,rate,development,public,life,countries,labour,business,major,set,political,found,change,power,day,production,party,level,period,form,policy,century,services,growth,terms,foreign,information,companies,service,money,exports,increase,home,house,women,war,control,total,support,economy,international,effect,oil,price,north,cost,minister,main,water,children,left,industrial,means,south,result,process,including,investment,west,exchange,half,manufacturing,rates,united,times,view,capital,society,council,real,community,position,called,law,family,increased,tax,figure,bank,research,future,school,population,provide,workers
# =========================
# As far as the Royal Navy were concerned the nuisance of excessive leakage was
# largely put a stop to when Sir Robert Seppings (1764–1840) introduced diagonal
# iron bracing into wooden hulls about 1830. Seppings, who used to say ‘partial
# strength produces general weakness’, seems to have been one of the first Naval
# Architects to have a clear mental picture of the stress systems in a ship's
# hull. In the merchant service wooden hulls were to a considerable extent
# replaced by composite and iron and steel construction after the middle of the
# century. A number of wooden ships continued to be built without adequate shear
# bracing, however, and such ships got more leaky as they got older, until, in an
# age when most of the pumping was done by hand, it became uneconomic to run them
# any longer. Up till 1914 Norwegian shipowners were still making money by buying
# up British sailing ships and running them with windmill pumps.
# **********
# time,people,day,world,water,life,government,house,found,left,system,home,local,company,set,war,form,head,hand,looked,public,children,service,money,john,century,power,called,told,days,cent,ships,business,family,social,national,country,built,sir,night,eyes,school,women,information,sea,building,round,line,half,market,times,act,control,development,change,party,north,main,major,held,support,door,ship,top,father,period,road,body,south,air,age,light,mind,land,level,run,services,royal,church,office,means,health,including,position,trade,white,view,terms,past,result,city,week,west,labour,law,political,real,court,hard,effect
# =========================
# Clear out all your possessions and be ruthless. Now is the time to take rubbish
# to the dump, to give things away to charity shops and jumble sales. There is no
# point in taking all your useless rubbish with you. Also clear up the garden. You
# are not supposed to leave rubbish behind for the next occupants to cope with,
# although you can leave it bagged up outside the door for the dustmen to take
# later. If you are leaving the area do not forget to pick up any clothes that are
# at the cleaners, or shoes, clocks, or other items that are away being mended.
# You will also need to withdraw sufficient cash from the bank to pay for the
# removal. It is common practice to tip the people who have done the removal work
# so you may want to withdraw enough for this too.
# **********
# time,people,day,house,home,life,left,found,world,told,government,looked,money,children,head,set,hand,local,company,eyes,door,night,business,days,family,women,mother,water,called,bank,feel,mind,school,cent,round,party,car,father,country,public,system,week,market,child,woman,half,police,leave,lot,pay,john,social,times,hard,power,court,held,change,form,office,person,information,top,moment,love,national,war,service,months,council,act,job,black,support,front,road,past,care,light,means,street,control,morning,body,heard,white,real,words,matter,book,close,idea,main,start,bit,law,question,hands,run,voice
# =========================
# Individual goals may well be in conflict with organisational goals even where
# there is a strong commitment to one goal by the organisation. It is worth
# repeating that there may also be competing goals within the organisation itself.
# Thus, for example, the prison service may wish to pursue the twin goals of the
# punishment of offenders  and at the same time their rehabilitation. These two
# goals may prove to be incompatible and yet each will have its supporters. Within
# the National Health Service there may well be a commitment to provide the best
# possible medical care that the state of medical knowledge will allow and yet
# this may be tempered by the requirement to act within tight financial
# constraints. The two goals may be in conflict. Many organisations will face the
# problem of which goals to prioritise in the light of competing goals.
# **********
# time,people,government,social,goals,home,world,local,health,service,life,system,public,care,national,goal,set,children,information,day,political,power,party,management,services,act,support,team,form,development,education,control,change,business,company,united,found,left,school,organisation,community,individual,law,women,policy,cent,staff,game,terms,court,family,person,means,level,authority,process,money,house,training,major,society,provide,season,labour,child,view,research,country,half,week,experience,john,manager,economic,action,market,cup,minutes,international,question,result,play,hand,involved,night,position,days,club,league,role,times,difficult,war,council,told,practice,future,approach,period,head
# =========================
# On 25 July 1985 the dock company put in a planning application for the
# construction of a Roll on — Roll off (‘Ro-Ro’) terminal in the River
# Medway. Permission was refused, there was an appeal and an inquiry by an
# inspector whose recommendations the Secretary of State for the Environment
# accepted. The appeal was dismissed. The main consideration was undoubtedly the
# increase in heavy goods vehicles that would be generated by the new development
# and the consequent increase in noise levels, in particular night-time levels in
# Medway Road and Bridge Road. These environmental objections were considered to
# be serious enough to outweigh the economic benefits of allowing the proposal. It
# was this development and in particular the evidence given at the Ro-Ro inquiry
# which in due course prompted the council to bring the present proceedings. In
# March 1988 the council passed the necessary resolution and the writ was issued
# on 20 July 1988.
# **********
# time,people,government,court,local,council,company,public,development,house,system,cent,party,day,act,national,world,set,found,information,home,social,life,road,law,children,left,power,appeal,service,support,minister,business,evidence,report,planning,country,form,political,police,held,committee,economic,action,control,school,policy,authority,money,major,market,level,change,decision,water,told,called,education,labour,secretary,question,million,office,terms,section,view,period,main,effect,family,services,head,health,women,including,days,land,meeting,result,community,john,car,means,march,war,hand,matter,months,future,times,increase,process,person,industry,position,provide,application,international,management,research
# =========================
# At the start of the exercise, the actual procedure was checked against a
# conceptual model that included the activities deemed necessary to achieve the
# agreed transformation. If the changes revealed by this comparison have not been
# made prior to the audit commencing, this could be the reason for the failure to
# meet the target levels of attainment. If, however, the procedure does comply
# with the procedure description derived earlier, then it will be necessary to
# subject each element or activity of the model to further scrutiny, for example
# by breaking them down to lower-order activities, or by auditing each element in
# the same manner as the parent procedure. This process is similar to work study
# exercises where measurable elements of a task are identified before the actual
# measurement takes place, and consideration is given to the resources required at
# each level, including the skills and experience of the operator.
# **********
# time,people,system,information,government,set,social,form,children,life,company,local,world,found,public,level,process,development,act,day,terms,school,cent,control,court,law,change,study,national,business,education,house,power,means,subject,effect,party,management,left,period,home,person,model,service,view,child,experience,language,support,question,women,research,section,evidence,required,provide,political,report,data,patients,practice,market,result,individual,major,services,training,policy,position,action,staff,called,money,approach,words,family,care,main,hand,range,involved,community,procedure,based,difficult,common,health,analysis,including,body,similar,times,sense,results,council,knowledge,society,role,authority,country
# =========================
# The Knights of the Blazing Sun were created after the Battle of Magritta in 1457
# during the crusades which eventually freed the land of Estalia from the Arabian
# invaders. The battle was a great victory for the Knights of the Old World, made
# all the remarkable by a strange and prophetic occurrence. During fierce street
# fighting around the temple of Myrmidia, the warrior goddess of Estalia, a group
# of knights found themselves surrounded by the dreaded Black Guard led by Emir
# Wasr the Cruel. Just as the Arabians closed in a sudden earth tremor shook the
# temple, dislodging a huge bronze statue of the goddess which plummeted to the
# street below crushing the Emir and many of his troops. The event was to prove
# the turning point of the battle. Afterwards, the surviving knights established
# the Order of the Blazing Sun with Myrmidia as its patron and protector.
# **********
# time,people,world,day,life,found,left,king,head,house,war,eyes,looked,home,government,told,hand,god,night,set,john,days,called,century,family,women,black,round,father,mother,church,children,power,death,land,party,water,country,local,held,city,army,white,door,street,woman,sun,form,times,mind,public,lord,light,north,love,moment,political,money,body,sir,half,brought,past,south,road,court,system,battle,close,national,company,heard,late,feel,words,hands,front,hard,west,lost,voice,period,school,support,town,temple,book,son,control,major,business,royal,week,social,sense,line,change,top,child,stood
# =========================
# The answer to the first, or ‘why’, question begins with a recognition that
# banks are private sector, profit-making organisations with obligations to
# shareholders to increase profits over time. Thus they will always be looking for
# ways of expanding their balance sheets provided this leads to extra profit. Look
# again at Table 3.3 which shows the aggregate balance sheet of a large number of
# banks. Notice that assets are composed of various forms of lending: to the
# personal sector, the commercial sector, the government or the Bank of England.
# The liabilities side is dominated by deposits. Notice also that we can express
# any class of asset as a proportion of total assets or liabilities and remember
# too that in section 1.1.5 we said that these ratios are arrived at as a matter
# of deliberate choice and are assumed to represent portfolio equilibrium.
# **********
# time,people,government,company,bank,cent,market,money,business,public,banks,world,system,local,rate,life,set,assets,social,information,financial,act,form,national,day,companies,found,level,capital,million,party,period,terms,house,sector,change,price,tax,service,effect,private,development,services,home,law,total,policy,demand,cost,economic,power,control,question,increase,left,women,labour,children,major,court,section,investment,share,means,political,country,income,account,rates,held,management,result,position,support,shares,future,industry,provide,person,net,balance,view,table,real,main,class,hand,pay,school,costs,family,process,society,education,called,international,foreign,months,individual,trade
# =========================
# Using the golfing tips he gleaned from such fine players, Andy soon had his
# handicap down to two. He was by then an assistant pro in its fullest sense, so
# he decided to try his hand at playing tournaments. Although he qualified for a
# few regional events, in fact he was aiming much higher: he wanted a crack at the
# Open Championship. So in 1973 Andy decided to try and qualify for the Open at
# Royal Troon — and it was here that an incident occurred that changed his
# career. He had played the first round, but before he had a chance even to hit a
# ball in the second he was out of the pre-qualifier, suffering from injuries he
# had received in a car accident with his caddie. Swallowing hard on the
# disappointment, Andy spent the next few years taking even more blows on the
# chin.
# **********
# ...
# =========================
# She'd been convinced all along that eventually she must lose him, that Marianne
# was right — some other attraction must inevitably draw him away. She hadn't
# changed her mind about that — a man such as Dane would always attract
# beautiful women, and Shannon could never hope to compete. But would the pain of
# losing him be any the less simply because she'd managed to hold him at bay?
# Eventually, probably sooner rather than later, he'd grow tired of waiting for
# Shannon, and then she'd be left with nothing, in any case. Though she could
# never let him know it, he already possessed her heart; if she were to give
# herself to him body and soul, at least the memories would be rich and ultimately
# fulfilling. Right now all she'd have to look back on would be frustration and
# longing suppressed by fear.
# **********
# time,people,life,day,world,women,home,left,found,house,looked,eyes,told,head,hand,children,night,mind,love,government,feel,set,body,mother,family,days,door,father,god,woman,money,round,called,water,local,moment,power,social,party,school,hard,light,change,public,times,voice,past,week,company,business,country,system,child,form,john,war,black,half,sense,person,hands,words,car,lot,held,idea,real,white,heart,heard,death,lost,question,means,experience,matter,top,leave,cent,road,book,control,close,political,hope,bit,national,job,brought,line,view,play,difficult,morning,months,start,support,front,taking,bed
# =========================
# There can be no doubt that for many women fear of loss is built into us by the
# way we've been reared. As children we may have been made to feel inadequate,
# silly or useless because we were never praised. In adult life, some may be
# submissive and ingratiating, expecting to be in the wrong, expecting to be
# discarded and unwanted. And surprise, surprise, they get just that sort of
# treatment. The only way to stop it happening, and therefore to stop the fear of
# it, is to develop self-esteem. Learn to be assertive, stand up for yourself and
# your own value. That way people will see you as even more lovable. That is what
# I mean by making fear your friend. If you are subject to these irrational fears,
# then use that fear as a trigger to change your attitude. It could revolutionise
# your life.
# **********
# time,people,life,children,women,day,world,home,found,house,looked,told,left,feel,head,government,eyes,child,hand,family,mother,mind,social,love,set,school,night,woman,change,fear,person,father,days,money,called,system,local,door,round,public,god,body,moment,control,party,power,sense,times,business,country,past,care,parents,hard,words,voice,friend,form,john,real,cent,war,information,difficult,lot,means,company,water,question,experience,week,support,idea,education,age,job,book,matter,sort,view,half,hands,heard,national,political,months,black,death,police,car,start,reason,bit,light,feeling,talk,wrong,leave,act,play
# =========================
# The prime document for EC statistics is now the VAT return. All who are engaged
# in intra-EC trade must now show thereon the total value of all goods dispatched
# to other EC customers and received from other EC suppliers in the special boxes
# provided on the return form. Where either category has exceeded £135,000 during
# 1992 further, more detailed information has to be submitted within the very
# strict time limit of ten working days after each month end. Known as the
# Intrastat system, the data can be submitted by a computerised medium but only if
# it meets Customs specification requirements and has prior approval. Specific
# details relating to each consignment are required but values and quantities may
# be aggregated where all other details are identical. Up to ten items of coded
# information are required comprising such details as the commodity reference of
# the goods, delivery terms, weight, method of transport and, for arrivals, the
# country of origin.
# **********
# time,people,information,government,system,company,cent,set,world,day,form,local,business,found,life,public,data,party,social,market,national,terms,house,home,children,service,act,court,development,law,left,change,country,control,period,days,minister,support,services,money,major,level,including,process,held,school,section,power,required,means,provide,women,trade,price,effect,person,office,political,research,policy,called,council,report,question,main,times,cost,subject,family,systems,special,rate,million,view,management,result,economic,total,range,water,education,labour,position,months,week,companies,individual,staff,evidence,study,tax,told,provided,hand,contract,society,book,based,figure,international
# =========================
# Back home, the observation would have been no less apt. In the years leading up
# to the First World War the Hooligan embarked on a remarkable career, appearing
# in name if not in person before numerous governmental and semi-official bodies
# of enquiry. He loomed large in the apocalyptic discourse surrounding the fears
# of racial decline and physical inefficiency. He figured centrally in the
# Edwardian era's deliberations on the ‘boy labour’ question. He would crop up
# repeatedly in the anxious preoccupation with the demoralising influence of
# popular amusements, the collapse of ‘fair play’ sportsmanship, and the
# allegations of excessive ‘freedom’and ‘affluence’ that were levelled
# against the young. The name of the Hooligan, in fact, provided a crystallising
# focus for any number of overlapping anxieties associated with imperial decline,
# military incapacity, the erosion of social discipline and moral authority, the
# eclipse of family life, and what was feared to be the death rattle of ‘Old
# England’.
# **********
# time,people,government,world,life,social,day,home,political,public,children,local,party,war,found,family,house,national,women,set,left,power,system,labour,cent,school,form,country,law,support,economic,told,change,society,act,development,terms,head,major,hand,century,days,called,times,company,education,question,information,control,period,john,policy,view,person,court,business,sense,police,means,money,looked,child,authority,night,service,level,evidence,mind,held,council,death,age,market,black,book,history,real,result,father,mother,play,past,community,position,main,process,action,experience,minister,west,body,effect,feel,care,matter,human,eyes,services,united,common
# =========================
# In fact, as I soon discovered, these ruins are inhabited. I met the old lady as
# I was walking down a steep path out of the village. She was struggling up, bent
# under a heavy sack. We greeted each other. The skin of her face hung in purple
# folds and the old eyes were blurred with cataract. When I offered to carry her
# sack she waved me aside. Who was this impertinent stranger eyeing her baggage?
# We moved on up to her tumbledown tower on the last crag of the village. At the
# base was a terrace with one stool on it. Before us stretched an enormous view of
# mountain, promontory and shimmering sea. From my pack I offered her an apple,
# the only food I had. She dismissed it with a regal gesture. Then I saw her
# toothless gums. I left her in peace with her bundle, her stool and her majestic
# view.
# **********
# time,people,day,left,looked,house,eyes,head,life,found,hand,world,home,told,night,round,door,children,water,set,days,called,road,mother,mind,father,white,woman,black,family,light,moment,government,voice,body,village,top,hands,women,feel,local,heard,front,half,money,love,car,past,times,hard,school,country,john,stood,week,morning,held,war,feet,party,table,dark,air,close,food,view,company,south,sea,north,bed,leave,business,sat,church,hair,line,child,god,bit,brought,girl,town,sir,system,street,taking,lot,main,words,form,public,inside,coming,late,city,moved,real,months,idea
# =========================
# Such integration can be largely formal; in Lesotho, for instance, the evidence
# of real integration in between Mathematics and Science is very slight. On the
# other hand it may represent a genuine attempt by specialists in related subjects
# to sit down together and plan a programme which allows for separate activities
# but suggests common themes and provides examples of integrated lessons as in the
# Nigerian Cultural and Creative Art syllabus. Yet again it may be the product of
# basic rethinking and true integration founded on new objectives and a fresh
# approach as in the Social Studies syllabus now under development in Sierra Leone
# where an integrated programme with significant regional variations is being
# planned in a series of central and local workshops and where a special series of
# booklets on skills development (e.g. map making, note taking skills, creative
# skills) is being produced for teachers.
# **********
# time,people,social,government,school,development,local,system,world,information,education,children,life,set,national,found,form,day,public,research,women,level,study,language,political,cent,support,teachers,change,company,business,schools,process,training,home,community,programme,management,terms,students,major,economic,market,subject,control,art,experience,party,house,staff,left,policy,skills,power,society,service,means,provide,services,country,approach,view,head,individual,range,family,main,book,evidence,history,studies,care,common,teaching,including,period,question,hand,pupils,based,called,knowledge,council,health,systems,special,data,central,practice,sense,class,science,labour,role,real,involved,project,effect,child,result
# =========================
# Regarding access to health care, we meet the fact that women usually live longer
# than men. This is one area of life in which women have a definite advantage! It
# would appear that access to the health service is reasonably equitable between
# men and women, and that women's longer lives should not be attributed to
# prejudice against men in the health sector! However, some writers have suggested
# that the diseases commonly found among men are treated with greater concern and
# more expensive medical treatment than those more commonly found among women. For
# instance, attention has recently been drawn to the inadequate provision of
# screening for cervical cancer despite the fact that this service could provide
# the means of identifying early forms of the disease before it reaches its
# incurable and lethal stage. (More discussion of women and health can be found in
# chapter 9, section 9.5.)
# **********
# women,time,people,health,life,social,children,patients,care,government,found,world,local,service,day,public,home,cent,system,information,family,services,age,form,set,house,national,disease,act,treatment,education,support,development,school,left,community,study,child,company,control,change,person,research,means,money,terms,court,law,hospital,evidence,woman,power,society,political,told,business,party,effect,level,provide,major,labour,question,view,period,common,country,medical,days,section,called,human,authority,staff,cancer,process,times,result,experience,hand,policy,report,body,difficult,market,head,water,feel,including,main,individual,mother,subject,practice,position,role,private,months,book,sense
# =========================
# The Dinner or Luncheon Party: Whatever time of day it is, this is most likely to
# mean inviting a group of people over for a ‘sit-down’ meal. The grandness of
# the meal, and how much of it you pay for, depends upon the expectations of
# yourself and your guests and perhaps their relationship to you. If, say, you are
# a young person — student or worker — who has invited over friends of the
# same age, they will probably expect to bring a bottle of wine with them. In
# fact, most friends, of any age, would bring a bottle of something — unless the
# dinner party was very grand. Relatives often seem to feel that they do not need
# to bring a contribution, unless, of course, you are young, living alone for the
# first time and being visited by your mother, in which case she will probably
# bring a month's supply of food and wash up for you as well!
# **********
# time,people,day,life,home,party,house,children,world,left,found,told,mother,government,family,looked,women,social,night,money,set,head,days,person,local,school,hand,father,feel,eyes,age,food,cent,called,water,week,child,mind,care,country,friends,love,john,support,round,labour,national,company,business,public,woman,change,system,times,door,table,held,service,information,lot,half,form,months,evening,war,friend,past,morning,hard,political,wife,job,moment,real,office,car,power,white,question,leave,court,act,parents,body,means,pay,god,bed,brought,idea,talk,bit,black,wine,taking,book,sense,major,health,living
# =========================
# The implementation of care management in April could rapidly illustrate how the
# admirable intentions of the government's community care policy might founder on
# the unintended consequences of more powerful forces and contradictions. Firstly,
# although the transfer of social security funds will allow more needs driven
# services, it will also cash limit expenditure. Secondly, this transfer punishes
# local authorities with few residential care homes and cuts off money for future
# expansion. Thirdly, the directive that care managers should not themselves give
# direct care runs counter to the core of good social work practice and creates a
# new corps of care administrators, thereby reducing the number of staff available
# to give direct care. Fourthly, no central guidance has emerged on how to
# coordinate at the local level, care management, the care programme approach, and
# hospital discharge procedures, thus inviting triplication of planning effort.
# **********
# people,time,care,government,local,social,services,health,system,children,community,public,home,cent,service,world,life,national,development,information,management,day,policy,support,set,company,staff,money,control,act,education,business,family,found,political,party,house,form,authority,women,change,school,power,market,court,council,level,authorities,law,major,provide,terms,child,left,economic,labour,research,country,training,process,society,means,practice,hospital,private,person,view,future,individual,report,programme,action,result,effect,war,planning,main,minister,approach,period,central,question,patients,million,role,including,financial,told,involved,days,office,cost,workers,position,called,held,hand,pay,difficult,provided
# =========================
# It was a great discovery. But it was utterly disastrous for classical physics.
# An electron encircling a nucleus is continuously subject to acceleration as its
# velocity keeps on changing direction. (Acceleration is just the rate of change
# of velocity.) It is an inexorable consequence of classical physics that such an
# accelerating electron radiates off some of its energy at a frequency
# corresponding to the frequency of the electron's circulation. This causes the
# electron to move closer to the nucleus and changes the frequency. The radiation
# loss continues. In other words, a classical "solar system" atom under
# electromagnetic forces is nothing like the actual solar system held together by
# gravitational forces. The atom would be unstable, as its electrons spiralled
# ever closer to the nucleus, and it would emit its dying radiation in a band of
# frequencies with no trace of discreteness. The nuclear atom dealt
# the coup de grâce to classical physics.
# **********
# time,energy,people,system,world,found,electron,theory,light,government,form,life,called,power,change,rate,set,physics,electrons,nuclear,field,cent,effect,day,information,left,particles,force,times,water,position,terms,matter,figure,control,black,level,radiation,result,quantum,means,social,range,local,research,science,mass,atom,development,atoms,body,forces,period,frequency,process,party,shown,house,line,study,national,surface,nucleus,earth,hand,single,similar,children,subject,evidence,space,words,section,low,major,money,public,view,political,head,home,nature,century,real,war,million,results,structure,human,data,women,cells,classical,school,main,idea,sun,patients,law,question
# =========================

# %% [markdown]
# Calculate the predictions for the experimental stimuli in the recognition test and also for the recalled words.

# %%
cooccurrence_predictions = {}
for text_name in memoranda:
    
    _, n = text_name.split('_')
    n = int(n)+1
    
    inwords = memoranda[text_name]['inwords'].split(',')
    outwords = memoranda[text_name]['outwords'].split(',')
    
    for word in inwords+outwords+recalled_words:
        
        try:

            prob = predictions[text_name][word]
            cooccurrence_predictions[str(n) + '-' + word] = prob
            
        except KeyError:
            
            print('Unknown word in text %s: "%s"' % (text_name,word))

cooccurrence_statistics_pkl = cache_fullpath('word_associates_from_cooccurrence_statistics.pkl')

with open(cooccurrence_statistics_pkl, 'wb') as f:
    pickle.dump(cooccurrence_predictions, f, protocol=2)    

assert utils.checksum(cooccurrence_statistics_pkl)\
    == 'efbcb9bae13142296ed164335313f69e380ec49811e885ce3bc4351a10cd2889'
# Out:
# Unknown word in text text_22: "dhow"

# %% [markdown]
# ## Create csv file with predictions for recalled words
#
# Here, we'll create a special file for use with the multionomial logistic regression modelling of the recall memory results. This file is a $J \times V^\prime + 1$ matrix, written as a csv file, where $J$ is the number of texts and $V^\prime$ is the set of recalled words, across all participants, that are also in the training corpus vocabulary.
#
# See `posterior-predictive-distributions` notebook for more details. There, an identical procedure is followed.

# %%
predictive_probabilities = []
text_names = sorted(predictions.keys(), key=lambda arg: int(arg.split('_')[1]))
for text_name in text_names:
    f = []
    for word in recalled_words:
        f.append(predictions[text_name][word])
    predictive_probabilities.append(f)

predictive_probabilities = numpy.array(predictive_probabilities)

predictive_probabilities = numpy.c_[predictive_probabilities, 1-predictive_probabilities.sum(1)]

header = ','.join(recalled_words + ['ALTERNATIVE_WORD'])

M = [header]
for i,f in enumerate(predictive_probabilities):
    M.append(text_names[i] + ',' + ','.join(map(str, f)))
M = '\n'.join(M)
    
cooccurrences_predictions_of_recalled_words = 'cooccurrences_predictions_of_recalled_words.csv'

with open(cache_fullpath(cooccurrences_predictions_of_recalled_words), 'w') as f:
    f.write(M)

# Verify the integrity of the exported csv file.
assert utils.checksum(cache_fullpath(cooccurrences_predictions_of_recalled_words))\
     == 'ae0b2e17fb6b800aa304a6990e1a6cfb5f6bd815ad4749828955dc96651e907c'
