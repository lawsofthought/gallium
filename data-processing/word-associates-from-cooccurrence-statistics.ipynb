# %% [markdown]
# # Predicted Word Associates of Texts, based on Word Cooccurrence Statistics
#
# Here, we will calculate the predicted word associates of the texts that are used in our text memory experiment. These predictions can be used to test a word association account of text memory, where word associations are defined in terms of cooccurrence statistics in the language.
#
# $$
# \newcommand{\data}{\mathcal{D}}
# \newcommand{\Prob}[1]{\mathrm{P}( #1 )}
# \newcommand{\given}{\vert}
# $$
#
# For this, we need to calculate
# $$
# \Prob{w_k \given w_l} \triangleq \frac{ \Prob{w_k,w_l} }{\Prob{w_l}},
# $$
# which is the empirical probability of observing word $w_k$ in some linguistic context, e.g., a short text, given that we've observed $w_l$ there. This is calculated as follows. First, we calculate $\Prob{w_k, w_l \given \textrm{text}=j}$, or the joint (empirical) probability of finding word $w_k$ and word $w_l$ in a given text $j$. If text $j$ has $n_j$ words, then
# there are $n_j (n_j - 1)$ ordered word pairs in total in text $j$. If there are $n_{jk}$ and $n_{jl}$ occurrences of words $w_k$ and $w_l$, respectively, when $w_k \neq w_l$,  there are $n_{jk} n_{jl}$ pairs containing the words $w_k$ and $w_l$. When $w_k = w_l$, there are $n_{jk} (n_{jl}-1)$ word pairs that are of words $w_k$ and $w_l$.
# From this,
# $$
# \mathrm{P}(w_k,w_l \given \textrm{text}=j) = \frac{n_{jk} (n_{jl} - \mathbb{I}(k = l))}{n_j (n_j-1)},
# $$
# where $\mathbb{I}(k = l)$ takes the value of 1 whenever $w_k = w_l$, and 0 otherwise. Consequently,
# averaging over all $J$ texts, we have
# $$
# \mathrm{P}(w_k,w_l) =\frac{1}{J} \sum_{j=1}^J \mathrm{P}(w_k,w_l \given \textrm{text}=j),
# $$
# and so from this, we may easily calculate $\Prob{w_k \given w_l} = \tfrac{ \Prob{w_k,w_l} }{\Prob{w_l}}$.
#
# Having calculated $\Prob{w_k \given w_l}$, given a text
# $$
# \textrm{text}_{j^\prime} \triangleq w_{j^\prime 1}, w_{j^\prime 2} \ldots w_{j^\prime n_{j^\prime}},
# $$
# the predicted probability that word $w_k$ is associated with $\textrm{text}_{j^\prime}$ is
# $$
# \mathrm{P}(w_k \vert \textrm{text}_{j^\prime}) = \frac{1}{n_{j^\prime}} \sum_{i = 1}^{n_{j^\prime}} \mathrm{P}(w_k \vert w_{j^\prime i}).
# $$

# %% [markdown]
# ## Preface
#
# This notebook requires some existing datasets, and will create a new dataset, see below. Some of the sparse matrix calculates are relatively intensive, but it will execute all cells completely in about 2-3 minutes.

# %%
from __future__ import division

# Standard library imports
import os
import pickle

# Third party imports
import pandas
import configobj
import numpy
from scipy.sparse import coo_matrix, csc_matrix, lil_matrix
from gustav.utils import SparseCountMatrix

# Local imports
from utils import utils, datautils

# %% [markdown]
# ## Check required files
#
# Check the integrity of required data files.

# %%
cache_directory = '../cache'
cache_fullpath = lambda path: os.path.join(cache_directory, path)

filenames = {
    'experiment_cfg' : [('Brismo.cfg',
                         '909d9f8de483c4547f26fb4c34b91e12908ab5c144e065dc0fe6c1504b1f22c9')],
    'text-corpus' : [('bnc_texts_78723408_250_500.txt.bz2', 
                      'dd8806f51088f7c8ad6c1c9bfadb6680c44bc5fd411e52970ea9c63596c83d34')],
    'vocabulary' : [('bnc_vocab_49328.txt',
                     '55737507ea9a2c18d26b81c0a446c074c6b8c72dedfa782c763161593e6e3b97')],
    'recall_results' : [('brisbane_06b643a_recall_results.pkl',
                         'a94d812373123b9a8b1eac848276e8ffc6a563ebca71ff2bf5adc97c825cbc14')]
}

utils.verify_cache_files(filenames['experiment_cfg'] +\
                         filenames['text-corpus'] +\
                         filenames['vocabulary'], 
           cache=cache_directory,
           verbose=False)

# bunzip the text-corpus
utils.bunzip(filenames['text-corpus'][0][0], cache=cache_directory)

# %% [markdown]
# ## Process the data:
#
# * Get the text stimuli that were used in the experiment
# * Get the corpus vocabulary as a Vocab object instance
# * Convert each text stimuli into a bag of words
# * Read in the experiment recall results
# * Find the recalled words that are also in the corpus vocabulary

# %%
memoranda = configobj.ConfigObj(cache_fullpath(filenames['experiment_cfg'][0][0]))['text_memoranda']

text_filename = cache_fullpath(os.path.splitext(filenames['text-corpus'][0][0])[0])

vocabulary_filename = cache_fullpath(filenames['vocabulary'][0][0])

vocabulary = open(vocabulary_filename).read().split()
vocab = datautils.Vocab(vocabulary)

text_to_words = lambda text: [word for word in datautils.tokenize(text) if word in vocab.word2index]

texts_as_words = {}
for text_name in memoranda:
    texts_as_words[text_name] = text_to_words(memoranda[text_name]['text'])

Df = {}
Df['recall'] = pandas.read_pickle(cache_fullpath('brisbane_06b643a_recall_results.pkl'))

recalled_words = sorted(set(Df['recall']['word'].values).intersection(vocabulary))

# %% [markdown]
# ## Make sparse matrix of document-word counts
#
# The following calculates a $J \times V$ sparse matrix $R$, where
# $$
# R_{jk} \triangleq \text{frequency of term $k$ in text $j$}.
# $$

# %%
#sparse_count_matrix_filename = 'bnc_78723408_250_500_vocab49328_sparse_matrix_count'

sparse_count_matrix = SparseCountMatrix.new(text_filename = text_filename,
                                            vocabulary_filename = vocabulary_filename)

# Create a coo sparse matrix
#sparse_count_matrix = numpy.load(cache_fullpath(sparse_count_matrix_filename) + '.npz')

R = coo_matrix((sparse_count_matrix['values'], 
                (sparse_count_matrix['rows'], sparse_count_matrix['cols'])), 
               shape=(sparse_count_matrix['J'], sparse_count_matrix['V'])).tolil()

# %% [markdown]
# We will compute a $J \times V$ matrix $S$ such that
# $$
# S_{jk} = \frac{n_{jk}}{n_j (n_j-1)}.
# $$
#
#
# For $w_k \neq w_l$, we can calculate $\Prob{P}(w_k, w_l)$ as follows:
# $$
# \begin{aligned}
# \mathrm{P}(w_k,w_l) &= \frac{1}{J} \sum_{j=1}^J \frac{n_{jk} n_{jl}}{n_j (n_j-1)},\\
#                     &= \frac{1}{J} \sum_{j=1}^J S_{jk} R_{jl}.
# \end{aligned}
# $$
#
# However, whenever $w_k = w_l$,
# $$
# \begin{aligned}
# \mathrm{P}(w_k,w_l) &= \frac{1}{J} \sum_{j=1}^J \frac{n_{jk} (n_{jl} - 1)}{n_j (n_j-1)},\\
#                     &= \frac{1}{J} \left( \sum_{j=1}^J S_{jk} R_{jl} - \sum_{j=1}^J S_{jk} \right)
# \end{aligned}
# $$

# %%
def get_joint_prob(R):
    
    J, V = R.shape 

    Rj = R.sum(1).A.flatten()

    z = Rj * (Rj - 1)

    Z = lil_matrix((J,J))

    Z.setdiag(1/z)

    S = (R.T * Z ).T 

    C = S.T * R 

    C.setdiag(C.diagonal() - S.sum(0).A.flatten())
    
    return C/J 

def get_conditional_prob(P):

    Pz = P.sum(1).A.flatten()
    
    Z = lil_matrix(P.shape)
    
    Z.setdiag(1/Pz)
    
    return (P.T * Z).T

# %%
P = get_joint_prob(R)

# %%
C = get_conditional_prob(P)

# %%
f = P.sum(0).A.flatten()

# %% [markdown]
# Here, we add an optional "smoothing" feature such that if the observed counts $R_{kl}$ are 0, we replaced the predicted probability $\Prob{w_k\given w_l}$, which will necessarily be 0.0, by $\Prob{w_k}$. In other words, this gives *back-off* model for the zero counts. The main purpose and benefit of this is to ensure that all zero count bigrams are given a reasonable nonzero estimate, and the values of zero would cause trouble in analysis when we need to calculate logarithms.

# %%
def get_conditional_probability(C, f, word, smooth=True):
    
    '''
    Return probability of cooccurrence given word `word`.
    `f` is unigram frequency of word
    '''
    
    j = vocab.word2index[word]
    
    Rj = C[j].A.flatten()
    
    p = Rj/Rj.sum()
        
    if smooth:
        I = Rj == 0
        p[I] = f[I] # Where observed cooccurrence is 0, use unigram frequency instewad
    
    return p/p.sum()

# %% [markdown]
# Do some sanity checks, by checking the cooccurrences of randomly chosen words.

# %%
def check_some_words(K, N, seed):
    random = numpy.random.RandomState(seed)
    
    for k in random.permutation(P.shape[0])[:K]:
        
        word_k = vocab.index2word[k]
        
        smoothed_associates = ','.join([vocab.index2word[i] 
                                        for i in numpy.flipud(numpy.argsort(get_conditional_probability(C, f, word_k)))[:N]])
        
        original_associates = ','.join([vocab.index2word[i] 
                                        for i in numpy.flipud(numpy.argsort(get_conditional_probability(C, f, word_k, smooth=False)))[:N]])
    
    
        print(vocab.index2word[k].capitalize())
        print('Smoothed: ' + smoothed_associates)
        print('-'*10)
        print('Original: ' + original_associates)
        print('='*100)

check_some_words(25, 100, 1001)
# Out:
# Loans
# Smoothed: loans,bank,banks,cent,loan,credit,government,money,million,rate,people,market,rates,debt,company,time,financial,capital,finance,tax,foreign,business,world,countries,income,companies,national,economic,pay,cash,billion,funds,cost,assets,lending,fund,investment,period,system,mortgage,students,deposits,total,international,property,support,local,paid,development,months,amount,payments,social,house,increase,building,exchange,agreement,scheme,country,trade,private,terms,account,public,set,policy,services,home,grants,provide,student,major,repayment,customers,borrowing,minister,commercial,security,demand,education,form,shares,institutions,accounts,main,costs,aid,fixed,discount,march,including,price,firms,budget,economy,provided,borrowers,banking,act
# ----------
# Original: loans,bank,banks,cent,loan,credit,government,money,million,rate,people,market,rates,debt,company,time,financial,capital,finance,tax,foreign,business,world,countries,income,companies,national,economic,pay,cash,billion,funds,cost,assets,lending,fund,investment,period,system,mortgage,students,deposits,total,international,property,support,local,paid,development,months,amount,payments,social,house,increase,building,exchange,agreement,scheme,country,trade,private,terms,account,public,set,policy,services,home,grants,provide,student,major,repayment,customers,borrowing,minister,commercial,security,demand,education,form,shares,institutions,accounts,main,costs,aid,fixed,discount,march,including,price,firms,budget,economy,provided,borrowers,banking,act
# ====================================================================================================
# Radioactive
# Smoothed: nuclear,waste,radioactive,dumping,power,radiation,time,sea,fuel,energy,people,plant,reactor,report,site,government,research,environmental,water,material,uranium,radioactivity,accident,public,world,industry,health,found,environment,atomic,earth,million,safety,times,countries,soviet,cent,plutonium,house,produced,fire,levels,activity,convention,result,factory,amount,released,system,international,damage,reactors,contamination,effects,dose,dump,information,days,caused,cancer,materials,told,dust,left,stations,protein,ban,level,food,pollution,reprocessing,drew,total,decay,station,cells,human,local,process,disposal,surface,dating,low,life,dangerous,figure,discharges,risk,sites,scientists,period,meeting,isotope,called,body,gas,expected,home,exposure,workers
# ----------
# Original: nuclear,waste,radioactive,dumping,power,radiation,time,sea,fuel,energy,people,plant,reactor,report,site,government,research,environmental,water,material,uranium,radioactivity,accident,public,world,industry,health,found,environment,atomic,earth,million,safety,times,countries,soviet,cent,plutonium,house,produced,fire,levels,activity,convention,result,factory,amount,released,system,international,damage,reactors,contamination,effects,dose,dump,information,days,caused,cancer,materials,told,dust,left,stations,protein,ban,level,food,pollution,reprocessing,drew,total,decay,station,cells,human,local,process,disposal,surface,dating,low,life,dangerous,figure,discharges,risk,sites,scientists,period,meeting,isotope,called,body,gas,expected,home,exposure,workers
# ====================================================================================================
# Puckish
# Smoothed: time,king,country,sense,told,people,eyes,life,seat,odd,war,remember,school,looked,voice,spirit,met,book,south,youth,hair,social,son,stop,mirror,hit,house,mouth,army,visit,final,land,balance,victim,start,disease,fine,news,national,meeting,sound,times,table,world,run,leave,secretary,talk,live,minor,hostels,view,love,neck,pleased,hope,started,found,pleasure,treatment,set,clean,brother,quietly,died,thrilled,office,closed,act,head,pulled,rest,discuss,fall,health,struck,solo,nature,oboe,barber,hear,string,favour,dance,family,movement,association,wooden,sensitive,ship,masts,peter,experience,recording,composer,notes,intense,red,called,children
# ----------
# Original: time,king,country,sense,told,people,eyes,life,seat,odd,war,remember,school,looked,voice,spirit,met,book,south,youth,hair,social,son,mirror,hit,stop,house,mouth,visit,army,final,land,balance,victim,start,disease,fine,news,national,meeting,sound,times,table,world,run,leave,secretary,talk,live,minor,hostels,view,love,pleased,neck,hope,started,found,pleasure,treatment,set,clean,quietly,brother,died,thrilled,office,head,rest,act,closed,pulled,fall,discuss,health,struck,nature,solo,oboe,favour,string,barber,hear,dance,family,movement,association,sensitive,wooden,masts,ship,peter,experience,notes,recording,composer,intense,red,called,basil
# ====================================================================================================
# Palled
# Smoothed: time,mother,list,church,father,day,home,people,school,coffin,street,night,linen,car,white,head,family,women,girl,house,blue,morning,week,finally,story,type,bit,million,front,names,hours,north,officers,job,produced,water,wee,days,middle,body,times,lid,short,sea,left,friend,girls,visit,sheet,overboard,government,police,door,found,brother,passage,granny,nice,encouraged,sat,operation,hair,decided,heard,age,feel,shown,choice,suddenly,hard,life,support,received,started,music,john,daily,route,canal,sick,view,united,feeling,friends,enamelled,manuscripts,tor,abbey,gold,bed,shop,majority,leaving,dad,hubby,west,purpose,bad,dead,road
# ----------
# Original: time,mother,list,church,father,day,home,people,school,coffin,street,night,linen,car,white,head,family,women,girl,house,blue,morning,week,finally,story,type,bit,million,front,names,hours,north,officers,job,produced,water,wee,days,middle,body,times,lid,short,sea,left,friend,girls,visit,sheet,overboard,police,door,found,brother,passage,granny,nice,encouraged,sat,operation,hair,decided,heard,age,feel,shown,choice,suddenly,hard,life,support,received,started,music,john,daily,canal,route,sick,view,united,feeling,friends,gold,enamelled,tor,abbey,manuscripts,bed,shop,majority,leaving,hubby,dad,west,purpose,bad,dead,road,faith
# ====================================================================================================
# Oracle
# Smoothed: oracle,database,software,system,systems,data,information,company,lifespan,applications,development,computer,users,relational,time,access,user,market,server,quarter,support,application,windows,version,technology,sun,databases,run,environment,adventurers,product,set,management,running,business,tools,products,claims,file,customers,week,network,test,manager,sales,distributed,months,standard,interface,central,performance,object,marketing,service,including,offer,services,licence,research,world,graphical,revenues,power,architecture,president,operating,companies,client,prices,versions,change,release,designed,based,include,team,international,hardware,firm,expected,director,figures,provide,project,local,environments,top,play,disk,machines,mainframe,account,processing,transfer,operation,left,includes,net,provided,people
# ----------
# Original: oracle,database,software,system,systems,data,information,company,lifespan,applications,development,computer,users,relational,time,access,user,market,server,quarter,support,application,windows,version,technology,sun,databases,run,environment,adventurers,product,set,management,running,business,tools,products,claims,file,customers,week,network,test,manager,sales,distributed,months,standard,interface,central,performance,object,marketing,service,including,offer,services,licence,research,world,graphical,revenues,power,architecture,president,operating,companies,client,prices,versions,change,release,designed,based,include,team,international,hardware,firm,expected,director,figures,provide,project,local,environments,top,play,disk,machines,mainframe,account,processing,transfer,operation,left,includes,net,provided,people
# ====================================================================================================
# Reconstructing
# Smoothed: time,history,world,system,museum,garden,common,building,social,people,church,language,million,century,power,life,half,house,original,clock,ballet,image,nature,evidence,idea,historical,party,period,country,found,constitution,wonderful,pottery,written,similar,evolution,natural,information,road,columns,terms,attention,called,report,major,developed,left,record,features,main,study,john,north,modern,west,development,theory,behaviour,castle,understanding,change,government,based,remains,key,national,labour,times,languages,account,minister,family,progress,rules,writing,species,act,coin,train,painting,figure,foreign,section,decided,book,action,result,landscape,fossil,south,cent,attempt,process,perspective,provided,son,office,provide,middle,economic
# ----------
# Original: time,history,world,system,museum,garden,common,building,social,people,church,language,million,century,power,life,half,house,original,clock,ballet,image,nature,evidence,idea,historical,party,period,country,found,constitution,wonderful,pottery,written,similar,evolution,natural,information,road,columns,terms,attention,called,report,major,developed,left,record,features,main,study,john,north,modern,west,development,theory,behaviour,castle,understanding,change,government,based,remains,key,national,labour,times,languages,account,minister,family,progress,rules,writing,species,act,coin,train,painting,figure,foreign,section,decided,book,action,result,landscape,fossil,south,cent,attempt,process,perspective,provided,son,office,provide,middle,economic
# ====================================================================================================
# Events
# Smoothed: events,time,people,world,life,event,day,social,history,information,government,children,found,local,political,war,national,party,set,home,major,public,past,support,change,system,experience,god,period,house,effect,family,days,future,women,sense,school,view,form,book,held,evidence,left,control,times,person,called,terms,question,power,involved,country,international,police,child,including,story,meeting,development,study,individual,night,council,centre,idea,process,action,mind,death,told,main,months,john,result,role,special,money,society,means,mental,programme,matter,nature,level,true,week,series,policy,human,provide,south,hand,situation,research,knowledge,feel,account,staff,club,news
# ----------
# Original: events,time,people,world,life,event,day,social,history,information,government,children,found,local,political,war,national,party,set,home,major,public,past,support,change,system,experience,god,period,house,effect,family,days,future,women,sense,school,view,form,book,held,evidence,left,control,times,person,called,terms,question,power,involved,country,international,police,child,including,story,meeting,development,study,individual,night,council,centre,idea,process,action,mind,death,told,main,months,john,result,role,special,money,society,means,mental,programme,matter,nature,level,true,week,series,policy,human,provide,south,hand,situation,research,knowledge,feel,account,staff,club,news
# ====================================================================================================
# Jailers
# Smoothed: time,people,officers,police,hundred,prison,magistrates,accept,church,looked,jail,makes,pounds,thousand,told,meet,life,offenders,staff,hours,headmaster,taking,real,abused,attitude,half,fines,table,plate,day,stay,smile,inside,eyes,evening,aware,savage,hand,wrong,prisoners,clerk,woman,mother,house,transferred,guy,killed,period,star,change,marriage,god,ran,suddenly,town,lightly,simply,mayor,law,wiped,include,sentenced,cups,pastries,wine,officer,papers,happen,keen,called,imprisonment,boy,information,joined,father,dead,world,shrugged,collar,hands,agony,breakdowns,split,specialist,hurt,concern,majority,easily,annoyed,sex,unsuitable,fourteen,pressure,regime,mates,school,sessions,straight,affected,disgust
# ----------
# Original: time,people,officers,police,hundred,prison,magistrates,accept,church,looked,jail,makes,pounds,thousand,told,meet,life,offenders,staff,hours,headmaster,attitude,abused,real,taking,half,fines,table,plate,day,stay,smile,inside,eyes,evening,aware,savage,hand,wrong,prisoners,clerk,woman,mother,house,transferred,guy,killed,period,star,change,marriage,god,ran,suddenly,mayor,lightly,simply,town,wiped,law,sentenced,include,pastries,wine,cups,officer,papers,happen,keen,called,imprisonment,boy,information,joined,father,dead,collar,hands,shrugged,agony,fourteen,unsuitable,sessions,offences,school,mates,affected,majority,wing,person,prove,sex,easily,unit,peoples,quarter,regime,friendship,hurt,split
# ====================================================================================================
# Cadged
# Smoothed: sir,fish,aircraft,day,white,brown,head,found,bought,time,attack,apparently,police,determined,pay,school,told,die,bombs,morning,brought,home,fire,farm,argue,sergeant,business,close,statement,talk,cell,tom,read,misunderstanding,translator,lightly,car,bit,round,night,direct,bomb,island,escaped,hurricanes,survived,reported,hurricane,ship,coming,ice,mullet,suppliers,building,wood,reporters,meant,bad,approaching,hold,sick,god,evening,bill,afternoon,idea,leaves,hit,moved,court,vanished,delivered,sea,passes,ride,suddenly,workmates,lagers,money,taxi,clothes,manager,shirt,pissed,stinking,wallet,uniform,track,world,bridge,trees,limestone,dales,gill,water,air,magnificent,late,trade,properly
# ----------
# Original: sir,fish,aircraft,day,white,brown,head,found,bought,time,attack,apparently,police,determined,pay,school,told,die,bombs,morning,brought,home,fire,farm,argue,sergeant,business,close,cell,talk,statement,read,lightly,translator,tom,misunderstanding,car,bit,round,night,direct,survived,ship,hurricane,hurricanes,escaped,island,reported,bomb,coming,suppliers,ice,mullet,building,wood,reporters,meant,bad,approaching,sick,god,evening,hold,afternoon,bill,idea,leaves,moved,hit,vanished,court,delivered,sea,passes,suddenly,ride,taxi,wallet,manager,clothes,pissed,uniform,workmates,money,lagers,shirt,stinking,world,track,limestone,trees,bridge,dales,gill,air,late,water,magnificent,properly,trade
# ====================================================================================================
# Delectable
# Smoothed: time,chocolate,eyes,love,mind,traditionally,treat,voice,rich,government,left,night,day,feel,road,sat,looked,sound,life,town,slice,church,eat,table,fresh,idea,lips,world,house,meal,deep,evening,people,called,beef,found,mouth,music,cake,head,food,delectable,delicious,woman,told,truffles,guests,fine,wife,perfect,round,inside,light,fingers,blue,cent,main,lay,arm,red,peter,fruit,effort,range,beginning,housework,understand,movement,heaven,short,butter,sit,door,assortment,path,days,bit,valley,moment,feeling,body,half,bed,sister,square,flavour,sense,white,moved,selection,simply,home,top,tea,towns,added,south,war,filled,cream
# ----------
# Original: time,chocolate,eyes,love,mind,traditionally,treat,voice,rich,left,night,day,feel,road,sat,looked,sound,life,town,slice,church,eat,table,fresh,idea,lips,world,house,meal,deep,evening,people,called,beef,found,mouth,music,cake,head,food,delectable,delicious,woman,told,truffles,guests,fine,wife,perfect,round,inside,light,fingers,blue,main,lay,arm,red,peter,fruit,effort,range,beginning,housework,understand,movement,heaven,short,butter,sit,door,assortment,path,days,bit,valley,moment,feeling,body,half,bed,sister,square,flavour,sense,white,moved,selection,simply,home,top,tea,towns,added,south,war,filled,cream,smooth,fat
# ====================================================================================================
# Dragged
# Smoothed: time,eyes,head,looked,people,door,night,hand,left,day,told,life,found,house,round,home,hands,car,voice,feet,heard,police,mother,moment,body,world,bed,mind,woman,water,hair,called,girl,light,stood,arms,love,mouth,front,road,father,hard,set,black,days,suddenly,sat,arm,floor,held,god,words,half,morning,dead,children,women,war,brought,feel,air,hear,top,leave,dark,white,happened,fell,caught,lot,inside,bit,stop,death,dragged,family,moved,started,times,stopped,close,matter,ground,lost,coming,forward,minutes,wall,john,run,table,street,past,pulled,taking,talk,rest,ran,friend,cold
# ----------
# Original: time,eyes,head,looked,people,door,night,hand,left,day,told,life,found,house,round,home,hands,car,voice,feet,heard,police,mother,moment,body,world,bed,mind,woman,water,hair,called,girl,light,stood,arms,love,mouth,front,road,father,hard,set,black,days,suddenly,sat,arm,floor,held,god,words,half,morning,dead,children,women,war,brought,feel,air,hear,top,leave,dark,white,happened,fell,caught,lot,inside,bit,stop,death,dragged,family,moved,started,times,stopped,close,matter,ground,lost,coming,forward,minutes,wall,john,run,table,street,past,pulled,taking,talk,rest,ran,friend,cold
# ====================================================================================================
# Widespread
# Smoothed: government,people,time,party,social,political,cent,world,local,public,support,national,system,labour,economic,found,women,life,minister,development,country,major,war,century,evidence,control,power,police,children,population,period,change,education,form,policy,common,report,law,community,north,including,result,species,countries,view,day,set,late,held,family,terms,health,times,society,level,central,opposition,research,workers,million,human,land,council,united,west,age,widespread,effect,main,foreign,south,information,international,industry,trade,similar,led,march,home,president,reported,act,union,action,recent,northern,difficult,means,market,water,individual,study,house,left,provide,military,called,growth,process,forces
# ----------
# Original: government,people,time,party,social,political,cent,world,local,public,support,national,system,labour,economic,found,women,life,minister,development,country,major,war,century,evidence,control,power,police,children,population,period,change,education,form,policy,common,report,law,community,north,including,result,species,countries,view,day,set,late,held,family,terms,health,times,society,level,central,opposition,research,workers,million,human,land,council,united,west,age,widespread,effect,main,foreign,south,information,international,industry,trade,similar,led,march,home,president,reported,act,union,action,recent,northern,difficult,means,market,water,individual,study,house,left,provide,military,called,growth,process,forces
# ====================================================================================================
# Contentions
# Smoothed: court,appeal,evidence,time,plaintiffs,section,defendant,house,people,act,law,public,argument,decision,society,social,matter,issue,view,child,police,person,words,steed,reason,effect,claims,employment,information,knowledge,matters,found,world,political,reference,material,lord,church,question,life,context,lordships,building,notice,decide,experience,documents,judge,conclusion,trial,parliament,form,children,report,contended,circumstances,past,support,review,proceedings,critical,power,leave,claim,historical,cent,modern,article,family,accepted,party,authority,taxpayer,practice,god,held,appellant,behalf,purpose,parliamentary,doubt,applied,original,called,government,meaning,treatment,truth,period,authorities,events,word,argued,background,contention,financial,common,development,nature,fair
# ----------
# Original: court,appeal,evidence,time,plaintiffs,section,defendant,house,people,act,law,public,argument,decision,society,social,matter,issue,view,child,police,person,words,steed,reason,effect,claims,employment,information,knowledge,matters,found,world,political,reference,material,lord,church,question,life,context,lordships,building,notice,decide,experience,documents,judge,conclusion,trial,parliament,form,children,report,contended,circumstances,past,support,review,proceedings,critical,power,leave,claim,historical,cent,modern,article,family,accepted,party,authority,taxpayer,practice,god,held,appellant,behalf,purpose,parliamentary,doubt,applied,original,called,government,meaning,treatment,truth,period,authorities,events,word,argued,background,contention,financial,common,development,nature,fair
# ====================================================================================================
# Vivid
# Smoothed: time,people,life,eyes,day,world,found,mind,black,house,head,home,book,told,left,mother,white,looked,memories,children,night,love,past,hand,blue,light,colour,war,god,door,set,days,dream,moment,death,experience,father,round,events,words,woman,sense,story,picture,family,memory,feel,john,called,real,school,remember,dreams,body,read,green,hands,water,music,heard,vivid,women,dark,form,child,voice,brought,history,suddenly,talk,red,lost,girl,colours,change,sort,power,front,word,effect,sleep,country,person,social,eye,bed,close,hair,times,feeling,idea,morning,account,personal,flowers,subject,art,study,books,moved
# ----------
# Original: time,people,life,eyes,day,world,found,mind,black,house,head,home,book,told,left,mother,white,looked,memories,children,night,love,past,hand,blue,light,colour,war,god,door,set,days,dream,moment,death,experience,father,round,events,words,woman,sense,story,picture,family,memory,feel,john,called,real,school,remember,dreams,body,read,green,hands,water,music,heard,vivid,women,dark,form,child,voice,brought,history,suddenly,talk,red,lost,girl,colours,change,sort,power,front,word,effect,sleep,country,person,social,eye,bed,close,hair,times,feeling,idea,morning,account,personal,flowers,subject,art,study,books,moved
# ====================================================================================================
# Sound
# Smoothed: sound,time,people,music,looked,eyes,head,sounds,day,voice,heard,door,hand,life,night,house,words,left,found,guitar,world,hear,told,set,home,mind,light,feel,round,word,moment,play,hard,called,lot,love,bit,playing,water,system,front,hands,mother,real,children,days,body,idea,woman,air,black,top,sense,car,bass,coming,father,information,close,dark,recording,money,noise,sort,white,bed,power,times,record,past,language,live,suddenly,morning,half,john,call,band,road,stood,start,effect,change,started,makes,feet,business,form,control,line,means,difficult,talk,inside,run,question,feeling,short,school,remember
# ----------
# Original: sound,time,people,music,looked,eyes,head,sounds,day,voice,heard,door,hand,life,night,house,words,left,found,guitar,world,hear,told,set,home,mind,light,feel,round,word,moment,play,hard,called,lot,love,bit,playing,water,system,front,hands,mother,real,children,days,body,idea,woman,air,black,top,sense,car,bass,coming,father,information,close,dark,recording,money,noise,sort,white,bed,power,times,record,past,language,live,suddenly,morning,half,john,call,band,road,stood,start,effect,change,started,makes,feet,business,form,control,line,means,difficult,talk,inside,run,question,feeling,short,school,remember
# ====================================================================================================
# Prospecting
# Smoothed: mining,gold,prospecting,local,companies,company,people,exploration,found,uranium,land,campaign,department,development,planning,information,public,community,time,opposition,mineral,minerals,million,industry,environmental,west,permission,meeting,oil,mines,issue,march,government,committee,support,north,situation,northern,resources,involved,major,rights,licences,island,results,operations,mine,continued,national,coal,discovered,set,mayo,geological,council,joint,licence,water,proposed,energy,prospect,day,economic,country,left,subsidiary,announced,taking,action,landowners,world,act,international,agreement,county,august,expected,formed,report,called,meetings,foreign,encouraging,minister,impact,based,lignite,nuclear,research,grants,production,commercial,series,metal,sort,concern,deposits,claimed,power,drilling
# ----------
# Original: mining,gold,prospecting,local,companies,company,people,exploration,found,uranium,land,campaign,department,development,planning,information,public,community,time,opposition,mineral,minerals,million,industry,environmental,west,permission,meeting,oil,mines,issue,march,government,committee,support,north,situation,northern,resources,involved,major,rights,licences,island,results,operations,mine,continued,national,coal,discovered,set,mayo,geological,council,joint,licence,water,proposed,energy,prospect,day,economic,country,left,subsidiary,announced,taking,action,landowners,world,act,international,agreement,county,august,expected,formed,report,called,meetings,foreign,encouraging,minister,impact,based,lignite,nuclear,research,grants,production,commercial,series,metal,sort,concern,deposits,claimed,power,drilling
# ====================================================================================================
# Updating
# Smoothed: system,information,time,data,file,training,required,records,systems,staff,updating,stage,form,computer,local,development,set,record,people,database,service,national,education,management,support,health,reference,company,index,courses,process,level,change,revision,future,services,nursing,library,experience,details,planning,provide,user,range,update,terms,main,school,industry,facilities,personnel,major,scheme,government,processing,operations,period,lifespan,publisher,access,subject,control,language,office,practice,means,addition,home,package,date,programme,entry,section,project,basic,key,considerable,held,cost,department,books,students,updated,figure,based,files,job,found,social,module,public,base,research,users,provided,type,include,manager,knowledge,unit
# ----------
# Original: system,information,time,data,file,training,required,records,systems,staff,updating,stage,form,computer,local,development,set,record,people,database,service,national,education,management,support,health,reference,company,index,courses,process,level,change,revision,future,services,nursing,library,experience,details,planning,provide,user,range,update,terms,main,school,industry,facilities,personnel,major,scheme,government,processing,operations,period,lifespan,publisher,access,subject,control,language,office,practice,means,addition,home,package,date,programme,entry,section,project,basic,key,considerable,held,cost,department,books,students,updated,figure,based,files,job,found,social,module,public,base,research,users,provided,type,include,manager,knowledge,unit
# ====================================================================================================
# Denier
# Smoothed: nylon,needle,leg,thread,comfort,top,fabric,straps,denier,designed,summer,load,cloth,woven,sheer,hosiery,fit,product,water,appearance,feel,bobbin,heavyweight,slings,coated,resistance,air,moulded,shaped,success,world,winter,sewing,nets,wear,glossy,retailing,outerwear,story,control,development,perfect,developed,coming,developments,system,rucksack,shoulder,harness,padded,polyurethane,people,tension,size,plate,modelling,adjustment,durability,aquarium,tool,eye,cut,kites,base,carrier,straight,ideal,limited,function,black,industry,hold,finer,sack,tear,shoulders,carrying,proofing,waterproof,belt,suit,frame,adjustable,hips,pad,heavy,wearer,abrasion,specially,stocking,time,spring,machine,panels,row,cotton,pack,metal,threads,internal
# ----------
# Original: nylon,needle,leg,thread,comfort,top,fabric,straps,denier,designed,summer,woven,cloth,load,hosiery,product,sheer,fit,water,appearance,feel,bobbin,slings,coated,resistance,heavyweight,air,moulded,shaped,winter,world,success,sewing,nets,outerwear,retailing,control,glossy,developed,coming,wear,perfect,story,development,developments,rucksack,padded,polyurethane,shoulder,harness,system,plate,tension,size,modelling,adjustment,durability,aquarium,kites,cut,tool,eye,base,straight,carrier,ideal,black,industry,function,hold,limited,finer,belt,shoulders,waterproof,pad,abrasion,sack,carrying,suit,hips,adjustable,proofing,wearer,frame,tear,heavy,specially,time,stocking,spring,row,panels,machine,polyester,materials,metal,internal,called,support
# ====================================================================================================
# Sprats
# Smoothed: penguin,fish,harry,mum,eyes,water,keeper,fishing,hand,told,meat,terns,king,north,birds,food,raised,door,boiled,bread,reared,adult,children,penguins,loves,home,arctic,people,diet,slow,time,vegetables,yer,granny,river,float,wet,feel,salt,bloaters,inside,move,vitamin,liver,cod,hatched,search,hands,fry,skin,role,centre,business,kids,day,bloomers,skuas,arrival,floor,flour,avoid,market,brother,hear,shop,looked,century,seamen,gang,sort,government,bone,baby,bath,reassuring,feels,ken,surrogate,adopted,bit,star,batman,follow,attraction,nest,snack,natural,marvelous,smells,holding,person,smell,pounds,movie,skips,hopper,hug,rock,enclosure,insecure
# ----------
# Original: penguin,fish,harry,mum,eyes,water,keeper,fishing,hand,told,meat,terns,king,north,birds,food,raised,door,boiled,bread,penguins,home,loves,children,adult,reared,arctic,people,diet,slow,time,vegetables,granny,yer,river,float,wet,feel,inside,salt,bloaters,move,vitamin,liver,cod,hatched,hands,search,fry,skin,role,centre,business,kids,day,bloomers,arrival,skuas,floor,flour,avoid,market,brother,shop,looked,hear,century,seamen,gang,sort,bone,bath,person,movie,reassuring,natural,solids,surrogate,snack,insecure,flown,hopper,batman,smell,mother,rock,starred,adopted,hug,feels,skips,family,walk,bit,star,enclosure,attraction,smells,follow,marvelous
# ====================================================================================================
# Stooges
# Smoothed: people,ha,time,pop,police,music,political,service,quality,bloody,carter,heard,minister,half,songs,fall,rock,obvious,north,hard,days,prime,voice,sort,bit,politics,night,estate,business,labour,government,found,power,called,consumers,band,day,film,life,started,community,allies,network,intelligence,told,months,hand,research,led,south,recognition,wrote,local,lot,facilities,album,guitar,mind,national,companies,provide,boys,major,home,violence,sounds,smith,plenty,advertising,trial,objective,read,obtained,love,star,john,boy,system,encouraged,including,doctors,youth,song,trust,fight,return,successful,audience,past,house,career,services,wrong,run,speaker,provided,women,playing,labourer,universe
# ----------
# Original: people,ha,time,pop,police,music,political,service,quality,bloody,carter,heard,minister,half,songs,fall,rock,obvious,north,hard,days,prime,voice,sort,bit,politics,night,estate,business,labour,government,found,power,called,consumers,band,day,film,life,started,community,intelligence,network,allies,told,months,hand,research,led,south,recognition,wrote,local,lot,facilities,album,guitar,mind,national,companies,provide,boys,major,home,violence,sounds,smith,plenty,advertising,trial,objective,read,obtained,love,star,john,boy,encouraged,including,doctors,youth,song,trust,fight,return,successful,audience,past,house,career,services,wrong,run,speaker,provided,playing,labourer,professional,universe,riff
# ====================================================================================================
# Idealistic
# Smoothed: people,world,war,time,political,children,life,love,social,set,nature,government,local,john,party,day,view,real,called,found,child,movement,public,book,community,power,means,change,action,home,form,question,national,country,reason,school,personal,experience,politics,left,century,family,society,father,matter,idea,age,relations,difficult,money,approach,sense,economic,students,business,leader,house,simply,history,feel,meeting,past,effect,service,parents,character,reality,education,true,ideas,street,person,future,hope,words,science,church,letters,trouble,strong,south,support,attitudes,ideal,system,policy,free,death,liberal,mind,read,care,romantic,established,centre,teachers,company,process,individual,material
# ----------
# Original: people,world,war,time,political,children,life,love,social,set,nature,government,local,john,party,day,view,real,called,found,child,movement,public,book,community,power,means,change,action,home,form,question,national,country,reason,school,personal,experience,politics,left,century,family,society,father,matter,idea,age,relations,difficult,money,approach,sense,economic,students,business,leader,house,simply,history,feel,meeting,past,effect,service,parents,character,reality,education,true,ideas,street,person,future,hope,words,science,church,letters,trouble,strong,south,support,attitudes,ideal,system,policy,free,death,liberal,mind,read,care,romantic,established,centre,teachers,company,process,individual,material
# ====================================================================================================
# Thumped
# Smoothed: time,door,looked,eyes,told,half,head,hand,home,round,left,day,table,people,voice,woman,night,moment,front,house,light,martin,mother,lot,bed,wrong,hands,hit,remember,black,shouted,ran,set,boy,heard,suddenly,bloody,hell,mouth,window,wife,found,moved,started,heart,arm,stood,minutes,bit,body,life,walked,feeling,white,oxford,real,called,morning,stared,lee,quickly,play,united,days,hard,sound,fell,cup,past,goal,hear,feel,wall,forward,brought,world,air,feet,run,times,taking,love,inside,ground,road,pulled,car,mind,stay,water,dark,money,mike,child,god,line,close,top,heavy,game
# ----------
# Original: time,door,looked,eyes,told,half,head,hand,home,round,left,day,table,people,voice,woman,night,moment,front,house,light,martin,mother,lot,bed,wrong,hands,hit,remember,black,shouted,ran,set,boy,heard,suddenly,bloody,hell,mouth,window,wife,found,moved,started,heart,arm,stood,minutes,bit,body,life,walked,feeling,white,oxford,real,called,morning,stared,lee,quickly,play,united,days,hard,sound,fell,cup,past,goal,hear,feel,wall,forward,brought,world,air,feet,run,times,taking,love,inside,ground,road,pulled,car,mind,stay,water,dark,money,mike,child,god,line,close,top,heavy,game
# ====================================================================================================
# Troublemakers
# Smoothed: people,prison,school,police,trouble,children,time,black,workers,means,teachers,prisoners,called,person,crowd,fire,local,pupil,day,bothered,life,association,pass,jail,action,teacher,official,conflict,taking,times,inmates,front,court,officers,sort,terms,staff,names,residents,talk,government,community,bad,cell,eyes,strikes,involved,boy,service,personal,council,labelled,parents,governor,past,authorities,shouted,john,set,started,yer,head,reported,incomers,worth,negative,rights,report,ground,automatically,mind,situation,days,special,scale,violence,yesterday,assembly,told,east,labels,pride,teaching,exam,stood,students,carnival,ago,juvenile,human,food,reports,party,public,suggested,ethnic,construction,cells,week,round
# ----------
# Original: people,prison,school,police,trouble,children,time,black,workers,means,teachers,prisoners,called,person,crowd,fire,local,pupil,day,bothered,life,association,pass,jail,action,teacher,official,conflict,taking,times,inmates,front,court,officers,sort,terms,staff,names,residents,talk,government,community,bad,cell,eyes,strikes,involved,boy,service,personal,council,labelled,parents,governor,past,authorities,shouted,john,set,started,yer,head,reported,incomers,worth,negative,rights,report,ground,automatically,mind,situation,days,special,scale,violence,yesterday,assembly,told,east,labels,teaching,pride,exam,stood,students,carnival,ago,juvenile,human,food,reports,party,public,suggested,ethnic,construction,cells,week,round
# ====================================================================================================
# Rhinoceroses
# Smoothed: trade,animals,cages,dinosaurs,lake,species,government,southern,cites,animal,legs,living,wild,elephant,parrot,lost,plain,endangered,supposed,stuff,shoot,zoos,silence,kangaroos,run,care,zoo,step,world,countries,people,culture,reptiles,remains,international,ivory,south,life,wildlife,herd,left,food,elephants,found,support,stand,age,mammals,money,century,north,time,conservation,creatures,ago,country,protection,standing,alive,coming,finished,meeting,ban,extinct,active,habits,power,products,empire,ten,fucking,nailed,soft,brother,tapirs,zebra,held,drawing,voluntary,welfare,chucked,hailstorms,blown,heat,doors,real,stuck,yer,bin,direction,sweet,dad,ate,charged,hell,ignorant,rain,miles,prairie,jungle
# ----------
# Original: trade,animals,cages,dinosaurs,lake,species,government,southern,cites,animal,legs,living,wild,elephant,parrot,lost,plain,endangered,run,silence,step,shoot,care,zoo,stuff,kangaroos,zoos,supposed,world,countries,people,culture,reptiles,remains,international,ivory,south,life,wildlife,herd,left,food,elephants,found,support,stand,age,mammals,money,century,north,time,conservation,creatures,ago,country,protection,standing,alive,coming,finished,meeting,ban,extinct,habits,active,power,products,soft,nailed,ten,empire,fucking,brother,zebra,tapirs,held,drawing,voluntary,welfare,tiniest,hundred,mere,charged,skin,heat,bush,sweet,stuck,hops,monotone,jungle,cares,tear,yer,hell,direction,sitting,blown,feed
# ====================================================================================================
# Petulantly
# Smoothed: time,told,looked,night,day,boy,door,roman,meet,suddenly,hand,eyes,head,feel,car,home,smiled,evening,round,bishop,idea,lines,crime,stood,flat,house,phone,father,left,drive,child,hands,wrong,reached,feet,doctor,started,sort,friends,understand,fed,knife,mind,smile,government,front,moment,cream,shrugged,leave,sitting,surely,earth,completely,business,talking,office,stay,appeared,hear,banks,charity,ham,bread,table,top,listen,people,air,sat,bill,solicitor,met,walked,bed,question,play,stared,suggested,brother,surprised,voice,coffee,children,line,edge,heard,speak,free,offer,matter,woman,finished,rang,building,suppose,thinking,read,piers,mother
# ----------
# Original: time,told,looked,night,day,boy,door,roman,meet,suddenly,hand,eyes,head,feel,car,home,smiled,evening,round,bishop,idea,lines,crime,stood,flat,house,phone,father,left,drive,child,hands,wrong,reached,feet,doctor,started,sort,friends,understand,fed,knife,mind,smile,front,moment,cream,shrugged,leave,sitting,surely,earth,completely,business,talking,office,stay,appeared,hear,banks,charity,ham,bread,table,top,listen,people,air,sat,bill,solicitor,met,walked,bed,question,play,stared,suggested,brother,surprised,voice,coffee,line,edge,heard,speak,free,offer,matter,woman,finished,rang,building,suppose,thinking,read,piers,mother,ready,spoke
# ====================================================================================================

# %% [markdown]
# Calculate the predicted probability that word $w_k$ is associated with $\textrm{text}_{j^\prime}$:
# $$
# \mathrm{P}(w_k \vert \textrm{text}_{j^\prime}) = \frac{1}{n_{j^\prime}} \sum_{i = 1}^{n_{j^\prime}} \mathrm{P}(w_k \vert w_{j^\prime i}).
# $$

# %%
predictions = {}
for text_name in memoranda:
    
    prime_words = texts_as_words[text_name]
    
    _predictions = numpy.zeros(len(vocabulary))
    for prime_word in prime_words:
        _predictions += get_conditional_probability(P, f, prime_word)
    
    _predictions /= len(prime_words)
    
    predictions[text_name] = dict(zip(vocabulary, _predictions))

# %% [markdown]
# View the predictions.

# %%
def print_topic(text_name, K=25):   
    return ','.join([w for w,_ in sorted(predictions[text_name].items(), 
                                         key=lambda value: value[1], 
                                         reverse=True)][:K])

# %%
for text_name in memoranda:
    print(memoranda[text_name]['text'])
    print('*'*10)
    print(print_topic(text_name, K=100))
    print('='*25)
# Out:
# ‘I don't know what I did without it’ is the sentiment. There is a difference
# between fully automatic washing machines — which change the nature of the task
# altogether — and ‘twin tub’ machines where the hot wet washing has to be
# lifted manually into a separate drying compartment. The women who had this type
# of machine complained about the considerable amount of work still required of
# the housewife, and the mess on the kitchen floor to be cleared up afterwards. In
# a similar way the launderette does not remove the physical drudgery of washing.
# The housewife has to get the washing there in the first place, she has to unload
# it, sort it, sit and watch it wash and dry (or dash out to shop in the interim)
# and then pack it all up again. This, when there is a baby in the pram and a two-
# or three-year-old to attend to, is no mean feat.
# **********
# time,people,day,women,home,life,house,water,children,found,left,world,looked,mother,hand,set,told,head,system,eyes,night,family,door,days,feel,woman,government,mind,money,round,machine,change,social,called,child,local,company,job,form,week,school,information,cent,times,hard,father,half,housewife,car,baby,lot,love,top,body,washing,white,table,control,wife,business,light,front,bed,power,hands,care,bit,party,service,black,public,line,john,hair,months,sort,held,morning,start,moment,main,person,leave,means,country,words,food,run,court,question,past,difficult,real,hours,support,road,war,girl,national,idea
# =========================
# Don Juan today has lost whatever sympathetic press the years of male domination
# gave him. Feminism and a greater acknowledged (though not necessarily practised)
# awareness of the equality and independence of sexual rights have becalmed the
# Don as a fool of time. Psychology has dissected him to death. AIDS has ousted
# him out of history. But there is little point, for instance, in turning on an
# artistic, enlightened medieval king because he also enjoyed slaughtering
# hundreds of deer in a day's hunt and daubing the fresh blood on his own face and
# those of his friends. Examples can be multiplied. To yank someone entirely out
# of their time and smack them around for not being of our time is perhaps a
# salutary but only a limited exercise. Yet the times have indeed changed: and
# Burton's early sexual insatiability, his later infidelities, his many women and
# his concurrent devotion to monogamy all need some explaining.
# **********
# time,people,women,life,world,day,found,social,government,home,children,left,family,house,set,political,told,sexual,power,system,local,party,hand,public,head,form,called,king,woman,times,school,days,looked,country,national,history,change,mother,death,father,war,society,john,law,mind,love,child,money,cent,night,god,book,company,feel,human,terms,century,person,sense,question,support,age,means,control,eyes,view,act,body,information,male,held,church,court,period,past,business,development,experience,real,major,words,week,black,position,half,evidence,subject,education,idea,matter,water,round,nature,effect,common,sex,months,brought,result,process
# =========================
# When John Major talks of a ‘nation being at ease with itself’, which
# particular nation is he speaking about? Is he addressing his comments to all
# those who have become marginalised and dispossessed as a result of right-wing
# Conservative policies over the years? Or is he speaking about that nation of
# complacent and indifferent shopkeepers who long for nothing other than a return
# to the days of imperial hegemony? The shopkeeper as the centre around which the
# social world revolves is a commercial image hammered into English consciousness
# by Mrs Thatcher. Self reliance, individual enterprise, ‘what's in it for
# me’, as opposed to‘how can we help our neighbour’, was the message. This
# theology slipped over the iron hand of the capitalist market like a silk glove.
# England became one nation again, a land of hope and glory, Elgar, teacakes and
# cricket. This England is not one recognised by many of my friends.
# **********
# time,people,government,world,social,life,day,party,political,home,house,labour,national,local,left,found,system,public,power,women,set,war,country,economic,john,hand,market,cent,major,god,development,children,business,told,family,policy,form,company,support,head,society,looked,days,called,change,minister,money,land,school,view,class,night,terms,held,law,times,community,control,means,mind,question,sense,century,council,information,church,eyes,service,position,education,past,mother,international,south,history,future,week,period,centre,process,real,united,father,act,round,words,feel,main,west,result,trade,body,level,person,individual,industry,office,brought,common,city
# =========================
# The form of animal husbandry adopted depends on the type of facilities available
# and the nature of the experiments. If an experiment produces animals that are to
# be kept for a long period, or that are to form the basis of a breeding colony,
# some form of barrier system is essential. If no precautions are taken to prevent
# infections it is inevitable that the health of the animals will deteriorate with
# a resulting decrease in breeding performance or death. A minimal barrier system
# requires people entering the animal area to remove their laboratory coats worn
# in other areas, and to put on protective  clothing. It is essential that they
# wash their hands thoroughly before handling the animals and the wearing of
# surgical gloves and a change of footwear or overshoes should be considered. A
# more stringent barrier includes the requirement for staff to shower on entering
# the unit and a complete change of clothes.
# **********
# time,people,system,life,found,world,day,government,form,water,children,animals,set,home,information,local,change,social,cent,left,house,women,health,control,public,company,family,head,patients,development,hand,body,care,school,national,effect,called,power,period,days,means,level,business,money,service,human,act,party,staff,support,research,looked,told,process,person,country,terms,animal,major,result,times,market,main,study,food,night,species,provide,law,range,eyes,difficult,view,common,light,evidence,services,including,child,age,months,question,feel,held,white,individual,mind,similar,political,type,words,court,education,mother,half,land,experience,past,black,nature
# =========================
# I then took her forward slightly to the evening after the operation, a time when
# she was fully awake and over the more drastic effects of the anaesthetic. I
# asked her how she felt now. To my surprise Kirsty burst into tears. No, she told
# me, she was not in any great pain — simply the discomfort she would have
# expected to follow surgery. She was not aware of feeling particularly ill. It
# was just that she knew that there was something seriously wrong with her —
# something far more dramatic than a grumbling appendix or the normal after-
# effects of an operation. Oh, the doctors and nurses had assured her again and
# again that she was fine and would soon be fit and well again. And yet, as she
# kept repeating, she was convinced that there was something that no one was
# telling her.
# **********
# time,people,day,life,home,told,found,left,looked,eyes,house,world,head,children,night,patients,hand,feel,mother,set,women,mind,government,days,hospital,family,health,door,care,father,system,local,called,woman,love,body,round,money,change,child,school,information,moment,voice,week,months,form,times,social,water,pain,words,john,public,patient,hard,heard,person,cent,effect,half,company,party,morning,god,operation,bed,car,business,control,doctor,light,past,country,hands,leave,hours,lot,treatment,held,service,feeling,idea,difficult,real,start,question,means,matter,sense,taking,experience,national,wrong,support,war,power,police,job,table
# =========================
# It was mentioned above that overflow records arise singly. In addition, an
# embedded overflow area will usually contain varying numbers of records from
# several tracks. This leads to overflow records usually being stored in unblocked
# format, even if the records in the prime data area are blocked. There is some
# advantage in treating the whole embedded overflow area as a single large blocked
# record, and manufacturers' software often does transfer the whole track into
# main storage when an addition is to be made; this allows for the addition
# itself, creation of link fields, changes of index, etc. However, handling the
# whole track as a single block would prevent rapid transfer of individual records
# from the embedded overflow area during direct access reference, which is the
# reason this method is often not adopted (but see the section on software
# packages, p. 264).
# **********
# time,records,people,system,record,data,overflow,information,track,file,set,software,government,company,found,world,form,cent,systems,local,day,home,life,control,water,left,index,development,social,main,house,section,required,computer,business,market,times,public,process,single,support,provide,level,means,children,national,access,change,act,additions,terms,shown,party,held,added,power,effect,result,period,range,major,position,called,head,including,line,service,court,key,figure,research,individual,school,women,files,management,space,hand,view,services,half,run,prime,money,based,country,law,days,start,person,common,similar,question,road,family,provided,direct,minister,field,words
# =========================
# Though innovation is a very positive term, it is important to remember that any
# particular innovation is only positive in retrospect, after it has worked. Before
# that, because change by definition is something no one has seen yet (despite
# models that may exist elsewhere), it has to be taken at least partially on
# faith. For example, why a continuing education program now? Why use funds to
# develop a new product when there are so many already on the market? Why take the
# risk of decentralizing the accounting office? In short, unless there is somebody
# behind the idea willing to take the risk of speaking up for it, the idea will
# evaporate and disappear. One reason there is so little change in most
# traditional bureaucratic organizations, I argue, is that they have conditioned
# out of people the willingness to stand up for a new idea. Instead, people learn
# to back off at the first sign that somebody might disapprove.
# **********
# time,people,government,life,world,social,system,change,local,market,day,children,public,found,education,information,set,company,school,development,form,women,business,political,home,power,cent,national,party,house,control,left,money,process,terms,idea,support,means,view,management,level,hand,told,research,question,family,called,policy,god,economic,person,major,effect,risk,law,labour,act,country,society,service,head,sense,experience,services,period,result,mind,difficult,office,community,real,individual,study,feel,care,days,provide,language,words,position,times,looked,future,product,child,main,health,training,water,financial,companies,held,common,war,industry,reason,staff,human,past,subject
# =========================
# Some social scientists have conceptualised these workers in terms of a reserve
# army of labour. In this case, they would constitute a pool of labour which can
# be utilised in boom periods and disregarded in recessions. This view sees the
# experience of the Third world as being little different from that of the
# industrialised countries. The large numbers who are unable to find regular
# work are not seen as a phenomenon characteristic of underdevelopment, but part
# of the capitalist division of labour and, therefore, a similar feature to the
# industrialisation process of European countries, differing in terms of quantity
# rather than quality. For Marx, however, the function of the reserve army of
# labour was keeping wages low and, to this end, the absolute size of the reserve
# army need not be very great. The high numbers and continuing growth of this
# sector in Latin America would suggest that concepts of European analysis are not
# sufficient.
# **********
# time,people,labour,government,social,world,cent,party,system,economic,life,political,women,local,national,public,terms,development,market,found,countries,form,set,day,power,workers,children,country,change,level,war,information,policy,major,home,control,support,left,period,production,money,process,company,society,means,business,service,house,view,class,rate,growth,trade,education,family,industry,army,real,result,effect,school,law,research,question,economy,services,act,international,main,community,nature,experience,position,water,industrial,minister,times,individual,called,million,evidence,union,century,united,increase,sense,capital,study,provide,common,role,age,future,force,including,management,health,held,hand,human
# =========================
# In the case of time constant, a production worker tends to be focused on the
# production schedule for today or this week. An R&D worker is aware that what he
# does today will not affect company output in this order of time span. It may be
# months or years before his work today makes an impact: in the case of a project
# failure it may never do so. Words such as ‘hurriedly’ and ‘quickly’ are
# likely to be associated with different orders of time spans in the minds of the
# two people. Salesmen are probably in between these two. They have in some cases
# a weekly or monthly schedule of orders to win but the long-term relationship
# with their customer is also of great importance and the weight to be put on the
# two factors at any one time calls for the exercise of judgement.
# **********
# time,people,company,day,life,world,social,home,government,system,children,found,set,information,cent,business,local,left,house,women,form,production,money,change,family,week,market,public,control,told,development,days,person,support,school,power,act,service,national,hand,terms,means,level,period,head,party,labour,months,times,words,called,looked,workers,management,care,major,feel,country,question,mind,court,services,effect,process,political,job,night,policy,research,child,rate,staff,result,view,project,real,experience,law,office,john,cost,body,half,difficult,society,eyes,pay,past,future,main,individual,health,including,community,mother,age,position,price,provide,sense
# =========================
# In the afternoon, we have a rehearsal, but without the guests. I just walk
# through the basic moves so the cameras can plot where everybody's going to be,
# and we try to work out how long people will take to walk down the stairs so we
# can play the right amount of music. If they can make it, we like the guests to
# arrive before the audience starts to go in, so they can walk through it, too.
# Those steps  down to the set can be daunting — I think it's everybody's
# nightmare, stepping out and falling flat on your face. Dusty Springfield was
# wearing new shoes, with very high heels, and was terrified that she'd slip, so
# just before she was due to go on, one of the team was dispatched to look for
# some scissors to scratch the soles with. Oh, the glamour of it all.
# **********
# time,people,day,life,home,left,house,looked,world,head,night,found,set,told,door,hand,eyes,children,round,days,feel,mother,called,play,music,mind,money,week,john,top,school,family,front,father,water,woman,women,car,love,black,road,local,white,times,moment,half,government,company,hard,light,lot,voice,heard,team,morning,party,past,hands,bit,start,body,system,business,bed,feet,country,walk,change,hair,public,form,street,held,real,run,idea,line,leave,words,close,evening,person,position,child,short,minutes,taking,office,job,police,remember,main,table,months,girl,book,started,information,air,sound
# =========================
# My understanding of the law is that an adult patient who is capable of doing so
# must give consent to any medical treatment if that treatment is to be lawful. At
# the time of the decision the patient needs a capacity commensurate with the
# gravity of that decision. If the patient lacks the requisite capacity, then the
# doctors must act in what they perceive to be his or her best interests, with
# information garnered from previous knowledge of the patient, discussion with
# family and friends, and taking into account any relevant directive previously
# made by the patient. What the legal force and effect of any such directive might
# be is uncertain; it is unclear whether health care staff are required to carry
# out the terms of the directive or whether those who act in good faith with the
# terms of the directive are immune from civil or criminal prosecution. There is,
# apparently, no case law on this point.
# **********
# time,people,law,patient,act,court,patients,government,life,information,health,social,care,treatment,children,public,system,person,found,day,company,local,world,home,terms,national,set,family,house,form,women,decision,authority,power,question,service,community,effect,evidence,section,party,child,business,directive,control,support,services,cent,hospital,legal,view,left,staff,change,action,means,development,council,political,medical,school,held,matter,told,result,period,practice,process,policy,study,education,individual,level,country,subject,required,common,provide,police,position,days,experience,body,hand,major,society,months,money,called,research,knowledge,age,nature,words,report,reason,sense,including,market,mind
# =========================
# The bones are bound to each other by tough, flexible ligaments and are
# articulated at the joints by muscles. There are just over 600 voluntary muscles
# in the human body. For our purposes, it is only necessary to mention the larger,
# superficial muscle groups which affect the shape of the body and are responsible
# for the movement of the limbs. These are referred to as skeletal muscles, most
# of which are attached at both ends to bones. The muscles that give expression to
# the face are also referred to as skeletal muscles, and they link bone to skin. A
# whole complex system of muscles is brought into play for each movement of the
# body: bending an arm involves the shortening of the biceps, while the tricep
# muscles at the back of the arm must relax and lengthen in unison. Meanwhile,
# others immobilise joints not needed in the action, while others still adjust to
# stabilize the body's equilibrium.
# **********
# time,people,body,muscles,head,life,found,day,system,hand,eyes,left,world,form,government,set,looked,water,home,feel,social,women,human,children,arm,house,local,muscle,exercise,times,development,information,position,mind,told,control,called,change,night,power,hands,level,effect,means,public,round,party,cent,hard,action,days,movement,light,act,person,main,family,national,arms,bones,money,leg,top,line,front,political,process,held,words,company,support,half,result,moment,skin,woman,real,difficult,question,close,training,period,bone,major,sense,school,figure,law,move,cells,common,child,similar,black,door,terms,business,white,play,view
# =========================
# The extent to which subject coverage on the shelves can be achieved is a matter
# of library policy, funding, the amount of shelf space available, and the
# efficiency of interlending systems to which the authority has recourse. These
# influences are considered in more detail in Chapter 12. The case for immediate
# shelf representation in a public library is made at some length by Ranganathan,
# in his fourth library law —‘save the time of the reader’. ‘Mental hunger
# for books is not compelling in the case of most people. Mental thirst for
# information is not inexorable in the case of most people. Both of them are
# fleeting in their nature. They both die out, unless satisfied immediately on
# their taking shape. No time lag should come between demand and supply. The tempo
# for reading is often momentary. It should be harnessed at the very moment.’
# **********
# time,people,life,government,information,world,system,public,library,local,day,found,social,children,set,house,home,law,form,book,left,school,money,books,national,women,party,hand,act,company,cent,change,development,power,head,terms,political,subject,policy,business,control,looked,level,services,words,question,service,court,mind,told,means,education,research,care,person,support,called,family,major,view,health,market,water,eyes,process,country,child,times,days,authority,effect,sense,matter,real,staff,community,labour,period,evidence,body,main,study,held,feel,experience,provide,section,difficult,individual,war,society,position,night,result,council,action,past,systems,language,god
# =========================
# In Ordinary Justice the National Consumer Council were scathingly critical of
# such court proceedings which in practice, they said, became a rubber stamp. The
# documents the court sent out were difficult to understand and no guidance was
# given on completing it. The ‘defendant’ was not asked about his personal
# circumstances. The Civil Justice Review found that a third of banks and building
# societies, and a fifth of local authorities, did not enquire about the debtor's
# circumstances before the hearing. Three quarters of local authorities did not
# follow up the Department of Environment's advice and carry out checks to see if
# the tenant was receiving the right benefits. Sixty-seven per cent of creditors
# had no knowledge of the debtor's financial state at the time of the original
# transaction, and 77 per cent did not obtain any further information before or
# during the proceedings.
# **********
# time,court,people,government,local,act,cent,law,information,company,public,party,system,social,business,house,children,service,life,national,day,council,set,money,found,home,world,form,person,section,authority,evidence,services,action,terms,power,bank,development,support,family,held,left,question,market,care,appeal,period,legal,education,authorities,political,women,pay,decision,country,school,control,child,office,effect,policy,health,debtor,report,proceedings,property,society,view,means,costs,change,told,provide,subject,days,practice,community,matter,police,financial,minister,including,major,process,called,level,tax,result,months,position,million,application,committee,land,labour,building,staff,management,required,economic
# =========================
# The Dickens study tells us that not every dismissed employee eligible to claim
# unfair dismissal does so. Only about one in ten of those eligible to claim
# actually does so. Among those who apply there is a greater tendency to bring
# unfair dismissal proceedings where the employer is a small single establishment
# employer with below average unionization. Nearly half of all applications are
# against employers with fewer than 20 employees. The larger the employer, the
# less likely it is that there will be an unfair dismissal claim. There are a
# number of possible explanations for this pattern of application. Larger
# employers are likely to have internal appeals procedures and failure there,
# where union representation may have been provided, is the point at which the
# employee draws the line. Employees may feel a sense of powerlessness in taking
# on a large organization or it may be that advisers are more reluctant to take on
# large organizations.
# **********
# time,people,government,court,company,social,cent,system,act,employer,local,party,employee,business,employment,women,life,law,information,public,national,world,labour,found,union,set,terms,children,form,day,house,employees,contract,pay,political,home,job,power,service,period,workers,support,claim,trade,development,person,change,left,action,question,dismissal,policy,council,control,market,school,staff,management,money,education,held,position,level,section,effect,employers,result,means,family,view,evidence,country,major,provide,decision,services,economic,days,minister,process,appeal,tax,industrial,week,authority,society,health,office,community,subject,individual,told,rights,reason,hand,care,study,called,age,training
# =========================
# Our terms of reference suggested that we should consider drama in the context of
# the great dramatic works of literature. We believe that plays should be
# approached through the dramatic medium; children should often see or participate
# in the play being acted, and not just read the text. This approach will not only
# result in an appreciation of the literary merits, but also foster an
# understanding of stagecraft. There is still an important place within drama
# activity for the exploration and study of scripted plays, and we addressed this
# aspect in our statements of attainment and programmes of study. At primary
# level, the range of material for exploration needs to be more diverse: myth,
# legend, fairy stories, poems. At secondary level, such work can expand naturally
# into the exploration of dramatic texts. Children's own writing can also be
# explored — at both levels — through the medium of drama.
# **********
# time,people,children,world,life,school,social,language,found,information,government,set,form,education,system,study,day,drama,local,level,play,women,development,terms,public,book,home,child,national,family,experience,cent,house,left,company,change,schools,political,words,view,john,research,sense,history,process,role,means,major,subject,business,act,range,writing,teachers,called,question,power,support,period,effect,control,text,age,pupils,hand,real,society,read,country,approach,evidence,told,individual,music,party,students,times,provide,care,training,main,stage,difficult,class,nature,human,production,community,story,war,person,programme,knowledge,including,result,head,days,written,mind,material
# =========================
# Activity 1 (15–20 mins): Identify a small group of clients, such as the first six
# people you saw in your last day's community care, the first six people attending
# your outpatients' clinic, or six individuals in a bay in your ward. For each
# client, list the nursing interventions either by yourself or someone else, such
# as ‘insulin injection’, ‘mouth care’, ‘socialisation’, ‘health
# promotion’, that each required in the fist hour of care, say between eight and
# nine, or nine and 10 in the morning. You should end up with at least six
# separate lists, some with perhaps only one item on it, others with several
# items, listed in the order that each client received, or was assisted with, that
# care. Are there any items common to several, or all, of the clients? Did they
# receive similar care at the same time or in the same order?
# **********
# time,people,care,social,health,patients,day,home,children,local,services,life,information,community,found,government,service,system,client,set,family,hospital,house,women,world,left,public,support,staff,company,cent,child,form,person,money,school,business,development,told,control,patient,change,hand,study,clients,act,national,days,individual,provide,head,practice,party,research,treatment,terms,looked,education,court,age,level,week,management,society,process,means,times,night,feel,list,law,authority,training,called,major,market,report,months,mother,difficult,including,country,period,effect,experience,items,policy,question,office,main,action,common,involved,power,evidence,body,words,held,result,view
# =========================
# Once again that requirement to get on with people, clients, account executives
# and the creative teams is basic to your daily work. Just how does cooperation
# between a planner and the creative team work? After all, creative people are
# supposed to be sensitive and aware of the consumer and society and in real touch
# with change and mood. Let's take an example of the planner and creative team
# together. Trying to devise the strategy for a lager campaign, the planner found
# out through the research that the key benefit consumers looked for in lager was
# refreshment — incidentally something no other beer advertiser mentioned. The
# creative team took this new insight and used it as a spring-board to create a
# very successful campaign based on sprouting leaves and the headline: "Refreshes
# the parts other beers cannot reach" , thus demonstrating the imaginative leap
# creative people make from research findings to effect communication messages.
# **********
# time,people,world,life,day,government,information,research,social,found,home,set,local,company,public,system,children,team,business,cent,house,national,market,left,women,school,development,change,form,money,party,service,support,major,head,told,terms,experience,country,real,process,society,means,called,hand,family,days,power,times,mind,level,person,john,services,political,looked,education,week,book,care,view,control,community,feel,job,act,individual,night,labour,management,account,sense,question,idea,effect,council,study,provide,staff,health,water,main,action,words,play,period,industry,past,result,future,policy,difficult,planning,war,including,creative,office,language,training,half
# =========================
# While many of these may be social occasions, work groups especially in large
# companies may often stay on late to participate in quality control circles or
# zero defect clubs. There are up to four million quality control circle
# participants in Japanese industry and in large companies two in five workers are
# members. Quality consciousness is said to be very high among Japanese workers
# who endeavour to eliminate components that are rejected as substandard. Each
# smaller work group attempts to perform better than their rival groups in both
# quality control and in the number of suggestions they offer to improve
# productivity. Workplace harmony is enhanced by communal sports clubs, company
# vacation resorts, one-class cafeterias and the absence of status barriers within
# the plant. There is an hierarchical structure, but managerial authority is
# respected as a benign guardian of company interests. Corporate identification
# with workers knowing their place is in short "a managers Nirvana".
# **********
# time,people,company,government,social,world,system,local,life,cent,control,business,day,public,management,workers,information,set,market,women,found,national,development,power,companies,home,children,quality,labour,form,party,service,house,industry,political,support,services,level,change,major,left,school,million,terms,family,money,act,education,country,staff,economic,process,means,policy,health,care,community,research,authority,society,view,provide,training,called,law,individual,council,trade,days,times,hand,period,position,result,experience,person,including,week,main,job,effect,class,future,production,court,held,water,head,question,told,action,union,involved,sense,cost,john,role,international,based,real
# =========================
# While it would be unlikely for a firm contractual commitment to be made which
# binds a record company to produce a promotional video, it is a matter of fact
# that a promotional video will be produced to support an artist's first single.
# With limited production costs, this video would fall into the £15,000 to
# £30,000 range, as opposed to the six-figure costs incurred by the established
# major artists. The cost of the promotional video for a developing artist would
# be recoupable against both audio and video income received by the record
# company. The income to pay these video costs is usually minimal with new
# artists, so these expenses are often set against future video exploitation. This
# is income which increases as the artist gains greater success and begins to
# release such items as compilation videos comprising selected promotional videos,
# or full length videos of live concert performances.
# **********
# time,people,video,company,world,government,cent,set,system,costs,life,information,business,market,income,local,day,home,public,art,national,money,tax,cost,social,found,children,form,house,support,women,major,party,development,record,service,companies,court,school,act,million,including,terms,family,pay,left,production,music,period,level,control,power,country,services,means,price,book,week,change,john,range,called,rate,effect,future,provide,artist,days,language,management,times,labour,main,real,policy,staff,industry,view,society,person,result,sales,artists,programme,training,law,political,total,question,process,individual,economic,trade,months,based,material,subject,held,position,hand
# =========================
# Despite the challenges associated with building up large-scale production, the
# Japanese are forging ahead in display technology — and for very good reasons.
# Obviously the straightforward replacement of bulky cathode ray tubes with flat
# panel display leads to significant power and weight reductions as exemplified in
# the commercialisation of laptop computers. The most strategically important
# reason for investing in flat panel display technology, however, is that with
# continued miniaturisation of the integrated circuits the display itself will
# become the platform on which the system is built. This raises the prospect of
# fully integrated systems for which the sourcing of individual components such as
# drivers, memory chips and processors on the world market would no longer be an
# issue. Countries with such a display manufacturing capability would dominate the
# market and effectively eliminate competition based on older technology made up
# from discrete components.
# **********
# time,people,system,world,market,company,government,information,systems,set,development,local,cent,business,life,day,power,technology,social,found,form,control,computer,public,left,children,home,national,industry,data,change,house,major,support,level,production,process,research,management,service,country,companies,political,party,called,money,software,terms,means,main,economic,range,including,future,labour,school,provide,women,water,services,based,hand,view,cost,policy,times,result,million,line,countries,effect,head,education,position,question,price,family,design,international,war,products,week,period,individual,days,john,single,real,product,car,run,top,office,society,told,half,quality,difficult,building,staff
# =========================
# Though less visible, it was export competition in goods and services which had a
# more fundamental effect on UK towns and cities. The internal economic geography
# of the UK has been reworked over a century by fundamental change in the nature
# and orientation of exports, which has reflected the success of individual
# industries and their factories. This demonstrates the principal changes so far this
# century in the composition of export goods. In 1900, the country was still
# largely dependent on exports of textiles, metals and coal, whereas by 1987
# nearly half the country's exports were accounted for by ‘machinery and
# transport equipment’ and chemicals. The impact of North Sea oil on the
# structure of the balance of payments may actually have reduced the absolute
# volume of manufacturing exports. This is because it raised the real sterling
# exchange rate, rendering ‘marginal’ manufacturing exports uncompetitive. We
# shall return to this issue at several points later in this volume.
# **********
# time,people,cent,government,world,market,trade,economic,industry,social,system,million,country,company,local,national,rate,development,public,life,countries,labour,business,major,set,political,found,change,power,day,production,party,level,period,form,century,policy,growth,services,exports,terms,foreign,information,companies,service,money,increase,home,house,women,control,war,total,support,economy,international,effect,oil,north,price,cost,minister,main,water,children,left,industrial,means,south,result,process,including,half,investment,exchange,west,manufacturing,rates,united,view,times,capital,society,real,council,community,called,position,law,family,increased,figure,tax,bank,research,future,school,population,provide,central
# =========================
# As far as the Royal Navy were concerned the nuisance of excessive leakage was
# largely put a stop to when Sir Robert Seppings (1764–1840) introduced diagonal
# iron bracing into wooden hulls about 1830. Seppings, who used to say ‘partial
# strength produces general weakness’, seems to have been one of the first Naval
# Architects to have a clear mental picture of the stress systems in a ship's
# hull. In the merchant service wooden hulls were to a considerable extent
# replaced by composite and iron and steel construction after the middle of the
# century. A number of wooden ships continued to be built without adequate shear
# bracing, however, and such ships got more leaky as they got older, until, in an
# age when most of the pumping was done by hand, it became uneconomic to run them
# any longer. Up till 1914 Norwegian shipowners were still making money by buying
# up British sailing ships and running them with windmill pumps.
# **********
# time,people,day,world,water,government,house,life,found,left,system,home,local,company,set,war,form,hand,head,looked,service,public,children,money,century,ships,john,power,called,told,days,cent,business,family,social,built,country,national,sir,night,sea,eyes,school,women,building,information,round,half,line,market,ship,development,control,times,act,change,party,north,main,major,held,support,door,top,father,period,road,body,age,south,royal,light,air,run,mind,land,level,services,office,means,including,health,church,trade,position,terms,view,white,past,result,city,west,week,labour,law,effect,political,real,court,hard
# =========================
# Clear out all your possessions and be ruthless. Now is the time to take rubbish
# to the dump, to give things away to charity shops and jumble sales. There is no
# point in taking all your useless rubbish with you. Also clear up the garden. You
# are not supposed to leave rubbish behind for the next occupants to cope with,
# although you can leave it bagged up outside the door for the dustmen to take
# later. If you are leaving the area do not forget to pick up any clothes that are
# at the cleaners, or shoes, clocks, or other items that are away being mended.
# You will also need to withdraw sufficient cash from the bank to pay for the
# removal. It is common practice to tip the people who have done the removal work
# so you may want to withdraw enough for this too.
# **********
# time,people,day,house,home,life,left,found,world,told,government,looked,money,children,head,set,hand,local,company,door,eyes,night,days,business,family,women,mother,water,called,bank,feel,mind,school,cent,round,party,car,father,country,public,system,week,market,leave,child,woman,half,police,pay,lot,john,social,times,hard,power,court,change,held,form,person,office,information,top,moment,love,national,war,months,service,council,act,job,black,support,front,road,past,care,light,means,street,control,morning,body,heard,real,white,words,matter,book,close,idea,main,hands,taking,start,law,bit,question,voice
# =========================
# Individual goals may well be in conflict with organisational goals even where
# there is a strong commitment to one goal by the organisation. It is worth
# repeating that there may also be competing goals within the organisation itself.
# Thus, for example, the prison service may wish to pursue the twin goals of the
# punishment of offenders  and at the same time their rehabilitation. These two
# goals may prove to be incompatible and yet each will have its supporters. Within
# the National Health Service there may well be a commitment to provide the best
# possible medical care that the state of medical knowledge will allow and yet
# this may be tempered by the requirement to act within tight financial
# constraints. The two goals may be in conflict. Many organisations will face the
# problem of which goals to prioritise in the light of competing goals.
# **********
# time,people,government,goals,social,home,world,local,service,health,life,system,public,care,national,goal,set,children,information,day,political,power,party,management,services,act,support,team,form,development,organisation,control,education,change,business,united,company,found,left,individual,school,community,women,law,policy,cent,staff,game,terms,court,family,means,person,level,authority,process,money,major,house,training,society,provide,season,labour,half,child,view,research,country,week,john,experience,manager,economic,action,market,cup,minutes,international,result,question,play,hand,involved,night,club,position,days,league,role,times,war,difficult,told,council,practice,future,approach,period,head
# =========================
# On 25 July 1985 the dock company put in a planning application for the
# construction of a Roll on — Roll off (‘Ro-Ro’) terminal in the River
# Medway. Permission was refused, there was an appeal and an inquiry by an
# inspector whose recommendations the Secretary of State for the Environment
# accepted. The appeal was dismissed. The main consideration was undoubtedly the
# increase in heavy goods vehicles that would be generated by the new development
# and the consequent increase in noise levels, in particular night-time levels in
# Medway Road and Bridge Road. These environmental objections were considered to
# be serious enough to outweigh the economic benefits of allowing the proposal. It
# was this development and in particular the evidence given at the Ro-Ro inquiry
# which in due course prompted the council to bring the present proceedings. In
# March 1988 the council passed the necessary resolution and the writ was issued
# on 20 July 1988.
# **********
# time,people,government,court,local,council,company,public,development,house,system,cent,party,day,act,national,world,set,found,information,home,social,life,road,law,children,left,power,appeal,service,support,minister,evidence,business,report,planning,country,form,political,police,held,committee,economic,action,control,policy,school,authority,major,money,level,market,change,decision,water,told,called,education,labour,secretary,million,question,office,terms,section,view,main,period,effect,family,services,head,including,health,women,days,land,meeting,result,community,john,car,march,means,war,hand,months,matter,future,increase,times,process,person,industry,position,application,international,provide,management,night
# =========================
# At the start of the exercise, the actual procedure was checked against a
# conceptual model that included the activities deemed necessary to achieve the
# agreed transformation. If the changes revealed by this comparison have not been
# made prior to the audit commencing, this could be the reason for the failure to
# meet the target levels of attainment. If, however, the procedure does comply
# with the procedure description derived earlier, then it will be necessary to
# subject each element or activity of the model to further scrutiny, for example
# by breaking them down to lower-order activities, or by auditing each element in
# the same manner as the parent procedure. This process is similar to work study
# exercises where measurable elements of a task are identified before the actual
# measurement takes place, and consideration is given to the resources required at
# each level, including the skills and experience of the operator.
# **********
# time,people,system,information,government,set,social,form,children,life,company,local,world,found,public,level,process,development,act,day,terms,school,cent,control,court,change,law,study,national,business,education,house,power,subject,means,effect,party,management,left,model,home,period,person,service,view,child,experience,language,support,question,women,research,required,section,evidence,provide,political,report,data,patients,practice,market,result,major,individual,services,training,policy,position,action,staff,approach,called,money,family,words,procedure,care,main,hand,range,involved,community,based,including,difficult,common,analysis,health,similar,body,times,results,sense,council,knowledge,society,role,authority,country
# =========================
# The Knights of the Blazing Sun were created after the Battle of Magritta in 1457
# during the crusades which eventually freed the land of Estalia from the Arabian
# invaders. The battle was a great victory for the Knights of the Old World, made
# all the remarkable by a strange and prophetic occurrence. During fierce street
# fighting around the temple of Myrmidia, the warrior goddess of Estalia, a group
# of knights found themselves surrounded by the dreaded Black Guard led by Emir
# Wasr the Cruel. Just as the Arabians closed in a sudden earth tremor shook the
# temple, dislodging a huge bronze statue of the goddess which plummeted to the
# street below crushing the Emir and many of his troops. The event was to prove
# the turning point of the battle. Afterwards, the surviving knights established
# the Order of the Blazing Sun with Myrmidia as its patron and protector.
# **********
# time,people,world,day,life,found,left,king,head,house,war,eyes,looked,home,government,told,hand,god,night,set,john,days,called,family,century,women,black,round,father,mother,church,children,power,land,death,party,water,country,city,local,held,white,street,army,door,sun,woman,form,times,battle,mind,public,light,lord,north,love,moment,brought,political,money,body,sir,half,past,south,road,court,system,national,close,company,heard,late,feel,words,hands,hard,front,west,temple,lost,school,voice,period,town,support,knights,book,son,major,control,business,royal,week,social,sense,main,line,change,top
# =========================
# The answer to the first, or ‘why’, question begins with a recognition that
# banks are private sector, profit-making organisations with obligations to
# shareholders to increase profits over time. Thus they will always be looking for
# ways of expanding their balance sheets provided this leads to extra profit. Look
# again at Table 3.3 which shows the aggregate balance sheet of a large number of
# banks. Notice that assets are composed of various forms of lending: to the
# personal sector, the commercial sector, the government or the Bank of England.
# The liabilities side is dominated by deposits. Notice also that we can express
# any class of asset as a proportion of total assets or liabilities and remember
# too that in section 1.1.5 we said that these ratios are arrived at as a matter
# of deliberate choice and are assumed to represent portfolio equilibrium.
# **********
# time,people,government,company,bank,cent,market,money,business,public,banks,world,local,system,rate,life,set,assets,social,information,financial,act,form,national,day,companies,found,level,capital,million,party,period,terms,house,sector,price,change,tax,service,private,effect,development,services,home,law,total,policy,cost,power,economic,demand,control,question,increase,labour,women,left,children,major,court,section,investment,share,means,political,country,income,account,rates,held,result,management,position,support,shares,future,industry,provide,person,net,balance,table,view,real,main,class,hand,pay,school,costs,education,family,process,society,called,international,foreign,individual,months,trade
# =========================
# Using the golfing tips he gleaned from such fine players, Andy soon had his
# handicap down to two. He was by then an assistant pro in its fullest sense, so
# he decided to try his hand at playing tournaments. Although he qualified for a
# few regional events, in fact he was aiming much higher: he wanted a crack at the
# Open Championship. So in 1973 Andy decided to try and qualify for the Open at
# Royal Troon — and it was here that an incident occurred that changed his
# career. He had played the first round, but before he had a chance even to hit a
# ball in the second he was out of the pre-qualifier, suffering from injuries he
# had received in a car accident with his caddie. Swallowing hard on the
# disappointment, Andy spent the next few years taking even more blows on the
# chin.
# **********
# ...
# =========================
# She'd been convinced all along that eventually she must lose him, that Marianne
# was right — some other attraction must inevitably draw him away. She hadn't
# changed her mind about that — a man such as Dane would always attract
# beautiful women, and Shannon could never hope to compete. But would the pain of
# losing him be any the less simply because she'd managed to hold him at bay?
# Eventually, probably sooner rather than later, he'd grow tired of waiting for
# Shannon, and then she'd be left with nothing, in any case. Though she could
# never let him know it, he already possessed her heart; if she were to give
# herself to him body and soul, at least the memories would be rich and ultimately
# fulfilling. Right now all she'd have to look back on would be frustration and
# longing suppressed by fear.
# **********
# time,people,life,day,world,women,left,home,found,house,looked,eyes,told,head,hand,children,night,mind,love,government,feel,body,set,mother,family,days,door,father,woman,god,money,round,called,water,local,moment,power,social,party,school,hard,light,change,public,times,voice,past,week,company,business,country,system,child,form,john,war,black,half,sense,hands,person,car,words,held,lot,idea,real,heart,white,heard,death,lost,means,experience,matter,question,top,leave,cent,road,book,control,hope,close,political,bit,line,job,national,brought,view,play,difficult,morning,months,start,support,front,taking,bed
# =========================
# There can be no doubt that for many women fear of loss is built into us by the
# way we've been reared. As children we may have been made to feel inadequate,
# silly or useless because we were never praised. In adult life, some may be
# submissive and ingratiating, expecting to be in the wrong, expecting to be
# discarded and unwanted. And surprise, surprise, they get just that sort of
# treatment. The only way to stop it happening, and therefore to stop the fear of
# it, is to develop self-esteem. Learn to be assertive, stand up for yourself and
# your own value. That way people will see you as even more lovable. That is what
# I mean by making fear your friend. If you are subject to these irrational fears,
# then use that fear as a trigger to change your attitude. It could revolutionise
# your life.
# **********
# time,people,life,children,women,day,world,home,found,house,looked,feel,told,left,head,government,eyes,child,hand,family,mother,love,fear,mind,social,set,school,change,night,woman,person,father,days,money,called,system,local,door,round,public,god,body,moment,party,control,power,sense,times,business,country,friend,care,past,parents,hard,words,voice,form,john,real,cent,war,information,lot,difficult,means,company,water,question,support,week,experience,job,idea,sort,education,age,matter,book,view,half,reason,hands,heard,national,months,political,death,police,black,car,start,wrong,bit,light,feeling,leave,talk,act,play
# =========================
# The prime document for EC statistics is now the VAT return. All who are engaged
# in intra-EC trade must now show thereon the total value of all goods dispatched
# to other EC customers and received from other EC suppliers in the special boxes
# provided on the return form. Where either category has exceeded £135,000 during
# 1992 further, more detailed information has to be submitted within the very
# strict time limit of ten working days after each month end. Known as the
# Intrastat system, the data can be submitted by a computerised medium but only if
# it meets Customs specification requirements and has prior approval. Specific
# details relating to each consignment are required but values and quantities may
# be aggregated where all other details are identical. Up to ten items of coded
# information are required comprising such details as the commodity reference of
# the goods, delivery terms, weight, method of transport and, for arrivals, the
# country of origin.
# **********
# time,people,information,government,system,company,cent,set,world,day,form,local,business,found,life,public,party,data,market,social,national,terms,house,home,children,service,act,court,development,law,country,left,control,change,period,days,minister,support,services,money,major,level,including,process,required,held,power,school,section,trade,means,provide,women,price,person,effect,office,political,policy,research,council,called,report,question,main,times,cost,subject,family,systems,special,rate,million,view,management,result,total,economic,range,water,education,labour,companies,position,months,week,individual,staff,evidence,study,tax,told,provided,hand,contract,details,book,society,based,international
# =========================
# Back home, the observation would have been no less apt. In the years leading up
# to the First World War the Hooligan embarked on a remarkable career, appearing
# in name if not in person before numerous governmental and semi-official bodies
# of enquiry. He loomed large in the apocalyptic discourse surrounding the fears
# of racial decline and physical inefficiency. He figured centrally in the
# Edwardian era's deliberations on the ‘boy labour’ question. He would crop up
# repeatedly in the anxious preoccupation with the demoralising influence of
# popular amusements, the collapse of ‘fair play’ sportsmanship, and the
# allegations of excessive ‘freedom’and ‘affluence’ that were levelled
# against the young. The name of the Hooligan, in fact, provided a crystallising
# focus for any number of overlapping anxieties associated with imperial decline,
# military incapacity, the erosion of social discipline and moral authority, the
# eclipse of family life, and what was feared to be the death rattle of ‘Old
# England’.
# **********
# time,people,government,world,life,social,home,day,political,public,children,local,party,war,found,family,house,national,women,set,system,left,power,labour,cent,school,form,country,support,law,economic,told,change,society,act,development,terms,head,major,hand,days,century,called,times,question,education,company,information,control,period,john,view,person,policy,court,sense,business,police,means,money,authority,looked,child,night,level,service,evidence,death,mind,held,council,age,market,black,book,history,real,play,father,result,mother,past,community,position,main,experience,action,process,minister,west,body,effect,feel,care,matter,common,human,eyes,services,difficult
# =========================
# In fact, as I soon discovered, these ruins are inhabited. I met the old lady as
# I was walking down a steep path out of the village. She was struggling up, bent
# under a heavy sack. We greeted each other. The skin of her face hung in purple
# folds and the old eyes were blurred with cataract. When I offered to carry her
# sack she waved me aside. Who was this impertinent stranger eyeing her baggage?
# We moved on up to her tumbledown tower on the last crag of the village. At the
# base was a terrace with one stool on it. Before us stretched an enormous view of
# mountain, promontory and shimmering sea. From my pack I offered her an apple,
# the only food I had. She dismissed it with a regal gesture. Then I saw her
# toothless gums. I left her in peace with her bundle, her stool and her majestic
# view.
# **********
# time,people,day,left,looked,house,eyes,head,life,found,hand,world,home,told,night,round,door,children,water,set,days,road,called,mother,mind,father,woman,white,black,family,light,village,moment,government,voice,body,women,hands,top,feel,local,half,front,heard,money,love,car,past,times,hard,school,country,john,stood,morning,week,held,feet,war,party,view,table,food,dark,close,north,air,sea,south,company,bed,leave,business,sat,church,girl,line,hair,child,god,bit,brought,town,sir,system,street,lot,taking,main,form,words,public,moved,inside,late,coming,city,real,months,idea
# =========================
# Such integration can be largely formal; in Lesotho, for instance, the evidence
# of real integration in between Mathematics and Science is very slight. On the
# other hand it may represent a genuine attempt by specialists in related subjects
# to sit down together and plan a programme which allows for separate activities
# but suggests common themes and provides examples of integrated lessons as in the
# Nigerian Cultural and Creative Art syllabus. Yet again it may be the product of
# basic rethinking and true integration founded on new objectives and a fresh
# approach as in the Social Studies syllabus now under development in Sierra Leone
# where an integrated programme with significant regional variations is being
# planned in a series of central and local workshops and where a special series of
# booklets on skills development (e.g. map making, note taking skills, creative
# skills) is being produced for teachers.
# **********
# time,people,social,government,school,development,local,system,world,information,education,children,life,set,national,found,form,day,public,research,women,level,study,language,political,cent,teachers,support,change,company,business,schools,process,training,home,community,programme,management,terms,students,major,economic,market,art,subject,control,experience,party,house,staff,skills,policy,left,power,society,service,means,provide,services,country,approach,view,head,individual,range,family,main,book,evidence,history,common,studies,teaching,care,including,period,hand,question,based,pupils,called,council,knowledge,health,systems,special,data,central,practice,sense,science,class,labour,real,role,project,involved,effect,child,future
# =========================
# Regarding access to health care, we meet the fact that women usually live longer
# than men. This is one area of life in which women have a definite advantage! It
# would appear that access to the health service is reasonably equitable between
# men and women, and that women's longer lives should not be attributed to
# prejudice against men in the health sector! However, some writers have suggested
# that the diseases commonly found among men are treated with greater concern and
# more expensive medical treatment than those more commonly found among women. For
# instance, attention has recently been drawn to the inadequate provision of
# screening for cervical cancer despite the fact that this service could provide
# the means of identifying early forms of the disease before it reaches its
# incurable and lethal stage. (More discussion of women and health can be found in
# chapter 9, section 9.5.)
# **********
# women,time,people,health,life,social,children,patients,care,government,found,world,local,service,day,public,home,cent,system,information,family,services,age,form,set,house,national,disease,act,treatment,education,support,development,school,left,community,study,child,company,control,change,research,person,means,terms,money,court,law,evidence,hospital,woman,power,society,political,told,business,party,effect,level,provide,major,labour,question,view,period,country,common,medical,section,days,called,human,authority,staff,cancer,process,times,result,experience,hand,policy,report,body,difficult,market,head,feel,water,main,including,individual,mother,subject,practice,position,role,private,months,book,management
# =========================
# The Dinner or Luncheon Party: Whatever time of day it is, this is most likely to
# mean inviting a group of people over for a ‘sit-down’ meal. The grandness of
# the meal, and how much of it you pay for, depends upon the expectations of
# yourself and your guests and perhaps their relationship to you. If, say, you are
# a young person — student or worker — who has invited over friends of the
# same age, they will probably expect to bring a bottle of wine with them. In
# fact, most friends, of any age, would bring a bottle of something — unless the
# dinner party was very grand. Relatives often seem to feel that they do not need
# to bring a contribution, unless, of course, you are young, living alone for the
# first time and being visited by your mother, in which case she will probably
# bring a month's supply of food and wash up for you as well!
# **********
# time,people,day,life,home,party,house,children,world,left,found,told,mother,government,family,looked,women,social,night,money,set,head,days,person,local,school,hand,father,feel,age,eyes,food,cent,called,water,week,child,mind,care,country,friends,love,john,support,labour,round,national,company,business,public,woman,change,system,times,door,table,held,service,information,lot,half,form,months,evening,war,friend,past,hard,morning,political,wife,job,real,moment,office,car,power,white,leave,question,court,act,parents,body,pay,means,god,brought,bed,idea,talk,black,bit,wine,taking,living,book,sense,major,health
# =========================
# The implementation of care management in April could rapidly illustrate how the
# admirable intentions of the government's community care policy might founder on
# the unintended consequences of more powerful forces and contradictions. Firstly,
# although the transfer of social security funds will allow more needs driven
# services, it will also cash limit expenditure. Secondly, this transfer punishes
# local authorities with few residential care homes and cuts off money for future
# expansion. Thirdly, the directive that care managers should not themselves give
# direct care runs counter to the core of good social work practice and creates a
# new corps of care administrators, thereby reducing the number of staff available
# to give direct care. Fourthly, no central guidance has emerged on how to
# coordinate at the local level, care management, the care programme approach, and
# hospital discharge procedures, thus inviting triplication of planning effort.
# **********
# people,time,care,government,local,social,services,health,system,children,community,home,public,cent,service,world,life,national,development,information,management,day,policy,support,set,company,staff,money,control,act,education,business,political,family,found,party,house,form,authority,women,change,school,power,authorities,market,court,level,council,law,major,provide,terms,child,left,economic,labour,research,country,training,practice,process,society,means,hospital,private,person,view,future,individual,programme,action,report,effect,result,war,planning,central,main,approach,minister,period,question,million,patients,role,including,financial,told,days,involved,office,cost,workers,called,position,held,hand,pay,difficult,provided
# =========================
# It was a great discovery. But it was utterly disastrous for classical physics.
# An electron encircling a nucleus is continuously subject to acceleration as its
# velocity keeps on changing direction. (Acceleration is just the rate of change
# of velocity.) It is an inexorable consequence of classical physics that such an
# accelerating electron radiates off some of its energy at a frequency
# corresponding to the frequency of the electron's circulation. This causes the
# electron to move closer to the nucleus and changes the frequency. The radiation
# loss continues. In other words, a classical "solar system" atom under
# electromagnetic forces is nothing like the actual solar system held together by
# gravitational forces. The atom would be unstable, as its electrons spiralled
# ever closer to the nucleus, and it would emit its dying radiation in a band of
# frequencies with no trace of discreteness. The nuclear atom dealt
# the coup de grâce to classical physics.
# **********
# time,energy,people,system,electron,world,found,theory,light,form,government,life,called,change,power,physics,rate,set,nuclear,electrons,field,cent,effect,day,information,left,particles,force,times,water,position,radiation,terms,matter,control,figure,level,black,result,means,frequency,atom,quantum,social,range,local,research,mass,forces,science,nucleus,atoms,development,body,period,process,shown,party,house,national,study,surface,single,line,earth,hand,similar,children,subject,words,evidence,section,low,space,major,public,money,classical,political,head,home,nature,view,real,century,war,million,results,structure,human,data,women,cells,idea,school,main,sun,law,patients,question
# =========================

# %% [markdown]
# Calculate the predictions for the experimental stimuli in the recognition test and also for the recalled words.

# %%
cooccurrence_predictions = {}
for text_name in memoranda:
    
    _, n = text_name.split('_')
    n = int(n)+1
    
    inwords = memoranda[text_name]['inwords'].split(',')
    outwords = memoranda[text_name]['outwords'].split(',')
    
    for word in inwords+outwords+recalled_words:
        
        try:

            prob = predictions[text_name][word]
            cooccurrence_predictions[str(n) + '-' + word] = prob
            
        except KeyError:
            
            print('Unknown word in text %s: "%s"' % (text_name,word))

cooccurrence_statistics_pkl = cache_fullpath('word_associates_from_cooccurrence_statistics.pkl')

with open(cooccurrence_statistics_pkl, 'wb') as f:
    pickle.dump(cooccurrence_predictions, f, protocol=2)    

assert utils.checksum(cooccurrence_statistics_pkl) == '234ce9f4d9dda7aca73947e562088b7aae8a5b87abe409121e36abd89b7d95c1'
# Out:
# Unknown word in text text_22: "dhow"

# %% [markdown]
# ## Create csv file with predictions for recalled words
#
# Here, we'll create a special file for use with the multionomial logistic regression modelling of the recall memory results. This file is a $J \times V^\prime + 1$ matrix, written as a csv file, where $J$ is the number of texts and $V^\prime$ is the set of recalled words, across all participants, that are also in the training corpus vocabulary.
#
# See `posterior-predictive-distributions` notebook for more details. There, an identical procedure is followed.

# %%
predictive_probabilities = []
text_names = sorted(predictions.keys(), key=lambda arg: int(arg.split('_')[1]))
for text_name in text_names:
    f = []
    for word in recalled_words:
        f.append(predictions[text_name][word])
    predictive_probabilities.append(f)

predictive_probabilities = numpy.array(predictive_probabilities)

predictive_probabilities = numpy.c_[predictive_probabilities, 1-predictive_probabilities.sum(1)]

header = ','.join(recalled_words + ['ALTERNATIVE_WORD'])

M = [header]
for i,f in enumerate(predictive_probabilities):
    M.append(text_names[i] + ',' + ','.join(map(str, f)))
M = '\n'.join(M)
    
cooccurrences_predictions_of_recalled_words = 'cooccurrences_predictions_of_recalled_words.csv'

with open(cache_fullpath(cooccurrences_predictions_of_recalled_words), 'w') as f:
    f.write(M)

# Verify the integrity of the exported csv file.
assert utils.checksum(cache_fullpath(cooccurrences_predictions_of_recalled_words))\
    == '4485c67d826cb43ae74cd9285c24f30cae75b09f2cdd0d17777eb23288e6cc06'
