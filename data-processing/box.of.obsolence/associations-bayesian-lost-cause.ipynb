# %% [markdown]
# # Predicted Word Associates of Texts, based on Word Association Norms
#
# Here, we calculated the predicted word associates of the texts that are used in the text memory experiment. These predictions can be used to test a word association account of text memory.

# %% [markdown]
# ## A probabilistic model of Word Association Data
#
# In a typical word association task, participants are given a word and asked to produce words that are related to it. For example, for the word "house", the participant might give the words "door", "window", "garden", etc. For a given stimulus word $w_j$, and combining responses across all participants, we can list the response words as $r_{j1}, r_{j2} \ldots r_{jn_j}$. A simple probabilistic generative of these responses is as follows:
# $$
# r_{ji} \sim \mathrm{dcat}(\pi_j), \quad \text{for $i \in \{1, 2 \ldots n_j\}$},
# $$
# where $\pi_j$ is a categorical probability distribution over the $V$ word types in the language. A hierarchical or multilevel model would model each $\pi_j$ itself as being drawn from a Dirichlet distribution, i.e.
# $$
# \pi_j \sim \mathrm{ddirich}(\alpha)
# $$
# where $\alpha$ are the (hyper)-parameters of the Dirichlet distribution, which can also be written as $\alpha = a\cdot m$, where $a > 0 $ is the scalar concentration parameter and the categorical distribution $m$ is the location parameter.
#
# The posterior distribution over $\pi_j$ is
# $$
# \mathrm{P}(\pi_j \vert \mathcal{D}) = \int \mathrm{P}(\pi_j \vert \mathcal{D}, a, m)\mathrm{P}(a, m \vert \mathcal{D}).
# $$
# Here,  $\mathcal{D})$ signifies the observed data, and
# $$
# \mathrm{P}(\pi_j \vert \mathcal{D}, a, m) = \mathrm{Dirichlet}(R_j ; a, m)
# $$
# where $R_j = R_{j1}, R_{j2} \ldots R_{jk} \ldots R_{jV}$ and $R_{jk}$ is the frequency with which word $w_k$ is produced as an associate of word $w_j$.
# We can approximate $\mathrm{P}(\pi_j \vert \mathcal{D})$ as follows:
# $$
# \begin{align}
# \mathrm{P}(\pi_j \vert \mathcal{D}) &= \int \mathrm{P}(\pi_j \vert \mathcal{D}, a, m)\mathrm{P}(a, m \vert \mathcal{D}),\\
# &\approx \mathrm{P}(\pi_j \vert \mathcal{D}, \hat{a}, \hat{m})
# \end{align}
# $$ where $\hat{a}$ and $\hat{m}$ are the means of the posterior distribution $\mathrm{P}(a, m \vert \mathcal{D})$.
#
#
# With this model, the probability of responding with word $w_k$ given word $w_j$ as a stimulus word is simply
# $$
# \mathrm{P}(w_k \vert w_j) = \int \mathrm{P}(w_k \vert w_j, \pi_j) \mathrm{P}(\pi_j \vert  \mathcal{D}),
# $$
# which can be calculated in closed form as
# $$
# \mathrm{P}(w_k \vert w_j) = \frac{R_{jk} + a\cdot m_k}{a + \sum_{k=1}^V R_{jk}}
# $$
#
# Given a text
# $$
# \textrm{text} \triangleq w_{1}, w_{2} \ldots w_{n},
# $$
# the predicted probability that word $w_k$ is associated with $\textrm{text}_{j}$ is
# $$
# \mathrm{P}(w_k \vert \textrm{text}) = \frac{1}{n} \sum_{j = 1}^{n} \mathrm{P}(w_k \vert w_{j}).
# $$

# %% [markdown]
# ## Preparation
#
# Import modules; create classes and functions; download and prepare all the data files etc needed for this analysis

# %%
# %matplotlib inline

from __future__ import division

from matplotlib import pyplot
import matplotlib.pylab as pylab

from collections import defaultdict

import os

import configobj
import numpy
import pandas
import cPickle as pickle

from utils import utils, topicmodels

from gustav.samplers import fortransamplers

from numpy.random import randint, dirichlet, rand
from numpy import ones, zeros, unique, empty

import string

# %%
class MakeVocab(object):
    
    '''
    A class to make a vocabulary.
    '''
    
    @classmethod
    def new(cls, word_list):
        
        return cls(word_list)
    
    def __init__(self, word_list):
        
        self.V = len(word_list)
    
        self.word2index = {w:i for i,w in enumerate(word_list)}
        self.index2word = {i:w for i,w in enumerate(word_list)}

        
def text_to_words(text, vocabulary):
    '''Extract words from a text'''
    return [word 
            for word in utils.tokenize(text) 
            if word in vocabulary.word2index]


class WordAssociations(object):
    
    '''
    An class to store the word association data in a dict of dict format, e.g
    
    associations['stimulus']['associate'] = count
    
    where `count` gives the number of times that `associate` was listed
    as an associate of `stimulus`.
    
    '''
    

    def __init__(self, word_associations_data):
        
        self.word_associations_data = word_associations_data
            
        self.build_associations()

    def build_associations(self):
        
        self.associations = defaultdict(lambda : defaultdict(int))
        
        for row in self.word_associations_data:
            
            subject, stimulus, assoc1, assoc2, assoc3 = row.split(';')

            for associate in (assoc1, assoc2, assoc3):
            
                self.associations[stimulus][associate] += 1


def update(args):
    '''Gibbs sampler update function.
    To be sent to parallel workers.'''
    polya_sampler = _get_sampler(args)
    return polya_sampler.update(args['iterations'])

def sample(args):
    '''Gibbs sampler sampling function. 
    To be sent to parallel workeres.'''
    polya_sampler = _get_sampler(args)
    return polya_sampler.sample(args['iterations'], thin=args['thin'])

def _get_sampler(args):
    
    R = topicmodels.zeros((args['J'], args['V']))
    R[args['rows'], args['cols']] = args['values']
    
    if not 'inits' in args:
        inits = {}
    else:
        inits = args['inits']
    
    return topicmodels.DirichletMultinomialCompound(R, inits=inits)


def gelman_diag(psi):
    
    '''The Gelman-Rubin convergence diagnostic.'''
    
    m, n = psi.shape
    
    B = n * numpy.var(psi.mean(1), ddof=1)
    
    W = psi.var(1, ddof=1).mean() 

    V = (n-1)/n * W + B/n    

    return numpy.sqrt(V/W)

def get_argslist(args, nchains=3, results=None):
    
    '''Set up arg list to be sent to parallel workers.'''
    
    if results is None:
        return [args]*nchains
    else:
        argslist = [args]*len(results)
        if results is not None:
            for i,result in enumerate(results):
                argslist[i]['inits'] = result
        return argslist

# %%
url_root = 'http://www.lawsofthought.org/shared'

cache_directory = '../_cache'
cache_fullpath = lambda path: os.path.join(cache_directory, path)

filenames = {
    'experiment_cfg' : [('Brismo.cfg',
                         '909d9f8de483c4547f26fb4c34b91e12908ab5c144e065dc0fe6c1504b1f22c9')],
    'corpus' : [('bnc_78723408_250_500_49328.npz.bz2', 
                 'b9d828f7697871e01a263b8f3978911c70ff45cab9af4c86fbb43c3baef969d9')]
}

utils.curl(url_root,
           filenames['experiment_cfg'] + filenames['corpus'], 
           cache=cache_directory,
           verbose=False)

stimuli = configobj.ConfigObj(cache_fullpath('Brismo.cfg'))['text_memoranda']

corpus_data = utils.loadnpz('bnc_78723408_250_500_49328.npz.bz2', 
                            cache=cache_directory,
                            verbose=False)

bnc_vocabulary = MakeVocab.new(word_list=corpus_data['vocabulary'])

texts = {}
for key,value in stimuli.items():
    texts[key] = text_to_words(value['text'], vocabulary=bnc_vocabulary)

# %% [markdown]
# The following assumes that the file `associations_en_05_01_2015.csv.bz2`, whose sha256 checksum is `06a527e5c9647f37a4a2ee0744a309f57f259e203238b87e0f466b74f7a6e63e` is available in the `_cache` directory.
#
# This is a compressed csv file of word association norms collected at https://www.smallworldofwords.org/en and generously shared by Simon De Deyne (https://simondedeyne.me/).
#
# Unfortunately, I am not at liberty to share this data presently, and so please contact either Simon De Deyne or Gert Storms in order to obtain it.

# %%
word_associations_data = utils.loadcsv('associations_en_05_01_2015.csv.bz2', 
                                       cache=cache_directory)

# %% [markdown]
# We'll restrict ourselves to stimulus words that are in our BNC corpus vocabulary. We'll restrict ourselves to associate words that are in the BNC corpus and the set of recalled words that are in the BNC corpus.

# %%
word_associations = WordAssociations(word_associations_data)

# Get the stimulus vocabulary 
stimulus_vocabulary_word_list = sorted([word.lower() 
                                        for word in word_associations.associations.keys() 
                                        if word in bnc_vocabulary.word2index])

stimulus_vocabulary = MakeVocab.new(stimulus_vocabulary_word_list)

# Get the association vocabulary
association_vocabulary = []
for stimulus in word_associations.associations:
    association_vocabulary.extend(
        [word.lower() for word in word_associations.associations[stimulus].keys() 
         if word.lower() in bnc_vocabulary.word2index]
    )

Df = {}
Df['recall'] = pandas.read_pickle(cache_fullpath('brisbane_06b643a_recall_results.pkl'))

recalled_words = sorted(set(map(string.lower, Df['recall']['word'].values)).intersection(corpus_data['vocabulary']))
  
association_vocabulary_word_list = sorted(set(association_vocabulary + recalled_words))

associate_vocabulary = MakeVocab.new(association_vocabulary_word_list)

# %% [markdown]
# The following creates a sparse representation of the $R$ count matrices.

# %%
rows = []
cols = []
values = []
for stimulus_word in word_associations.associations:
    for associate_word in word_associations.associations[stimulus_word]:
        
        try:
            
            j = stimulus_vocabulary.word2index[stimulus_word]
            k = associate_vocabulary.word2index[associate_word]

            value = word_associations.associations[stimulus_word][associate_word]

            rows.append(j)
            cols.append(k)
            values.append(value)
        
        except KeyError:
        
            pass
        
args = dict(rows = rows,
            cols = cols,
            values = values,
            J = stimulus_vocabulary.V,
            V = associate_vocabulary.V)

# %% [markdown]
# ### Start Cluster

# %%
# Start a cluster on the command line with "ipcluster start -n NCHAINS" 
# where NCHAINS is at least as large as the number of chains you are using in the sampler

from ipyparallel import Client

clients = Client()

clients.block = True

clients[:].push(dict(_get_sampler=_get_sampler));
    
with clients[:].sync_imports():
    from utils import topicmodels

view = clients.load_balanced_view()
# Out:
# importing topicmodels from utils on engine(s)

# %% [markdown]
# Update the Gibbs samplers. The convergence rate seems fast so 1000 should be more than enough for burn-in. Of course, we will check it below too.

# %%
args['iterations'] = 1000

results = view.map(update, get_argslist(args, nchains=3))

# %%
results
# Out:
# [{'b': 57.43008610933294,
#   'c': 9082.968124977902,
#   'psi': array([  3.89411886e-06,   1.39080836e-05,   2.57947939e-05, ...,
#            1.60232471e-06,   5.99696632e-07,   9.28083264e-06])},
#  {'b': 57.437841789043254,
#   'c': 9218.723392788199,
#   'psi': array([  5.25172384e-06,   8.20211914e-06,   1.36864105e-05, ...,
#            3.46497564e-06,   2.26439891e-06,   8.70785626e-06])},
#  {'b': 57.48626355278941,
#   'c': 9257.17816973585,
#   'psi': array([  5.61182204e-06,   8.02518121e-06,   2.46929404e-05, ...,
#            2.41954770e-06,   6.81463237e-07,   8.98309333e-06])}]

# %% [markdown]
# Now, sample from `b`, `c` and `psi`.

# %%
args['iterations'] = 100
args['thin'] = 10

samples = view.map(sample, get_argslist(args, results=results))

# %% [markdown]
# Check diagnostics for `b` and `c` using Gelman-Rubin.

# %%
gelman_diag(numpy.array([samples[k]['c'] for k in (0, 1, 2)]))
# Out:
# 0.99543353533485535

# %%
gelman_diag(numpy.array([samples[k]['b'] for k in (0, 1, 2)]))
# Out:
# 0.99523360612496081

# %% [markdown]
# For the `psi`, we will simply check if the mean vectors of each chain are more or less identical, i.e. highly intercorrelated.

# %%
psi = numpy.array([numpy.array(samples[k]['psi']).mean(0) for k in (0, 1, 2)])
numpy.corrcoef(psi)
# Out:
# array([[ 1.        ,  0.99995385,  0.99995504],
#        [ 0.99995385,  1.        ,  0.99995483],
#        [ 0.99995504,  0.99995483,  1.        ]])

# %% [markdown]
# Now, average across the samples to be `b` and `psi`, which are actually the `a` and `m`, respectively, in the description at the top of this page.

# %%
psi = psi.mean(0)

b = numpy.array([samples[k]['b'] for k in (0, 1, 2)]).mean()

bpsi = b * psi 

R = topicmodels.zeros((args['J'], args['V']))
R[args['rows'], args['cols']] = args['values']

smoothed_association_matrix = ((R + bpsi).T/(R + bpsi).sum(1)).T

# %% [markdown]
# Some more sanity checking. Sample some words, and make sure their associates according to the model match the original data.

# %%
def check_some_words(K, N, seed):
    random = numpy.random.RandomState(seed)
    
    for k in random.permutation(smoothed_association_matrix.shape[0])[:K]:
        
        smoothed_associates = ','.join([associate_vocabulary.index2word[i] 
                                        for i in numpy.flipud(numpy.argsort(smoothed_association_matrix[k]))[:N]])
        
        original_associates = ','.join([associate_vocabulary.index2word[i] 
                                        for i in numpy.flipud(numpy.argsort(R[k]))[:N]])
    
    
        print(stimulus_vocabulary.index2word[k].capitalize())
        print('Smoothed: ' + smoothed_associates)
        print('-'*10)
        print('Original: ' + original_associates)
        print('='*100)

check_some_words(25, 100, 1001)
# Out:
# Respond
# Smoothed: answer,reply,question,talk,call,letter,response,speak,listen,communicate,react,return,email,retort,paper,test,quick,phone,write,pond,quickly,emergency,interview,rebuttal,reciprocate,school,time,sex,children,cat,words,smile,fight,anger,read,choice,flight,pen,voice,wave,correct,text,forward,key,respect,talking,communication,homework,argue,button,conversation,agree,professional,shout,waiting,message,hear,reaction,telephone,speaking,send,needy,command,awake,concern,acknowledge,automatic,request,comment,meetings,ambulance,controlled,feedback,invitation,attend,query,critique,immediately,interpret,coma,unresponsive,comeback,concur,validate,generate,resign,bicker,remit,adroit,paraphrase,resurrect,rejoinder,concisely,food,money,water,love,red,fun,bad
# ----------
# Original: answer,reply,question,talk,call,letter,response,react,speak,listen,communicate,return,email,retort,interview,pond,rebuttal,paper,reciprocate,phone,quick,emergency,quickly,write,test,waiting,agree,read,resign,sex,coma,fight,speaking,concur,validate,reaction,interpret,conversation,query,immediately,children,hear,adroit,argue,respect,choice,professional,talking,concern,command,shout,homework,ambulance,attend,telephone,meetings,resurrect,key,cat,feedback,concisely,comeback,remit,comment,time,controlled,awake,flight,paraphrase,pen,acknowledge,anger,rejoinder,correct,invitation,needy,send,text,automatic,forward,generate,voice,wave,message,unresponsive,words,request,bicker,button,smile,critique,school,communication,fervour,female,fertilize,fertile,females,feminine,femininity
# ====================================================================================================
# Melted
# Smoothed: cheese,ice,hot,chocolate,snow,butter,heat,molten,water,lava,metal,heart,liquid,plastic,puddle,sun,frozen,wax,oozing,love,red,fire,warm,soft,wet,gold,cream,steel,fluid,candle,watery,snowman,glacier,liquefied,sad,summer,brain,bread,mess,winter,candy,smoke,soup,sweat,sticky,iron,flow,environment,destruction,glue,witch,rubber,relaxed,hood,copper,drip,gooey,atmosphere,melt,popcorn,volcano,sensual,burnt,damaged,furnace,dryer,heated,destroyed,runny,iceberg,toaster,glob,crayons,drippy,ran,thaw,cooled,flowed,thawed,dripped,dissolved,seeped,oozed,defrosted,fudged,food,money,fun,bad,white,school,green,people,car,time,happy,black,life,sex,music
# ----------
# Original: cheese,ice,hot,snow,butter,chocolate,heat,molten,water,lava,liquid,metal,heart,plastic,puddle,frozen,sun,wax,oozing,candle,love,liquefied,warm,soft,cream,fire,gold,wet,fluid,glacier,snowman,watery,steel,red,sweat,crayons,oozed,glob,popcorn,ran,furnace,soup,defrosted,copper,sad,witch,drippy,destruction,cooled,dripped,sticky,drip,volcano,gooey,hood,summer,dryer,rubber,candy,environment,burnt,toaster,flowed,brain,dissolved,relaxed,mess,glue,smoke,iron,heated,winter,seeped,runny,atmosphere,sensual,destroyed,flow,thaw,thawed,bread,melt,iceberg,damaged,fudged,ferrous,feminine,ferocious,ferret,ferrets,fen,femininity,ferries,fern,fence,ferns,ferment,femur,fermenting,fend
# ====================================================================================================
# Quiet
# Smoothed: silent,silence,peace,peaceful,calm,hush,loud,library,time,shy,noiseless,noise,mouse,shush,sleep,whisper,serene,hushed,soft,tranquil,shh,zone,riot,neighborhood,eerie,reserved,restful,subdued,retiring,quietude,music,person,child,study,dark,home,space,cool,tired,church,quiet,class,night,teacher,secret,gray,special,woods,low,read,dream,reading,noisy,awkward,cats,private,storm,piano,period,hall,content,sleepy,bother,countryside,western,front,times,lacking,sleeping,reasonable,aloof,meek,serenity,softly,introvert,discontent,restore,calmness,tigers,respite,lark,sash,reticent,bucolic,thud,cougar,snowy,soundless,equanimity,somnolent,quiescent,food,money,water,love,red,fun,bad,white,school
# ----------
# Original: silent,silence,peace,peaceful,calm,hush,library,loud,time,noiseless,shy,shush,noise,mouse,whisper,sleep,hushed,serene,soft,tranquil,shh,quietude,reserved,eerie,neighborhood,retiring,riot,zone,subdued,restful,low,cool,countryside,read,period,special,night,front,storm,reticent,reasonable,restore,cougar,person,dream,dark,calmness,discontent,piano,study,meek,softly,space,sash,cats,awkward,western,tired,class,tigers,respite,introvert,sleeping,times,bother,secret,snowy,sleepy,home,reading,hall,content,lacking,thud,teacher,bucolic,soundless,aloof,private,lark,woods,quiet,quiescent,music,serenity,church,somnolent,noisy,equanimity,child,gray,females,fete,fetching,festooned,fetched,feminist,femininity,feta,fetal
# ====================================================================================================
# Rarity
# Smoothed: unusual,uncommon,unique,rare,precious,gem,scarce,special,treasure,antique,valuable,expensive,endangered,oddity,seldom,odd,infrequent,scarcity,love,gold,stone,strange,ancient,diamond,obscure,diamonds,jewels,singular,sparse,antiques,occurrence,undiscovered,food,book,beauty,box,lost,chair,picture,exciting,adventure,amazing,golden,common,object,furniture,pure,kindness,exotic,identity,regret,museum,demand,dear,stamp,vase,perception,pony,cabinet,abnormal,belonging,resource,sarcasm,album,obsolete,unicorn,ace,surprising,artifact,cactus,priceless,vinyl,relic,eclipse,dearth,ponies,enigmatic,uniqueness,bootleg,artefact,serendipitous,weirdness,collectable,applejack,vapours,money,water,red,fun,bad,white,school,green,people,car,time,happy,black,life,sex
# ----------
# Original: unusual,uncommon,rare,unique,precious,scarce,gem,special,treasure,antique,valuable,expensive,oddity,seldom,endangered,odd,infrequent,scarcity,sparse,strange,occurrence,singular,obscure,antiques,jewels,diamond,diamonds,love,undiscovered,ancient,stone,gold,pony,ponies,adventure,ace,exotic,artifact,priceless,cactus,common,golden,bootleg,chair,relic,amazing,artefact,vinyl,surprising,dearth,weirdness,vase,dear,regret,uniqueness,lost,stamp,picture,box,vapours,belonging,unicorn,album,applejack,resource,perception,furniture,sarcasm,enigmatic,museum,book,pure,kindness,food,collectable,object,obsolete,abnormal,demand,exciting,identity,eclipse,serendipitous,cabinet,beauty,feminist,fibrous,fend,fender,fez,fennel,fey,fens,fewest,feral,fiancee,ferment,females,fewer,feverish
# ====================================================================================================
# Teaching
# Smoothed: learning,school,teacher,student,class,education,learn,blackboard,children,knowledge,classroom,students,books,apple,university,study,instructing,hard,wisdom,sharing,chalk,college,caring,desk,talking,professor,training,profession,teachers,studying,pupil,chalkboard,love,people,time,music,book,words,smart,job,math,talk,female,information,plan,language,tool,board,reading,colors,thoughtful,growth,process,left,pet,follow,enjoy,sight,degree,responsible,sweater,subject,scene,lecture,patience,manners,load,moment,ideal,hearing,discovery,awareness,helping,growing,satisfaction,assistant,enjoyable,notebook,assignment,inspiration,license,instruction,transfer,primary,lessons,allowance,educate,tutor,aide,encouraging,peers,underpaid,enlightening,lecturer,affiliation,guiding,lectures,curriculum,expanding,explaining
# ----------
# Original: learning,teacher,school,student,class,education,blackboard,learn,children,knowledge,students,classroom,university,apple,books,instructing,study,chalk,sharing,wisdom,hard,college,desk,caring,teachers,studying,chalkboard,talking,training,professor,pupil,profession,educating,time,lessons,people,thoughtful,language,smart,growing,math,load,degree,methodologies,female,expanding,curriculum,process,reading,tutorial,board,satisfaction,left,growth,helping,awareness,pedagogy,plan,mentoring,patience,lecturing,lectures,lecturer,educate,lecture,discovery,hearing,inspiration,encouraging,sweater,transfer,colors,information,license,words,preaching,book,notebook,primary,love,job,manners,scene,affiliation,guiding,tool,talk,pet,allowance,sight,follow,subject,underpaid,assignment,aide,enjoyable,peers,moment,assistant,instruction
# ====================================================================================================
# Scene
# Smoothed: movie,play,act,stage,crime,film,landscape,picture,view,theatre,drama,theater,vista,fight,park,beauty,social,actor,setting,music,tree,trees,winter,movies,set,sight,photo,hipster,director,scenery,obscene,goth,scenario,backdrop,love,red,green,black,book,game,girl,hair,fire,annoying,party,beautiful,change,kids,free,nature,rock,pretty,police,mountain,top,cut,action,television,plane,mess,short,kid,paint,parents,argument,gay,safety,event,accident,fashion,club,trip,fit,finish,magazine,crowd,painting,colorful,emotional,lights,image,camera,crying,shot,vision,score,corner,basketball,mood,tape,musical,video,pub,curtain,imagination,plot,opera,underground,hip,moment
# ----------
# Original: movie,play,act,stage,film,landscape,crime,picture,view,theatre,drama,theater,vista,park,fight,social,actor,setting,beauty,director,winter,obscene,movies,music,goth,set,trees,sight,tree,photo,hipster,backdrop,scenario,scenery,girl,tape,corner,paint,tantrum,rave,game,police,crying,fire,safety,hills,painting,vibe,magazine,piracy,plane,finish,basketball,hair,tragedy,accident,video,pub,mountain,image,imagination,camera,plot,crowd,acting,black,short,sitcom,love,shot,television,score,incident,free,doughnut,nature,green,trip,fashion,hip,demo,scenic,mess,entry,change,action,picnic,beautiful,related,opera,actors,colorful,curtain,kids,episode,venerable,lights,musical,kid,argument
# ====================================================================================================
# Meditate
# Smoothed: yoga,calm,peace,quiet,relax,pray,monk,peaceful,concentrate,breathe,ponder,mediate,sleep,focus,mind,prayer,breathing,buddy,ohm,religion,rest,silence,decide,spiritual,sitting,solitude,mindful,reflect,trance,dwell,centered,bad,time,music,study,scary,clean,god,ocean,forest,empty,helpful,judge,thinking,medical,bridge,join,practice,sit,middle,silent,relaxing,associate,candle,relaxation,vampire,float,trousers,breeze,healing,nun,pause,mat,meditation,negotiate,temple,settle,concentration,east,resolve,karma,tranquil,clam,diplomacy,guru,tranquility,pensive,monks,reflective,contemplate,eastern,stillness,chant,visualize,levitate,mysticism,hypnosis,alleviate,mantra,lotus,yogi,interpreter,food,money,water,love,red,fun,white,school
# ----------
# Original: yoga,calm,peace,quiet,relax,pray,monk,peaceful,concentrate,mediate,ponder,breathe,sleep,focus,buddy,breathing,ohm,mind,prayer,spiritual,silence,trance,dwell,reflect,mindful,solitude,rest,decide,centered,religion,sitting,levitate,guru,yogi,vampire,ocean,nun,breeze,tranquil,tranquility,middle,resolve,study,mantra,reflective,pause,sit,chant,karma,mysticism,concentration,lotus,thinking,empty,mat,float,forest,clam,helpful,bridge,meditation,time,clean,temple,candle,stillness,healing,interpreter,bad,medical,judge,practice,music,monks,contemplate,relaxation,trousers,silent,diplomacy,god,pensive,negotiate,east,eastern,settle,relaxing,scary,alleviate,hypnosis,visualize,join,associate,fez,fend,fencer,fiasco,fences,fencing,feudalism,fiat
# ====================================================================================================
# Thirteen
# Smoothed: unlucky,fourteen,teenager,candles,luck,lucky,prime,twelve,girl,superstition,age,teen,adolescent,claustrophobia,dozen,birthday,adolescence,thirty,floor,odd,puberty,eleven,fifteen,red,school,happy,life,house,family,baby,fear,teeth,film,day,moon,busy,date,pressure,universe,random,stairs,count,steps,teenagers,calendar,elevator,ghosts,acne,teenage,percent,hormones,braces,twenty,clocks,coven,sixteen,apostles,jinx,hotels,forcing,blackbirds,tantrums,food,money,water,love,fun,bad,white,green,people,car,time,black,sex,music,person,hard,pain,dog,cold,child,sad,blue,death,paper,woman,light,book,game,nice,study,dark,children,hair,hot,fire,science,power,home
# ----------
# Original: unlucky,fourteen,teenager,candles,luck,prime,twelve,lucky,superstition,girl,adolescent,teen,claustrophobia,age,dozen,thirty,adolescence,birthday,odd,fifteen,eleven,floor,puberty,coven,jinx,hormones,percent,house,school,twenty,ghosts,calendar,elevator,teenagers,blackbirds,count,day,date,family,forcing,braces,tantrums,film,fear,teenage,stairs,hotels,clocks,baby,sixteen,universe,happy,steps,red,apostles,teeth,busy,random,moon,pressure,acne,life,femoral,feminists,feminist,ferrets,ferrous,ferries,feminism,ferrule,femur,ferry,feminine,femininity,fence,fen,ferret,fertile,fend,fennel,fencing,fences,fens,feral,ferment,fermentation,fermented,fermenting,fern,ferns,fencer,fenced,ferocious,fender,zygote,fervent,fertilisation,fiasco,fetus,feud
# ====================================================================================================
# Pair
# Smoothed: couple,shoes,socks,pear,duo,set,cards,double,join,twins,aces,gloves,matching,fruit,pants,marriage,birds,match,dice,matched,love,horses,scissors,testicles,duet,pare,hair,friend,party,eyes,apple,eggs,association,share,boots,bond,ears,rape,item,breasts,similar,trousers,apples,tits,half,sock,diamonds,related,hearts,rack,teamwork,twin,lovers,bananas,pigeon,earrings,panties,sisters,lone,pod,couples,electrons,dual,oxen,complement,skates,pears,blessings,paradox,tandem,antagonistic,doves,matchmaking,complementing,food,money,water,red,fun,bad,white,school,green,people,car,time,happy,black,life,sex,music,person,hard,pain,house,dog,cold,child,sad,blue
# ----------
# Original: couple,shoes,socks,pear,duo,set,cards,double,aces,join,twins,gloves,matching,match,pants,birds,matched,fruit,marriage,dice,duet,testicles,horses,scissors,love,pare,skates,teamwork,association,tandem,hearts,complement,complementing,rape,similar,diamonds,lone,pod,antagonistic,twin,tits,oxen,eggs,matchmaking,pigeon,related,ears,friend,breasts,bond,hair,sock,bananas,doves,apple,rack,trousers,paradox,apples,couples,party,electrons,sisters,boots,share,eyes,lovers,panties,dual,half,item,earrings,blessings,pears,ferrule,ferrous,ferries,ferrets,ferret,zygote,ferocious,fend,feminists,femoral,femur,fen,fence,fenced,fencer,fences,fencing,fender,ferns,fennel,fens,fertile,feral,ferment,fermentation,fermented
# ====================================================================================================
# Lift
# Smoothed: elevator,raise,heavy,carry,weight,rise,weights,hold,airplane,box,strength,force,physics,pull,fork,elevate,power,chair,push,cloud,spirit,throw,drop,object,ride,bend,wings,uphold,heft,heighten,hoist,food,people,happy,light,strong,baby,fear,clean,politics,hat,air,move,wind,mountain,hands,fly,stone,legs,positive,hungry,sugar,flight,arm,electricity,president,arms,fluid,hug,button,balloon,swing,feather,vehicle,arrow,current,tidy,smash,vase,pound,earthquake,ski,grip,buttons,draft,inspire,chin,doors,heels,balloons,spirits,erect,crane,pedestal,airplanes,confined,lorry,heave,ascend,loft,floors,dale,perk,brighten,levitate,stops,storey,money,water,love
# ----------
# Original: elevator,raise,carry,heavy,weight,weights,rise,hold,airplane,box,fork,force,pull,physics,elevate,strength,power,spirit,chair,uphold,push,throw,hoist,cloud,drop,wings,bend,heft,ride,object,heighten,legs,hat,arrow,inspire,chin,stops,wind,fly,president,storey,mountain,perk,baby,airplanes,floors,levitate,electricity,feather,strong,brighten,flight,current,sugar,vehicle,draft,move,air,lorry,smash,stone,clean,grip,hug,pound,fluid,politics,arm,hungry,vase,arms,ski,buttons,dale,balloons,loft,tidy,ascend,hands,food,swing,balloon,heels,crane,heave,earthquake,doors,erect,light,happy,confined,fear,pedestal,spirits,positive,button,people,feminist,fend,fever
# ====================================================================================================
# Tango
# Smoothed: dance,orange,sexy,salsa,mango,music,passion,drink,shoes,cash,dancing,dress,waltz,fun,hot,romance,rose,couple,whiskey,ballroom,samba,foxtrot,flamenco,red,happy,sex,person,woman,book,hair,movie,heart,bird,difficult,film,apple,movement,military,wedding,airplane,juice,fence,wheel,leg,awkward,excitement,guitar,skirt,enemy,deer,wolf,grace,swing,nut,romantic,hip,lesson,steps,squirrel,dip,dancer,ballet,challenging,sensual,heels,demanding,elegance,alpha,citrus,clash,charlie,partners,sultry,mingle,chuck,fizzy,flair,tangent,rhythmic,tangerine,duet,flamingo,bravo,rumba,takes,food,money,water,love,bad,white,school,green,people,car,time,black,life,hard,pain
# ----------
# Original: dance,orange,sexy,salsa,mango,music,passion,drink,cash,dancing,shoes,dress,waltz,couple,rose,whiskey,ballroom,fun,samba,flamenco,romance,foxtrot,hot,challenging,difficult,charlie,juice,grace,military,person,hip,awkward,sultry,mingle,wolf,tangent,woman,rumba,skirt,rhythmic,movie,movement,lesson,tangerine,takes,enemy,book,demanding,apple,red,flamingo,flair,steps,fizzy,dancer,sensual,nut,sex,clash,hair,duet,film,elegance,wheel,citrus,squirrel,heart,alpha,bravo,guitar,heels,chuck,deer,wedding,fence,airplane,bird,leg,happy,dip,ballet,swing,romantic,partners,excitement,exist,executors,festered,fester,fervid,fervour,festival,fervently,fervent,fertilizer,fertilize,festering,festive,festivals,festivities
# ====================================================================================================
# Seasoning
# Smoothed: salt,spice,pepper,spices,herbs,food,cooking,chicken,taste,turkey,spicy,paprika,hot,meat,yummy,flavor,rub,herb,tasty,bread,winter,spring,experience,flavour,thanksgiving,dressing,sage,curry,cinnamon,savory,stuffing,thyme,green,nice,wood,fish,bird,slow,orange,fruit,dinner,flowers,oil,cook,fail,pot,lots,market,hunger,shake,steak,south,mix,salty,catholic,holidays,pork,recipe,cupboard,north,grill,onion,garlic,pour,mild,gardening,cuisine,mustard,enhance,ketchup,reasoning,salmon,aging,bottles,chili,zest,basil,rosemary,sprinkle,parsley,plethora,seasons,fauna,dune,oregano,tutu,initiation,poultry,cumin,grilling,piquant,cookware,bozo,curing,marinade,money,water,love,red,fun
# ----------
# Original: salt,spice,pepper,spices,herbs,food,cooking,chicken,turkey,taste,paprika,spicy,herb,hot,meat,rub,yummy,flavor,experience,dressing,savory,sage,cinnamon,thyme,thanksgiving,tasty,bread,stuffing,curry,flavour,winter,spring,bird,mild,poultry,initiation,bottles,hunger,fish,sprinkle,fruit,cook,market,cupboard,mustard,ketchup,slow,onion,garlic,piquant,seasons,chili,flowers,south,tutu,aging,orange,curing,shake,grill,grilling,recipe,dinner,pour,enhance,zest,north,cookware,pork,holidays,cuisine,parsley,basil,oil,plethora,bozo,reasoning,pot,steak,mix,wood,rosemary,lots,catholic,marinade,dune,salty,salmon,gardening,green,fail,fauna,nice,cumin,oregano,feral,fens,fennel,ferment,fermentation
# ====================================================================================================
# Conquest
# Smoothed: war,victory,win,conquer,battle,conquistador,adventure,king,sex,fight,religion,military,knight,roman,mission,defeat,capture,crusade,gold,history,goal,beat,paradise,dominate,knights,domination,invasion,overtake,bad,life,girl,power,women,word,dangerous,ocean,world,country,hate,control,army,loss,push,soldier,effort,desire,sword,task,challenge,past,destroy,avoid,castle,sexual,struggle,bomb,ruler,journey,conflict,achievement,winner,west,explore,ships,discovery,quest,kingdom,objective,mustache,dating,countries,triumph,civilization,kings,maps,monarchy,surrender,disability,voyage,swords,lovers,explorer,genocide,territory,emperor,victor,rewarding,vanquish,subdue,template,imperialism,overthrow,invader,pillage,colonialism,spoils,colonies,prowess,annex,militant
# ----------
# Original: war,victory,win,conquer,battle,conquistador,adventure,king,mission,sex,defeat,religion,knight,capture,fight,military,roman,crusade,overtake,gold,dominate,domination,history,invasion,knights,paradise,goal,beat,spoils,discovery,world,mustache,militant,country,ocean,control,imperialism,vanquish,conflict,emperor,explore,prowess,rewarding,west,hate,civilization,template,soldier,bad,sexual,invader,challenge,achievement,avoid,desire,countries,dating,effort,power,overthrow,quest,castle,struggle,ruler,journey,women,conquering,captivate,word,dangerous,triumph,conquered,bomb,crusades,crusaders,annex,domineering,objective,life,swords,disability,lovers,sword,kings,subdue,winner,maps,pillage,kingdom,army,explorer,territory,ships,loss,surrender,victor,task,genocide,push,colonialism
# ====================================================================================================
# Cubes
# Smoothed: ice,square,squares,dice,sugar,shape,math,geometry,boxes,blocks,box,cheese,shapes,spheres,art,office,solid,block,puzzle,jelly,root,circles,rectangle,corners,triangles,offices,rubric,hard,children,movie,wood,drink,ball,building,film,stone,memory,maths,straight,butter,mathematics,bottle,object,figure,honey,brick,rigid,pointy,bees,volume,crystal,sphere,pieces,companion,flute,roots,figures,metric,neon,tactile,thriller,cola,edges,geometric,spaces,planting,pixel,metre,towers,containers,chunks,dimensions,stacked,cuboid,holders,cages,cubicles,food,money,water,love,red,fun,bad,white,school,green,people,car,time,happy,black,life,sex,music,person,pain,house,dog,cold
# ----------
# Original: ice,square,squares,dice,sugar,shape,math,boxes,geometry,blocks,box,spheres,cheese,shapes,corners,puzzle,circles,solid,rubric,offices,office,root,rectangle,art,triangles,block,jelly,cuboid,straight,thriller,figures,tactile,geometric,cubicles,cola,figure,rigid,holders,memory,pointy,planting,movie,mathematics,maths,children,flute,cages,neon,stacked,dimensions,edges,bees,pieces,towers,bottle,brick,film,wood,object,stone,containers,companion,roots,ball,butter,metre,metric,pixel,volume,spaces,crystal,sphere,building,drink,honey,hard,chunks,femur,fen,fertiliser,femoral,fertilisation,fence,feminists,fenced,fertilise,fencer,fertility,fender,fences,fertile,ferns,ferocious,fermented,ferret,ferrets,fermentation,ferment,ferries,feral
# ====================================================================================================
# Declaration
# Smoothed: independence,statement,love,speech,loud,rights,declare,shout,announcement,paper,exclamation,war,freedom,document,bold,official,confidence,strong,politics,law,king,opinion,speaking,claim,signature,woman,words,police,travel,government,force,truth,plane,court,marriage,gay,speak,pride,legal,taxes,sentence,firm,final,speaker,agreement,grammar,airport,explain,honesty,laws,seal,major,programming,election,income,divorce,thesis,swear,forceful,outstanding,express,leadership,shouting,constitution,oath,engagement,nationality,demonstration,telling,proposal,certainty,conviction,principle,customs,announce,intention,treaty,messenger,imperial,import,eureka,finality,ejaculation,affirmation,decree,manifest,emphatic,edict,proclamation,utterance,firmness,stated,ultimatum,pronouncement,food,money,water,red,fun,bad
# ----------
# Original: independence,statement,love,speech,declare,rights,loud,shout,announcement,exclamation,paper,freedom,document,war,confidence,official,bold,strong,claim,speaking,king,law,opinion,signature,politics,express,ultimatum,proclamation,imperial,finality,swear,words,final,conviction,election,firmness,firm,marriage,ejaculation,explain,major,programming,eureka,plane,police,legal,import,woman,principle,divorce,affirmation,utterance,messenger,demonstration,engagement,outstanding,truth,nationality,grammar,agreement,income,speaker,speak,thesis,telling,decree,government,shouting,court,airport,emphatic,treaty,honesty,forceful,force,travel,customs,pride,certainty,taxes,constitution,seal,stated,edict,laws,gay,leadership,manifest,pronouncement,proposal,intention,oath,announce,sentence,feminist,fen,felling,flab,fence,fellow
# ====================================================================================================
# Cashew
# Smoothed: nut,peanut,nuts,tree,tasty,salt,yummy,almond,food,delicious,brown,fat,healthy,curve,salty,snack,allergy,crunch,chew,roasted,sweet,milk,yuck,chicken,yum,cream,butter,protein,sneeze,tin,snacks,curry,walnut,pecan,pistachio,white,green,soft,fight,expensive,brain,energy,beer,chocolate,dad,oil,store,bag,shape,boyfriend,market,salad,mix,shell,baking,seed,dish,crunchy,flavour,beige,curved,mixed,crop,academia,calories,chewy,brittle,pulse,allergies,choke,peanuts,raisin,fibre,wrestle,yoghurt,raisins,nutmeg,crescent,salted,hazelnut,caloric,eschew,guinea,planters,tastefully,money,water,love,red,fun,bad,school,people,car,time,happy,black,life,sex,music
# ----------
# Original: nut,peanut,nuts,tree,tasty,salt,yummy,almond,food,delicious,roasted,brown,chew,healthy,salty,fat,snack,crunch,allergy,curve,walnut,butter,snacks,sweet,tin,milk,protein,pecan,yum,sneeze,yuck,pistachio,curry,cream,chicken,boyfriend,eschew,shell,soft,pulse,brain,yoghurt,peanuts,nutmeg,raisins,raisin,store,market,expensive,baking,beer,brittle,bag,crop,curved,planters,crescent,academia,calories,dad,allergies,hazelnut,dish,mix,mixed,seed,shape,wrestle,tastefully,energy,green,guinea,fight,crunchy,white,beige,oil,fibre,caloric,choke,chewy,flavour,salted,salad,chocolate,femoral,fend,feminists,ferries,ferrous,ferrule,ferry,feminist,fertile,femur,fence,fen,ferrets,fender,fennel
# ====================================================================================================
# Distinguish
# Smoothed: separate,differentiate,difference,choose,gentleman,identify,honor,determine,unique,extinguish,suit,award,honour,sort,select,guest,notable,categorize,discern,smart,class,fancy,choice,mark,decide,similar,noble,medal,evaluate,compare,highlight,distinguished,discriminate,water,black,eyes,change,rich,hat,color,break,dad,taste,cars,leader,special,judge,fine,decision,finish,wise,quality,character,spy,stage,odd,elegant,professor,degree,rat,pick,finished,superior,detail,improve,notice,classy,distant,divide,fame,mature,observe,examine,sounds,clarity,excel,moustache,analyze,aged,accomplish,graduate,refined,extraordinary,twins,selection,resolve,slight,discrimination,define,cigar,recognize,impress,perceive,differences,preference,valued,remarkable,dashing,establish,refine
# ----------
# Original: separate,differentiate,difference,choose,gentleman,identify,determine,honor,unique,extinguish,suit,categorize,honour,discern,select,guest,notable,award,sort,distinguished,medal,noble,mark,discriminate,decide,highlight,similar,class,evaluate,smart,fancy,choice,compare,extraordinary,mature,discrimination,stage,odd,analyze,dashing,elegant,bearded,hat,regarded,slight,rich,selection,establish,classy,notice,moustache,finished,accomplish,finish,differences,water,clarity,professor,fine,dad,taste,change,divide,define,quality,character,characteristics,degree,fame,graduate,resolve,special,uplift,valued,judge,delineate,preference,schism,aged,pick,wise,superior,black,revere,cigar,break,eyes,refined,detail,rat,twins,distant,impress,sounds,distinction,perceive,color,improve,remarkable,designate
# ====================================================================================================
# Battery
# Smoothed: power,charge,car,assault,electricity,energy,acid,life,dead,phone,positive,low,cell,pack,rechargeable,electric,bunny,collection,electronics,empty,violence,juice,guns,clock,post,remote,tests,source,ram,charger,operated,water,woman,women,mother,round,heavy,crime,break,gun,army,negative,cars,chicken,silver,moon,burn,choice,watch,park,set,toy,tears,engine,chemical,toys,storage,device,independent,cord,copper,cable,toxic,recycle,potential,auto,drawer,weapons,outdated,necklace,drums,replace,batter,combination,percent,minus,metallic,reserve,poisonous,saved,wireless,cluster,voltage,duration,tranquility,flashlight,lighthouse,ups,poles,bruises,artillery,volt,cylindrical,chopped,recharge,powered,capacitor,cadmium,arsenal,cannons
# ----------
# Original: power,charge,car,assault,electricity,energy,acid,life,positive,cell,dead,rechargeable,pack,low,phone,collection,electronics,bunny,electric,source,empty,post,ram,tests,clock,remote,charger,operated,juice,violence,guns,army,potential,cannons,powered,recharge,toys,mother,toy,toxic,charging,poles,arsenal,poisonous,crime,duration,artillery,saved,resourced,nape,burn,choice,wireless,minus,break,heavy,auto,metallic,gun,weapons,lighthouse,women,device,water,cable,woman,drums,watch,tranquility,cadmium,tears,combination,storage,percent,cord,drawer,batter,cars,chopped,copper,replace,recycle,cylindrical,park,chicken,silver,reserve,flashlight,independent,capacitor,necklace,negative,bruises,engine,volts,voltage,set,moon,ups,chemical
# ====================================================================================================
# Plump
# Smoothed: fat,round,chubby,juicy,obese,fruit,rotund,ripe,chicken,overweight,plum,soft,pillow,grape,jolly,pudgy,red,person,woman,lady,comfortable,lips,belly,tomato,pudding,cherry,peach,cuddly,cushion,pleasing,curvy,rounded,cushions,portly,food,happy,girl,job,metal,clothes,beautiful,pink,pretty,dress,orange,cake,healthy,purple,thin,pleasant,babies,turkey,grandmother,tender,excess,choose,greedy,goose,berry,cheeks,fatty,rolling,vertical,cooked,berries,stout,raisin,squat,lard,voluptuous,meaty,succulent,homely,childlike,bosom,bulge,fleshy,boobies,matron,toasted,womanly,gauche,sated,bulbous,tubby,ottoman,statuesque,cherubic,money,water,love,fun,bad,white,school,green,people,car,time,black
# ----------
# Original: fat,round,chubby,juicy,obese,rotund,fruit,ripe,chicken,plum,overweight,pudgy,pillow,jolly,soft,grape,cushions,cherry,lady,pleasing,woman,comfortable,lips,person,portly,peach,curvy,cuddly,tomato,pudding,rounded,red,cushion,belly,grandmother,berries,berry,cooked,bulbous,sated,goose,lard,orange,bulge,pretty,succulent,toasted,cake,matron,childlike,stout,tender,pink,fleshy,bosom,ottoman,choose,tubby,womanly,homely,raisin,excess,turkey,statuesque,pleasant,job,boobies,girl,happy,cheeks,babies,food,rolling,voluptuous,beautiful,metal,purple,clothes,healthy,cherubic,thin,meaty,greedy,gauche,fatty,vertical,squat,dress,fermenting,fern,ferns,femur,ferocious,felon,ferret,felony,fencer,fen,fellowship,ferrets
# ====================================================================================================
# Hummus
# Smoothed: food,chickpeas,dip,bread,spread,yummy,tasty,garlic,vegetarian,gross,earth,delicious,sauce,paste,green,restaurant,soil,snack,carrot,creamy,pea,white,death,brown,smell,box,orange,forest,dinner,healthy,nasty,dry,floor,yum,hungry,disgusting,meal,sister,sandwich,boyfriend,foreign,chips,middle,rice,turkey,exotic,allergy,beans,spicy,beige,hippy,bean,supermarket,favorite,oily,herbs,tasteless,chick,bits,crackers,mushy,biscuits,varied,tents,gritty,vegetation,mush,slop,sesame,tortilla,inedible,kebab,eatable,detritus,dips,uneatable,guppy,morocco,taramasalata,money,water,love,red,fun,bad,school,people,car,time,happy,black,life,sex,music,person,hard,pain,house,dog,cold
# ----------
# Original: food,chickpeas,dip,bread,spread,yummy,tasty,garlic,vegetarian,paste,sauce,gross,earth,delicious,soil,carrot,restaurant,green,creamy,snack,pea,sister,chips,guppy,detritus,varied,bean,gritty,hungry,beans,allergy,supermarket,exotic,middle,inedible,tasteless,meal,nasty,morocco,smell,crackers,turkey,rice,boyfriend,taramasalata,box,dry,bits,sandwich,vegetation,oily,healthy,orange,herbs,mushy,chick,foreign,death,biscuits,disgusting,mush,beige,forest,kebab,slop,floor,dinner,tents,favorite,dips,spicy,hippy,brown,tortilla,uneatable,white,sesame,yum,eatable,fatigued,fatigue,fathoms,ferrous,ferrule,ferry,favouritism,fertile,fertilisation,ferrets,fertilise,fertiliser,fertility,fathomless,fertilization,fertilize,fertilizer,fervent,fervently,fervid,ferries
# ====================================================================================================
# Lawful
# Smoothed: legal,lawyer,police,allowed,judge,law,court,honest,unlawful,crime,wife,awful,marriage,rules,correct,justice,married,citizen,obedient,permitted,safe,jury,abiding,government,criminal,husband,illegal,act,trustworthy,neutral,conduct,sheriff,wedded,authorised,bad,boring,computer,evil,free,books,easy,truth,action,speech,phone,wedding,lies,true,fine,square,authority,association,laughter,community,duty,blind,degree,chaos,direct,equal,contract,responsible,stable,laws,upright,obey,boundary,righteous,truthful,yawn,respectful,intercourse,acceptable,chaotic,accepted,attorney,pistol,waffle,heir,outlaw,conscientious,courts,honourable,abide,uphold,trusted,upstanding,rodeo,bison,alignment,matrimony,carnal,dutiful,docile,stringent,judiciary,solicitor,regulated,legit,accountable
# ----------
# Original: legal,lawyer,police,allowed,judge,honest,law,court,unlawful,awful,wife,crime,married,justice,obedient,correct,marriage,rules,permitted,citizen,jury,safe,abiding,criminal,wedded,act,neutral,government,illegal,conduct,sheriff,husband,trustworthy,authorised,equal,laws,truth,computer,boring,solicitor,judiciary,pistol,trusted,laughter,free,upright,legislate,outlaw,lies,contract,rodeo,acceptable,waffle,truthful,evil,accepted,yawn,allowable,honourable,wedding,docile,matrimony,sanctioned,attorney,authority,dutiful,chaos,duty,respectful,easy,accountable,chaotic,uphold,bison,phone,regulated,courts,stringent,deviance,responsible,degree,direct,intercourse,fine,heir,carnal,conscientious,rightful,righteous,books,abide,action,obey,stable,association,community,blind,boundary,alignment,legit
# ====================================================================================================
# Cookies
# Smoothed: chocolate,monster,sweet,milk,baking,food,delicious,jar,yummy,computer,cake,yum,dessert,dough,warm,sugar,bake,biscuits,fat,candy,cream,crunchy,baked,treats,happiness,tasty,fresh,coffee,eating,chips,sweets,web,flour,crackers,snacks,crumbs,desserts,crumbles,happy,hard,girl,hot,brown,annoying,cat,soft,eat,wind,mom,joy,flower,cooking,tea,desert,cook,weed,trash,grandma,spoon,computers,nuts,reward,grain,nut,lace,treat,biscuit,chip,cakes,tray,lip,chewy,peanut,bakery,presence,oatmeal,monsters,browser,diabetes,brownies,raisins,included,goodies,unloved,butterscotch,crumbling,browsing,ores,nookie,arrowroot,money,water,love,red,fun,bad,white,school,green,people
# ----------
# Original: chocolate,monster,sweet,milk,baking,food,delicious,jar,yummy,dough,yum,cake,computer,dessert,bake,sugar,warm,biscuits,treats,crunchy,baked,fat,cream,candy,fresh,snacks,happiness,sweets,crumbs,desserts,web,crumbles,crackers,tasty,flour,coffee,chips,eating,cat,nookie,tray,soft,grandma,biscuit,diabetes,cooking,reward,spoon,nuts,raisins,desert,lip,weed,chip,goodies,cook,peanut,grain,computers,wind,lace,cakes,arrowroot,ores,treat,flower,presence,unloved,included,girl,nut,bakery,oatmeal,eat,trash,brown,mom,tea,hot,brownies,annoying,monsters,happy,browser,browsing,crumbling,butterscotch,joy,hard,chewy,fiance,fend,fiancee,fez,fewest,fender,fey,fennel,fiat,fewer
# ====================================================================================================
# Circumstance
# Smoothed: situation,happening,event,chance,evidence,condition,happen,surroundings,circumcision,life,circle,pomp,accident,random,victim,unfortunate,fate,circumference,surrounding,coincidence,milieu,bad,change,story,control,special,position,environment,issue,occasion,events,stance,occurrence,happenings,money,happy,death,trouble,force,negative,uncomfortable,meeting,rules,unhappy,maths,meaning,set,awful,level,late,reason,stuck,stand,morning,experience,period,trial,opportunity,result,associate,circus,web,judgement,current,funeral,lucky,unexpected,grief,clue,unclear,specific,atmosphere,delivery,variable,consequence,embarrassed,unpredictable,setting,separation,cum,context,arena,dire,consequences,apology,conditions,unavoidable,changeable,accidental,affairs,scenario,reasons,instance,favorable,predicament,risks,synchronicity,untimely,serendipitous,personalized
# ----------
# Original: situation,happening,event,evidence,chance,circumcision,surroundings,condition,happen,pomp,circle,life,coincidence,unfortunate,victim,accident,circumference,fate,surrounding,milieu,random,stance,events,issue,environment,occurrence,story,position,occasion,control,bad,change,special,happenings,level,morning,judgement,web,instance,grief,risks,personalized,unhappy,extenuating,arena,lucky,consequence,maths,stuck,death,reason,period,apology,rules,atmosphere,accidental,meeting,untimely,changeable,unavoidable,cum,consequences,awful,unclear,uncomfortable,force,variable,result,specific,trial,current,stand,experience,reasons,late,separation,synchronicity,predicament,favorable,funeral,clue,serendipitous,trouble,delivery,unexpected,money,conditions,negative,scenario,context,set,opportunity,unpredictable,circus,dire,embarrassed,setting,meaning,affairs,happy
# ====================================================================================================
# Art
# Smoothed: painting,sculpture,paint,museum,picture,music,beauty,color,drawing,craft,beautiful,artist,draw,creativity,abstract,design,skill,life,history,girls,fine,culture,colors,form,brush,modern,paintings,gallery,book,study,science,expensive,weird,pleasure,colorful,project,creative,expression,media,talent,statue,visual,canvas,crafts,aesthetics,artifice,money,school,house,movie,smile,dance,class,pink,world,tasty,colour,magic,pencil,meaning,lovely,create,library,theatre,wonderful,colours,literature,photo,bell,letters,lover,pictures,relaxing,purpose,frame,creation,major,tart,fart,clay,artificial,technical,classic,photos,classes,poet,bronze,appreciation,theme,images,portrait,strawberries,unconscious,initiate,doodle,decorative,artists,aspiration,exhibition,expressive
# ----------
# Original: painting,sculpture,paint,museum,picture,music,beauty,drawing,color,craft,abstract,beautiful,artist,draw,creativity,skill,design,form,modern,brush,colors,paintings,culture,history,fine,gallery,girls,life,aesthetics,expensive,science,project,colorful,book,talent,statue,visual,artifice,crafts,study,media,creative,canvas,weird,pleasure,expression,oils,artful,appreciation,major,bell,world,lovely,bronze,initiate,artificial,lover,transcendence,class,expressive,poet,movie,critic,images,palette,louvre,pictures,technical,house,photos,literature,clay,magic,letters,unconscious,reflections,photo,classic,classes,theme,decorative,colours,pink,strawberries,museums,frame,watercolour,liberation,money,quirk,purpose,tart,doodle,exhibition,aspiration,dissemble,smile,wonderful,dance,library
# ====================================================================================================
# Prayer
# Smoothed: god,church,religion,hands,bible,useless,hope,kneel,mat,quiet,false,dumb,priest,holy,time,book,heart,talk,waste,joke,faith,belief,silent,pointless,sincere,worship,meditation,futile,thankful,hymn,plea,contemplate,rosary,fervent,supplication,blue,study,power,cat,evil,song,cool,night,bed,calm,garden,crazy,silly,empty,comfort,magic,father,question,read,desire,respect,personal,hill,service,religious,living,call,conversation,sin,public,bullshit,grace,angel,foolish,candle,reaction,organized,nonsense,lord,daily,tidy,praise,whisper,oppression,pair,hopeless,ignorance,desperate,spit,pray,listening,beg,blessing,calming,deity,devotion,heartfelt,atheism,bedtime,rotation,collective,palms,shawl,rosemary,goodwill
# ----------
# Original: god,church,religion,hands,useless,bible,kneel,hope,mat,dumb,priest,quiet,holy,false,joke,book,silent,time,meditation,sincere,waste,plea,worship,rosary,futile,thankful,faith,hymn,fervent,supplication,pointless,belief,heart,talk,contemplate,ignorance,nonsense,power,reaction,bullshit,night,conversation,personal,sin,question,evil,desperate,beg,pair,study,garden,candle,retards,psalm,calming,calm,comfort,empty,payer,organized,public,goodwill,call,cool,blue,palms,atheism,listening,cat,suckers,shawl,grace,living,respect,desire,deity,magic,read,lord,spit,devotion,rosemary,heartfelt,silly,blessing,rotation,pray,horseshit,hopeless,priests,preachers,creationists,whisper,hill,service,bedtime,religious,collective,song,oppression
# ====================================================================================================

# %% [markdown]
# ### Make predictions
#
# The following does the
# $$
# \mathrm{P}(w_k \vert \textrm{text}) = \frac{1}{n} \sum_{j = 1}^{n} \mathrm{P}(w_k \vert w_{j}).
# $$
# for each text.

# %%
predicted_associates = {}
for text_name in stimuli:
    
    w = numpy.zeros_like(smoothed_association_matrix[0])
    
    for word in texts[text_name]:

        try:
            j = stimulus_vocabulary.word2index[word]
            w += smoothed_association_matrix[j]
        except:
            pass
    
    predicted_associates[text_name] = w/w.sum()

# %% [markdown]
# Let's have a look at these predictions.

# %%
for text_name in stimuli:
    print(stimuli[text_name]['text'])
    print('-'*26)
    print(','.join([associate_vocabulary.index2word[i] 
                    for i in numpy.flipud(numpy.argsort(predicted_associates[text_name]))[:100]]))
    print('='*50)
# Out:
# ‘I don't know what I did without it’ is the sentiment. There is a difference
# between fully automatic washing machines — which change the nature of the task
# altogether — and ‘twin tub’ machines where the hot wet washing has to be
# lifted manually into a separate drying compartment. The women who had this type
# of machine complained about the considerable amount of work still required of
# the housewife, and the mess on the kitchen floor to be cleared up afterwards. In
# a similar way the launderette does not remove the physical drudgery of washing.
# The housewife has to get the washing there in the first place, she has to unload
# it, sort it, sit and watch it wash and dry (or dash out to shop in the interim)
# and then pack it all up again. This, when there is a baby in the pram and a two-
# or three-year-old to attend to, is no mean feat.
# --------------------------
# clothes,clean,water,machine,car,laundry,dishes,soap,money,bath,baby,job,food,cleaning,alike,chair,mother,cold,time,woman,store,run,wet,type,buy,box,dry,dirty,dog,hands,carriage,computer,home,hair,girl,divide,cook,sex,children,truck,wood,line,arid,identical,quantity,change,suitcase,drying,rain,stand,brother,chore,cooking,fast,sister,warm,clock,hot,desert,keyboard,trees,coins,robot,wait,infant,observe,listen,school,mandatory,delete,alter,bubbles,sink,move,child,girls,green,divorce,nurture,house,wrist,organize,body,total,apron,board,sexy,love,dryer,bottom,empty,train,sort,liquid,font,buggy,dirt,clothing,hyphen,wife
# ==================================================
# Don Juan today has lost whatever sympathetic press the years of male domination
# gave him. Feminism and a greater acknowledged (though not necessarily practised)
# awareness of the equality and independence of sexual rights have becalmed the
# Don as a fool of time. Psychology has dissected him to death. AIDS has ousted
# him out of history. But there is little point, for instance, in turning on an
# artistic, enlightened medieval king because he also enjoyed slaughtering
# hundreds of deer in a day's hunt and daubing the fresh blood on his own face and
# those of his friends. Examples can be multiplied. To yank someone entirely out
# of their time and smack them around for not being of our time is perhaps a
# salutary but only a limited exercise. Yet the times have indeed changed: and
# Burton's early sexual insatiability, his later infidelities, his many women and
# his concurrent devotion to monogamy all need some explaining.
# --------------------------
# clock,love,female,time,freedom,queen,sex,night,women,newspaper,red,hit,day,found,disease,watch,power,life,mind,past,light,creative,hour,world,rights,human,nice,penis,fun,castle,knight,woman,idiot,food,animal,slap,money,black,sun,girls,stupid,brain,flies,boy,sad,moment,hot,iron,caring,clean,knowledge,forest,strong,gender,knights,equality,people,war,study,deer,space,girl,jester,prince,paper,paint,company,crown,happy,dog,civil,flag,math,history,ancient,doe,kill,sweat,school,pain,push,hours,gay,book,ruler,awake,fruit,god,family,free,late,painting,helps,fast,science,feeling,sexy,story,alert,rule
# ==================================================
# When John Major talks of a ‘nation being at ease with itself’, which
# particular nation is he speaking about? Is he addressing his comments to all
# those who have become marginalised and dispossessed as a result of right-wing
# Conservative policies over the years? Or is he speaking about that nation of
# complacent and indifferent shopkeepers who long for nothing other than a return
# to the days of imperial hegemony? The shopkeeper as the centre around which the
# social world revolves is a commercial image hammered into English consciousness
# by Mrs Thatcher. Self reliance, individual enterprise, ‘what's in it for
# me’, as opposed to‘how can we help our neighbour’, was the message. This
# theology slipped over the iron hand of the capitalist market like a silk glove.
# England became one nation again, a land of hope and glory, Elgar, teacakes and
# cricket. This England is not one recognised by many of my friends.
# --------------------------
# country,money,talking,person,business,people,hand,picture,earth,middle,god,religion,flag,minor,love,building,weeks,wide,republican,soft,politics,home,awake,smooth,united,globe,war,text,words,months,army,mind,time,happy,fingers,bat,easy,letter,food,voice,government,unique,game,royal,pride,listening,ball,insect,single,king,talk,metal,party,sell,awareness,peace,company,test,outcome,opposite,study,photo,answer,mouth,worm,power,fun,language,clothes,uncaring,apathetic,family,cold,sea,finger,week,nights,store,email,network,faith,careless,land,boring,nationality,leather,world,music,foot,city,patriotism,sun,car,friendly,sport,chirp,shop,advertisement,college,white
# ==================================================
# The form of animal husbandry adopted depends on the type of facilities available
# and the nature of the experiments. If an experiment produces animals that are to
# be kept for a long period, or that are to form the basis of a breeding colony,
# some form of barrier system is essential. If no precautions are taken to prevent
# infections it is inevitable that the health of the animals will deteriorate with
# a resulting decrease in breeding performance or death. A minimal barrier system
# requires people entering the animal area to remove their laboratory coats worn
# in other areas, and to put on protective  clothing. It is essential that they
# wash their hands thoroughly before handling the animals and the wearing of
# surgical gloves and a change of footwear or overshoes should be considered. A
# more stringent barrier includes the requirement for staff to shower on entering
# the unit and a complete change of clothes.
# --------------------------
# stop,dog,wall,shape,science,clean,cat,clothes,shoes,water,reef,money,paper,fingers,hands,computer,shirt,finish,life,time,coins,dogs,block,function,pets,foundation,alter,finished,fence,doctor,wild,pants,cats,zoo,warm,feet,test,cold,food,human,ants,lessen,birds,required,mold,love,furry,fill,style,dress,blood,car,body,green,soap,mammals,basic,people,white,keyboard,socks,increase,mother,plan,study,measure,mandatory,obstacle,jeans,shoe,trees,person,tired,unavoidable,fitting,rod,beast,shield,black,menstruation,organization,school,necessity,horse,lower,bath,delete,laundry,clothing,tree,scientist,create,mammal,torn,bad,employees,humans,bear,hospital,family
# ==================================================
# I then took her forward slightly to the evening after the operation, a time when
# she was fully awake and over the more drastic effects of the anaesthetic. I
# asked her how she felt now. To my surprise Kirsty burst into tears. No, she told
# me, she was not in any great pain — simply the discomfort she would have
# expected to follow surgery. She was not aware of feeling particularly ill. It
# was just that she knew that there was something seriously wrong with her —
# something far more dramatic than a grumbling appendix or the normal after-
# effects of an operation. Oh, the doctors and nurses had assured her again and
# again that she was fine and would soon be fit and well again. And yet, as she
# kept repeating, she was convinced that there was something that no one was
# telling her.
# --------------------------
# sick,surgery,pain,doctor,hurt,story,hospital,sad,party,happy,night,emotion,clock,morning,bad,lead,alert,explode,healthy,backward,easy,confident,incorrect,book,sleep,awake,cry,birthday,game,easily,surgeon,uncomfortable,crying,unexpected,day,average,time,usual,ouch,operation,play,medical,asleep,bubble,balloon,conscious,water,touch,sadness,eyes,pop,cut,heart,thin,tired,dark,procedure,ahead,error,money,boring,blood,theatre,light,bed,organ,dusk,shock,bit,abnormal,sense,knowing,watch,line,love,twilight,leader,body,tattle,alive,barely,trail,military,speak,fast,ordinary,rest,joy,spoke,baby,red,sunset,cold,scalpel,gift,salty,calm,knife,speaking,ache
# ==================================================
# It was mentioned above that overflow records arise singly. In addition, an
# embedded overflow area will usually contain varying numbers of records from
# several tracks. This leads to overflow records usually being stored in unblocked
# format, even if the records in the prime data area are blocked. There is some
# advantage in treating the whole embedded overflow area as a single large blocked
# record, and manufacturers' software often does transfer the whole track into
# main storage when an addition is to be made; this allows for the addition
# itself, creation of link fields, changes of index, etc. However, handling the
# whole track as a single block would prevent rapid transfer of individual records
# from the embedded overflow area during direct access reference, which is the
# reason this method is often not adopted (but see the section on software
# packages, p. 264).
# --------------------------
# water,computer,subtraction,math,person,stop,fast,river,book,move,hardware,train,toilet,flood,chain,money,extra,multiplication,run,unmarried,information,street,follow,excess,quick,spill,music,field,logic,race,unique,library,god,time,finger,paper,pipe,path,married,box,straight,division,science,green,program,running,cup,dam,space,road,word,maths,excuse,card,change,single,mathematics,rib,house,mess,disc,wood,computers,add,connection,file,line,player,record,document,list,exchange,primary,closet,madness,join,double,grass,door,sum,bath,life,container,disk,stack,style,dictionary,love,piece,corn,art,unit,tape,woman,car,school,bus,lead,entry,animal
# ==================================================
# Though innovation is a very positive term, it is important to remember that any
# particular innovation is only positive in retrospect, after it has worked. Before
# that, because change by definition is something no one has seen yet (despite
# models that may exist elsewhere), it has to be taken at least partially on
# faith. For example, why a continuing education program now? Why use funds to
# develop a new product when there are so many already on the market? Why take the
# risk of decentralizing the accounting office? In short, unless there is somebody
# behind the idea willing to take the risk of speaking up for it, the idea will
# evaporate and disappear. One reason there is so little change in most
# traditional bureaucratic organizations, I argue, is that they have conditioned
# out of people the willingness to stand up for a new idea. Instead, people learn
# to back off at the first sign that somebody might disapprove.
# --------------------------
# money,school,negative,creative,word,tall,invention,vanish,computer,smart,water,live,fight,happy,meaning,study,concept,danger,coins,plan,bright,game,alter,person,talking,grow,teach,memory,god,forget,dictionary,religion,brain,stop,logic,mind,inspiration,language,paper,words,life,fun,humans,clothes,knowledge,bad,time,boring,family,food,friends,disagree,light,create,desk,crowd,sell,semester,excuse,sit,technology,recall,teacher,optimistic,creation,steam,reward,change,store,thinking,persons,belief,debate,gamble,hope,learn,alive,progress,notion,business,idea,science,post,chance,bank,university,magic,item,position,math,invisible,book,human,wrong,church,love,frown,learning,future,shop
# ==================================================
# Some social scientists have conceptualised these workers in terms of a reserve
# army of labour. In this case, they would constitute a pool of labour which can
# be utilised in boom periods and disregarded in recessions. This view sees the
# experience of the Third world as being little different from that of the
# industrialised countries. The large numbers who are unable to find regular
# work are not seen as a phenomenon characteristic of underdevelopment, but part
# of the capitalist division of labour and, therefore, a similar feature to the
# industrialisation process of European countries, differing in terms of quantity
# rather than quality. For Marx, however, the function of the reserve army of
# labour was keeping wages low and, to this end, the absolute size of the reserve
# army need not be very great. The high numbers and continuing growth of this
# sector in Latin America would suggest that concepts of European analysis are not
# sufficient.
# --------------------------
# money,party,war,water,soldier,navy,birth,conditions,amount,toil,save,hard,math,normal,union,time,alike,military,quality,love,green,nations,map,globe,job,school,army,words,restaurant,travel,earth,politics,table,baby,hold,life,day,pay,trait,salary,event,explosion,world,food,study,vodka,rules,movie,people,film,effort,loud,total,book,quantity,childbirth,guns,happening,quiet,science,special,section,swim,contract,power,swimming,pain,labor,medium,bank,multiplication,idea,measure,blood,complete,hint,private,bang,method,borders,nature,menstruation,economy,death,game,soldiers,bomb,wide,opinion,office,blue,knowledge,federal,person,height,continents,short,plenty,network,purpose
# ==================================================
# In the case of time constant, a production worker tends to be focused on the
# production schedule for today or this week. An R&D worker is aware that what he
# does today will not affect company output in this order of time span. It may be
# months or years before his work today makes an impact: in the case of a project
# failure it may never do so. Words such as ‘hurriedly’ and ‘quickly’ are
# likely to be associated with different orders of time spans in the minds of the
# two people. Salesmen are probably in between these two. They have in some cases
# a weekly or monthly schedule of orders to win but the long-term relationship
# with their customer is also of great importance and the weight to be put on the
# two factors at any one time calls for the exercise of judgement.
# --------------------------
# clock,time,day,calendar,fast,watch,factory,bee,friends,lose,school,daily,money,hour,love,hard,period,job,month,effect,business,input,flies,employee,play,game,life,heavy,movie,awake,monthly,bridge,busy,run,change,influence,hit,fat,court,plan,language,person,result,service,line,task,alert,days,family,film,space,sex,timetable,bad,weekly,hours,loss,judge,product,computer,success,yearly,gym,mass,store,length,attention,magazine,letters,friend,late,significance,theatre,crash,labor,priority,client,wait,corporation,assembly,fun,routine,hurry,schedule,steady,measure,construction,study,paper,scale,stage,crowd,buy,humans,appointment,bills,regular,sweat,newspaper,tick
# ==================================================
# In the afternoon, we have a rehearsal, but without the guests. I just walk
# through the basic moves so the cameras can plot where everybody's going to be,
# and we try to work out how long people will take to walk down the stairs so we
# can play the right amount of music. If they can make it, we like the guests to
# arrive before the audience starts to go in, so they can walk through it, too.
# Those steps  down to the set can be daunting — I think it's everybody's
# nightmare, stepping out and falling flat on your face. Dusty Springfield was
# wearing new shoes, with very high heels, and was terrified that she'd slip, so
# just before she was due to go on, one of the team was dispatched to look for
# some scissors to scratch the soles with. Oh, the glamour of it all.
# --------------------------
# run,scared,play,money,cut,fall,stairs,dog,itch,scary,simple,exercise,feet,paper,talk,practice,story,climb,stroll,dream,theatre,dirty,fun,time,hard,late,steps,date,crowd,tea,sharp,easy,amble,game,quantity,hike,dance,fear,sidewalk,dress,sport,walk,music,player,nap,sleep,games,theater,sports,plan,frightened,morning,land,tennis,table,people,book,apartment,cat,ball,slide,garden,movie,red,stage,hair,horror,total,friends,shoes,socks,dark,task,home,baby,tool,person,love,ice,water,move,night,performance,notes,house,hurt,challenging,destination,depart,pain,tools,leave,humans,difficult,fast,ladder,wood,evening,trip,nature
# ==================================================
# My understanding of the law is that an adult patient who is capable of doing so
# must give consent to any medical treatment if that treatment is to be lawful. At
# the time of the decision the patient needs a capacity commensurate with the
# gravity of that decision. If the patient lacks the requisite capacity, then the
# doctors must act in what they perceive to be his or her best interests, with
# information garnered from previous knowledge of the patient, discussion with
# family and friends, and taking into account any relevant directive previously
# made by the patient. What the legal force and effect of any such directive might
# be is uncertain; it is unclear whether health care staff are required to carry
# out the terms of the directive or whether those who act in good faith with the
# terms of the directive are immune from civil or criminal prosecution. There is,
# apparently, no case law on this point.
# --------------------------
# doctor,hospital,calm,play,sick,love,lawyer,legal,school,police,knowledge,waiting,conditions,medicine,law,wait,earlier,prior,power,past,time,money,words,bank,rule,court,ability,rules,study,nurse,unsure,child,talk,choice,clock,volume,agree,agreement,people,understand,god,illness,size,medical,judge,war,religion,affect,smart,books,result,system,mature,care,contract,action,health,mind,strong,change,hold,justice,giving,book,weight,space,bad,data,crime,life,bed,sex,cancer,jail,heavy,disease,earth,polite,theater,belief,conversation,happy,amount,rights,mother,cure,rod,pretend,safe,music,nice,intelligence,field,permission,tote,mandatory,illegal,learning,ill,person
# ==================================================
# The bones are bound to each other by tough, flexible ligaments and are
# articulated at the joints by muscles. There are just over 600 voluntary muscles
# in the human body. For our purposes, it is only necessary to mention the larger,
# superficial muscle groups which affect the shape of the body and are responsible
# for the movement of the limbs. These are referred to as skeletal muscles, most
# of which are attached at both ends to bones. The muscles that give expression to
# the face are also referred to as skeletal muscles, and they link bone to skin. A
# whole complex system of muscles is brought into play for each movement of the
# body: bending an arm involves the shortening of the biceps, while the tricep
# muscles at the back of the arm must relax and lengthen in unison. Meanwhile,
# others immobilise joints not needed in the action, while others still adjust to
# stabilize the body's equilibrium.
# --------------------------
# strong,strength,skeleton,body,leg,arms,hard,person,bigger,gym,exercise,balance,hand,arm,change,chain,anatomy,soul,movement,skin,stretch,white,mind,muscle,difficult,dog,human,move,muscles,water,tone,fun,workout,square,dance,tendons,free,effect,fit,red,bones,tied,bring,torso,corpus,run,soft,form,circle,fake,legs,flesh,emotion,ache,flex,weak,food,weights,motion,limb,beautiful,happy,corpse,fat,skull,shallow,head,rest,sleep,yoga,language,life,computer,broken,marrow,movie,reaction,power,people,calm,rope,biceps,music,time,games,weapon,image,surface,game,influence,woman,action,sexy,equal,complicated,bendy,calcium,beach,adult,break
# ==================================================
# The extent to which subject coverage on the shelves can be achieved is a matter
# of library policy, funding, the amount of shelf space available, and the
# efficiency of interlending systems to which the authority has recourse. These
# influences are considered in more detail in Chapter 12. The case for immediate
# shelf representation in a public library is made at some length by Ranganathan,
# in his fourth library law —‘save the time of the reader’. ‘Mental hunger
# for books is not compelling in the case of most people. Mental thirst for
# information is not inexorable in the case of most people. Both of them are
# fleeting in their nature. They both die out, unless satisfied immediately on
# their taking shape. No time lag should come between demand and supply. The tempo
# for reading is often momentary. It should be harnessed at the very moment.’
# --------------------------
# book,books,time,money,knowledge,clock,food,crazy,quiet,fast,water,library,brain,reading,happy,life,slow,wood,school,librarian,music,police,news,read,demand,study,person,health,width,drink,rule,mind,speed,square,quick,minute,storage,government,beat,words,space,humans,death,object,insurance,paper,rules,content,wall,circle,giving,watch,quantity,friends,lawyer,crowd,data,people,form,smart,topic,jet,measure,ruler,provide,writing,live,height,size,power,trees,law,world,hour,private,green,mass,persons,outer,illness,hunger,stuff,store,politics,supply,total,boss,rescue,head,science,quarter,short,stealing,triangle,rhythm,nurture,population,magazine,urgent,pace
# ==================================================
# In Ordinary Justice the National Consumer Council were scathingly critical of
# such court proceedings which in practice, they said, became a rubber stamp. The
# documents the court sent out were difficult to understand and no guidance was
# given on completing it. The ‘defendant’ was not asked about his personal
# circumstances. The Civil Justice Review found that a third of banks and building
# societies, and a fifth of local authorities, did not enquire about the debtor's
# circumstances before the hearing. Three quarters of local authorities did not
# follow up the Department of Environment's advice and carry out checks to see if
# the tenant was receiving the right benefits. Sixty-seven per cent of creditors
# had no knowledge of the debtor's financial state at the time of the original
# transaction, and 77 per cent did not obtain any further information before or
# during the proceedings.
# --------------------------
# money,penny,law,judge,hard,store,lost,court,dollar,knowledge,comprehend,lead,house,private,tennis,power,government,papers,clock,office,plain,bank,perfect,lawyer,giving,paper,river,war,gift,study,normal,close,rent,landlord,nearby,school,buy,letter,green,people,business,data,fair,coin,book,city,aid,unique,home,boring,music,learn,ear,country,food,advice,sound,legal,information,apartment,receive,mail,condom,wisdom,percent,meeting,buyer,pride,news,woo,postage,easy,mine,polite,tote,jury,books,smart,lift,words,band,ball,rights,shop,town,anthem,word,hold,neighborhood,section,space,listening,construction,copper,tire,intelligence,police,love,person,secret
# ==================================================
# The Dickens study tells us that not every dismissed employee eligible to claim
# unfair dismissal does so. Only about one in ten of those eligible to claim
# actually does so. Among those who apply there is a greater tendency to bring
# unfair dismissal proceedings where the employer is a small single establishment
# employer with below average unionization. Nearly half of all applications are
# against employers with fewer than 20 employees. The larger the employer, the
# less likely it is that there will be an unfair dismissal claim. There are a
# number of possible explanations for this pattern of application. Larger
# employers are likely to have internal appeals procedures and failure there,
# where union representation may have been provided, is the point at which the
# employee draws the line. Employees may feel a sense of powerlessness in taking
# on a large organization or it may be that advisers are more reluctant to take on
# large organizations.
# --------------------------
# job,boss,bigger,worker,money,touch,employee,unjust,company,life,carry,inside,wrong,form,straight,mine,insurance,marriage,smell,huge,school,business,habit,fair,hesitant,bad,learn,giving,common,hard,size,sad,people,normal,fingers,ownership,middle,gold,unmarried,feel,emotion,person,law,justice,assert,stealing,stake,salary,external,office,organs,shy,child,manager,false,time,sense,staff,unwilling,paper,loss,love,married,toes,twenty,employer,success,fat,brought,submit,check,ticket,sensibility,feeling,decimal,career,books,lawyer,college,legal,food,test,share,eleven,game,hold,biased,unequal,join,colleague,lie,pint,receive,congress,house,book,grab,advantage,unsure,rights
# ==================================================
# Our terms of reference suggested that we should consider drama in the context of
# the great dramatic works of literature. We believe that plays should be
# approached through the dramatic medium; children should often see or participate
# in the play being acted, and not just read the text. This approach will not only
# result in an appreciation of the literary merits, but also foster an
# understanding of stagecraft. There is still an important place within drama
# activity for the exploration and study of scripted plays, and we addressed this
# aspect in our statements of attainment and programmes of study. At primary
# level, the range of material for exploration needs to be more diverse: myth,
# legend, fairy stories, poems. At secondary level, such work can expand naturally
# into the exploration of dramatic texts. Children's own writing can also be
# explored — at both levels — through the medium of drama.
# --------------------------
# book,play,school,books,kids,theatre,story,theater,fun,words,learn,middle,queen,adventure,tale,reading,child,library,paper,actor,stage,average,read,travel,hard,drama,knowledge,game,size,movie,legend,flat,primary,love,class,acting,research,conditions,grow,psychic,care,hero,straight,map,join,tertiary,message,test,fabric,discovery,tales,gratitude,girl,world,meaning,write,act,contract,science,life,view,parent,education,games,study,myth,children,happy,wings,home,flair,pen,outcome,girls,floor,secondary,stove,word,jungle,space,ratio,magic,writing,cloth,nature,movies,enlarge,art,ball,spirit,answer,color,phone,emotional,sports,time,family,theatrical,people,varied
# ==================================================
# Activity 1 (15–20 mins): Identify a small group of clients, such as the first six
# people you saw in your last day's community care, the first six people attending
# your outpatients' clinic, or six individuals in a bay in your ward. For each
# client, list the nursing interventions either by yourself or someone else, such
# as ‘insulin injection’, ‘mouth care’, ‘socialisation’, ‘health
# promotion’, that each required in the fist hour of care, say between eight and
# nine, or nine and 10 in the morning. You should end up with at least six
# separate lists, some with perhaps only one item on it, others with several
# items, listed in the order that each client received, or was assisted with, that
# care. Are there any items common to several, or all, of the clients? Did they
# receive similar care at the same time or in the same order?
# --------------------------
# love,time,hospital,doctor,customer,stuff,clock,night,concern,person,money,list,alike,job,health,hand,punch,minute,sun,water,day,light,home,nurse,people,friends,medicine,gift,nurture,package,needle,child,service,shopping,teeth,baby,grocery,family,business,bear,humans,patient,objects,caring,mother,lips,watch,careful,fun,medical,tend,crowd,exercise,feel,groceries,raise,object,children,words,caution,persons,divide,mandatory,food,lawyer,loving,shot,divorce,sunrise,play,wealth,ocean,tender,affection,care,human,tongue,fight,population,sick,inventory,neighborhood,glass,happy,women,kids,kiss,store,free,ordinary,hour,check,white,happiness,dawn,paper,accept,elderly,school,pain
# ==================================================
# Once again that requirement to get on with people, clients, account executives
# and the creative teams is basic to your daily work. Just how does cooperation
# between a planner and the creative team work? After all, creative people are
# supposed to be sensitive and aware of the consumer and society and in real touch
# with change and mood. Let's take an example of the planner and creative team
# together. Trying to devise the strategy for a lager campaign, the planner found
# out through the research that the key benefit consumers looked for in lager was
# refreshment — incidentally something no other beer advertiser mentioned. The
# creative team took this new insight and used it as a spring-board to create a
# very successful campaign based on sprouting leaves and the headline: "Refreshes
# the parts other beers cannot reach" , thus demonstrating the imaginative leap
# creative people make from research findings to effect communication messages.
# --------------------------
# art,money,artistic,study,sport,happy,person,player,plan,jump,newspaper,lost,feel,calendar,lock,politics,sports,news,simple,friends,bank,diary,people,humans,smart,paper,writing,knowledge,mind,thinking,science,war,imagination,frog,crowd,affect,paint,spirit,book,game,painting,talk,fall,change,music,football,true,persons,family,day,door,tree,feeling,stretch,green,easy,grab,world,awake,trees,artist,result,political,love,fun,emotion,president,soft,create,population,skin,imaginative,sad,human,wedding,hand,time,party,leader,drink,buyer,story,life,idea,election,alter,coins,teamwork,business,autumn,necessity,sense,project,drawing,agenda,original,job,organiser,arts,win
# ==================================================
# While many of these may be social occasions, work groups especially in large
# companies may often stay on late to participate in quality control circles or
# zero defect clubs. There are up to four million quality control circle
# participants in Japanese industry and in large companies two in five workers are
# members. Quality consciousness is said to be very high among Japanese workers
# who endeavour to eliminate components that are rejected as substandard. Each
# smaller work group attempts to perform better than their rival groups in both
# quality control and in the number of suggestions they offer to improve
# productivity. Workplace harmony is enhanced by communal sports clubs, company
# vacation resorts, one-class cafeterias and the absence of status barriers within
# the plant. There is an hierarchical structure, but managerial authority is
# respected as a benign guardian of company interests. Corporate identification
# with workers knowing their place is in short "a managers Nirvana".
# --------------------------
# business,quantity,power,friends,building,money,music,control,enemy,office,peace,knowledge,angel,people,round,bad,school,green,tall,mind,job,time,freak,heaven,corporation,life,act,dollars,police,factory,holiday,awake,tardy,parent,card,join,pieces,boss,football,person,remain,missing,destroy,play,home,friend,kill,broken,billion,beach,square,team,remove,band,dog,dead,class,worth,car,dance,party,manage,assurance,update,guests,food,awareness,remote,fun,busy,company,expensive,organization,government,competition,stage,tree,firm,gift,stop,learn,night,type,computer,soccer,lots,leader,leave,smart,license,study,boring,price,desk,authority,network,friendly,protector,hard,love
# ==================================================
# While it would be unlikely for a firm contractual commitment to be made which
# binds a record company to produce a promotional video, it is a matter of fact
# that a promotional video will be produced to support an artist's first single.
# With limited production costs, this video would fall into the £15,000 to
# £30,000 range, as opposed to the six-figure costs incurred by the established
# major artists. The cost of the promotional video for a developing artist would
# be recoupable against both audio and video income received by the record
# company. The income to pay these video costs is usually minimal with new
# artists, so these expenses are often set against future video exploitation. This
# is income which increases as the artist gains greater success and begins to
# release such items as compilation videos comprising selected promotional videos,
# or full length videos of live concert performances.
# --------------------------
# money,movie,tape,music,film,game,audio,salary,camera,player,painter,business,friends,paint,tax,visual,television,recorder,free,sound,watch,price,store,minor,stuff,width,hard,time,autumn,marriage,painting,pay,cassette,company,corporation,job,play,creative,vegetables,life,record,past,love,art,create,picture,army,factory,food,fruit,list,disc,height,solid,relationship,unmarried,home,people,distance,musician,ruler,guests,law,space,opposite,write,stove,win,die,happiness,earnings,recording,friend,fun,stage,poor,family,games,tennis,screen,album,video,happy,effort,wages,strong,check,black,earn,wealth,leaves,person,slavery,motion,married,energy,vinyl,color,freedom,day
# ==================================================
# Despite the challenges associated with building up large-scale production, the
# Japanese are forging ahead in display technology — and for very good reasons.
# Obviously the straightforward replacement of bulky cathode ray tubes with flat
# panel display leads to significant power and weight reductions as exemplified in
# the commercialisation of laptop computers. The most strategically important
# reason for investing in flat panel display technology, however, is that with
# continued miniaturisation of the integrated circuits the display itself will
# become the platform on which the system is built. This raises the prospect of
# fully integrated systems for which the sourcing of individual components such as
# drivers, memory chips and processors on the world market would no longer be an
# issue. Countries with such a display manufacturing capability would dominate the
# market and effectively eliminate competition based on older technology made up
# from discrete components.
# --------------------------
# computer,screen,monitor,window,wood,person,pieces,exhibit,heavy,factory,future,science,board,earth,computers,light,store,food,shop,fat,electricity,people,sun,gold,sell,apartment,forward,globe,art,wall,stage,ability,fish,win,logic,level,magazine,game,destroy,control,potato,money,quiet,house,unique,map,electronics,easy,kill,machine,strength,substitute,power,remove,ingredients,tire,excuse,smooth,view,car,honest,strong,world,glass,single,nations,industry,travel,race,train,brain,direct,politics,judge,line,meaningful,buy,secret,television,surface,produce,skill,mass,job,iron,wide,construction,loss,remember,picture,farmers,discussion,movie,box,table,separate,demonstrate,sunshine,time,information
# ==================================================
# Though less visible, it was export competition in goods and services which had a
# more fundamental effect on UK towns and cities. The internal economic geography
# of the UK has been reworked over a century by fundamental change in the nature
# and orientation of exports, which has reflected the success of individual
# industries and their factories. This demonstrates the principal changes so far this
# century in the composition of export goods. In 1900, the country was still
# largely dependent on exports of textiles, metals and coal, whereas by 1987
# nearly half the country's exports were accounted for by ‘machinery and
# transport equipment’ and chemicals. The impact of North Sea oil on the
# structure of the balance of payments may actually have reduced the absolute
# volume of manufacturing exports. This is because it raised the real sterling
# exchange rate, rendering ‘marginal’ manufacturing exports uncompetitive. We
# shall return to this issue at several points later in this volume.
# --------------------------
# money,music,import,building,silver,hundred,factory,trade,school,time,loud,person,south,sound,car,ocean,black,child,tools,change,water,inside,land,home,map,ship,affect,nation,industry,direction,invisible,world,true,green,win,move,metal,trees,sexual,science,result,send,rural,cold,magazine,business,noise,vodka,writing,amount,power,city,pole,history,speed,essay,hit,unique,coins,single,east,light,book,carry,independent,west,country,cars,alter,clothes,fuel,mass,food,total,economy,size,taxes,sight,cricket,weight,plant,external,centurion,life,compass,beam,complete,train,machine,fire,mine,truck,crash,gas,main,space,pound,organs,sell,equal
# ==================================================
# As far as the Royal Navy were concerned the nuisance of excessive leakage was
# largely put a stop to when Sir Robert Seppings (1764–1840) introduced diagonal
# iron bracing into wooden hulls about 1830. Seppings, who used to say ‘partial
# strength produces general weakness’, seems to have been one of the first Naval
# Architects to have a clear mental picture of the stress systems in a ship's
# hull. In the merchant service wooden hulls were to a considerable extent
# replaced by composite and iron and steel construction after the middle of the
# century. A number of wooden ships continued to be built without adequate shear
# bracing, however, and such ships got more leaky as they got older, until, in an
# age when most of the pumping was done by hand, it became uneconomic to run them
# any longer. Up till 1914 Norwegian shipowners were still making money by buying
# up British sailing ships and running them with windmill pumps.
# --------------------------
# boat,sea,ship,water,boats,metal,ocean,hard,time,blue,sail,strong,worried,sails,cash,fast,power,money,navy,table,frame,sign,line,tree,hundred,spoon,stiff,king,building,child,halt,annoying,queen,crazy,madam,center,photo,military,red,strength,steel,brain,half,wood,sailing,average,furniture,sailor,army,build,shop,health,muscle,wind,iron,painting,sends,sufficient,exercise,leg,house,chair,shoes,orange,seller,car,mind,clothes,fingers,knight,board,pain,marine,anxiety,worker,horse,finger,natural,incomplete,bother,pest,ships,store,walk,food,foot,waves,job,ore,speed,pirates,fine,jogging,life,acceptable,jog,green,war,purple,era
# ==================================================
# Clear out all your possessions and be ruthless. Now is the time to take rubbish
# to the dump, to give things away to charity shops and jumble sales. There is no
# point in taking all your useless rubbish with you. Also clear up the garden. You
# are not supposed to leave rubbish behind for the next occupants to cope with,
# although you can leave it bagged up outside the door for the dustmen to take
# later. If you are leaving the area do not forget to pick up any clothes that are
# at the cleaners, or shoes, clocks, or other items that are away being mended.
# You will also need to withdraw sufficient cash from the bank to pay for the
# removal. It is common practice to tip the people who have done the removal work
# so you may want to withdraw enough for this too.
# --------------------------
# money,trash,garbage,depart,waste,exit,giving,choose,leave,remember,clock,remove,perfect,goodbye,flowers,retreat,green,sad,junk,stuff,feet,deal,worthless,van,bin,nonsense,window,person,lose,rubbish,door,memory,truck,socks,holiday,vacation,people,assumed,salary,shirt,flower,handle,absence,day,pants,check,plenty,manage,stealing,river,list,home,nose,poop,select,house,food,top,knob,alleged,poor,shopping,dump,bank,tree,friends,train,store,stay,hair,left,humans,dirt,ordinary,red,guessed,job,bad,car,watch,advice,bullshit,hide,close,stupid,objects,departing,family,buy,ground,quit,drugs,withdrawal,time,waiter,bye,laces,water,crowd,sex
# ==================================================
# Individual goals may well be in conflict with organisational goals even where
# there is a strong commitment to one goal by the organisation. It is worth
# repeating that there may also be competing goals within the organisation itself.
# Thus, for example, the prison service may wish to pursue the twin goals of the
# punishment of offenders  and at the same time their rehabilitation. These two
# goals may prove to be incompatible and yet each will have its supporters. Within
# the National Health Service there may well be a commitment to provide the best
# possible medical care that the state of medical knowledge will allow and yet
# this may be tempered by the requirement to act within tight financial
# constraints. The two goals may be in conflict. Many organisations will face the
# problem of which goals to prioritise in the light of competing goals.
# --------------------------
# soccer,money,doctor,football,aims,war,marriage,life,fight,person,love,chase,achievement,aim,jail,hospital,achievements,achieve,play,plans,objectives,success,crime,score,company,clock,net,future,school,relationship,target,power,dreams,aspirations,hopes,reach,business,hockey,health,ambition,support,nurse,follow,dark,food,country,dream,military,targets,career,time,win,game,resolution,medicine,wealth,bulb,unique,weak,bright,argument,job,pride,happiness,single,brother,sister,car,field,necessity,cost,promise,station,goal,supply,desires,bank,church,pain,care,bad,anthem,aid,fit,customer,personal,plan,bars,purpose,anger,identical,intelligence,people,smart,family,succeed,study,law,mind,set
# ==================================================
# On 25 July 1985 the dock company put in a planning application for the
# construction of a Roll on — Roll off (‘Ro-Ro’) terminal in the River
# Medway. Permission was refused, there was an appeal and an inquiry by an
# inspector whose recommendations the Secretary of State for the Environment
# accepted. The appeal was dismissed. The main consideration was undoubtedly the
# increase in heavy goods vehicles that would be generated by the new development
# and the consequent increase in noise levels, in particular night-time levels in
# Medway Road and Bridge Road. These environmental objections were considered to
# be serious enough to outweigh the economic benefits of allowing the proposal. It
# was this development and in particular the evidence given at the Ro-Ro inquiry
# which in due course prompted the council to bring the present proceedings. In
# March 1988 the council passed the necessary resolution and the writ was issued
# on 20 July 1988.
# --------------------------
# question,water,street,money,car,rock,court,police,sex,building,business,grow,job,carry,boat,cars,bread,loud,proof,weight,decrease,airport,meeting,marriage,detective,city,gadget,green,train,build,government,highway,path,add,assistant,friends,school,law,growth,month,date,cancer,board,tumble,wedding,ring,committee,travel,arrested,house,road,crime,food,form,ball,trip,stream,music,walk,light,nice,computer,river,request,ship,paper,housing,enlarge,study,bus,office,bun,worker,sound,traffic,nature,decision,desk,judge,child,time,plan,primary,flow,corporation,drive,investigation,advice,parade,trucks,fat,information,army,people,surroundings,load,research,lake,project,slip
# ==================================================
# At the start of the exercise, the actual procedure was checked against a
# conceptual model that included the activities deemed necessary to achieve the
# agreed transformation. If the changes revealed by this comparison have not been
# made prior to the audit commencing, this could be the reason for the failure to
# meet the target levels of attainment. If, however, the procedure does comply
# with the procedure description derived earlier, then it will be necessary to
# subject each element or activity of the model to further scrutiny, for example
# by breaking them down to lower-order activities, or by auditing each element in
# the same manner as the parent procedure. This process is similar to work study
# exercises where measurable elements of a task are identified before the actual
# measurement takes place, and consideration is given to the resources required at
# each level, including the skills and experience of the operator.
# --------------------------
# real,operation,job,chemistry,begin,true,fire,process,science,steps,method,alike,water,goal,doctor,greet,school,time,rules,medical,task,surgery,mother,fun,learn,telephone,polite,child,study,knowledge,follow,logic,father,phone,ruler,success,obey,test,table,money,hard,finish,earth,agree,object,morning,skinny,aim,life,contrast,past,weather,previous,car,plan,excuse,list,fashion,topic,people,truth,instructions,thin,succeed,protocol,win,practice,bad,words,mandatory,computer,oxygen,tall,books,hydrogen,length,hot,abilities,thinking,play,food,flat,periodic,plane,paper,previously,smooth,game,red,store,natural,run,woman,arrow,reality,wind,factual,machine,complete,book
# ==================================================
# The Knights of the Blazing Sun were created after the Battle of Magritta in 1457
# during the crusades which eventually freed the land of Estalia from the Arabian
# invaders. The battle was a great victory for the Knights of the Old World, made
# all the remarkable by a strange and prophetic occurrence. During fierce street
# fighting around the temple of Myrmidia, the warrior goddess of Estalia, a group
# of knights found themselves surrounded by the dreaded Black Guard led by Emir
# Wasr the Cruel. Just as the Arabians closed in a sudden earth tremor shook the
# temple, dislodging a huge bronze statue of the goddess which plummeted to the
# street below crushing the Emir and many of his troops. The event was to prove
# the turning point of the battle. Afterwards, the surviving knights established
# the Order of the Blazing Sun with Myrmidia as its patron and protector.
# --------------------------
# war,fight,road,god,lost,army,light,weird,moon,earth,white,avenue,worship,church,planet,door,win,religion,strong,gold,odd,soldier,death,shut,car,ship,globe,stone,dark,bright,dog,sword,party,head,protect,people,hot,beauty,battle,green,soldiers,shine,synagogue,quick,evil,time,metal,shield,night,leader,finally,love,unusual,round,saint,blue,water,fighter,military,day,liberty,medal,angry,star,art,unexpected,warm,money,beautiful,home,enormous,address,lane,sea,ground,follow,life,fire,person,holy,blood,field,silver,statue,fast,struggle,lead,happy,happening,amazing,woman,wide,warmth,mother,house,arts,sky,soil,power,surprise
# ==================================================
# The answer to the first, or ‘why’, question begins with a recognition that
# banks are private sector, profit-making organisations with obligations to
# shareholders to increase profits over time. Thus they will always be looking for
# ways of expanding their balance sheets provided this leads to extra profit. Look
# again at Table 3.3 which shows the aggregate balance sheet of a large number of
# banks. Notice that assets are composed of various forms of lending: to the
# personal sector, the commercial sector, the government or the Bank of England.
# The liabilities side is dominated by deposits. Notice also that we can express
# any class of asset as a proportion of total assets or liabilities and remember
# too that in section 1.1.5 we said that these ratios are arrived at as a matter
# of deliberate choice and are assumed to represent portfolio equilibrium.
# --------------------------
# money,bed,paper,private,river,balance,question,answer,sum,section,business,public,equal,school,secret,space,memory,fast,clock,size,house,beam,forget,observe,scale,division,property,piece,region,white,wealth,chair,recall,add,weight,art,complete,sign,politics,bank,train,finance,decision,portion,cash,mark,zone,reply,mine,option,steady,time,information,stuff,life,gain,grow,response,people,decrease,personal,additional,advertisement,food,savings,act,army,study,board,financial,folder,query,scales,attention,mass,note,belongings,warning,music,science,ad,test,segment,watch,math,aware,amount,mind,ratio,material,teller,equilibrium,job,choose,share,breasts,cloth,intentional,building,circle
# ==================================================
# Using the golfing tips he gleaned from such fine players, Andy soon had his
# handicap down to two. He was by then an assistant pro in its fullest sense, so
# he decided to try his hand at playing tournaments. Although he qualified for a
# few regional events, in fact he was aiming much higher: he wanted a crack at the
# Open Championship. So in 1973 Andy decided to try and qualify for the Open at
# Royal Troon — and it was here that an incident occurred that changed his
# career. He had played the first round, but before he had a chance even to hit a
# ball in the second he was out of the pre-qualifier, suffering from injuries he
# had received in a car accident with his caddie. Swallowing hard on the
# disappointment, Andy spent the next few years taking even more blows on the
# chin.
# --------------------------
# ...
# changed her mind about that — a man such as Dane would always attract
# beautiful women, and Shannon could never hope to compete. But would the pain of
# losing him be any the less simply because she'd managed to hold him at bay?
# Eventually, probably sooner rather than later, he'd grow tired of waiting for
# Shannon, and then she'd be left with nothing, in any case. Though she could
# never let him know it, he already possessed her heart; if she were to give
# herself to him body and soul, at least the memories would be rich and ultimately
# fulfilling. Right now all she'd have to look back on would be frustration and
# longing suppressed by fear.
# --------------------------
# love,water,time,brain,garden,win,tools,money,tool,finally,game,hair,hurt,sleepy,pretty,girl,wood,fur,sad,desire,mind,red,easy,future,anger,dog,wealthy,waiting,poor,weight,sex,winning,hand,someday,light,magnet,pencil,backyard,spirit,heart,easily,music,soul,lose,faith,patience,barn,picture,shack,exhausted,skin,race,lost,body,life,storage,blood,death,line,female,door,loss,girls,farm,ocean,bed,house,past,angry,beautiful,sleep,food,sports,art,handed,beat,scared,quick,tight,shovel,grasp,yearning,woman,plant,leave,lovely,head,gorgeous,happy,beauty,child,hot,ouch,tears,cat,sexy,attack,wait,ship,boat
# ==================================================
# There can be no doubt that for many women fear of loss is built into us by the
# way we've been reared. As children we may have been made to feel inadequate,
# silly or useless because we were never praised. In adult life, some may be
# submissive and ingratiating, expecting to be in the wrong, expecting to be
# discarded and unwanted. And surprise, surprise, they get just that sort of
# treatment. The only way to stop it happening, and therefore to stop the fear of
# it, is to develop self-esteem. Learn to be assertive, stand up for yourself and
# your own value. That way people will see you as even more lovable. That is what
# I mean by making fear your friend. If you are subject to these irrational fears,
# then use that fear as a trigger to change your attitude. It could revolutionise
# your life.
# --------------------------
# death,party,sign,scared,halt,love,gun,happy,bad,birthday,touch,school,kids,afraid,child,red,event,type,crazy,money,grow,sad,teach,person,mature,loathing,shock,unexpected,study,incorrect,fun,emotion,stupid,funny,object,terror,dark,fear,joy,anxiety,weak,tall,topic,girls,girl,scare,sit,cease,question,sense,gift,coins,worthless,live,film,anger,alter,worry,desist,family,time,movie,spiders,create,sex,uncertainty,danger,children,dog,living,pain,pal,dominant,hospital,error,female,medicine,hurt,friends,clothes,buddy,light,humans,medical,smile,frightened,fright,organize,unknown,current,life,unsure,unloved,sentence,arrange,read,stress,ghost,phobia,crowd
# ==================================================
# The prime document for EC statistics is now the VAT return. All who are engaged
# in intra-EC trade must now show thereon the total value of all goods dispatched
# to other EC customers and received from other EC suppliers in the special boxes
# provided on the return form. Where either category has exceeded £135,000 during
# 1992 further, more detailed information has to be submitted within the very
# strict time limit of ten working days after each month end. Known as the
# Intrastat system, the data can be submitted by a computerised medium but only if
# it meets Customs specification requirements and has prior approval. Specific
# details relating to each consignment are required but values and quantities may
# be aggregated where all other details are identical. Up to ten items of coded
# information are required comprising such details as the commodity reference of
# the goods, delivery terms, weight, method of transport and, for arrivals, the
# country of origin.
# --------------------------
# time,paper,information,knowledge,data,home,book,day,sum,twins,computer,math,words,money,precise,car,fingers,weeks,library,exact,complete,mandatory,clock,beginning,specific,middle,twin,unique,week,shape,stuff,start,study,conditions,rules,speed,toes,twenty,move,school,teacher,decimal,list,exchange,months,morals,married,heavy,eleven,plan,ring,science,type,past,enter,calendar,fat,fine,word,size,age,average,family,truck,marriage,package,news,barter,boring,species,class,rib,life,mail,baby,travel,carry,field,job,books,mass,airport,pizza,happy,busy,minutiae,previous,madness,music,function,nation,swap,contract,land,scale,birth,nights,decade,technology,border
# ==================================================
# Back home, the observation would have been no less apt. In the years leading up
# to the First World War the Hooligan embarked on a remarkable career, appearing
# in name if not in person before numerous governmental and semi-official bodies
# of enquiry. He loomed large in the apocalyptic discourse surrounding the fears
# of racial decline and physical inefficiency. He figured centrally in the
# Edwardian era's deliberations on the ‘boy labour’ question. He would crop up
# repeatedly in the anxious preoccupation with the demoralising influence of
# popular amusements, the collapse of ‘fair play’ sportsmanship, and the
# allegations of excessive ‘freedom’and ‘affluence’ that were levelled
# against the young. The name of the Hooligan, in fact, provided a crystallising
# focus for any number of overlapping anxieties associated with imperial decline,
# military incapacity, the erosion of social discipline and moral authority, the
# eclipse of family life, and what was feared to be the death rattle of ‘Old
# England’.
# --------------------------
# girl,fall,time,people,job,baby,answer,death,moon,nervous,love,house,sun,snake,human,lots,study,army,fun,party,refuse,age,life,child,power,war,peace,friends,black,money,earth,talk,globe,family,game,circle,food,shake,leader,science,reject,birth,mark,friendly,hard,apartment,school,royal,woman,corn,body,slope,individual,field,children,friend,games,environment,cut,police,conversation,play,discussion,king,equal,boss,bad,control,heart,ball,building,music,toy,period,pain,farm,worried,roll,amazing,ahead,incline,concentrate,happy,noise,history,force,person,query,parents,lady,view,fight,soldier,scared,wide,male,network,solar,law,story
# ==================================================
# In fact, as I soon discovered, these ruins are inhabited. I met the old lady as
# I was walking down a steep path out of the village. She was struggling up, bent
# under a heavy sack. We greeted each other. The skin of her face hung in purple
# folds and the old eyes were blurred with cataract. When I offered to carry her
# sack she waved me aside. Who was this impertinent stranger eyeing her baggage?
# We moved on up to her tumbledown tower on the last crag of the village. At the
# base was a terrace with one stool on it. Before us stretched an enormous view of
# mountain, promontory and shimmering sea. From my pack I offered her an apple,
# the only food I had. She dismissed it with a regal gesture. Then I saw her
# toothless gums. I left her in peace with her bundle, her stool and her majestic
# view.
# --------------------------
# bag,town,royal,chair,teeth,ocean,huge,hill,blue,luggage,woman,bar,tall,mountain,green,poop,sit,hand,weight,ball,eye,red,people,king,suitcase,road,water,fire,fruit,eat,travel,home,danger,vista,opinion,baby,eyes,gigantic,potato,love,window,sight,queen,color,mouth,war,climb,scene,pink,unknown,wave,light,seat,watch,load,lift,running,soft,castle,orange,tree,heavy,brown,tote,metal,idiot,sticks,vision,beautiful,handed,bottom,lunch,elephant,joy,snow,horse,legs,scenery,fat,person,dark,blind,backpack,race,broken,hold,potatoes,community,burlap,crown,hands,crooked,burden,movement,landscape,world,walk,trip,white,dead
# ==================================================
# Such integration can be largely formal; in Lesotho, for instance, the evidence
# of real integration in between Mathematics and Science is very slight. On the
# other hand it may represent a genuine attempt by specialists in related subjects
# to sit down together and plan a programme which allows for separate activities
# but suggests common themes and provides examples of integrated lessons as in the
# Nigerian Cultural and Creative Art syllabus. Yet again it may be the product of
# basic rethinking and true integration founded on new objectives and a fresh
# approach as in the Social Studies syllabus now under development in Sierra Leone
# where an integrated programme with significant regional variations is being
# planned in a series of central and local workshops and where a special series of
# booklets on skills development (e.g. map making, note taking skills, creative
# skills) is being produced for teachers.
# --------------------------
# school,art,television,computer,music,world,real,study,abilities,time,family,people,true,false,simple,chair,talent,knowledge,proof,honest,talents,middle,book,fail,painting,close,math,books,food,easy,science,job,event,paper,artistic,unique,local,calculus,learning,fun,education,smart,country,hard,giving,research,dress,love,life,truth,meaningful,fake,moment,friends,person,arrested,paint,schedule,mad,city,set,stand,maths,race,similar,thin,society,party,divide,writing,authentic,dance,growth,test,list,fingers,child,dog,project,language,insult,crime,money,clean,black,program,community,students,fruit,produce,item,drawing,divorce,join,blue,write,building,change,housing,stealing
# ==================================================
# Regarding access to health care, we meet the fact that women usually live longer
# than men. This is one area of life in which women have a definite advantage! It
# would appear that access to the health service is reasonably equitable between
# men and women, and that women's longer lives should not be attributed to
# prejudice against men in the health sector! However, some writers have suggested
# that the diseases commonly found among men are treated with greater concern and
# more expensive medical treatment than those more commonly found among women. For
# instance, attention has recently been drawn to the inadequate provision of
# screening for cervical cancer despite the fact that this service could provide
# the means of identifying early forms of the disease before it reaches its
# incurable and lethal stage. (More discussion of women and health can be found in
# chapter 9, section 9.5.)
# --------------------------
# lost,doctor,girls,food,love,money,death,wealth,girl,book,female,care,hospital,worry,time,life,medicine,happy,yesterday,sex,talk,happiness,greet,sick,strong,people,ladies,sickness,illness,exercise,play,door,beautiful,children,lady,females,body,car,military,mother,supply,friends,pretty,health,key,section,bad,wellness,discovered,denied,nurse,ill,fitness,moment,pain,keys,pride,disease,enter,breast,school,dog,wife,alive,station,church,cure,pencil,conversation,cancer,piece,strength,house,power,entry,die,breathe,hair,friend,living,past,home,racism,definition,red,absolute,tennis,job,hot,customer,support,black,card,debate,rich,discover,business,sexy,private,span
# ==================================================
# The Dinner or Luncheon Party: Whatever time of day it is, this is most likely to
# mean inviting a group of people over for a ‘sit-down’ meal. The grandness of
# the meal, and how much of it you pay for, depends upon the expectations of
# yourself and your guests and perhaps their relationship to you. If, say, you are
# a young person — student or worker — who has invited over friends of the
# same age, they will probably expect to bring a bottle of wine with them. In
# fact, most friends, of any age, would bring a bottle of something — unless the
# dinner party was very grand. Relatives often seem to feel that they do not need
# to bring a contribution, unless, of course, you are young, living alone for the
# first time and being visited by your mother, in which case she will probably
# bring a month's supply of food and wash up for you as well!
# --------------------------
# food,carry,family,time,eat,love,fun,clock,money,day,beer,dinner,wine,lunch,glass,brought,people,night,supper,human,birthday,touch,friends,red,demand,party,father,happy,warm,clean,water,baby,school,drink,fetch,gift,light,life,piano,hope,teacher,hungry,provide,anticipate,watch,close,calendar,donation,deliver,pals,hour,person,week,meal,bee,sun,politics,individual,salary,car,period,alive,era,emotion,animal,woman,evening,alcohol,white,hard,share,friend,tote,dead,hands,container,mom,hopes,sex,child,sense,youth,table,meat,mother,friendly,basket,green,learner,study,job,wait,date,clothes,accompany,bottle,nice,gathering,home,welcoming
# ==================================================
# The implementation of care management in April could rapidly illustrate how the
# admirable intentions of the government's community care policy might founder on
# the unintended consequences of more powerful forces and contradictions. Firstly,
# although the transfer of social security funds will allow more needs driven
# services, it will also cash limit expenditure. Secondly, this transfer punishes
# local authorities with few residential care homes and cuts off money for future
# expansion. Thirdly, the directive that care managers should not themselves give
# direct care runs counter to the core of good social work practice and creates a
# new corps of care administrators, thereby reducing the number of staff available
# to give direct care. Fourthly, no central guidance has emerged on how to
# coordinate at the local level, care management, the care programme approach, and
# hospital discharge procedures, thus inviting triplication of planning effort.
# --------------------------
# love,money,concern,home,boss,straight,people,move,nurture,middle,package,strong,draw,party,bear,health,child,careful,nurse,friendly,car,friends,cash,tend,time,close,school,computer,apple,caution,bank,doctor,perfect,feel,lead,family,bad,warm,food,network,center,top,hard,past,mother,earth,neighborhood,nearby,plan,loving,politics,tender,change,town,control,affection,speed,police,study,safe,green,hospital,honest,rule,service,children,business,sick,baby,rules,direction,butterfly,music,power,caring,map,law,worry,organize,worker,kindness,life,book,city,government,elderly,empathy,taker,forward,rod,rich,paper,picture,growth,guard,safety,bed,studies,produce,line
# ==================================================
# It was a great discovery. But it was utterly disastrous for classical physics.
# An electron encircling a nucleus is continuously subject to acceleration as its
# velocity keeps on changing direction. (Acceleration is just the rate of change
# of velocity.) It is an inexorable consequence of classical physics that such an
# accelerating electron radiates off some of its energy at a frequency
# corresponding to the frequency of the electron's circulation. This causes the
# electron to move closer to the nucleus and changes the frequency. The radiation
# loss continues. In other words, a classical "solar system" atom under
# electromagnetic forces is nothing like the actual solar system held together by
# gravitational forces. The atom would be unstable, as its electrons spiralled
# ever closer to the nucleus, and it would emit its dying radiation in a band of
# frequencies with no trace of discreteness. The nuclear atom dealt
# the coup de grâce to classical physics.
# --------------------------
# music,science,speed,atom,bomb,physics,sun,neutron,proton,fast,cell,car,power,chemistry,nuclear,center,real,energy,blood,nucleus,time,molecule,radio,particle,electricity,light,nearer,math,money,microscope,electron,art,core,heat,school,negative,death,computer,cancer,heart,panel,centre,war,space,result,movement,hertz,true,sound,biology,guitar,pitch,language,farther,waves,ray,matter,wave,quantum,danger,amount,object,velocity,charge,house,astronomy,books,flare,literature,positron,study,piano,plan,life,architecture,love,bad,topic,channel,north,mass,element,rate,book,gravity,water,coins,tiny,gas,truth,letters,dance,green,alter,motion,organization,hard,force,draw,atoms
# ==================================================

# %% [markdown]
# Get all the predictions for each recalled words and all words in the recognition tests.

# %%
stimuli_words = []

for text_name in stimuli:
    
    _, n = text_name.split('_')
    n = int(n)+1
    inwords = stimuli[text_name]['inwords'].split(',')
    outwords = stimuli[text_name]['outwords'].split(',')
    for word in inwords+outwords+recalled_words:
        try:
            p = predicted_associates[text_name][associate_vocabulary.word2index[word]]
            stimuli_words.append((str(n) + '-' + word, p))
        except KeyError:
            print('Unknown word in text %s: "%s"' % (text_name,word))

associations_predictions = dict(stimuli_words)

with open(cache_fullpath('word_associates_from_association_norms_mdc.pkl'), 'wb') as f:
    pickle.dump(associations_predictions, f, protocol=2)
# Out:
# Unknown word in text text_22: "dhow"
